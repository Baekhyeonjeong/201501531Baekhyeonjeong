# %% [markdown]
# <a href="https://colab.research.google.com/github/Baekhyeonjeong/Baekhyeonjeong/blob/main/%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%A7%90%ED%95%A0%EC%88%98%EC%97%86%EB%8A%94%EB%B9%84%EB%B0%80_%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 107924
total_count = 19653  ## 전체 크기=19,653

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1884
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1885
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1886
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1887
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1888
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1889
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1890
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1891
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1892
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1893
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1894
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1895
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1896
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1897
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1898
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1899
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1900
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1901
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1902
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1903
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1904
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1905
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1906
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1907
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1908
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1909
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1910
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1911
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1912
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1913
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1914
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1915
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1916
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1917
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1965

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20200417110808" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20200417110808" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20200417110808" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20200417110808" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="161967"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>36,529</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738216, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>brilliant_AKA_밝음(bril****)</span>
# </a>
# </em>
# <em>2019.05.30 15:58</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','bril****', 'CyNhpJ+qkjXfv8NY+ybBa3IwKx8Uf0vOBr+s8Bk5owM=', '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 ', '15738216', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738216">28791</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738216">1504</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>김희정(priv****)</span>
# </a>
# </em>
# <em>2019.05.30 12:25</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','priv****', 'jjv6qM3ZHF+lm+39Ztvra2Lo83lph6tORA6Ng1vSq7c=', '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데.. ', '15736627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736627">18779</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736627">1586</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737678, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>리오(papi****)</span>
# </a>
# </em>
# <em>2019.05.30 14:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','papi****', 'MTkAnDzFvty9bU2B71ZQzyRKjwY2JaVjKPdGGzAr/dg=', '지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다. ', '15737678', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737678">17453</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737678">1113</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738415, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>멍뭉이(sumi****)</span>
# </a>
# </em>
# <em>2019.05.30 16:28</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sumi****', 'sgYqpMep7dXfkS9MIe7PUYd7jFWtdgzLJkaBtub5awU=', '전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화 ', '15738415', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738415">17034</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738415">936</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737905, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>여행의 발견(riod****)</span>
# </a>
# </em>
# <em>2019.05.30 15:13</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','riod****', 'juqbdcsvFbC66hNLcJoPL915nTb3fG9phj/JBg2Onu4=', '황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다. ', '15737905', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737905">16034</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737905">802</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15743239, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>페르(sa02****)</span>
# </a>
# </em>
# <em>2019.05.31 01:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sa02****', 'oNASB02ZlvYtjSbLjY7Ad7LZYBuFnabVFbcmNshznE8=', '반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다. ', '15743239', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15743239">12886</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15743239">299</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15735958, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>크렙하스(powe****)</span>
# </a>
# </em>
# <em>2019.05.30 10:50</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','powe****', '9TuTPRPp8SJGxhDYjew+C/fTE2ULWMVtUC9FMuzzpY0=', '뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다. ', '15735958', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15735958">12245</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15735958">729</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736477, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>도미(dudd****)</span>
# </a>
# </em>
# <em>2019.05.30 12:05</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','dudd****', 'amVW2iA/7hvLRy9PjeSN9h5lJCLI6OoVWO3oTlzrJfg=', '누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다. ', '15736477', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736477">11199</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736477">493</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																박서준이 잘못했네ㅋㅋㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737802, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>구마(gym9****)</span>
# </a>
# </em>
# <em>2019.05.30 15:01</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gym9****', 'a9/eGsZ8229Knvoa9cSby+xkeIpPHG996qjVe+AagTY=', '박서준이 잘못했네ㅋㅋㅋㅋ ', '15737802', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737802">10863</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737802">443</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737882, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>블루이즈(cank****)</span>
# </a>
# </em>
# <em>2019.05.30 15:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','cank****', 'dPSPsRFbLOmFyijW3aatPuDcOm8ywHmehVCD+QR4qYw=', '나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나.. ', '15737882', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737882">10612</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737882">380</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "161967",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=161967#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=161967#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("161967", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738216, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>brilliant_AKA_밝음(bril****)</span>
# </a>
# </em>
# <em>2019.05.30 15:58</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','bril****', 'CyNhpJ+qkjXfv8NY+ybBa3IwKx8Uf0vOBr+s8Bk5owM=', '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 ', '15738216', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738216">28791</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738216">1504</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>김희정(priv****)</span>
# </a>
# </em>
# <em>2019.05.30 12:25</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','priv****', 'ia+L3ovTsOJOamiddckFuEgyDXZKv2w/A+UcZ4F0fPk=', '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데.. ', '15736627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736627">18753</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736627">1586</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 내용
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('28749', '1501')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'brilliant_AKA_밝음(bril****)'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2019, 5, 30, 15, 58)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 68555
total_count = 37738  ## 전체 크기=36524

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....
# 501 번째 페이지 parsing....
# 502 번째 페이지 parsing....
# 503 번째 페이지 parsing....
# 504 번째 페이지 parsing....
# 505 번째 페이지 parsing....
# 506 번째 페이지 parsing....
# 507 번째 페이지 parsing....
# 508 번째 페이지 parsing....
# 509 번째 페이지 parsing....
# 510 번째 페이지 parsing....
# 511 번째 페이지 parsing....
# 512 번째 페이지 parsing....
# 513 번째 페이지 parsing....
# 514 번째 페이지 parsing....
# 515 번째 페이지 parsing....
# 516 번째 페이지 parsing....
# 517 번째 페이지 parsing....
# 518 번째 페이지 parsing....
# 519 번째 페이지 parsing....
# 520 번째 페이지 parsing....
# 521 번째 페이지 parsing....
# 522 번째 페이지 parsing....
# 523 번째 페이지 parsing....
# 524 번째 페이지 parsing....
# 525 번째 페이지 parsing....
# 526 번째 페이지 parsing....
# 527 번째 페이지 parsing....
# 528 번째 페이지 parsing....
# 529 번째 페이지 parsing....
# 530 번째 페이지 parsing....
# 531 번째 페이지 parsing....
# 532 번째 페이지 parsing....
# 533 번째 페이지 parsing....
# 534 번째 페이지 parsing....
# 535 번째 페이지 parsing....
# 536 번째 페이지 parsing....
# 537 번째 페이지 parsing....
# 538 번째 페이지 parsing....
# 539 번째 페이지 parsing....
# 540 번째 페이지 parsing....
# 541 번째 페이지 parsing....
# 542 번째 페이지 parsing....
# 543 번째 페이지 parsing....
# 544 번째 페이지 parsing....
# 545 번째 페이지 parsing....
# 546 번째 페이지 parsing....
# 547 번째 페이지 parsing....
# 548 번째 페이지 parsing....
# 549 번째 페이지 parsing....
# 550 번째 페이지 parsing....
# 551 번째 페이지 parsing....
# 552 번째 페이지 parsing....
# 553 번째 페이지 parsing....
# 554 번째 페이지 parsing....
# 555 번째 페이지 parsing....
# 556 번째 페이지 parsing....
# 557 번째 페이지 parsing....
# 558 번째 페이지 parsing....
# 559 번째 페이지 parsing....
# 560 번째 페이지 parsing....
# 561 번째 페이지 parsing....
# 562 번째 페이지 parsing....
# 563 번째 페이지 parsing....
# 564 번째 페이지 parsing....
# 565 번째 페이지 parsing....
# 566 번째 페이지 parsing....
# 567 번째 페이지 parsing....
# 568 번째 페이지 parsing....
# 569 번째 페이지 parsing....
# 570 번째 페이지 parsing....
# 571 번째 페이지 parsing....
# 572 번째 페이지 parsing....
# 573 번째 페이지 parsing....
# 574 번째 페이지 parsing....
# 575 번째 페이지 parsing....
# 576 번째 페이지 parsing....
# 577 번째 페이지 parsing....
# 578 번째 페이지 parsing....
# 579 번째 페이지 parsing....
# 580 번째 페이지 parsing....
# 581 번째 페이지 parsing....
# 582 번째 페이지 parsing....
# 583 번째 페이지 parsing....
# 584 번째 페이지 parsing....
# 585 번째 페이지 parsing....
# 586 번째 페이지 parsing....
# 587 번째 페이지 parsing....
# 588 번째 페이지 parsing....
# 589 번째 페이지 parsing....
# 590 번째 페이지 parsing....
# 591 번째 페이지 parsing....
# 592 번째 페이지 parsing....
# 593 번째 페이지 parsing....
# 594 번째 페이지 parsing....
# 595 번째 페이지 parsing....
# 596 번째 페이지 parsing....
# 597 번째 페이지 parsing....
# 598 번째 페이지 parsing....
# 599 번째 페이지 parsing....
# 600 번째 페이지 parsing....
# 601 번째 페이지 parsing....
# 602 번째 페이지 parsing....
# 603 번째 페이지 parsing....
# 604 번째 페이지 parsing....
# 605 번째 페이지 parsing....
# 606 번째 페이지 parsing....
# 607 번째 페이지 parsing....
# 608 번째 페이지 parsing....
# 609 번째 페이지 parsing....
# 610 번째 페이지 parsing....
# 611 번째 페이지 parsing....
# 612 번째 페이지 parsing....
# 613 번째 페이지 parsing....
# 614 번째 페이지 parsing....
# 615 번째 페이지 parsing....
# 616 번째 페이지 parsing....
# 617 번째 페이지 parsing....
# 618 번째 페이지 parsing....
# 619 번째 페이지 parsing....
# 620 번째 페이지 parsing....
# 621 번째 페이지 parsing....
# 622 번째 페이지 parsing....
# 623 번째 페이지 parsing....
# 624 번째 페이지 parsing....
# 625 번째 페이지 parsing....
# 626 번째 페이지 parsing....
# 627 번째 페이지 parsing....
# 628 번째 페이지 parsing....
# 629 번째 페이지 parsing....
# 630 번째 페이지 parsing....
# 631 번째 페이지 parsing....
# 632 번째 페이지 parsing....
# 633 번째 페이지 parsing....
# 634 번째 페이지 parsing....
# 635 번째 페이지 parsing....
# 636 번째 페이지 parsing....
# 637 번째 페이지 parsing....
# 638 번째 페이지 parsing....
# 639 번째 페이지 parsing....
# 640 번째 페이지 parsing....
# 641 번째 페이지 parsing....
# 642 번째 페이지 parsing....
# 643 번째 페이지 parsing....
# 644 번째 페이지 parsing....
# 645 번째 페이지 parsing....
# 646 번째 페이지 parsing....
# 647 번째 페이지 parsing....
# 648 번째 페이지 parsing....
# 649 번째 페이지 parsing....
# 650 번째 페이지 parsing....
# 651 번째 페이지 parsing....
# 652 번째 페이지 parsing....
# 653 번째 페이지 parsing....
# 654 번째 페이지 parsing....
# 655 번째 페이지 parsing....
# 656 번째 페이지 parsing....
# 657 번째 페이지 parsing....
# 658 번째 페이지 parsing....
# 659 번째 페이지 parsing....
# 660 번째 페이지 parsing....
# 661 번째 페이지 parsing....
# 662 번째 페이지 parsing....
# 663 번째 페이지 parsing....
# 664 번째 페이지 parsing....
# 665 번째 페이지 parsing....
# 666 번째 페이지 parsing....
# 667 번째 페이지 parsing....
# 668 번째 페이지 parsing....
# 669 번째 페이지 parsing....
# 670 번째 페이지 parsing....
# 671 번째 페이지 parsing....
# 672 번째 페이지 parsing....
# 673 번째 페이지 parsing....
# 674 번째 페이지 parsing....
# 675 번째 페이지 parsing....
# 676 번째 페이지 parsing....
# 677 번째 페이지 parsing....
# 678 번째 페이지 parsing....
# 679 번째 페이지 parsing....
# 680 번째 페이지 parsing....
# 681 번째 페이지 parsing....
# 682 번째 페이지 parsing....
# 683 번째 페이지 parsing....
# 684 번째 페이지 parsing....
# 685 번째 페이지 parsing....
# 686 번째 페이지 parsing....
# 687 번째 페이지 parsing....
# 688 번째 페이지 parsing....
# 689 번째 페이지 parsing....
# 690 번째 페이지 parsing....
# 691 번째 페이지 parsing....
# 692 번째 페이지 parsing....
# 693 번째 페이지 parsing....
# 694 번째 페이지 parsing....
# 695 번째 페이지 parsing....
# 696 번째 페이지 parsing....
# 697 번째 페이지 parsing....
# 698 번째 페이지 parsing....
# 699 번째 페이지 parsing....
# 700 번째 페이지 parsing....
# 701 번째 페이지 parsing....
# 702 번째 페이지 parsing....
# 703 번째 페이지 parsing....
# 704 번째 페이지 parsing....
# 705 번째 페이지 parsing....
# 706 번째 페이지 parsing....
# 707 번째 페이지 parsing....
# 708 번째 페이지 parsing....
# 709 번째 페이지 parsing....
# 710 번째 페이지 parsing....
# 711 번째 페이지 parsing....
# 712 번째 페이지 parsing....
# 713 번째 페이지 parsing....
# 714 번째 페이지 parsing....
# 715 번째 페이지 parsing....
# 716 번째 페이지 parsing....
# 717 번째 페이지 parsing....
# 718 번째 페이지 parsing....
# 719 번째 페이지 parsing....
# 720 번째 페이지 parsing....
# 721 번째 페이지 parsing....
# 722 번째 페이지 parsing....
# 723 번째 페이지 parsing....
# 724 번째 페이지 parsing....
# 725 번째 페이지 parsing....
# 726 번째 페이지 parsing....
# 727 번째 페이지 parsing....
# 728 번째 페이지 parsing....
# 729 번째 페이지 parsing....
# 730 번째 페이지 parsing....
# 731 번째 페이지 parsing....
# 732 번째 페이지 parsing....
# 733 번째 페이지 parsing....
# 734 번째 페이지 parsing....
# 735 번째 페이지 parsing....
# 736 번째 페이지 parsing....
# 737 번째 페이지 parsing....
# 738 번째 페이지 parsing....
# 739 번째 페이지 parsing....
# 740 번째 페이지 parsing....
# 741 번째 페이지 parsing....
# 742 번째 페이지 parsing....
# 743 번째 페이지 parsing....
# 744 번째 페이지 parsing....
# 745 번째 페이지 parsing....
# 746 번째 페이지 parsing....
# 747 번째 페이지 parsing....
# 748 번째 페이지 parsing....
# 749 번째 페이지 parsing....
# 750 번째 페이지 parsing....
# 751 번째 페이지 parsing....
# 752 번째 페이지 parsing....
# 753 번째 페이지 parsing....
# 754 번째 페이지 parsing....
# 755 번째 페이지 parsing....
# 756 번째 페이지 parsing....
# 757 번째 페이지 parsing....
# 758 번째 페이지 parsing....
# 759 번째 페이지 parsing....
# 760 번째 페이지 parsing....
# 761 번째 페이지 parsing....
# 762 번째 페이지 parsing....
# 763 번째 페이지 parsing....
# 764 번째 페이지 parsing....
# 765 번째 페이지 parsing....
# 766 번째 페이지 parsing....
# 767 번째 페이지 parsing....
# 768 번째 페이지 parsing....
# 769 번째 페이지 parsing....
# 770 번째 페이지 parsing....
# 771 번째 페이지 parsing....
# 772 번째 페이지 parsing....
# 773 번째 페이지 parsing....
# 774 번째 페이지 parsing....
# 775 번째 페이지 parsing....
# 776 번째 페이지 parsing....
# 777 번째 페이지 parsing....
# 778 번째 페이지 parsing....
# 779 번째 페이지 parsing....
# 780 번째 페이지 parsing....
# 781 번째 페이지 parsing....
# 782 번째 페이지 parsing....
# 783 번째 페이지 parsing....
# 784 번째 페이지 parsing....
# 785 번째 페이지 parsing....
# 786 번째 페이지 parsing....
# 787 번째 페이지 parsing....
# 788 번째 페이지 parsing....
# 789 번째 페이지 parsing....
# 790 번째 페이지 parsing....
# 791 번째 페이지 parsing....
# 792 번째 페이지 parsing....
# 793 번째 페이지 parsing....
# 794 번째 페이지 parsing....
# 795 번째 페이지 parsing....
# 796 번째 페이지 parsing....
# 797 번째 페이지 parsing....
# 798 번째 페이지 parsing....
# 799 번째 페이지 parsing....
# 800 번째 페이지 parsing....
# 801 번째 페이지 parsing....
# 802 번째 페이지 parsing....
# 803 번째 페이지 parsing....
# 804 번째 페이지 parsing....
# 805 번째 페이지 parsing....
# 806 번째 페이지 parsing....
# 807 번째 페이지 parsing....
# 808 번째 페이지 parsing....
# 809 번째 페이지 parsing....
# 810 번째 페이지 parsing....
# 811 번째 페이지 parsing....
# 812 번째 페이지 parsing....
# 813 번째 페이지 parsing....
# 814 번째 페이지 parsing....
# 815 번째 페이지 parsing....
# 816 번째 페이지 parsing....
# 817 번째 페이지 parsing....
# 818 번째 페이지 parsing....
# 819 번째 페이지 parsing....
# 820 번째 페이지 parsing....
# 821 번째 페이지 parsing....
# 822 번째 페이지 parsing....
# 823 번째 페이지 parsing....
# 824 번째 페이지 parsing....
# 825 번째 페이지 parsing....
# 826 번째 페이지 parsing....
# 827 번째 페이지 parsing....
# 828 번째 페이지 parsing....
# 829 번째 페이지 parsing....
# 830 번째 페이지 parsing....
# 831 번째 페이지 parsing....
# 832 번째 페이지 parsing....
# 833 번째 페이지 parsing....
# 834 번째 페이지 parsing....
# 835 번째 페이지 parsing....
# 836 번째 페이지 parsing....
# 837 번째 페이지 parsing....
# 838 번째 페이지 parsing....
# 839 번째 페이지 parsing....
# 840 번째 페이지 parsing....
# 841 번째 페이지 parsing....
# 842 번째 페이지 parsing....
# 843 번째 페이지 parsing....
# 844 번째 페이지 parsing....
# 845 번째 페이지 parsing....
# 846 번째 페이지 parsing....
# 847 번째 페이지 parsing....
# 848 번째 페이지 parsing....
# 849 번째 페이지 parsing....
# 850 번째 페이지 parsing....
# 851 번째 페이지 parsing....
# 852 번째 페이지 parsing....
# 853 번째 페이지 parsing....
# 854 번째 페이지 parsing....
# 855 번째 페이지 parsing....
# 856 번째 페이지 parsing....
# 857 번째 페이지 parsing....
# 858 번째 페이지 parsing....
# 859 번째 페이지 parsing....
# 860 번째 페이지 parsing....
# 861 번째 페이지 parsing....
# 862 번째 페이지 parsing....
# 863 번째 페이지 parsing....
# 864 번째 페이지 parsing....
# 865 번째 페이지 parsing....
# 866 번째 페이지 parsing....
# 867 번째 페이지 parsing....
# 868 번째 페이지 parsing....
# 869 번째 페이지 parsing....
# 870 번째 페이지 parsing....
# 871 번째 페이지 parsing....
# 872 번째 페이지 parsing....
# 873 번째 페이지 parsing....
# 874 번째 페이지 parsing....
# 875 번째 페이지 parsing....
# 876 번째 페이지 parsing....
# 877 번째 페이지 parsing....
# 878 번째 페이지 parsing....
# 879 번째 페이지 parsing....
# 880 번째 페이지 parsing....
# 881 번째 페이지 parsing....
# 882 번째 페이지 parsing....
# 883 번째 페이지 parsing....
# 884 번째 페이지 parsing....
# 885 번째 페이지 parsing....
# 886 번째 페이지 parsing....
# 887 번째 페이지 parsing....
# 888 번째 페이지 parsing....
# 889 번째 페이지 parsing....
# 890 번째 페이지 parsing....
# 891 번째 페이지 parsing....
# 892 번째 페이지 parsing....
# 893 번째 페이지 parsing....
# 894 번째 페이지 parsing....
# 895 번째 페이지 parsing....
# 896 번째 페이지 parsing....
# 897 번째 페이지 parsing....
# 898 번째 페이지 parsing....
# 899 번째 페이지 parsing....
# 900 번째 페이지 parsing....
# 901 번째 페이지 parsing....
# 902 번째 페이지 parsing....
# 903 번째 페이지 parsing....
# 904 번째 페이지 parsing....
# 905 번째 페이지 parsing....
# 906 번째 페이지 parsing....
# 907 번째 페이지 parsing....
# 908 번째 페이지 parsing....
# 909 번째 페이지 parsing....
# 910 번째 페이지 parsing....
# 911 번째 페이지 parsing....
# 912 번째 페이지 parsing....
# 913 번째 페이지 parsing....
# 914 번째 페이지 parsing....
# 915 번째 페이지 parsing....
# 916 번째 페이지 parsing....
# 917 번째 페이지 parsing....
# 918 번째 페이지 parsing....
# 919 번째 페이지 parsing....
# 920 번째 페이지 parsing....
# 921 번째 페이지 parsing....
# 922 번째 페이지 parsing....
# 923 번째 페이지 parsing....
# 924 번째 페이지 parsing....
# 925 번째 페이지 parsing....
# 926 번째 페이지 parsing....
# 927 번째 페이지 parsing....
# 928 번째 페이지 parsing....
# 929 번째 페이지 parsing....
# 930 번째 페이지 parsing....
# 931 번째 페이지 parsing....
# 932 번째 페이지 parsing....
# 933 번째 페이지 parsing....
# 934 번째 페이지 parsing....
# 935 번째 페이지 parsing....
# 936 번째 페이지 parsing....
# 937 번째 페이지 parsing....
# 938 번째 페이지 parsing....
# 939 번째 페이지 parsing....
# 940 번째 페이지 parsing....
# 941 번째 페이지 parsing....
# 942 번째 페이지 parsing....
# 943 번째 페이지 parsing....
# 944 번째 페이지 parsing....
# 945 번째 페이지 parsing....
# 946 번째 페이지 parsing....
# 947 번째 페이지 parsing....
# 948 번째 페이지 parsing....
# 949 번째 페이지 parsing....
# 950 번째 페이지 parsing....
# 951 번째 페이지 parsing....
# 952 번째 페이지 parsing....
# 953 번째 페이지 parsing....
# 954 번째 페이지 parsing....
# 955 번째 페이지 parsing....
# 956 번째 페이지 parsing....
# 957 번째 페이지 parsing....
# 958 번째 페이지 parsing....
# 959 번째 페이지 parsing....
# 960 번째 페이지 parsing....
# 961 번째 페이지 parsing....
# 962 번째 페이지 parsing....
# 963 번째 페이지 parsing....
# 964 번째 페이지 parsing....
# 965 번째 페이지 parsing....
# 966 번째 페이지 parsing....
# 967 번째 페이지 parsing....
# 968 번째 페이지 parsing....
# 969 번째 페이지 parsing....
# 970 번째 페이지 parsing....
# 971 번째 페이지 parsing....
# 972 번째 페이지 parsing....
# 973 번째 페이지 parsing....
# 974 번째 페이지 parsing....
# 975 번째 페이지 parsing....
# 976 번째 페이지 parsing....
# 977 번째 페이지 parsing....
# 978 번째 페이지 parsing....
# 979 번째 페이지 parsing....
# 980 번째 페이지 parsing....
# 981 번째 페이지 parsing....
# 982 번째 페이지 parsing....
# 983 번째 페이지 parsing....
# 984 번째 페이지 parsing....
# 985 번째 페이지 parsing....
# 986 번째 페이지 parsing....
# 987 번째 페이지 parsing....
# 988 번째 페이지 parsing....
# 989 번째 페이지 parsing....
# 990 번째 페이지 parsing....
# 991 번째 페이지 parsing....
# 992 번째 페이지 parsing....
# 993 번째 페이지 parsing....
# 994 번째 페이지 parsing....
# 995 번째 페이지 parsing....
# 996 번째 페이지 parsing....
# 997 번째 페이지 parsing....
# 998 번째 페이지 parsing....
# 999 번째 페이지 parsing....
# 1000 번째 페이지 parsing....
# 1001 번째 페이지 parsing....
# 1002 번째 페이지 parsing....
# 1003 번째 페이지 parsing....
# 1004 번째 페이지 parsing....
# 1005 번째 페이지 parsing....
# 1006 번째 페이지 parsing....
# 1007 번째 페이지 parsing....
# 1008 번째 페이지 parsing....
# 1009 번째 페이지 parsing....
# 1010 번째 페이지 parsing....
# 1011 번째 페이지 parsing....
# 1012 번째 페이지 parsing....
# 1013 번째 페이지 parsing....
# 1014 번째 페이지 parsing....
# 1015 번째 페이지 parsing....
# 1016 번째 페이지 parsing....
# 1017 번째 페이지 parsing....
# 1018 번째 페이지 parsing....
# 1019 번째 페이지 parsing....
# 1020 번째 페이지 parsing....
# 1021 번째 페이지 parsing....
# 1022 번째 페이지 parsing....
# 1023 번째 페이지 parsing....
# 1024 번째 페이지 parsing....
# 1025 번째 페이지 parsing....
# 1026 번째 페이지 parsing....
# 1027 번째 페이지 parsing....
# 1028 번째 페이지 parsing....
# 1029 번째 페이지 parsing....
# 1030 번째 페이지 parsing....
# 1031 번째 페이지 parsing....
# 1032 번째 페이지 parsing....
# 1033 번째 페이지 parsing....
# 1034 번째 페이지 parsing....
# 1035 번째 페이지 parsing....
# 1036 번째 페이지 parsing....
# 1037 번째 페이지 parsing....
# 1038 번째 페이지 parsing....
# 1039 번째 페이지 parsing....
# 1040 번째 페이지 parsing....
# 1041 번째 페이지 parsing....
# 1042 번째 페이지 parsing....
# 1043 번째 페이지 parsing....
# 1044 번째 페이지 parsing....
# 1045 번째 페이지 parsing....
# 1046 번째 페이지 parsing....
# 1047 번째 페이지 parsing....
# 1048 번째 페이지 parsing....
# 1049 번째 페이지 parsing....
# 1050 번째 페이지 parsing....
# 1051 번째 페이지 parsing....
# 1052 번째 페이지 parsing....
# 1053 번째 페이지 parsing....
# 1054 번째 페이지 parsing....
# 1055 번째 페이지 parsing....
# 1056 번째 페이지 parsing....
# 1057 번째 페이지 parsing....
# 1058 번째 페이지 parsing....
# 1059 번째 페이지 parsing....
# 1060 번째 페이지 parsing....
# 1061 번째 페이지 parsing....
# 1062 번째 페이지 parsing....
# 1063 번째 페이지 parsing....
# 1064 번째 페이지 parsing....
# 1065 번째 페이지 parsing....
# 1066 번째 페이지 parsing....
# 1067 번째 페이지 parsing....
# 1068 번째 페이지 parsing....
# 1069 번째 페이지 parsing....
# 1070 번째 페이지 parsing....
# 1071 번째 페이지 parsing....
# 1072 번째 페이지 parsing....
# 1073 번째 페이지 parsing....
# 1074 번째 페이지 parsing....
# 1075 번째 페이지 parsing....
# 1076 번째 페이지 parsing....
# 1077 번째 페이지 parsing....
# 1078 번째 페이지 parsing....
# 1079 번째 페이지 parsing....
# 1080 번째 페이지 parsing....
# 1081 번째 페이지 parsing....
# 1082 번째 페이지 parsing....
# 1083 번째 페이지 parsing....
# 1084 번째 페이지 parsing....
# 1085 번째 페이지 parsing....
# 1086 번째 페이지 parsing....
# 1087 번째 페이지 parsing....
# 1088 번째 페이지 parsing....
# 1089 번째 페이지 parsing....
# 1090 번째 페이지 parsing....
# 1091 번째 페이지 parsing....
# 1092 번째 페이지 parsing....
# 1093 번째 페이지 parsing....
# 1094 번째 페이지 parsing....
# 1095 번째 페이지 parsing....
# 1096 번째 페이지 parsing....
# 1097 번째 페이지 parsing....
# 1098 번째 페이지 parsing....
# 1099 번째 페이지 parsing....
# 1100 번째 페이지 parsing....
# 1101 번째 페이지 parsing....
# 1102 번째 페이지 parsing....
# 1103 번째 페이지 parsing....
# 1104 번째 페이지 parsing....
# 1105 번째 페이지 parsing....
# 1106 번째 페이지 parsing....
# 1107 번째 페이지 parsing....
# 1108 번째 페이지 parsing....
# 1109 번째 페이지 parsing....
# 1110 번째 페이지 parsing....
# 1111 번째 페이지 parsing....
# 1112 번째 페이지 parsing....
# 1113 번째 페이지 parsing....
# 1114 번째 페이지 parsing....
# 1115 번째 페이지 parsing....
# 1116 번째 페이지 parsing....
# 1117 번째 페이지 parsing....
# 1118 번째 페이지 parsing....
# 1119 번째 페이지 parsing....
# 1120 번째 페이지 parsing....
# 1121 번째 페이지 parsing....
# 1122 번째 페이지 parsing....
# 1123 번째 페이지 parsing....
# 1124 번째 페이지 parsing....
# 1125 번째 페이지 parsing....
# 1126 번째 페이지 parsing....
# 1127 번째 페이지 parsing....
# 1128 번째 페이지 parsing....
# 1129 번째 페이지 parsing....
# 1130 번째 페이지 parsing....
# 1131 번째 페이지 parsing....
# 1132 번째 페이지 parsing....
# 1133 번째 페이지 parsing....
# 1134 번째 페이지 parsing....
# 1135 번째 페이지 parsing....
# 1136 번째 페이지 parsing....
# 1137 번째 페이지 parsing....
# 1138 번째 페이지 parsing....
# 1139 번째 페이지 parsing....
# 1140 번째 페이지 parsing....
# 1141 번째 페이지 parsing....
# 1142 번째 페이지 parsing....
# 1143 번째 페이지 parsing....
# 1144 번째 페이지 parsing....
# 1145 번째 페이지 parsing....
# 1146 번째 페이지 parsing....
# 1147 번째 페이지 parsing....
# 1148 번째 페이지 parsing....
# 1149 번째 페이지 parsing....
# 1150 번째 페이지 parsing....
# 1151 번째 페이지 parsing....
# 1152 번째 페이지 parsing....
# 1153 번째 페이지 parsing....
# 1154 번째 페이지 parsing....
# 1155 번째 페이지 parsing....
# 1156 번째 페이지 parsing....
# 1157 번째 페이지 parsing....
# 1158 번째 페이지 parsing....
# 1159 번째 페이지 parsing....
# 1160 번째 페이지 parsing....
# 1161 번째 페이지 parsing....
# 1162 번째 페이지 parsing....
# 1163 번째 페이지 parsing....
# 1164 번째 페이지 parsing....
# 1165 번째 페이지 parsing....
# 1166 번째 페이지 parsing....
# 1167 번째 페이지 parsing....
# 1168 번째 페이지 parsing....
# 1169 번째 페이지 parsing....
# 1170 번째 페이지 parsing....
# 1171 번째 페이지 parsing....
# 1172 번째 페이지 parsing....
# 1173 번째 페이지 parsing....
# 1174 번째 페이지 parsing....
# 1175 번째 페이지 parsing....
# 1176 번째 페이지 parsing....
# 1177 번째 페이지 parsing....
# 1178 번째 페이지 parsing....
# 1179 번째 페이지 parsing....
# 1180 번째 페이지 parsing....
# 1181 번째 페이지 parsing....
# 1182 번째 페이지 parsing....
# 1183 번째 페이지 parsing....
# 1184 번째 페이지 parsing....
# 1185 번째 페이지 parsing....
# 1186 번째 페이지 parsing....
# 1187 번째 페이지 parsing....
# 1188 번째 페이지 parsing....
# 1189 번째 페이지 parsing....
# 1190 번째 페이지 parsing....
# 1191 번째 페이지 parsing....
# 1192 번째 페이지 parsing....
# 1193 번째 페이지 parsing....
# 1194 번째 페이지 parsing....
# 1195 번째 페이지 parsing....
# 1196 번째 페이지 parsing....
# 1197 번째 페이지 parsing....
# 1198 번째 페이지 parsing....
# 1199 번째 페이지 parsing....
# 1200 번째 페이지 parsing....
# 1201 번째 페이지 parsing....
# 1202 번째 페이지 parsing....
# 1203 번째 페이지 parsing....
# 1204 번째 페이지 parsing....
# 1205 번째 페이지 parsing....
# 1206 번째 페이지 parsing....
# 1207 번째 페이지 parsing....
# 1208 번째 페이지 parsing....
# 1209 번째 페이지 parsing....
# 1210 번째 페이지 parsing....
# 1211 번째 페이지 parsing....
# 1212 번째 페이지 parsing....
# 1213 번째 페이지 parsing....
# 1214 번째 페이지 parsing....
# 1215 번째 페이지 parsing....
# 1216 번째 페이지 parsing....
# 1217 번째 페이지 parsing....
# 1218 번째 페이지 parsing....
# 1219 번째 페이지 parsing....
# 1220 번째 페이지 parsing....
# 1221 번째 페이지 parsing....
# 1222 번째 페이지 parsing....
# 1223 번째 페이지 parsing....
# 1224 번째 페이지 parsing....
# 1225 번째 페이지 parsing....
# 1226 번째 페이지 parsing....
# 1227 번째 페이지 parsing....
# 1228 번째 페이지 parsing....
# 1229 번째 페이지 parsing....
# 1230 번째 페이지 parsing....
# 1231 번째 페이지 parsing....
# 1232 번째 페이지 parsing....
# 1233 번째 페이지 parsing....
# 1234 번째 페이지 parsing....
# 1235 번째 페이지 parsing....
# 1236 번째 페이지 parsing....
# 1237 번째 페이지 parsing....
# 1238 번째 페이지 parsing....
# 1239 번째 페이지 parsing....
# 1240 번째 페이지 parsing....
# 1241 번째 페이지 parsing....
# 1242 번째 페이지 parsing....
# 1243 번째 페이지 parsing....
# 1244 번째 페이지 parsing....
# 1245 번째 페이지 parsing....
# 1246 번째 페이지 parsing....
# 1247 번째 페이지 parsing....
# 1248 번째 페이지 parsing....
# 1249 번째 페이지 parsing....
# 1250 번째 페이지 parsing....
# 1251 번째 페이지 parsing....
# 1252 번째 페이지 parsing....
# 1253 번째 페이지 parsing....
# 1254 번째 페이지 parsing....
# 1255 번째 페이지 parsing....
# 1256 번째 페이지 parsing....
# 1257 번째 페이지 parsing....
# 1258 번째 페이지 parsing....
# 1259 번째 페이지 parsing....
# 1260 번째 페이지 parsing....
# 1261 번째 페이지 parsing....
# 1262 번째 페이지 parsing....
# 1263 번째 페이지 parsing....
# 1264 번째 페이지 parsing....
# 1265 번째 페이지 parsing....
# 1266 번째 페이지 parsing....
# 1267 번째 페이지 parsing....
# 1268 번째 페이지 parsing....
# 1269 번째 페이지 parsing....
# 1270 번째 페이지 parsing....
# 1271 번째 페이지 parsing....
# 1272 번째 페이지 parsing....
# 1273 번째 페이지 parsing....
# 1274 번째 페이지 parsing....
# 1275 번째 페이지 parsing....
# 1276 번째 페이지 parsing....
# 1277 번째 페이지 parsing....
# 1278 번째 페이지 parsing....
# 1279 번째 페이지 parsing....
# 1280 번째 페이지 parsing....
# 1281 번째 페이지 parsing....
# 1282 번째 페이지 parsing....
# 1283 번째 페이지 parsing....
# 1284 번째 페이지 parsing....
# 1285 번째 페이지 parsing....
# 1286 번째 페이지 parsing....
# 1287 번째 페이지 parsing....
# 1288 번째 페이지 parsing....
# 1289 번째 페이지 parsing....
# 1290 번째 페이지 parsing....
# 1291 번째 페이지 parsing....
# 1292 번째 페이지 parsing....
# 1293 번째 페이지 parsing....
# 1294 번째 페이지 parsing....
# 1295 번째 페이지 parsing....
# 1296 번째 페이지 parsing....
# 1297 번째 페이지 parsing....
# 1298 번째 페이지 parsing....
# 1299 번째 페이지 parsing....
# 1300 번째 페이지 parsing....
# 1301 번째 페이지 parsing....
# 1302 번째 페이지 parsing....
# 1303 번째 페이지 parsing....
# 1304 번째 페이지 parsing....
# 1305 번째 페이지 parsing....
# 1306 번째 페이지 parsing....
# 1307 번째 페이지 parsing....
# 1308 번째 페이지 parsing....
# 1309 번째 페이지 parsing....
# 1310 번째 페이지 parsing....
# 1311 번째 페이지 parsing....
# 1312 번째 페이지 parsing....
# 1313 번째 페이지 parsing....
# 1314 번째 페이지 parsing....
# 1315 번째 페이지 parsing....
# 1316 번째 페이지 parsing....
# 1317 번째 페이지 parsing....
# 1318 번째 페이지 parsing....
# 1319 번째 페이지 parsing....
# 1320 번째 페이지 parsing....
# 1321 번째 페이지 parsing....
# 1322 번째 페이지 parsing....
# 1323 번째 페이지 parsing....
# 1324 번째 페이지 parsing....
# 1325 번째 페이지 parsing....
# 1326 번째 페이지 parsing....
# 1327 번째 페이지 parsing....
# 1328 번째 페이지 parsing....
# 1329 번째 페이지 parsing....
# 1330 번째 페이지 parsing....
# 1331 번째 페이지 parsing....
# 1332 번째 페이지 parsing....
# 1333 번째 페이지 parsing....
# 1334 번째 페이지 parsing....
# 1335 번째 페이지 parsing....
# 1336 번째 페이지 parsing....
# 1337 번째 페이지 parsing....
# 1338 번째 페이지 parsing....
# 1339 번째 페이지 parsing....
# 1340 번째 페이지 parsing....
# 1341 번째 페이지 parsing....
# 1342 번째 페이지 parsing....
# 1343 번째 페이지 parsing....
# 1344 번째 페이지 parsing....
# 1345 번째 페이지 parsing....
# 1346 번째 페이지 parsing....
# 1347 번째 페이지 parsing....
# 1348 번째 페이지 parsing....
# 1349 번째 페이지 parsing....
# 1350 번째 페이지 parsing....
# 1351 번째 페이지 parsing....
# 1352 번째 페이지 parsing....
# 1353 번째 페이지 parsing....
# 1354 번째 페이지 parsing....
# 1355 번째 페이지 parsing....
# 1356 번째 페이지 parsing....
# 1357 번째 페이지 parsing....
# 1358 번째 페이지 parsing....
# 1359 번째 페이지 parsing....
# 1360 번째 페이지 parsing....
# 1361 번째 페이지 parsing....
# 1362 번째 페이지 parsing....
# 1363 번째 페이지 parsing....
# 1364 번째 페이지 parsing....
# 1365 번째 페이지 parsing....
# 1366 번째 페이지 parsing....
# 1367 번째 페이지 parsing....
# 1368 번째 페이지 parsing....
# 1369 번째 페이지 parsing....
# 1370 번째 페이지 parsing....
# 1371 번째 페이지 parsing....
# 1372 번째 페이지 parsing....
# 1373 번째 페이지 parsing....
# 1374 번째 페이지 parsing....
# 1375 번째 페이지 parsing....
# 1376 번째 페이지 parsing....
# 1377 번째 페이지 parsing....
# 1378 번째 페이지 parsing....
# 1379 번째 페이지 parsing....
# 1380 번째 페이지 parsing....
# 1381 번째 페이지 parsing....
# 1382 번째 페이지 parsing....
# 1383 번째 페이지 parsing....
# 1384 번째 페이지 parsing....
# 1385 번째 페이지 parsing....
# 1386 번째 페이지 parsing....
# 1387 번째 페이지 parsing....
# 1388 번째 페이지 parsing....
# 1389 번째 페이지 parsing....
# 1390 번째 페이지 parsing....
# 1391 번째 페이지 parsing....
# 1392 번째 페이지 parsing....
# 1393 번째 페이지 parsing....
# 1394 번째 페이지 parsing....
# 1395 번째 페이지 parsing....
# 1396 번째 페이지 parsing....
# 1397 번째 페이지 parsing....
# 1398 번째 페이지 parsing....
# 1399 번째 페이지 parsing....
# 1400 번째 페이지 parsing....
# 1401 번째 페이지 parsing....
# 1402 번째 페이지 parsing....
# 1403 번째 페이지 parsing....
# 1404 번째 페이지 parsing....
# 1405 번째 페이지 parsing....
# 1406 번째 페이지 parsing....
# 1407 번째 페이지 parsing....
# 1408 번째 페이지 parsing....
# 1409 번째 페이지 parsing....
# 1410 번째 페이지 parsing....
# 1411 번째 페이지 parsing....
# 1412 번째 페이지 parsing....
# 1413 번째 페이지 parsing....
# 1414 번째 페이지 parsing....
# 1415 번째 페이지 parsing....
# 1416 번째 페이지 parsing....
# 1417 번째 페이지 parsing....
# 1418 번째 페이지 parsing....
# 1419 번째 페이지 parsing....
# 1420 번째 페이지 parsing....
# 1421 번째 페이지 parsing....
# 1422 번째 페이지 parsing....
# 1423 번째 페이지 parsing....
# 1424 번째 페이지 parsing....
# 1425 번째 페이지 parsing....
# 1426 번째 페이지 parsing....
# 1427 번째 페이지 parsing....
# 1428 번째 페이지 parsing....
# 1429 번째 페이지 parsing....
# 1430 번째 페이지 parsing....
# 1431 번째 페이지 parsing....
# 1432 번째 페이지 parsing....
# 1433 번째 페이지 parsing....
# 1434 번째 페이지 parsing....
# 1435 번째 페이지 parsing....
# 1436 번째 페이지 parsing....
# 1437 번째 페이지 parsing....
# 1438 번째 페이지 parsing....
# 1439 번째 페이지 parsing....
# 1440 번째 페이지 parsing....
# 1441 번째 페이지 parsing....
# 1442 번째 페이지 parsing....
# 1443 번째 페이지 parsing....
# 1444 번째 페이지 parsing....
# 1445 번째 페이지 parsing....
# 1446 번째 페이지 parsing....
# 1447 번째 페이지 parsing....
# 1448 번째 페이지 parsing....
# 1449 번째 페이지 parsing....
# 1450 번째 페이지 parsing....
# 1451 번째 페이지 parsing....
# 1452 번째 페이지 parsing....
# 1453 번째 페이지 parsing....
# 1454 번째 페이지 parsing....
# 1455 번째 페이지 parsing....
# 1456 번째 페이지 parsing....
# 1457 번째 페이지 parsing....
# 1458 번째 페이지 parsing....
# 1459 번째 페이지 parsing....
# 1460 번째 페이지 parsing....
# 1461 번째 페이지 parsing....
# 1462 번째 페이지 parsing....
# 1463 번째 페이지 parsing....
# 1464 번째 페이지 parsing....
# 1465 번째 페이지 parsing....
# 1466 번째 페이지 parsing....
# 1467 번째 페이지 parsing....
# 1468 번째 페이지 parsing....
# 1469 번째 페이지 parsing....
# 1470 번째 페이지 parsing....
# 1471 번째 페이지 parsing....
# 1472 번째 페이지 parsing....
# 1473 번째 페이지 parsing....
# 1474 번째 페이지 parsing....
# 1475 번째 페이지 parsing....
# 1476 번째 페이지 parsing....
# 1477 번째 페이지 parsing....
# 1478 번째 페이지 parsing....
# 1479 번째 페이지 parsing....
# 1480 번째 페이지 parsing....
# 1481 번째 페이지 parsing....
# 1482 번째 페이지 parsing....
# 1483 번째 페이지 parsing....
# 1484 번째 페이지 parsing....
# 1485 번째 페이지 parsing....
# 1486 번째 페이지 parsing....
# 1487 번째 페이지 parsing....
# 1488 번째 페이지 parsing....
# 1489 번째 페이지 parsing....
# 1490 번째 페이지 parsing....
# 1491 번째 페이지 parsing....
# 1492 번째 페이지 parsing....
# 1493 번째 페이지 parsing....
# 1494 번째 페이지 parsing....
# 1495 번째 페이지 parsing....
# 1496 번째 페이지 parsing....
# 1497 번째 페이지 parsing....
# 1498 번째 페이지 parsing....
# 1499 번째 페이지 parsing....
# 1500 번째 페이지 parsing....
# 1501 번째 페이지 parsing....
# 1502 번째 페이지 parsing....
# 1503 번째 페이지 parsing....
# 1504 번째 페이지 parsing....
# 1505 번째 페이지 parsing....
# 1506 번째 페이지 parsing....
# 1507 번째 페이지 parsing....
# 1508 번째 페이지 parsing....
# 1509 번째 페이지 parsing....
# 1510 번째 페이지 parsing....
# 1511 번째 페이지 parsing....
# 1512 번째 페이지 parsing....
# 1513 번째 페이지 parsing....
# 1514 번째 페이지 parsing....
# 1515 번째 페이지 parsing....
# 1516 번째 페이지 parsing....
# 1517 번째 페이지 parsing....
# 1518 번째 페이지 parsing....
# 1519 번째 페이지 parsing....
# 1520 번째 페이지 parsing....
# 1521 번째 페이지 parsing....
# 1522 번째 페이지 parsing....
# 1523 번째 페이지 parsing....
# 1524 번째 페이지 parsing....
# 1525 번째 페이지 parsing....
# 1526 번째 페이지 parsing....
# 1527 번째 페이지 parsing....
# 1528 번째 페이지 parsing....
# 1529 번째 페이지 parsing....
# 1530 번째 페이지 parsing....
# 1531 번째 페이지 parsing....
# 1532 번째 페이지 parsing....
# 1533 번째 페이지 parsing....
# 1534 번째 페이지 parsing....
# 1535 번째 페이지 parsing....
# 1536 번째 페이지 parsing....
# 1537 번째 페이지 parsing....
# 1538 번째 페이지 parsing....
# 1539 번째 페이지 parsing....
# 1540 번째 페이지 parsing....
# 1541 번째 페이지 parsing....
# 1542 번째 페이지 parsing....
# 1543 번째 페이지 parsing....
# 1544 번째 페이지 parsing....
# 1545 번째 페이지 parsing....
# 1546 번째 페이지 parsing....
# 1547 번째 페이지 parsing....
# 1548 번째 페이지 parsing....
# 1549 번째 페이지 parsing....
# 1550 번째 페이지 parsing....
# 1551 번째 페이지 parsing....
# 1552 번째 페이지 parsing....
# 1553 번째 페이지 parsing....
# 1554 번째 페이지 parsing....
# 1555 번째 페이지 parsing....
# 1556 번째 페이지 parsing....
# 1557 번째 페이지 parsing....
# 1558 번째 페이지 parsing....
# 1559 번째 페이지 parsing....
# 1560 번째 페이지 parsing....
# 1561 번째 페이지 parsing....
# 1562 번째 페이지 parsing....
# 1563 번째 페이지 parsing....
# 1564 번째 페이지 parsing....
# 1565 번째 페이지 parsing....
# 1566 번째 페이지 parsing....
# 1567 번째 페이지 parsing....
# 1568 번째 페이지 parsing....
# 1569 번째 페이지 parsing....
# 1570 번째 페이지 parsing....
# 1571 번째 페이지 parsing....
# 1572 번째 페이지 parsing....
# 1573 번째 페이지 parsing....
# 1574 번째 페이지 parsing....
# 1575 번째 페이지 parsing....
# 1576 번째 페이지 parsing....
# 1577 번째 페이지 parsing....
# 1578 번째 페이지 parsing....
# 1579 번째 페이지 parsing....
# 1580 번째 페이지 parsing....
# 1581 번째 페이지 parsing....
# 1582 번째 페이지 parsing....
# 1583 번째 페이지 parsing....
# 1584 번째 페이지 parsing....
# 1585 번째 페이지 parsing....
# 1586 번째 페이지 parsing....
# 1587 번째 페이지 parsing....
# 1588 번째 페이지 parsing....
# 1589 번째 페이지 parsing....
# 1590 번째 페이지 parsing....
# 1591 번째 페이지 parsing....
# 1592 번째 페이지 parsing....
# 1593 번째 페이지 parsing....
# 1594 번째 페이지 parsing....
# 1595 번째 페이지 parsing....
# 1596 번째 페이지 parsing....
# 1597 번째 페이지 parsing....
# 1598 번째 페이지 parsing....
# 1599 번째 페이지 parsing....
# 1600 번째 페이지 parsing....
# 1601 번째 페이지 parsing....
# 1602 번째 페이지 parsing....
# 1603 번째 페이지 parsing....
# 1604 번째 페이지 parsing....
# 1605 번째 페이지 parsing....
# 1606 번째 페이지 parsing....
# 1607 번째 페이지 parsing....
# 1608 번째 페이지 parsing....
# 1609 번째 페이지 parsing....
# 1610 번째 페이지 parsing....
# 1611 번째 페이지 parsing....
# 1612 번째 페이지 parsing....
# 1613 번째 페이지 parsing....
# 1614 번째 페이지 parsing....
# 1615 번째 페이지 parsing....
# 1616 번째 페이지 parsing....
# 1617 번째 페이지 parsing....
# 1618 번째 페이지 parsing....
# 1619 번째 페이지 parsing....
# 1620 번째 페이지 parsing....
# 1621 번째 페이지 parsing....
# 1622 번째 페이지 parsing....
# 1623 번째 페이지 parsing....
# 1624 번째 페이지 parsing....
# 1625 번째 페이지 parsing....
# 1626 번째 페이지 parsing....
# 1627 번째 페이지 parsing....
# 1628 번째 페이지 parsing....
# 1629 번째 페이지 parsing....
# 1630 번째 페이지 parsing....
# 1631 번째 페이지 parsing....
# 1632 번째 페이지 parsing....
# 1633 번째 페이지 parsing....
# 1634 번째 페이지 parsing....
# 1635 번째 페이지 parsing....
# 1636 번째 페이지 parsing....
# 1637 번째 페이지 parsing....
# 1638 번째 페이지 parsing....
# 1639 번째 페이지 parsing....
# 1640 번째 페이지 parsing....
# 1641 번째 페이지 parsing....
# 1642 번째 페이지 parsing....
# 1643 번째 페이지 parsing....
# 1644 번째 페이지 parsing....
# 1645 번째 페이지 parsing....
# 1646 번째 페이지 parsing....
# 1647 번째 페이지 parsing....
# 1648 번째 페이지 parsing....
# 1649 번째 페이지 parsing....
# 1650 번째 페이지 parsing....
# 1651 번째 페이지 parsing....
# 1652 번째 페이지 parsing....
# 1653 번째 페이지 parsing....
# 1654 번째 페이지 parsing....
# 1655 번째 페이지 parsing....
# 1656 번째 페이지 parsing....
# 1657 번째 페이지 parsing....
# 1658 번째 페이지 parsing....
# 1659 번째 페이지 parsing....
# 1660 번째 페이지 parsing....
# 1661 번째 페이지 parsing....
# 1662 번째 페이지 parsing....
# 1663 번째 페이지 parsing....
# 1664 번째 페이지 parsing....
# 1665 번째 페이지 parsing....
# 1666 번째 페이지 parsing....
# 1667 번째 페이지 parsing....
# 1668 번째 페이지 parsing....
# 1669 번째 페이지 parsing....
# 1670 번째 페이지 parsing....
# 1671 번째 페이지 parsing....
# 1672 번째 페이지 parsing....
# 1673 번째 페이지 parsing....
# 1674 번째 페이지 parsing....
# 1675 번째 페이지 parsing....
# 1676 번째 페이지 parsing....
# 1677 번째 페이지 parsing....
# 1678 번째 페이지 parsing....
# 1679 번째 페이지 parsing....
# 1680 번째 페이지 parsing....
# 1681 번째 페이지 parsing....
# 1682 번째 페이지 parsing....
# 1683 번째 페이지 parsing....
# 1684 번째 페이지 parsing....
# 1685 번째 페이지 parsing....
# 1686 번째 페이지 parsing....
# 1687 번째 페이지 parsing....
# 1688 번째 페이지 parsing....
# 1689 번째 페이지 parsing....
# 1690 번째 페이지 parsing....
# 1691 번째 페이지 parsing....
# 1692 번째 페이지 parsing....
# 1693 번째 페이지 parsing....
# 1694 번째 페이지 parsing....
# 1695 번째 페이지 parsing....
# 1696 번째 페이지 parsing....
# 1697 번째 페이지 parsing....
# 1698 번째 페이지 parsing....
# 1699 번째 페이지 parsing....
# 1700 번째 페이지 parsing....
# 1701 번째 페이지 parsing....
# 1702 번째 페이지 parsing....
# 1703 번째 페이지 parsing....
# 1704 번째 페이지 parsing....
# 1705 번째 페이지 parsing....
# 1706 번째 페이지 parsing....
# 1707 번째 페이지 parsing....
# 1708 번째 페이지 parsing....
# 1709 번째 페이지 parsing....
# 1710 번째 페이지 parsing....
# 1711 번째 페이지 parsing....
# 1712 번째 페이지 parsing....
# 1713 번째 페이지 parsing....
# 1714 번째 페이지 parsing....
# 1715 번째 페이지 parsing....
# 1716 번째 페이지 parsing....
# 1717 번째 페이지 parsing....
# 1718 번째 페이지 parsing....
# 1719 번째 페이지 parsing....
# 1720 번째 페이지 parsing....
# 1721 번째 페이지 parsing....
# 1722 번째 페이지 parsing....
# 1723 번째 페이지 parsing....
# 1724 번째 페이지 parsing....
# 1725 번째 페이지 parsing....
# 1726 번째 페이지 parsing....
# 1727 번째 페이지 parsing....
# 1728 번째 페이지 parsing....
# 1729 번째 페이지 parsing....
# 1730 번째 페이지 parsing....
# 1731 번째 페이지 parsing....
# 1732 번째 페이지 parsing....
# 1733 번째 페이지 parsing....
# 1734 번째 페이지 parsing....
# 1735 번째 페이지 parsing....
# 1736 번째 페이지 parsing....
# 1737 번째 페이지 parsing....
# 1738 번째 페이지 parsing....
# 1739 번째 페이지 parsing....
# 1740 번째 페이지 parsing....
# 1741 번째 페이지 parsing....
# 1742 번째 페이지 parsing....
# 1743 번째 페이지 parsing....
# 1744 번째 페이지 parsing....
# 1745 번째 페이지 parsing....
# 1746 번째 페이지 parsing....
# 1747 번째 페이지 parsing....
# 1748 번째 페이지 parsing....
# 1749 번째 페이지 parsing....
# 1750 번째 페이지 parsing....
# 1751 번째 페이지 parsing....
# 1752 번째 페이지 parsing....
# 1753 번째 페이지 parsing....
# 1754 번째 페이지 parsing....
# 1755 번째 페이지 parsing....
# 1756 번째 페이지 parsing....
# 1757 번째 페이지 parsing....
# 1758 번째 페이지 parsing....
# 1759 번째 페이지 parsing....
# 1760 번째 페이지 parsing....
# 1761 번째 페이지 parsing....
# 1762 번째 페이지 parsing....
# 1763 번째 페이지 parsing....
# 1764 번째 페이지 parsing....
# 1765 번째 페이지 parsing....
# 1766 번째 페이지 parsing....
# 1767 번째 페이지 parsing....
# 1768 번째 페이지 parsing....
# 1769 번째 페이지 parsing....
# 1770 번째 페이지 parsing....
# 1771 번째 페이지 parsing....
# 1772 번째 페이지 parsing....
# 1773 번째 페이지 parsing....
# 1774 번째 페이지 parsing....
# 1775 번째 페이지 parsing....
# 1776 번째 페이지 parsing....
# 1777 번째 페이지 parsing....
# 1778 번째 페이지 parsing....
# 1779 번째 페이지 parsing....
# 1780 번째 페이지 parsing....
# 1781 번째 페이지 parsing....
# 1782 번째 페이지 parsing....
# 1783 번째 페이지 parsing....
# 1784 번째 페이지 parsing....
# 1785 번째 페이지 parsing....
# 1786 번째 페이지 parsing....
# 1787 번째 페이지 parsing....
# 1788 번째 페이지 parsing....
# 1789 번째 페이지 parsing....
# 1790 번째 페이지 parsing....
# 1791 번째 페이지 parsing....
# 1792 번째 페이지 parsing....
# 1793 번째 페이지 parsing....
# 1794 번째 페이지 parsing....
# 1795 번째 페이지 parsing....
# 1796 번째 페이지 parsing....
# 1797 번째 페이지 parsing....
# 1798 번째 페이지 parsing....
# 1799 번째 페이지 parsing....
# 1800 번째 페이지 parsing....
# 1801 번째 페이지 parsing....
# 1802 번째 페이지 parsing....
# 1803 번째 페이지 parsing....
# 1804 번째 페이지 parsing....
# 1805 번째 페이지 parsing....
# 1806 번째 페이지 parsing....
# 1807 번째 페이지 parsing....
# 1808 번째 페이지 parsing....
# 1809 번째 페이지 parsing....
# 1810 번째 페이지 parsing....
# 1811 번째 페이지 parsing....
# 1812 번째 페이지 parsing....
# 1813 번째 페이지 parsing....
# 1814 번째 페이지 parsing....
# 1815 번째 페이지 parsing....
# 1816 번째 페이지 parsing....
# 1817 번째 페이지 parsing....
# 1818 번째 페이지 parsing....
# 1819 번째 페이지 parsing....
# 1820 번째 페이지 parsing....
# 1821 번째 페이지 parsing....
# 1822 번째 페이지 parsing....
# 1823 번째 페이지 parsing....
# 1824 번째 페이지 parsing....
# 1825 번째 페이지 parsing....
# 1826 번째 페이지 parsing....
# 1827 번째 페이지 parsing....
# 1828 번째 페이지 parsing....
# 1829 번째 페이지 parsing....
# 1830 번째 페이지 parsing....
# 1831 번째 페이지 parsing....
# 1832 번째 페이지 parsing....
# 1833 번째 페이지 parsing....
# 1834 번째 페이지 parsing....
# 1835 번째 페이지 parsing....
# 1836 번째 페이지 parsing....
# 1837 번째 페이지 parsing....
# 1838 번째 페이지 parsing....
# 1839 번째 페이지 parsing....
# 1840 번째 페이지 parsing....
# 1841 번째 페이지 parsing....
# 1842 번째 페이지 parsing....
# 1843 번째 페이지 parsing....
# 1844 번째 페이지 parsing....
# 1845 번째 페이지 parsing....
# 1846 번째 페이지 parsing....
# 1847 번째 페이지 parsing....
# 1848 번째 페이지 parsing....
# 1849 번째 페이지 parsing....
# 1850 번째 페이지 parsing....
# 1851 번째 페이지 parsing....
# 1852 번째 페이지 parsing....
# 1853 번째 페이지 parsing....
# 1854 번째 페이지 parsing....
# 1855 번째 페이지 parsing....
# 1856 번째 페이지 parsing....
# 1857 번째 페이지 parsing....
# 1858 번째 페이지 parsing....
# 1859 번째 페이지 parsing....
# 1860 번째 페이지 parsing....
# 1861 번째 페이지 parsing....
# 1862 번째 페이지 parsing....
# 1863 번째 페이지 parsing....
# 1864 번째 페이지 parsing....
# 1865 번째 페이지 parsing....
# 1866 번째 페이지 parsing....
# 1867 번째 페이지 parsing....
# 1868 번째 페이지 parsing....
# 1869 번째 페이지 parsing....
# 1870 번째 페이지 parsing....
# 1871 번째 페이지 parsing....
# 1872 번째 페이지 parsing....
# 1873 번째 페이지 parsing....
# 1874 번째 페이지 parsing....
# 1875 번째 페이지 parsing....
# 1876 번째 페이지 parsing....
# 1877 번째 페이지 parsing....
# 1878 번째 페이지 parsing....
# 1879 번째 페이지 parsing....
# 1880 번째 페이지 parsing....
# 1881 번째 페이지 parsing....
# 1882 번째 페이지 parsing....
# 1883 번째 페이지 parsing....
# 1884 번째 페이지 parsing....
# 1885 번째 페이지 parsing....
# 1886 번째 페이지 parsing....
# 1887 번째 페이지 parsing....
# 1888 번째 페이지 parsing....
# 1889 번째 페이지 parsing....
# 1890 번째 페이지 parsing....
# 1891 번째 페이지 parsing....
# 1892 번째 페이지 parsing....
# 1893 번째 페이지 parsing....
# 1894 번째 페이지 parsing....
# 1895 번째 페이지 parsing....
# 1896 번째 페이지 parsing....
# 1897 번째 페이지 parsing....
# 1898 번째 페이지 parsing....
# 1899 번째 페이지 parsing....
# 1900 번째 페이지 parsing....
# 1901 번째 페이지 parsing....
# 1902 번째 페이지 parsing....
# 1903 번째 페이지 parsing....
# 1904 번째 페이지 parsing....
# 1905 번째 페이지 parsing....
# 1906 번째 페이지 parsing....
# 1907 번째 페이지 parsing....
# 1908 번째 페이지 parsing....
# 1909 번째 페이지 parsing....
# 1910 번째 페이지 parsing....
# 1911 번째 페이지 parsing....
# 1912 번째 페이지 parsing....
# 1913 번째 페이지 parsing....
# 1914 번째 페이지 parsing....
# 1915 번째 페이지 parsing....
# 1916 번째 페이지 parsing....
# 1917 번째 페이지 parsing....
# 1918 번째 페이지 parsing....
# 1919 번째 페이지 parsing....
# 1920 번째 페이지 parsing....
# 1921 번째 페이지 parsing....
# 1922 번째 페이지 parsing....
# 1923 번째 페이지 parsing....
# 1924 번째 페이지 parsing....
# 1925 번째 페이지 parsing....
# 1926 번째 페이지 parsing....
# 1927 번째 페이지 parsing....
# 1928 번째 페이지 parsing....
# 1929 번째 페이지 parsing....
# 1930 번째 페이지 parsing....
# 1931 번째 페이지 parsing....
# 1932 번째 페이지 parsing....
# 1933 번째 페이지 parsing....
# 1934 번째 페이지 parsing....
# 1935 번째 페이지 parsing....
# 1936 번째 페이지 parsing....
# 1937 번째 페이지 parsing....
# 1938 번째 페이지 parsing....
# 1939 번째 페이지 parsing....
# 1940 번째 페이지 parsing....
# 1941 번째 페이지 parsing....
# 1942 번째 페이지 parsing....
# 1943 번째 페이지 parsing....
# 1944 번째 페이지 parsing....
# 1945 번째 페이지 parsing....
# 1946 번째 페이지 parsing....
# 1947 번째 페이지 parsing....
# 1948 번째 페이지 parsing....
# 1949 번째 페이지 parsing....
# 1950 번째 페이지 parsing....
# 1951 번째 페이지 parsing....
# 1952 번째 페이지 parsing....
# 1953 번째 페이지 parsing....
# 1954 번째 페이지 parsing....
# 1955 번째 페이지 parsing....
# 1956 번째 페이지 parsing....
# 1957 번째 페이지 parsing....
# 1958 번째 페이지 parsing....
# 1959 번째 페이지 parsing....
# 1960 번째 페이지 parsing....
# 1961 번째 페이지 parsing....
# 1962 번째 페이지 parsing....
# 1963 번째 페이지 parsing....
# 1964 번째 페이지 parsing....
# 1965 번째 페이지 parsing....
# 1966 번째 페이지 parsing....
# 1967 번째 페이지 parsing....
# 1968 번째 페이지 parsing....
# 1969 번째 페이지 parsing....
# 1970 번째 페이지 parsing....
# 1971 번째 페이지 parsing....
# 1972 번째 페이지 parsing....
# 1973 번째 페이지 parsing....
# 1974 번째 페이지 parsing....
# 1975 번째 페이지 parsing....
# 1976 번째 페이지 parsing....
# 1977 번째 페이지 parsing....
# 1978 번째 페이지 parsing....
# 1979 번째 페이지 parsing....
# 1980 번째 페이지 parsing....
# 1981 번째 페이지 parsing....
# 1982 번째 페이지 parsing....
# 1983 번째 페이지 parsing....
# 1984 번째 페이지 parsing....
# 1985 번째 페이지 parsing....
# 1986 번째 페이지 parsing....
# 1987 번째 페이지 parsing....
# 1988 번째 페이지 parsing....
# 1989 번째 페이지 parsing....
# 1990 번째 페이지 parsing....
# 1991 번째 페이지 parsing....
# 1992 번째 페이지 parsing....
# 1993 번째 페이지 parsing....
# 1994 번째 페이지 parsing....
# 1995 번째 페이지 parsing....
# 1996 번째 페이지 parsing....
# 1997 번째 페이지 parsing....
# 1998 번째 페이지 parsing....
# 1999 번째 페이지 parsing....
# 2000 번째 페이지 parsing....
# 2001 번째 페이지 parsing....
# 2002 번째 페이지 parsing....
# 2003 번째 페이지 parsing....
# 2004 번째 페이지 parsing....
# 2005 번째 페이지 parsing....
# 2006 번째 페이지 parsing....
# 2007 번째 페이지 parsing....
# 2008 번째 페이지 parsing....
# 2009 번째 페이지 parsing....
# 2010 번째 페이지 parsing....
# 2011 번째 페이지 parsing....
# 2012 번째 페이지 parsing....
# 2013 번째 페이지 parsing....
# 2014 번째 페이지 parsing....
# 2015 번째 페이지 parsing....
# 2016 번째 페이지 parsing....
# 2017 번째 페이지 parsing....
# 2018 번째 페이지 parsing....
# 2019 번째 페이지 parsing....
# 2020 번째 페이지 parsing....
# 2021 번째 페이지 parsing....
# 2022 번째 페이지 parsing....
# 2023 번째 페이지 parsing....
# 2024 번째 페이지 parsing....
# 2025 번째 페이지 parsing....
# 2026 번째 페이지 parsing....
# 2027 번째 페이지 parsing....
# 2028 번째 페이지 parsing....
# 2029 번째 페이지 parsing....
# 2030 번째 페이지 parsing....
# 2031 번째 페이지 parsing....
# 2032 번째 페이지 parsing....
# 2033 번째 페이지 parsing....
# 2034 번째 페이지 parsing....
# 2035 번째 페이지 parsing....
# 2036 번째 페이지 parsing....
# 2037 번째 페이지 parsing....
# 2038 번째 페이지 parsing....
# 2039 번째 페이지 parsing....
# 2040 번째 페이지 parsing....
# 2041 번째 페이지 parsing....
# 2042 번째 페이지 parsing....
# 2043 번째 페이지 parsing....
# 2044 번째 페이지 parsing....
# 2045 번째 페이지 parsing....
# 2046 번째 페이지 parsing....
# ...
# 3108 번째 페이지 parsing....
# 3109 번째 페이지 parsing....
# 3110 번째 페이지 parsing....
# 3111 번째 페이지 parsing....
# 3112 번째 페이지 parsing....
# 3113 번째 페이지 parsing....
# 3114 번째 페이지 parsing....
# 3115 번째 페이지 parsing....
# 3116 번째 페이지 parsing....
# 3117 번째 페이지 parsing....
# 3118 번째 페이지 parsing....
# 3119 번째 페이지 parsing....
# 3120 번째 페이지 parsing....
# 3121 번째 페이지 parsing....
# 3122 번째 페이지 parsing....
# 3123 번째 페이지 parsing....
# 3124 번째 페이지 parsing....
# 3125 번째 페이지 parsing....
# 3126 번째 페이지 parsing....
# 3127 번째 페이지 parsing....
# 3128 번째 페이지 parsing....
# 3129 번째 페이지 parsing....
# 3130 번째 페이지 parsing....
# 3131 번째 페이지 parsing....
# 3132 번째 페이지 parsing....
# 3133 번째 페이지 parsing....
# 3134 번째 페이지 parsing....
# 3135 번째 페이지 parsing....
# 3136 번째 페이지 parsing....
# 3137 번째 페이지 parsing....
# 3138 번째 페이지 parsing....
# 3139 번째 페이지 parsing....
# 3140 번째 페이지 parsing....
# 3141 번째 페이지 parsing....
# 3142 번째 페이지 parsing....
# 3143 번째 페이지 parsing....
# 3144 번째 페이지 parsing....
# 3145 번째 페이지 parsing....
# 3146 번째 페이지 parsing....
# 3147 번째 페이지 parsing....
# 3148 번째 페이지 parsing....
# 3149 번째 페이지 parsing....
# 3150 번째 페이지 parsing....
# 3151 번째 페이지 parsing....
# 3152 번째 페이지 parsing....
# 3153 번째 페이지 parsing....
# 3154 번째 페이지 parsing....
# 3155 번째 페이지 parsing....
# 3156 번째 페이지 parsing....
# 3157 번째 페이지 parsing....
# 3158 번째 페이지 parsing....
# 3159 번째 페이지 parsing....
# 3160 번째 페이지 parsing....
# 3161 번째 페이지 parsing....
# 3162 번째 페이지 parsing....
# 3163 번째 페이지 parsing....
# 3164 번째 페이지 parsing....
# 3165 번째 페이지 parsing....
# 3166 번째 페이지 parsing....
# 3167 번째 페이지 parsing....
# 3168 번째 페이지 parsing....
# 3169 번째 페이지 parsing....
# 3170 번째 페이지 parsing....
# 3171 번째 페이지 parsing....
# 3172 번째 페이지 parsing....
# 3173 번째 페이지 parsing....
# 3174 번째 페이지 parsing....
# 3175 번째 페이지 parsing....
# 3176 번째 페이지 parsing....
# 3177 번째 페이지 parsing....
# 3178 번째 페이지 parsing....
# 3179 번째 페이지 parsing....
# 3180 번째 페이지 parsing....
# 3181 번째 페이지 parsing....
# 3182 번째 페이지 parsing....
# 3183 번째 페이지 parsing....
# 3184 번째 페이지 parsing....
# 3185 번째 페이지 parsing....
# 3186 번째 페이지 parsing....
# 3187 번째 페이지 parsing....
# 3188 번째 페이지 parsing....
# 3189 번째 페이지 parsing....
# 3190 번째 페이지 parsing....
# 3191 번째 페이지 parsing....
# 3192 번째 페이지 parsing....
# 3193 번째 페이지 parsing....
# 3194 번째 페이지 parsing....
# 3195 번째 페이지 parsing....
# 3196 번째 페이지 parsing....
# 3197 번째 페이지 parsing....
# 3198 번째 페이지 parsing....
# 3199 번째 페이지 parsing....
# 3200 번째 페이지 parsing....
# 3201 번째 페이지 parsing....
# 3202 번째 페이지 parsing....
# 3203 번째 페이지 parsing....
# 3204 번째 페이지 parsing....
# 3205 번째 페이지 parsing....
# 3206 번째 페이지 parsing....
# 3207 번째 페이지 parsing....
# 3208 번째 페이지 parsing....
# 3209 번째 페이지 parsing....
# 3210 번째 페이지 parsing....
# 3211 번째 페이지 parsing....
# 3212 번째 페이지 parsing....
# 3213 번째 페이지 parsing....
# 3214 번째 페이지 parsing....
# 3215 번째 페이지 parsing....
# 3216 번째 페이지 parsing....
# 3217 번째 페이지 parsing....
# 3218 번째 페이지 parsing....
# 3219 번째 페이지 parsing....
# 3220 번째 페이지 parsing....
# 3221 번째 페이지 parsing....
# 3222 번째 페이지 parsing....
# 3223 번째 페이지 parsing....
# 3224 번째 페이지 parsing....
# 3225 번째 페이지 parsing....
# 3226 번째 페이지 parsing....
# 3227 번째 페이지 parsing....
# 3228 번째 페이지 parsing....
# 3229 번째 페이지 parsing....
# 3230 번째 페이지 parsing....
# 3231 번째 페이지 parsing....
# 3232 번째 페이지 parsing....
# 3233 번째 페이지 parsing....
# 3234 번째 페이지 parsing....
# 3235 번째 페이지 parsing....
# 3236 번째 페이지 parsing....
# 3237 번째 페이지 parsing....
# 3238 번째 페이지 parsing....
# 3239 번째 페이지 parsing....
# 3240 번째 페이지 parsing....
# 3241 번째 페이지 parsing....
# 3242 번째 페이지 parsing....
# 3243 번째 페이지 parsing....
# 3244 번째 페이지 parsing....
# 3245 번째 페이지 parsing....
# 3246 번째 페이지 parsing....
# 3247 번째 페이지 parsing....
# 3248 번째 페이지 parsing....
# 3249 번째 페이지 parsing....
# 3250 번째 페이지 parsing....
# 3251 번째 페이지 parsing....
# 3252 번째 페이지 parsing....
# 3253 번째 페이지 parsing....
# 3254 번째 페이지 parsing....
# 3255 번째 페이지 parsing....
# 3256 번째 페이지 parsing....
# 3257 번째 페이지 parsing....
# 3258 번째 페이지 parsing....
# 3259 번째 페이지 parsing....
# 3260 번째 페이지 parsing....
# 3261 번째 페이지 parsing....
# 3262 번째 페이지 parsing....
# 3263 번째 페이지 parsing....
# 3264 번째 페이지 parsing....
# 3265 번째 페이지 parsing....
# 3266 번째 페이지 parsing....
# 3267 번째 페이지 parsing....
# 3268 번째 페이지 parsing....
# 3269 번째 페이지 parsing....
# 3270 번째 페이지 parsing....
# 3271 번째 페이지 parsing....
# 3272 번째 페이지 parsing....
# 3273 번째 페이지 parsing....
# 3274 번째 페이지 parsing....
# 3275 번째 페이지 parsing....
# 3276 번째 페이지 parsing....
# 3277 번째 페이지 parsing....
# 3278 번째 페이지 parsing....
# 3279 번째 페이지 parsing....
# 3280 번째 페이지 parsing....
# 3281 번째 페이지 parsing....
# 3282 번째 페이지 parsing....
# 3283 번째 페이지 parsing....
# 3284 번째 페이지 parsing....
# 3285 번째 페이지 parsing....
# 3286 번째 페이지 parsing....
# 3287 번째 페이지 parsing....
# 3288 번째 페이지 parsing....
# 3289 번째 페이지 parsing....
# 3290 번째 페이지 parsing....
# 3291 번째 페이지 parsing....
# 3292 번째 페이지 parsing....
# 3293 번째 페이지 parsing....
# 3294 번째 페이지 parsing....
# 3295 번째 페이지 parsing....
# 3296 번째 페이지 parsing....
# 3297 번째 페이지 parsing....
# 3298 번째 페이지 parsing....
# 3299 번째 페이지 parsing....
# 3300 번째 페이지 parsing....
# 3301 번째 페이지 parsing....
# 3302 번째 페이지 parsing....
# 3303 번째 페이지 parsing....
# 3304 번째 페이지 parsing....
# 3305 번째 페이지 parsing....
# 3306 번째 페이지 parsing....
# 3307 번째 페이지 parsing....
# 3308 번째 페이지 parsing....
# 3309 번째 페이지 parsing....
# 3310 번째 페이지 parsing....
# 3311 번째 페이지 parsing....
# 3312 번째 페이지 parsing....
# 3313 번째 페이지 parsing....
# 3314 번째 페이지 parsing....
# 3315 번째 페이지 parsing....
# 3316 번째 페이지 parsing....
# 3317 번째 페이지 parsing....
# 3318 번째 페이지 parsing....
# 3319 번째 페이지 parsing....
# 3320 번째 페이지 parsing....
# 3321 번째 페이지 parsing....
# 3322 번째 페이지 parsing....
# 3323 번째 페이지 parsing....
# 3324 번째 페이지 parsing....
# 3325 번째 페이지 parsing....
# 3326 번째 페이지 parsing....
# 3327 번째 페이지 parsing....
# 3328 번째 페이지 parsing....
# 3329 번째 페이지 parsing....
# 3330 번째 페이지 parsing....
# 3331 번째 페이지 parsing....
# 3332 번째 페이지 parsing....
# 3333 번째 페이지 parsing....
# 3334 번째 페이지 parsing....
# 3335 번째 페이지 parsing....
# 3336 번째 페이지 parsing....
# 3337 번째 페이지 parsing....
# 3338 번째 페이지 parsing....
# 3339 번째 페이지 parsing....
# 3340 번째 페이지 parsing....
# 3341 번째 페이지 parsing....
# 3342 번째 페이지 parsing....
# 3343 번째 페이지 parsing....
# 3344 번째 페이지 parsing....
# 3345 번째 페이지 parsing....
# 3346 번째 페이지 parsing....
# 3347 번째 페이지 parsing....
# 3348 번째 페이지 parsing....
# 3349 번째 페이지 parsing....
# 3350 번째 페이지 parsing....
# 3351 번째 페이지 parsing....
# 3352 번째 페이지 parsing....
# 3353 번째 페이지 parsing....
# 3354 번째 페이지 parsing....
# 3355 번째 페이지 parsing....
# 3356 번째 페이지 parsing....
# 3357 번째 페이지 parsing....
# 3358 번째 페이지 parsing....
# 3359 번째 페이지 parsing....
# 3360 번째 페이지 parsing....
# 3361 번째 페이지 parsing....
# 3362 번째 페이지 parsing....
# 3363 번째 페이지 parsing....
# 3364 번째 페이지 parsing....
# 3365 번째 페이지 parsing....
# 3366 번째 페이지 parsing....
# 3367 번째 페이지 parsing....
# 3368 번째 페이지 parsing....
# 3369 번째 페이지 parsing....
# 3370 번째 페이지 parsing....
# 3371 번째 페이지 parsing....
# 3372 번째 페이지 parsing....
# 3373 번째 페이지 parsing....
# 3374 번째 페이지 parsing....
# 3375 번째 페이지 parsing....
# 3376 번째 페이지 parsing....
# 3377 번째 페이지 parsing....
# 3378 번째 페이지 parsing....
# 3379 번째 페이지 parsing....
# 3380 번째 페이지 parsing....
# 3381 번째 페이지 parsing....
# 3382 번째 페이지 parsing....
# 3383 번째 페이지 parsing....
# 3384 번째 페이지 parsing....
# 3385 번째 페이지 parsing....
# 3386 번째 페이지 parsing....
# 3387 번째 페이지 parsing....
# 3388 번째 페이지 parsing....
# 3389 번째 페이지 parsing....
# 3390 번째 페이지 parsing....
# 3391 번째 페이지 parsing....
# 3392 번째 페이지 parsing....
# 3393 번째 페이지 parsing....
# 3394 번째 페이지 parsing....
# 3395 번째 페이지 parsing....
# 3396 번째 페이지 parsing....
# 3397 번째 페이지 parsing....
# 3398 번째 페이지 parsing....
# 3399 번째 페이지 parsing....
# 3400 번째 페이지 parsing....
# 3401 번째 페이지 parsing....
# 3402 번째 페이지 parsing....
# 3403 번째 페이지 parsing....
# 3404 번째 페이지 parsing....
# 3405 번째 페이지 parsing....
# 3406 번째 페이지 parsing....
# 3407 번째 페이지 parsing....
# 3408 번째 페이지 parsing....
# 3409 번째 페이지 parsing....
# 3410 번째 페이지 parsing....
# 3411 번째 페이지 parsing....
# 3412 번째 페이지 parsing....
# 3413 번째 페이지 parsing....
# 3414 번째 페이지 parsing....
# 3415 번째 페이지 parsing....
# 3416 번째 페이지 parsing....
# 3417 번째 페이지 parsing....
# 3418 번째 페이지 parsing....
# 3419 번째 페이지 parsing....
# 3420 번째 페이지 parsing....
# 3421 번째 페이지 parsing....
# 3422 번째 페이지 parsing....
# 3423 번째 페이지 parsing....
# 3424 번째 페이지 parsing....
# 3425 번째 페이지 parsing....
# 3426 번째 페이지 parsing....
# 3427 번째 페이지 parsing....
# 3428 번째 페이지 parsing....
# 3429 번째 페이지 parsing....
# 3430 번째 페이지 parsing....
# 3431 번째 페이지 parsing....
# 3432 번째 페이지 parsing....
# 3433 번째 페이지 parsing....
# 3434 번째 페이지 parsing....
# 3435 번째 페이지 parsing....
# 3436 번째 페이지 parsing....
# 3437 번째 페이지 parsing....
# 3438 번째 페이지 parsing....
# 3439 번째 페이지 parsing....
# 3440 번째 페이지 parsing....
# 3441 번째 페이지 parsing....
# 3442 번째 페이지 parsing....
# 3443 번째 페이지 parsing....
# 3444 번째 페이지 parsing....
# 3445 번째 페이지 parsing....
# 3446 번째 페이지 parsing....
# 3447 번째 페이지 parsing....
# 3448 번째 페이지 parsing....
# 3449 번째 페이지 parsing....
# 3450 번째 페이지 parsing....
# 3451 번째 페이지 parsing....
# 3452 번째 페이지 parsing....
# 3453 번째 페이지 parsing....
# 3454 번째 페이지 parsing....
# 3455 번째 페이지 parsing....
# 3456 번째 페이지 parsing....
# 3457 번째 페이지 parsing....
# 3458 번째 페이지 parsing....
# 3459 번째 페이지 parsing....
# 3460 번째 페이지 parsing....
# 3461 번째 페이지 parsing....
# 3462 번째 페이지 parsing....
# 3463 번째 페이지 parsing....
# 3464 번째 페이지 parsing....
# 3465 번째 페이지 parsing....
# 3466 번째 페이지 parsing....
# 3467 번째 페이지 parsing....
# 3468 번째 페이지 parsing....
# 3469 번째 페이지 parsing....
# 3470 번째 페이지 parsing....
# 3471 번째 페이지 parsing....
# 3472 번째 페이지 parsing....
# 3473 번째 페이지 parsing....
# 3474 번째 페이지 parsing....
# 3475 번째 페이지 parsing....
# 3476 번째 페이지 parsing....
# 3477 번째 페이지 parsing....
# 3478 번째 페이지 parsing....
# 3479 번째 페이지 parsing....
# 3480 번째 페이지 parsing....
# 3481 번째 페이지 parsing....
# 3482 번째 페이지 parsing....
# 3483 번째 페이지 parsing....
# 3484 번째 페이지 parsing....
# 3485 번째 페이지 parsing....
# 3486 번째 페이지 parsing....
# 3487 번째 페이지 parsing....
# 3488 번째 페이지 parsing....
# 3489 번째 페이지 parsing....
# 3490 번째 페이지 parsing....
# 3491 번째 페이지 parsing....
# 3492 번째 페이지 parsing....
# 3493 번째 페이지 parsing....
# 3494 번째 페이지 parsing....
# 3495 번째 페이지 parsing....
# 3496 번째 페이지 parsing....
# 3497 번째 페이지 parsing....
# 3498 번째 페이지 parsing....
# 3499 번째 페이지 parsing....
# 3500 번째 페이지 parsing....
# 3501 번째 페이지 parsing....
# 3502 번째 페이지 parsing....
# 3503 번째 페이지 parsing....
# 3504 번째 페이지 parsing....
# 3505 번째 페이지 parsing....
# 3506 번째 페이지 parsing....
# 3507 번째 페이지 parsing....
# 3508 번째 페이지 parsing....
# 3509 번째 페이지 parsing....
# 3510 번째 페이지 parsing....
# 3511 번째 페이지 parsing....
# 3512 번째 페이지 parsing....
# 3513 번째 페이지 parsing....
# 3514 번째 페이지 parsing....
# 3515 번째 페이지 parsing....
# 3516 번째 페이지 parsing....
# 3517 번째 페이지 parsing....
# 3518 번째 페이지 parsing....
# 3519 번째 페이지 parsing....
# 3520 번째 페이지 parsing....
# 3521 번째 페이지 parsing....
# 3522 번째 페이지 parsing....
# 3523 번째 페이지 parsing....
# 3524 번째 페이지 parsing....
# 3525 번째 페이지 parsing....
# 3526 번째 페이지 parsing....
# 3527 번째 페이지 parsing....
# 3528 번째 페이지 parsing....
# 3529 번째 페이지 parsing....
# 3530 번째 페이지 parsing....
# 3531 번째 페이지 parsing....
# 3532 번째 페이지 parsing....
# 3533 번째 페이지 parsing....
# 3534 번째 페이지 parsing....
# 3535 번째 페이지 parsing....
# 3536 번째 페이지 parsing....
# 3537 번째 페이지 parsing....
# 3538 번째 페이지 parsing....
# 3539 번째 페이지 parsing....
# 3540 번째 페이지 parsing....
# 3541 번째 페이지 parsing....
# 3542 번째 페이지 parsing....
# 3543 번째 페이지 parsing....
# 3544 번째 페이지 parsing....
# 3545 번째 페이지 parsing....
# 3546 번째 페이지 parsing....
# 3547 번째 페이지 parsing....
# 3548 번째 페이지 parsing....
# 3549 번째 페이지 parsing....
# 3550 번째 페이지 parsing....
# 3551 번째 페이지 parsing....
# 3552 번째 페이지 parsing....
# 3553 번째 페이지 parsing....
# 3554 번째 페이지 parsing....
# 3555 번째 페이지 parsing....
# 3556 번째 페이지 parsing....
# 3557 번째 페이지 parsing....
# 3558 번째 페이지 parsing....
# 3559 번째 페이지 parsing....
# 3560 번째 페이지 parsing....
# 3561 번째 페이지 parsing....
# 3562 번째 페이지 parsing....
# 3563 번째 페이지 parsing....
# 3564 번째 페이지 parsing....
# 3565 번째 페이지 parsing....
# 3566 번째 페이지 parsing....
# 3567 번째 페이지 parsing....
# 3568 번째 페이지 parsing....
# 3569 번째 페이지 parsing....
# 3570 번째 페이지 parsing....
# 3571 번째 페이지 parsing....
# 3572 번째 페이지 parsing....
# 3573 번째 페이지 parsing....
# 3574 번째 페이지 parsing....
# 3575 번째 페이지 parsing....
# 3576 번째 페이지 parsing....
# 3577 번째 페이지 parsing....
# 3578 번째 페이지 parsing....
# 3579 번째 페이지 parsing....
# 3580 번째 페이지 parsing....
# 3581 번째 페이지 parsing....
# 3582 번째 페이지 parsing....
# 3583 번째 페이지 parsing....
# 3584 번째 페이지 parsing....
# 3585 번째 페이지 parsing....
# 3586 번째 페이지 parsing....
# 3587 번째 페이지 parsing....
# 3588 번째 페이지 parsing....
# 3589 번째 페이지 parsing....
# 3590 번째 페이지 parsing....
# 3591 번째 페이지 parsing....
# 3592 번째 페이지 parsing....
# 3593 번째 페이지 parsing....
# 3594 번째 페이지 parsing....
# 3595 번째 페이지 parsing....
# 3596 번째 페이지 parsing....
# 3597 번째 페이지 parsing....
# 3598 번째 페이지 parsing....
# 3599 번째 페이지 parsing....
# 3600 번째 페이지 parsing....
# 3601 번째 페이지 parsing....
# 3602 번째 페이지 parsing....
# 3603 번째 페이지 parsing....
# 3604 번째 페이지 parsing....
# 3605 번째 페이지 parsing....
# 3606 번째 페이지 parsing....
# 3607 번째 페이지 parsing....
# 3608 번째 페이지 parsing....
# 3609 번째 페이지 parsing....
# 3610 번째 페이지 parsing....
# 3611 번째 페이지 parsing....
# 3612 번째 페이지 parsing....
# 3613 번째 페이지 parsing....
# 3614 번째 페이지 parsing....
# 3615 번째 페이지 parsing....
# 3616 번째 페이지 parsing....
# 3617 번째 페이지 parsing....
# 3618 번째 페이지 parsing....
# 3619 번째 페이지 parsing....
# 3620 번째 페이지 parsing....
# 3621 번째 페이지 parsing....
# 3622 번째 페이지 parsing....
# 3623 번째 페이지 parsing....
# 3624 번째 페이지 parsing....
# 3625 번째 페이지 parsing....
# 3626 번째 페이지 parsing....
# 3627 번째 페이지 parsing....
# 3628 번째 페이지 parsing....
# 3629 번째 페이지 parsing....
# 3630 번째 페이지 parsing....
# 3631 번째 페이지 parsing....
# 3632 번째 페이지 parsing....
# 3633 번째 페이지 parsing....
# 3634 번째 페이지 parsing....
# 3635 번째 페이지 parsing....
# 3636 번째 페이지 parsing....
# 3637 번째 페이지 parsing....
# 3638 번째 페이지 parsing....
# 3639 번째 페이지 parsing....
# 3640 번째 페이지 parsing....
# 3641 번째 페이지 parsing....
# 3642 번째 페이지 parsing....
# 3643 번째 페이지 parsing....
# 3644 번째 페이지 parsing....
# 3645 번째 페이지 parsing....
# 3646 번째 페이지 parsing....
# 3647 번째 페이지 parsing....
# 3648 번째 페이지 parsing....
# 3649 번째 페이지 parsing....
# 3650 번째 페이지 parsing....
# 3651 번째 페이지 parsing....
# 3652 번째 페이지 parsing....
# 3653 번째 페이지 parsing....
# 3654 번째 페이지 parsing....
# 3655 번째 페이지 parsing....
# 3656 번째 페이지 parsing....
# 3657 번째 페이지 parsing....
# 3658 번째 페이지 parsing....
# 3659 번째 페이지 parsing....
# 3660 번째 페이지 parsing....
# 3661 번째 페이지 parsing....
# 3662 번째 페이지 parsing....
# 3663 번째 페이지 parsing....
# 3664 번째 페이지 parsing....
# 3665 번째 페이지 parsing....
# 3666 번째 페이지 parsing....
# 3667 번째 페이지 parsing....
# 3668 번째 페이지 parsing....
# 3669 번째 페이지 parsing....
# 3670 번째 페이지 parsing....
# 3671 번째 페이지 parsing....
# 3672 번째 페이지 parsing....
# 3673 번째 페이지 parsing....
# 3674 번째 페이지 parsing....
# 3675 번째 페이지 parsing....
# 3676 번째 페이지 parsing....
# 3677 번째 페이지 parsing....
# 3678 번째 페이지 parsing....
# 3679 번째 페이지 parsing....
# 3680 번째 페이지 parsing....
# 3681 번째 페이지 parsing....
# 3682 번째 페이지 parsing....
# 3683 번째 페이지 parsing....
# 3684 번째 페이지 parsing....
# 3685 번째 페이지 parsing....
# 3686 번째 페이지 parsing....
# 3687 번째 페이지 parsing....
# 3688 번째 페이지 parsing....
# 3689 번째 페이지 parsing....
# 3690 번째 페이지 parsing....
# 3691 번째 페이지 parsing....
# 3692 번째 페이지 parsing....
# 3693 번째 페이지 parsing....
# 3694 번째 페이지 parsing....
# 3695 번째 페이지 parsing....
# 3696 번째 페이지 parsing....
# 3697 번째 페이지 parsing....
# 3698 번째 페이지 parsing....
# 3699 번째 페이지 parsing....
# 3700 번째 페이지 parsing....
# 3701 번째 페이지 parsing....
# 3702 번째 페이지 parsing....
# 3703 번째 페이지 parsing....
# 3704 번째 페이지 parsing....
# 3705 번째 페이지 parsing....
# 3706 번째 페이지 parsing....
# 3707 번째 페이지 parsing....
# 3708 번째 페이지 parsing....
# 3709 번째 페이지 parsing....
# 3710 번째 페이지 parsing....
# 3711 번째 페이지 parsing....
# 3712 번째 페이지 parsing....
# 3713 번째 페이지 parsing....
# 3714 번째 페이지 parsing....
# 3715 번째 페이지 parsing....
# 3716 번째 페이지 parsing....
# 3717 번째 페이지 parsing....
# 3718 번째 페이지 parsing....
# 3719 번째 페이지 parsing....
# 3720 번째 페이지 parsing....
# 3721 번째 페이지 parsing....
# 3722 번째 페이지 parsing....
# 3723 번째 페이지 parsing....
# 3724 번째 페이지 parsing....
# 3725 번째 페이지 parsing....
# 3726 번째 페이지 parsing....
# 3727 번째 페이지 parsing....
# 3728 번째 페이지 parsing....
# 3729 번째 페이지 parsing....
# 3730 번째 페이지 parsing....
# 3731 번째 페이지 parsing....
# 3732 번째 페이지 parsing....
# 3733 번째 페이지 parsing....
# 3734 번째 페이지 parsing....
# 3735 번째 페이지 parsing....
# 3736 번째 페이지 parsing....
# 3737 번째 페이지 parsing....
# 3738 번째 페이지 parsing....
# 3739 번째 페이지 parsing....
# 3740 번째 페이지 parsing....
# 3741 번째 페이지 parsing....
# 3742 번째 페이지 parsing....
# 3743 번째 페이지 parsing....
# 3744 번째 페이지 parsing....
# 3745 번째 페이지 parsing....
# 3746 번째 페이지 parsing....
# 3747 번째 페이지 parsing....
# 3748 번째 페이지 parsing....
# 3749 번째 페이지 parsing....
# 3750 번째 페이지 parsing....
# 3751 번째 페이지 parsing....
# 3752 번째 페이지 parsing....
# 3753 번째 페이지 parsing....
# 3754 번째 페이지 parsing....
# 3755 번째 페이지 parsing....
# 3756 번째 페이지 parsing....
# 3757 번째 페이지 parsing....
# 3758 번째 페이지 parsing....
# 3759 번째 페이지 parsing....
# 3760 번째 페이지 parsing....
# 3761 번째 페이지 parsing....
# 3762 번째 페이지 parsing....
# 3763 번째 페이지 parsing....
# 3764 번째 페이지 parsing....
# 3765 번째 페이지 parsing....
# 3766 번째 페이지 parsing....
# 3767 번째 페이지 parsing....
# 3768 번째 페이지 parsing....
# 3769 번째 페이지 parsing....
# 3770 번째 페이지 parsing....
# 3771 번째 페이지 parsing....
# 3772 번째 페이지 parsing....
# 3773 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['와리천재(gusw****)',
#   '이게 진짜 명작이다.... 보기전, 대만영화라서 편견이 있었는데, 완전히 반성한다....',
#   '10',
#   '2443',
#   '117',
#   datetime.datetime(2013, 7, 5, 21, 59),
#   0],
#  ['바나나(8745****)',
#   '몇번봐도 너무 재미씀',
#   '10',
#   '1725',
#   '75',
#   datetime.datetime(2013, 6, 15, 12, 35),
#   0],
#  ['별(lya9****)',
#   '이런 영화 다시 안나오나..?',
#   '10',
#   '1566',
#   '64',
#   datetime.datetime(2013, 7, 6, 14, 0),
#   0],
#  ['김민영(myki****)',
#   '너무너무좋아...',
#   '10',
#   '1177',
#   '60',
#   datetime.datetime(2013, 7, 24, 21, 59),
#   0],
#  ['하냥(chlt****)',
#   '영화 전문가들은 대체 어느영화에 10점을 줄지 궁금하다',
#   '10',
#   '1069',
#   '65',
#   datetime.datetime(2013, 7, 21, 21, 44),
#   0],
#  ['충격과공포의 킬(adki****)',
#   '짱!',
#   '10',
#   '913',
#   '54',
#   datetime.datetime(2013, 7, 24, 19, 50),
#   0],
#  ['123(alsw****)',
#   '주걸륜 진짜 천재인것 같아',
#   '10',
#   '854',
#   '37',
#   datetime.datetime(2013, 7, 1, 15, 26),
#   0],
#  ['하서니이(pjj0****)',
#   '명작을 지금 봐서 미안할 정도.',
#   '10',
#   '686',
#   '30',
#   datetime.datetime(2013, 7, 5, 17, 5),
#   0],
#  ['몽땅연필(bbgo****)',
#   '진짜....와....,...이건진짜  말로표현할수가없다진짜..주걸륜이너무대단하다는생각밖에는..',
#   '10',
#   '594',
#   '30',
#   datetime.datetime(2013, 6, 15, 4, 29),
#   0],
#  ['이구(tjfx****)',
#   '나만 이영화 무서웠음? 마지막에 무서움',
#   '10',
#   '578',
#   '54',
#   datetime.datetime(2013, 9, 17, 4, 14),
#   0],
#  ['onem****',
#   '이제서야 보다니..주걸륜이 감독이었어 ~우왕',
#   '10',
#   '489',
#   '28',
#   datetime.datetime(2013, 7, 24, 14, 45),
#   0],
#  ['1221(heea****)',
#   '명불허전 최고의 영화입니다 피아노배틀 장면만 알고 전체적인 내용은 몰랐는데 그 시대에 이런 영화라니.. 10점도 모자랍ㄴ다',
#   '10',
#   '356',
#   '16',
#   datetime.datetime(2015, 5, 7, 11, 51),
#   '관람객'],
#  ['하루(kdy3****)',
#   '정말 재밌다. 아름다운 피아노 그리고 샤오위',
#   '9',
#   '261',
#   '19',
#   datetime.datetime(2013, 7, 24, 12, 22),
#   0],
#  ['sonh****',
#   '클라스는 영원하다... 계륜미 갓',
#   '10',
#   '251',
#   '13',
#   datetime.datetime(2015, 5, 7, 22, 46),
#   '관람객'],
#  ['료코냥(rhd1****)',
#   '자주 느끼는 거지만 기자.평론가들은 참 영화 볼줄을 모르네요.',
#   '10',
#   '266',
#   '40',
#   datetime.datetime(2013, 7, 21, 4, 15),
#   0],
#  ['testamatta(test****)',
#   '내가 본 영화중에 최고',
#   '10',
#   '231',
#   '20',
#   datetime.datetime(2013, 7, 24, 4, 12),
#   0],
#  ['회원가입(flqp****)',
#   '존나 삘찔짯네 마지막에 왤케슬프냐..',
#   '10',
#   '217',
#   '17',
#   datetime.datetime(2013, 6, 15, 21, 57),
#   0],
#  ['306(kkps****)',
#   '중국어 배우기 전에도 감동이었는데 중국어 알아들으면서 보니까 더욱 감동...계륜미 진짜 청순하고 이쁘다',
#   '10',
#   '175',
#   '6',
#   datetime.datetime(2013, 7, 1, 15, 40),
#   0],
#  ['아란(aran****)',
#   '여운이 많이남는영화..',
#   '10',
#   '167',
#   '9',
#   datetime.datetime(2013, 7, 17, 5, 17),
#   0],
#  ['dori****',
#   '어렸을 때 보고 이해안되서 다시봤는데 소름끼침..',
#   '10',
#   '170',
#   '13',
#   datetime.datetime(2013, 6, 16, 21, 12),
#   0],
#  ['카스온라인(shjl****)',
#   '개 재미있음',
#   '10',
#   '161',
#   '11',
#   datetime.datetime(2013, 6, 16, 20, 5),
#   0],
#  ['tnak****',
#   '다시봐도 후회하지 않는 영화',
#   '10',
#   '155',
#   '8',
#   datetime.datetime(2015, 5, 8, 16, 30),
#   '관람객'],
#  ['김윤희(yoon****)',
#   '영상미, 줄거리, 연기, 연주 모두가 잘 어우러진 청춘음악영화',
#   '10',
#   '133',
#   '7',
#   datetime.datetime(2015, 5, 7, 22, 53),
#   '관람객'],
#  ['린친(ligh****)',
#   '감독한 주걸륜이 참 대단하다는 생각.',
#   '10',
#   '131',
#   '6',
#   datetime.datetime(2013, 11, 29, 9, 12),
#   0],
#  ['muso****',
#   '피아노 배틀 장면 건반 5개로 연주함...그 외에는 사랑이야기..개인적으로 주인공의 천재성을 좀 더 각인 시켰더라면...',
#   '9',
#   '142',
#   '18',
#   datetime.datetime(2013, 7, 1, 14, 19),
#   0],
#  ['ㅇㅇ(spct****)',
#   '고등학교 때 봤던 영화를 결혼하고 싶은 남자와 다시 봤습니다. 좋았어요.',
#   '10',
#   '126',
#   '12',
#   datetime.datetime(2015, 5, 18, 22, 39),
#   '관람객'],
#  ['차붐(rud8****)',
#   '최고입니다.',
#   '10',
#   '116',
#   '7',
#   datetime.datetime(2013, 7, 26, 15, 13),
#   0],
#  ['burgundy(sexy****)',
#   '아련하고멋진영화.계륜미 최고~',
#   '10',
#   '106',
#   '8',
#   datetime.datetime(2015, 5, 9, 21, 30),
#   '관람객'],
#  ['kj54****',
#   '스토리가 너무 애절하고 재밋당...',
#   '10',
#   '101',
#   '6',
#   datetime.datetime(2013, 6, 16, 22, 9),
#   0],
#  ['피크닉(rokn****)',
#   '언제까지나 말할 수 없는 비밀',
#   '10',
#   '88',
#   '5',
#   datetime.datetime(2015, 5, 10, 19, 43),
#   '관람객'],
#  ['Jee yong(chic****)',
#   '너무감동적이네요..오늘처음봤어요 5번정도봤는데 이런영화안나오나요?ㅠㅠ',
#   '10',
#   '96',
#   '13',
#   datetime.datetime(2013, 7, 7, 0, 21),
#   0],
#  ['김주현(kjhy****)',
#   '건축학개론보다 재밌는듯',
#   '10',
#   '86',
#   '9',
#   datetime.datetime(2015, 4, 19, 20, 12),
#   0],
#  ['정승환자(s112****)',
#   '이거보고 울었다',
#   '10',
#   '76',
#   '7',
#   datetime.datetime(2013, 6, 9, 11, 52),
#   0],
#  ['비짱(ksa1****)',
#   '흐흐 피아노 너무잘치는듯',
#   '10',
#   '73',
#   '12',
#   datetime.datetime(2013, 6, 15, 8, 31),
#   0],
#  ['Human(phre****)',
#   '추억의 영화 / 계속 다시 보고 싶은 영화',
#   '10',
#   '60',
#   '7',
#   datetime.datetime(2015, 5, 9, 19, 54),
#   '관람객'],
#  ['qhrm****',
#   '열번 봐라 스무번 봐라 백번봐라',
#   '10',
#   '61',
#   '10',
#   datetime.datetime(2013, 7, 18, 18, 37),
#   0],
#  ['발렌시아(vcvk****)',
#   '최고의 영화',
#   '10',
#   '56',
#   '8',
#   datetime.datetime(2013, 7, 20, 22, 50),
#   0],
#  ['삐삐(dhl0****)',
#   '잔잔하게 좋은 피아노곡을 들으며 푹 빠져봤네요..',
#   '9',
#   '50',
#   '9',
#   datetime.datetime(2015, 5, 9, 14, 48),
#   '관람객'],
#  ['ridl****',
#   '이런 영화 또 없나',
#   '10',
#   '44',
#   '7',
#   datetime.datetime(2013, 7, 3, 22, 55),
#   0],
#  ['coth****',
#   '몇번이나 본영화지만 스크린으로 보니 더한 감동이...',
#   '9',
#   '48',
#   '11',
#   datetime.datetime(2015, 5, 7, 16, 50),
#   '관람객'],
#  ['사각김밥(qq15****)',
#   '진짜 최고',
#   '10',
#   '44',
#   '8',
#   datetime.datetime(2013, 7, 20, 22, 12),
#   0],
#  ['rudg****',
#   '거짓말안하고 자꾸생각나서 열번이상은본거같아요 평점같은거 안남기는데.. 너무 좋은영화예요 세번봤을땐까진 눈물이났었는데 이젠 한장면 한장면 너무 소중해서 더욱더집중하게되네요 꼭보시길바랄께요~ 말이필요없는영화예요',
#   '10',
#   '45',
#   '9',
#   datetime.datetime(2013, 7, 31, 12, 29),
#   0],
#  ['sk(a462****)',
#   '계륜미와주걸륜의리즈시절이겹쳣을때 탄생한영화 평범한 로맨틱영화인줄알앗더니만 반전이 영화를 흥미롭게 만들엇다 마지막 엔딩을 볼때즈음엔 누구나아련한감정을 느낄것이다. 이 영화를 3번봣는데 첫번째엔반전에두번째엔복선에 세번째...',
#   '10',
#   '42',
#   '8',
#   datetime.datetime(2014, 6, 15, 2, 56),
#   0],
#  ['sg14****',
#   '말이필요없다',
#   '10',
#   '39',
#   '9',
#   datetime.datetime(2013, 7, 21, 21, 20),
#   0],
#  ['golf****',
#   '근데 현재의 아버지는 아들을 잃었네...',
#   '10',
#   '32',
#   '3',
#   datetime.datetime(2019, 8, 7, 15, 12),
#   0],
#  ['naja****',
#   '진짜....제가너무사랑해요 이영화...진짜루...정말로...꼭보세요 이건...',
#   '10',
#   '36',
#   '11',
#   datetime.datetime(2013, 7, 18, 3, 11),
#   0],
#  ['sky angel(skya****)',
#   '잘짜인시나리오와아름다운멜로디,숨겨진비밀과그의대한궁금증때문에영화에더욱더심취하게한다.허나주걸륜의연기가신인배우처럼보일정도로경직되고어색했다.연기는계륜미가돋보인다.영화에숨겨져있는비밀의짜임의풍미가,남다른기품과케이스로모두를빠지게...',
#   '9',
#   '40',
#   '17',
#   datetime.datetime(2013, 7, 17, 1, 56),
#   0],
#  ['euns****',
#   '피아노 배틀 장면을 이 영화의 명장면으로 꼽는 사람은 이 영화를 제대로 안본거임',
#   '10',
#   '21',
#   '1',
#   datetime.datetime(2019, 10, 10, 19, 11),
#   0],
#  ['상처는받았지만그냥자(ooo0****)',
#   '교사가 이렇게 중요합니다. 딴사람들한테 말하지 말래놓고 학생들한테까지 다말함ㅋㅋ #교육영화',
#   '7',
#   '24',
#   '4',
#   datetime.datetime(2019, 6, 6, 23, 34),
#   0],
#  ['rlag****',
#   '미쳣다 이게 영화인가? 내생에 최고의 영화야 진짜..미쳣어...나 원래 절대 영화든 드라마든 2번 안보는데 이건 2번보고 2번다 눈물흘림 ㅋㅋㅋ 미친영화야 이건 ....',
#   '10',
#   '26',
#   '6',
#   datetime.datetime(2016, 1, 14, 15, 12),
#   0],
#  ['봄추니(beom****)',
#   '베이징 올림픽이 배드민턴 열풍을 일으켰다면 이 영화는 보는 사람으로 하여금 피아노홀릭을 일으킨 최고의 영화네요',
#   '10',
#   '27',
#   '9',
#   datetime.datetime(2013, 6, 29, 13, 33),
#   0],
#  ['협회위원장(girl****)',
#   '2008년까지 추잡스런 평점테러조작을 당했음에도 시간이 지날수록 만점에가까운 점수를 받는다는건 그만큼 이영화가 시간에 빛이바래지 않는 명작이란 반증이겠지. 정직한 네티즌들이 그걸 증명주고 있다.',
#   '10',
#   '29',
#   '13',
#   datetime.datetime(2016, 3, 1, 3, 23),
#   0],
#  ['그냥이이(rkdg****)',
#   '23살에보고 35에 다시 봐도 역시 최고의 영화입니다',
#   '10',
#   '16',
#   '2',
#   datetime.datetime(2019, 8, 3, 1, 16),
#   0],
#  ['무지개(hjw0****)',
#   '누가 뭐래도 내 인생 최고의 영화들중하나ㅜㅜ',
#   '10',
#   '27',
#   '13',
#   datetime.datetime(2013, 7, 9, 0, 9),
#   0],
#  ['명궁(s112****)',
#   '아주아주 재밌고 안동중앙시네마 분위기 너무좋아요',
#   '10',
#   '23',
#   '10',
#   datetime.datetime(2015, 5, 11, 8, 10),
#   '관람객'],
#  ['그갸갸갹(abbe****)',
#   '그렇게 열심히 뛰어간 아빠는... 너무해',
#   '8',
#   '11',
#   '0',
#   datetime.datetime(2019, 8, 21, 0, 28),
#   0],
#  ['슈인(love****)',
#   '두번봤는데, 역시 재밌어요.. 사랑하는 사람을 위해 그..곳으로 ..멋지당',
#   '10',
#   '25',
#   '15',
#   datetime.datetime(2013, 6, 17, 1, 3),
#   0],
#  ['민(89mi****)',
#   '이게 1등영화 무조건 10점!',
#   '10',
#   '28',
#   '18',
#   datetime.datetime(2013, 7, 22, 18, 57),
#   0],
#  ['zaro****',
#   '10점도 모자란 영화. 원작 주걸륜 감독 주걸륜 주연 주걸륜. 다해먹고 대박친 영화',
#   '10',
#   '9',
#   '1',
#   datetime.datetime(2019, 9, 15, 1, 16),
#   0],
#  ['이세영(dltp****)',
#   '주걸륜은 진짜 천재인듯..어떻게 이런 생각을 했는지 심지어 연기까지 잘하고!영화 처음부터 마지막까지 감동과 반전을 동시에 주는 영화는 말할 수 없는 비밀밖에 없는거 같다..ㅠ한번쯤은 꼭 봐야 할 영화!!!!사실 몇번...',
#   '10',
#   '10',
#   '2',
#   datetime.datetime(2019, 5, 12, 23, 17),
#   0],
#  ['ttyj****',
#   '최고',
#   '10',
#   '26',
#   '18',
#   datetime.datetime(2013, 7, 15, 4, 48),
#   0],
#  ['꿔모꿔모(ymj6****)',
#   '나 샤오위야 너는 나를 사랑하니? 나는 너를 사랑해',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2017, 8, 12, 0, 3),
#   0],
#  ['은하철도(soov****)',
#   '샤오위의 미소만으로도 멋진 영화^^~',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2016, 7, 19, 1, 0),
#   0],
#  ['박하향(bboo****)',
#   '아빠가 제일 불쌍해ㅜㅜ 이제야 이런 명작을 보다니',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2018, 4, 15, 16, 40),
#   0],
#  ['쪼르르(love****)',
#   '이 영화 4년전 처음 봤을때 정말 충격의 도가니였는데..ㅠ 이 영화때문에 대만여행을 하게 됐고, 담강중학교,진리대학,단수이에 가서 영화의 여운을 즐겼다. 몇번을 봐도 재미있는 영화..강추!!!',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2019, 6, 19, 14, 24),
#   0],
#  ['다큰공룡둘리(mu02****)',
#   '완전 감동이다~;;  다시봐도 계륜미 짱',
#   '10',
#   '8',
#   '2',
#   datetime.datetime(2018, 11, 28, 0, 32),
#   0],
#  ['myde****',
#   '몇 번을 봐도 질리지 않는영화..  주인공들과 음악과 배경이 어우러져 더할 나위 없이 아름다운 영화입니다.  주걸륜의 매력이 만퍼센트 발휘된 영화.. 정말 명작입니다',
#   '10',
#   '18',
#   '12',
#   datetime.datetime(2015, 12, 27, 14, 49),
#   '관람객'],
#  ['jeya****',
#   '요즘 이터널 선샤인, 말할수없는비밀같은 명작들 다시해주는거,ㅡ 점점 더 문화인들이 많아진다는뜻이겠지, 나와 같은 감성을 가진 사람들이 많다는게 그리고 이렇게 공감할수있는 영화들을 만들어주심에 감사',
#   '10',
#   '20',
#   '14',
#   datetime.datetime(2015, 12, 23, 9, 5),
#   '관람객'],
#  ['매니 파퀴아오(ldy2****)',
#   '영화는 기대를 하고 보면 안되는듯~',
#   '5',
#   '21',
#   '15',
#   datetime.datetime(2018, 9, 8, 2, 22),
#   0],
#  ['넥셔스이글(alsw****)',
#   '내가본 대만영화중 단연코 1위다',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2018, 2, 11, 9, 21),
#   0],
#  ['황상훈(sktm****)',
#   '명작은 역시 명작이네요재미잇게잘보았습미다~!',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2016, 11, 28, 23, 11),
#   '관람객'],
#  ['리리코(alsd****)',
#   "재개봉으로 봄.. 초번에 오글거리는 대사와 장면에 '이 영화가 왜 유명하단 거지...?'러는 생각으로 보다가 후반부에 눈물울 흘렸음. 슬프면서 가슴을 먹먹하게 만드는 (+ 하이틴스러움) 영화",
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2016, 11, 28, 19, 22),
#   '관람객'],
#  ['이브(japo****)',
#   '피아노배틀씬이 유명해서 그것만 봤는데 다시보니 정말 명작임..',
#   '10',
#   '5',
#   '0',
#   datetime.datetime(2016, 7, 22, 13, 24),
#   0],
#  ['psh0****',
#   '피아노 곡만 알고 있던 영화 ! 봐야지 봐야지 하다가 오늘 드디어 봤는데 정말 감동적이다 마지막에 열린 결말이 더 여운을 남겨준다 ..',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 12, 19, 22, 40),
#   0],
#  ['오모리찌개(kkon****)',
#   '대만영화란 선입견때문에 지금껏 안본 내가 후회스럽고 땅을치고 후회됨..ㅠ 계륜미 너무 예뻤고 주걸륜은 외모가 아니라 연기와 피아노 실력과 연출력이 외모를 다 커버치고도 남는다..',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2019, 6, 19, 13, 38),
#   0],
#  ['건담(alex****)',
#   '졸업식날까지 적지않은 시간에 좋아하는 사람을 맘대로  볼수없다는것은 안타깝다. 죽음을 맞이할때까지 자기가 아닌 다른여인을  좋아한다는 오해를 풀지 못했다는것 또한 매우 슬프다. 난 남주 아버지한테 화나고 여주 엄마는...',
#   '10',
#   '6',
#   '1',
#   datetime.datetime(2016, 8, 25, 1, 24),
#   0],
#  ['박현아(prin****)',
#   '영화를 처음 봤을땐 보이지 않던 그녀의 슬픈 표정. 왜 영화를 두번 보는지 알게 되었다',
#   '10',
#   '8',
#   '3',
#   datetime.datetime(2018, 12, 22, 22, 47),
#   0],
#  ['최군(cks5****)',
#   '새벽에보고누웠는데잠을청할수가없었다...감동과여운때문에...',
#   '10',
#   '21',
#   '16',
#   datetime.datetime(2014, 3, 15, 22, 17),
#   0],
#  ['Qwer(whtn****)',
#   '몇년전에 말할 수 없는 비밀 제목만 보고 야한영화인 줄 알고 보려했던 내가 너무 한심하고 반성하게 만든영화... 진짜 명작 꼭 보세요!!!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 2, 24, 21, 6),
#   0],
#  ['kaka****',
#   '영화의 영상미와 분위기 색감사운드트랙도 다 너무 좋아요...주는 느낌 자체로 훌륭한 영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2018, 2, 24, 17, 11),
#   0],
#  ['dsfe2342342(rlaw****)',
#   '여운이 남는 영화. 여러번 봤다',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 10, 6, 23, 47),
#   0],
#  ['전성빈(jsb0****)',
#   '최고다 진짜로 10년전에나온 스토리라곤 믿기지않는다 ㄹㅇ 안봤으면 보는거추천해요 말이필요없고 말로 표현할수가없음',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2017, 9, 11, 18, 29),
#   0],
#  ['강안남자(thde****)',
#   '가슴이 찡하고, 울림이 있고 , 여운이 많이 남는~~정말 진정한  사랑이야기입니다.계륜미 정말  짱입니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 8, 28, 1, 25),
#   0],
#  ['백균(yuna****)',
#   '아 진짜 재밌다....',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 8, 27, 2, 54),
#   0],
#  ['fullest(indi****)',
#   '내용도 재밌는데  계륜미의 단발머리!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 7, 26, 16, 8),
#   0],
#  ['spsl****',
#   '가슴이 먹먹해지는 영화입니다.',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 7, 19, 15, 51),
#   0],
#  ['흥렁이(w2g4****)',
#   '완전 추천합니다 !피아노 선율에 빠져보세요',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 7, 19, 15, 9),
#   0],
#  ['람지(aesi****)',
#   '또 보고싶은 영화! 최고!!',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 7, 19, 13, 49),
#   0],
#  ['윤지혜(a012****)',
#   '8년이 지난 아직까지 내 인생 최고의 영화',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 6, 14, 12, 39),
#   0],
#  ['짓창인생(ikai****)',
#   '명작이다.    10자10자10자10자',
#   '10',
#   '4',
#   '0',
#   datetime.datetime(2016, 5, 2, 16, 34),
#   0],
#  ['high****',
#   '음악만 좋네...',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2008, 10, 7, 7, 16),
#   0],
#  ['biwo****',
#   '최고는 아니다!',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2008, 9, 15, 9, 13),
#   0],
#  ['fort****',
#   '평점 잘매겨도 7점짜리 영화다 너무 과장포장 됐음',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2008, 9, 14, 16, 42),
#   0],
#  ['adam****',
#   '반개도 아깝다....이 유치뽕짝은 뭐냐.........--',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2008, 8, 5, 15, 56),
#   0],
#  ['onmo****',
#   '말도 안되는 비밀',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2008, 7, 2, 13, 50),
#   0],
#  ['enly****',
#   '두 주인공의 음악성, 볼거리 들을거리는 좋았으나, 너무 유치한 반전의 연속....',
#   '1',
#   '4',
#   '0',
#   datetime.datetime(2008, 6, 21, 11, 1),
#   0],
#  ['네이션뉴스(nati****)',
#   '저도 이런 사랑하고 싶네요',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2019, 7, 20, 22, 27),
#   0],
#  ['포항갈치(kalb****)',
#   'ㅅㅂ 미쳤다 와 방금 ocn으로 봤는데 너무 재밌어서 욕밖에 안나온다',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2018, 11, 28, 0, 24),
#   0],
#  ['Claire(kei0****)',
#   '5번정도 봤는데 또봐도...감동ㅠ흑흑.. 너무너무 추억돋아서 좋았어요...ㅠ',
#   '10',
#   '6',
#   '2',
#   datetime.datetime(2015, 5, 17, 20, 19),
#   '관람객'],
#  ['jesu****',
#   '좋긴한데 평점이 뻥이 넘 심함..',
#   '1',
#   '6',
#   '2',
#   datetime.datetime(2008, 10, 8, 15, 30),
#   0],
#  ['상표(blis****)',
#   '아... 훌륭합니다.',
#   '10',
#   '7',
#   '3',
#   datetime.datetime(2015, 9, 11, 15, 6),
#   '관람객'],
#  ['김미정(jade****)',
#   '아름다운 판타지영화. 피아노선율이 영화가 끝나고도 잔잔히 남는 영화.',
#   '8',
#   '15',
#   '11',
#   datetime.datetime(2015, 10, 20, 19, 48),
#   '관람객'],
#  ['KCa(jkk9****)',
#   '진짜 명작이다 근데 선생님이 큰실수 했네.. 그걸 처말하냐',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 5, 11, 0, 18),
#   0],
#  ['소피(morn****)',
#   '12년전 2008년에 고3때 처음 접한 영화. 당시 내 기억으론 중국어 시간에 중국어 교사가 피아노배틀을 틀어줬는데 그 뒤에 영화를 접했고한동안 반전체에 말할수 없는 비밀 신드롬이 일어나기도 했다. 반 남학생들 기본...',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2020, 5, 3, 6, 21),
#   0],
#  ['쏠(hssl****)',
#   '어찌 잊으리 또보아서 너무 좋았다 처음 볼때나 지금이나 명작이고너무 결말도 좋은 영화다 몃번을 봐도 정말 잘많든영화다 .',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2018, 11, 28, 0, 28),
#   0],
#  ['박성진(dpff****)',
#   '무엇보다 음악이 너무 좋았던 영화',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2016, 7, 28, 11, 26),
#   0],
#  ['서인영(seoi****)',
#   '그때 그 당시 사랑하던 사람과 함께 보았던, 애잔함이 마음에 남은 영화.당신도  이 영화를 다시 만나게 된다면 나에 대한 그 마음을 다시금 떠올리기를',
#   '10',
#   '3',
#   '0',
#   datetime.datetime(2016, 1, 14, 15, 1),
#   '관람객'],
#  ['dbse****',
#   '더빙으로 봐서 그런가 쓰레기던데 반전은 놀라웠찌만 그저그랬음',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 9, 15, 11, 47),
#   0],
#  ['ares****',
#   '솔직히 지나치게 평점높네요. 7-8점짜리 영화수준인데.. 평점깎아내리기 필요합니다.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 9, 15, 2, 28),
#   0],
#  ['ainn****',
#   '6점이나 7점이 적당하다. 솔직히 9점은 아니다.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 9, 15, 0, 1),
#   0],
#  ['gusw****', '굿', '1', '3', '0', datetime.datetime(2008, 8, 6, 21, 41), 0],
#  ['sina****',
#   '아름답지만.아름답지않기에',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 17, 16, 2),
#   0],
#  ['pcpc****',
#   '최고지만 최고를위해',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 17, 13, 54),
#   0],
#  ['jull****',
#   '머리만 복잡함 - -',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 16, 15, 53),
#   0],
#  ['yyc2****',
#   '별로던디~',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 15, 23, 36),
#   0],
#  ['147k****',
#   '졸작.... 왜이리 평점이 높을까?? 말도안되;;',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 15, 22, 1),
#   0],
#  ['jaso****',
#   '재미있긴한데 이렇게 등수가 놓진않아요 조작의혹',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 14, 21, 25),
#   0],
#  ['poto****',
#   '사랑을 조금이라도 해봣던 사람이라면 이딴영화에 감동먹을수가 없음',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 14, 1, 20),
#   0],
#  ['layn****',
#   '티켓 값이 아깝다 왜 평점이 이렇게 높은가',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 13, 21, 35),
#   0],
#  ['cndt****',
#   '별루..',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 13, 17, 48),
#   0],
#  ['oks5****',
#   '재미없음',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 13, 17, 47),
#   0],
#  ['tdw2****',
#   '별로...',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 13, 17, 1),
#   0],
#  ['high****',
#   '뜬금없는 판타지',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 13, 15, 22),
#   0],
#  ['s3aa****',
#   '별반개도아깝다. 아무리 영화라지만 이건 뭐 ㅡㅡ',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 12, 21, 57),
#   0],
#  ['sksk****',
#   '감동은있어 근데왜 그렇게됀건데 반전은잇어 근데왜 그런반전이나온건데',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 12, 20, 23),
#   0],
#  ['bnne****',
#   '솔직히 잼없네',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 12, 19, 47),
#   0],
#  ['rkwh****',
#   '먹어 ^^',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 12, 11, 38),
#   0],
#  ['rudt****',
#   '이건아니다',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 12, 6, 42),
#   0],
#  ['siba****', '최악', '1', '3', '0', datetime.datetime(2008, 7, 1, 12, 40), 0],
#  ['delo****',
#   '참나 이거보고 세기의 역작이란다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 1, 11, 56),
#   0],
#  ['qhaq****',
#   '반전 처음부터 예상 할수 있는..시간을 달리는 소녀+동감+어디선가 본듯한 ..지루해',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 1, 4, 0),
#   0],
#  ['pajs****',
#   '초딩들이 좋아할만한 영화',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 7, 1, 2, 31),
#   0],
#  ['8282****',
#   'OK,, but definitely not the best.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 30, 0, 16),
#   0],
#  ['marr****',
#   '이게 1등이라니.. 용납할수 없으므로...',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 29, 23, 19),
#   0],
#  ['n491****',
#   '재밌긴하다 허나 너무 띄어주는 영화인듯;;;;;',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 29, 15, 12),
#   0],
#  ['drow****',
#   '10대 소녀빨 평점이 다소 불만임 사실 상당히 민망한 영화 ^^;;',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 29, 14, 42),
#   0],
#  ['nrgr****',
#   '난 별로...',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 29, 11, 30),
#   0],
#  ['yell****',
#   '개연성이 전혀없는 스토리전개 ㅇㅇ  계륜미 얼굴빨',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 28, 23, 7),
#   0],
#  ['mgs6****',
#   '이게 왜 1위야 정말 이해가안돼.. 이건 뭐 재미도 없고 감동도없고..',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 28, 1, 58),
#   0],
#  ['izel****',
#   '하나도 공감을 못하겠고 뭐가 재미있다는건지 모르겠다.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 27, 11, 54),
#   0],
#  ['tjdw****',
#   '재미없다',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 26, 16, 40),
#   0],
#  ['zigz****',
#   '볼 만은 하지만 거품',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 26, 0, 52),
#   0],
#  ['qkqh****',
#   '잼없다................................',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 24, 20, 42),
#   0],
#  ['pola****',
#   '이런영화가 평점1위라는게 대한민국 국민들의 영화수준이다.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 23, 21, 43),
#   0],
#  ['dldk****',
#   '이런 뭥미.. 평점에 낚였다. 별반개도 아까운 영화',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 23, 21, 40),
#   0],
#  ['rudf****',
#   '안봣는데..그냥너무높으니깐내리고싶다..',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 22, 20, 56),
#   0],
#  ['ehrr****',
#   '평점 심한듯.... 솔직히 지루했음...어디까지나 주관적..',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 22, 19, 1),
#   0],
#  ['wjdg****',
#   '정말 이렇게 높은건 이해가 안된다.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 21, 14, 43),
#   0],
#  ['skdl****',
#   '난 그닥 이었었다 피아노만 잘치던데',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 21, 12, 24),
#   0],
#  ['kin1****',
#   '솔직히 재미없어',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 21, 11, 54),
#   0],
#  ['ekzm****',
#   '솔직히 10점은 아니라고 생각한다. 대체 뭐에 이리 열광하는지',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 21, 11, 38),
#   0],
#  ['rkdt****',
#   '별로엿는데;;',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 19, 11, 39),
#   0],
#  ['asd6****',
#   '이런 지겨운 사랑 이야기가 왜 평점이 이렇게 높은지 이해가 않됨.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 19, 7, 23),
#   0],
#  ['tris****',
#   '어디서 본 듯 한 장면들만 넘쳐나던데 ㅋㅋㅋㅋㅋ',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 18, 4, 34),
#   0],
#  ['yh85****',
#   '이게왜이리 평점이높나요??어이없네',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 17, 13, 3),
#   0],
#  ['sdsh****',
#   '이게 어떻게 영화중 평점이 일위란말인가',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 15, 17, 8),
#   0],
#  ['kimj****',
#   '8.5점이딱맞는 정도의 영화',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 15, 14, 19),
#   0],
#  ['bail****',
#   '팬들이 다른 명작영화에 평점깎는 짓이 무개념이라 깎는다. 영화자체는 한 8-9점.',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 15, 2, 30),
#   0],
#  ['vict****',
#   '내용에 비해 평점이 너무 높다 ㅡㅡ 지금 만나러 갑니다가 훨 재밌음',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 15, 0, 3),
#   0],
#  ['par4****',
#   '이게 왜 1위인지..-_- 완전 어이없네요',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 14, 0, 45),
#   0],
#  ['your****', '재미업음', '1', '3', '0', datetime.datetime(2008, 6, 12, 12, 9), 0],
#  ['sena****',
#   '피아니스트의 전설중 피아노 배틀씬 그대로 베낌 ㅋㅋ',
#   '1',
#   '3',
#   '0',
#   datetime.datetime(2008, 6, 11, 5, 22),
#   0],
#  ['국밥마녀(mk20****)',
#   '<로맨스,판타지,ost>    환상의 3중주',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2019, 11, 14, 0, 0),
#   0],
#  ['유유자적(cnxn****)',
#   '스토리 개연성이 약간 떨어짐',
#   '8',
#   '4',
#   '1',
#   datetime.datetime(2019, 10, 14, 21, 57),
#   0],
#  ['twin****',
#   '영화관에서 못 본게 후회된다...ㅠ여운이 많이 남는 또 보고 싶은 영화~',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2019, 6, 21, 7, 28),
#   0],
#  ['ㅊ(haye****)',
#   '이거 안본사람 없게해주세요 흠잡을데가 없는 영화 개꿀잼',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2019, 4, 28, 18, 43),
#   0],
#  ['냥이(ddon****)',
#   '이건 십점 줘도 됨 로맨스 안좋아하는데 로맨스 중 정말 재밌게 본 영화 중 하나몰입도 최고',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 11, 28, 1, 15),
#   0],
#  ['cho1****',
#   '하... 이영화 다보고 1시간동안 마음이 먹먹하네요 하..',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 4, 22, 6, 24),
#   0],
#  ['서갱(4422****)',
#   '갓띵영화입니다  최고였어요',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 4, 15, 6, 48),
#   0],
#  ['칼날선생(bone****)',
#   '시대를 너무 앞서간 영화~~10점도 모자르다~',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 3, 24, 19, 22),
#   0],
#  ['햇살소년(wjdg****)',
#   '본지 1년은 됐는데 아직도 여운이...',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 3, 21, 10, 40),
#   0],
#  ['오이(rich****)',
#   '너무 유명한 피아노 배틀 영상을보고 찾아본 영화 2007년 영화지만 영화의 내용과 결말을 모르고 볼수있던게 참 다행이다',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2018, 3, 17, 6, 25),
#   0],
#  ['scho****',
#   '음악이 매혹적이며 첫사랑의 풋풋함이 느껴져서 좋다',
#   '9',
#   '4',
#   '1',
#   datetime.datetime(2016, 8, 27, 21, 18),
#   '관람객'],
#  ['응찌(pom_****)',
#   '몇번봐도 소름돋는영화..이런영화또 안나오나..',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2016, 7, 24, 15, 37),
#   '관람객'],
#  ['유니콘(kkyy****)',
#   '말할수없는 비밀2도 나왓으면좋겠다',
#   '10',
#   '4',
#   '1',
#   datetime.datetime(2015, 7, 2, 0, 22),
#   0],
#  ['yuii****',
#   '너무 끼워맞춤',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 10, 17, 22, 56),
#   0],
#  ['zlrm****',
#   '솔직히 저정도 평점은 아니에요.앞부분 전개는 상당히 지루해요 뒷심 영화입니다.',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 9, 14, 9, 3),
#   0],
#  ['dudr****',
#   '이 평점 말도 안됨',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 8, 6, 15, 45),
#   0],
#  ['fjqm****',
#   '정말 구리다ㅠ 이미다 눈치쳈다 이것도 반전이라고 ㅠㅋㅋㅋ',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 8, 3, 0, 8),
#   0],
#  ['kill****',
#   '돈내고 볼수없는 비밀',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 8, 2, 21, 26),
#   0],
#  ['mega****',
#   '니들 말대로 이런영화가 순위에..',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 8, 2, 21, 1),
#   0],
#  ['blue****',
#   '모든걸 일본 영화를 그대로 따라했지만...여의치 않고 감독/주인공의 독선만 보인다',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 8, 2, 4, 47),
#   0],
#  ['okqu****',
#   '별 내용도 없는데 감성만 자극하는 그런 3류 영화',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 7, 17, 22, 53),
#   0],
#  ['inth****',
#   '괜찮은 영화지만 이 평점은 좀 과하다는 생각이',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 7, 17, 20, 42),
#   0],
#  ['kes8****',
#   '음악 빼면 시체',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 7, 13, 21, 32),
#   0],
#  ['keyr****',
#   '뻔하고 진부한 결말 역시 중국 영화는 볼 게 못 된다 보기 전에 기대한 내가 싫어진다',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 6, 26, 19, 33),
#   0],
#  ['1sel****',
#   '후아....제발 좀....이게 9점대라니 정말 문화적 쇼크',
#   '1',
#   '4',
#   '1',
#   datetime.datetime(2008, 6, 18, 18, 10),
#   0],
#  ['리네아(dusw****)',
#   '10년이 지난 지금도 말할 수 없는 비밀을 뛰어넘는 피아노 소재의 영화가 없다.',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2020, 3, 11, 4, 43),
#   '관람객'],
#  ['차수아(july****)',
#   '두번 보면 더 재미있어요.',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2018, 10, 24, 9, 32),
#   0],
#  ['포대화상미륵존여래불(baks****)',
#   '주걸륜...배우&가수&작가&감독으로써의 능력이란 소름끼칠 정도네.누가 뭐래도 이녀석의 미친 재능은 인정할수밖에 없다.복받은 놈',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2017, 12, 30, 1, 25),
#   0],
#  ['Guri Kate(anas****)',
#   '제가 좋아하는 영화 상위리스트에 언제나 있는 말할 수 없는 비밀. 몇번을 봤는지 모르겠네요! 음악이 너무 좋아요!',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2016, 4, 3, 18, 56),
#   '관람객'],
#  ['mepisto(zize****)',
#   '설레임 첫사랑 영화중 최고로 꼽는 영화',
#   '10',
#   '5',
#   '2',
#   datetime.datetime(2015, 7, 3, 12, 36),
#   '관람객'],
#  ['뀨우(ksps****)',
#   '고딩때는 진짜 재미없는 영화였는데. 6년이 지난 뒤 보니 그때의 내가 얼마나 어렸었는지 깨닫게 되네. 수많은 사람들의 입에 오르내리는 데에는 이유가 있는 거구나. OO띵작임 평점 10점이 아니라 무조건 만점을 받아야...',
#   '10',
#   '6',
#   '3',
#   datetime.datetime(2018, 4, 10, 21, 36),
#   0],
#  ['솔칭(solc****)',
#   '다시봐도 예쁘고 명작!',
#   '10',
#   '7',
#   '4',
#   datetime.datetime(2015, 11, 22, 18, 38),
#   '관람객'],
#  ['미르아이(sube****)',
#   '너무 멋있어... 스포당하고 봐서 조금 아쉽긴 했지만... 짱짱',
#   '10',
#   '7',
#   '4',
#   datetime.datetime(2015, 9, 15, 0, 16),
#   '관람객'],
#  ['민승환(minc****)',
#   '굿 너무 좋은영화인듯 이런거 더 없나 찾아볼 정도로 좋은영화',
#   '10',
#   '8',
#   '5',
#   datetime.datetime(2018, 11, 28, 0, 24),
#   0],
#  ['깜장콩(blac****)',
#   '79년의 주걸륜은 다른 사람들에겐 안 보이는 걸까?',
#   '10',
#   '8',
#   '5',
#   datetime.datetime(2018, 4, 7, 5, 12),
#   0],
#  ['즐라탄탄해(nsyn****)',
#   '확실히 예전엔 이런류의 영화가 유행했다. 저 당시에는 나름 재밌게 본 기억도 난다. 근래들어 영화를 다시 보게 되었는데 극도의 오그라듦으로 시청은 중도포기했지만, 예전의 난 참 어리고 순수했었구나.. 과거를 회상하는...',
#   '1',
#   '8',
#   '5',
#   datetime.datetime(2018, 3, 2, 16, 29),
#   0],
#  ['1기 박한결(tota****)',
#   '너무너무 좋아 ㅎㅎㅎ다시보고싶은영화',
#   '10',
#   '8',
#   '5',
#   datetime.datetime(2015, 10, 8, 15, 15),
#   '관람객'],
#  ['포인트(ksn2****)',
#   '한번 더 보고 싶을 정도로 잘 보았어요~~^^',
#   '9',
#   '8',
#   '5',
#   datetime.datetime(2015, 9, 21, 14, 55),
#   '관람객'],
#  ['아서와친구들(moon****)',
#   '10점 영화는 아니라 생각함. 처음에만 혹했지 두번 세번 볼 수 있는 영화는 아님.',
#   '1',
#   '10',
#   '7',
#   datetime.datetime(2017, 4, 9, 21, 12),
#   0],
#  ['퐈이야(wili****)',
#   '급식들을 위한영화....나이먹고 보니 정말 말같지도않는 설정...',
#   '1',
#   '10',
#   '7',
#   datetime.datetime(2016, 11, 29, 7, 5),
#   0],
#  ['dudd****',
#   '평이 거품임. 피아노 배틀은 볼만함. 막판이 정말.. 난 그녀와 함께 졸업했다? 뭐지 그럼 주걸륜은 그 시대 사람들 눈에 보인다는 거? 그 전에 여주가 망상 얘기 선생님한테 한번 했다가 완전 ㅄ 된느 것도 개억지. ...',
#   '1',
#   '11',
#   '8',
#   datetime.datetime(2018, 8, 16, 10, 15),
#   0],
#  ['Cutlas(kjs4****)',
#   '엔딩이 이게 뭐냐;;  아버지 어쩌라고 혼자가냐',
#   '1',
#   '12',
#   '9',
#   datetime.datetime(2018, 12, 28, 20, 43),
#   0],
#  ['다름(meri****)',
#   '아어 급식들한테 속았어!!!',
#   '1',
#   '15',
#   '12',
#   datetime.datetime(2017, 6, 5, 22, 51),
#   0],
#  ['호롤놀롤루(asg9****)',
#   '별점에 낚임개연성 하나도없고보는내내 벙찜 오글거리고평점 6~7점대 영화지만별점맞추기위해 1점',
#   '1',
#   '16',
#   '13',
#   datetime.datetime(2017, 9, 28, 22, 2),
#   0],
#  ['맥과이어(guk5****)',
#   '정말 아름다운 음악, 영상 그리고 배우들..10년간 3번 정도 봤는데 매번 새로운 느낌..이런 멋진 영화를 대만에서 다시 만들수 있을까?',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 9, 3, 23, 45),
#   0],
#  ['흐규(park****)',
#   '한 장면도 빠짐없이 완벽했던 영화.. 내 최애 영화임ㅠㅠ',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 5, 29, 0, 7),
#   0],
#  ['앤빌(popp****)',
#   '완벽하다 타이타닉과 더불어 인생영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2020, 5, 22, 1, 31),
#   0],
#  ['와다츠미의여행(csyn****)',
#   '영상미도 주인공 캐스팅도 좋고 사랑이야기도 다 좋았는데 하나부터 열까지 말이안되서 오류투성이라 좀 어이가없었음. 감독맘대로 설정을 다 해버리고 아무런 설명도없어 ㅋ 이해안되는건 나만그러냐?',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2020, 2, 20, 11, 11),
#   0],
#  ['poiu(into****)',
#   '배우 이상엽씨가 여주인공으로 나온다고 해서 봤습니당 ㅎㅎ',
#   '8',
#   '2',
#   '0',
#   datetime.datetime(2019, 11, 6, 13, 11),
#   0],
#  ['서디귿(phea****)',
#   '아름다운 피아노 소리에 듣고따라',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2019, 10, 16, 0, 40),
#   0],
#  ['birt****',
#   '학교에서 주구장창 틀어주는 영화',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2019, 6, 11, 22, 55),
#   0],
#  ['cool****',
#   '개봉 당시에 봤다면 재미있었을 것 같음. 여배우들 예쁨. 피아노 연주 장면 너무 좋음.',
#   '6',
#   '2',
#   '0',
#   datetime.datetime(2018, 12, 29, 19, 16),
#   0],
#  ['verd****',
#   '음.. 너무 좋아요....',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 12, 29, 2, 36),
#   0],
#  ['나(boll****)',
#   '아련하다는 말이 잘어울리는 영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 11, 19, 16, 57),
#   0],
#  ['인간(5e7s****)',
#   '영화는 예전에 봤으면서 이렇게 좋은 영화 평점을 지금 올리는 내가 참 한심하다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 5, 6, 15, 10),
#   0],
#  ['고럼고럼(jeon****)',
#   '아직도 못본 사람이 있다니....안타까울 따름입니다 ㅠㅠㅠㅠ ft 서윤',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 4, 8, 22, 35),
#   0],
#  ['하늘높이비상(shee****)',
#   '피아노 선율이 아름다운 영화예요',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 4, 6, 21, 24),
#   0],
#  ['superhyunee(shkw****)',
#   '무심결에 틀었는데 감동적이네~',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 4, 4, 7, 24),
#   0],
#  ['맥심(hya2****)',
#   '이거보면 주걸륜에 빠짐. 영화 분위기도 스토리도 음악도 주걸륜도 너무 좋다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 31, 1, 2),
#   0],
#  ['김규리(rlar****)',
#   '재개봉해주세요ㅠㅠ 제발,,',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 24, 23, 24),
#   0],
#  ['준수(shwh****)',
#   '내 인생 최고의 영화.. 봐도봐도 안 질림.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 17, 2, 8),
#   0],
#  ['앙 첼띠(chos****)',
#   '봐도 봐도 진짜 좋은 영화',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 16, 16, 8),
#   0],
#  ['set3****',
#   '보면 볼수록 빠져든다. 어쩜 이렇게 잘 만들었을까?',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 16, 16, 8),
#   0],
#  ['뉴턴히스(tjdw****)',
#   '재밌어요~~~ 피아노배틀이 한번인게 좀 아쉽다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 16, 15, 31),
#   0],
#  ['건축노예(dpfk****)',
#   '벌써 10년이야? 다시봐도 꿀잼이네',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2018, 3, 16, 15, 29),
#   0],
#  ['리타이(demo****)',
#   '헤드셋을끼고  계륜미가   주걸륜쳐다볼때  졸이쁨',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2017, 7, 2, 1, 25),
#   0],
#  ['revolution(serg****)',
#   '잔잔하지만 여운이 남는.',
#   '7',
#   '2',
#   '0',
#   datetime.datetime(2016, 12, 15, 5, 25),
#   '관람객'],
#  ['이태윤(anki****)',
#   '재개봉하는 영화는 왜 재개봉하는지 알 수 있다.',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 11, 27, 19, 57),
#   '관람객'],
#  ['김민우(chun****)',
#   '말이필요있냐 이런풋풋하고감동적인영화는 100년에한번나올까말까다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 7, 27, 18, 25),
#   '관람객'],
#  ['호날두루니박지성(whda****)',
#   'CGV에서 틀어줬는데 개꿀잼요',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 7, 19, 14, 47),
#   0],
#  ['시연(hell****)',
#   '주걸륜   아버지는....',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 3, 6, 18, 16),
#   0],
#  ['장성진(jsj_****)',
#   '와 지금 봐도 최고의 영화이다',
#   '10',
#   '2',
#   '0',
#   datetime.datetime(2016, 3, 1, 21, 26),
#   0],
#  ['koko****',
#   '진짜 졸려 죽는줄 알앗네',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 9, 15, 2, 40),
#   0],
#  ['mj__****',
#   '주위에서 진짜 진짜 재밌다고 해서 기대 진짜많이하고봤는데 ㅡㅡ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 9, 14, 20, 28),
#   0],
#  ['kid6****',
#   '8점 영화다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 9, 14, 1, 47),
#   0],
#  ['ghgh****',
#   '쉬운곡만 치는것 같다 .. 라면 어떻게 될까 ..ㅋ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 9, 12, 14, 12),
#   0],
#  ['pre0****',
#   '재미있는거 인정! 허나 평점9점을 넘을만큼은..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 7, 13, 17, 8),
#   0],
#  ['powe****',
#   "Definitely not a Five star movie.. Don't expect too much~",
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 29, 4, 39),
#   0],
#  ['leez****',
#   '솔직히 재밌는데 8점대가 어울리는듯',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 27, 18, 55),
#   0],
#  ['kkmh****',
#   '재미는 있지만,,식스센스와 시간을 달리는 소녀의 짬뽕면을 먹는 느낌??',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 26, 23, 28),
#   0],
#  ['pcw8****',
#   '너무 소설이였다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 26, 2, 48),
#   0],
#  ['ppar****',
#   '제목부터뻔항영화지만 피아노치는부분은볼만하고하니 평점7정도가적당',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 26, 2, 15),
#   0],
#  ['dduc****', '재밌다', '1', '2', '0', datetime.datetime(2008, 6, 24, 20, 22), 0],
#  ['tgv9****',
#   '재미있지만....1위할 영화는 아닌것 같앙',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 22, 16, 51),
#   0],
#  ['zopp****',
#   '8점 정도',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 22, 13, 35),
#   0],
#  ['nany****',
#   '7점짜리 영화',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 22, 12, 50),
#   0],
#  ['915s****',
#   '중후반까진 정말재밌게봤다..실평가는8정도.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 22, 2, 46),
#   0],
#  ['yong****', '그냥', '1', '2', '0', datetime.datetime(2008, 6, 22, 1, 45), 0],
#  ['jb34****',
#   '한 6점 정도가 적당한 영화다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 21, 14, 41),
#   0],
#  ['as2o****',
#   '에혀.. 이건뭐 -가 없는게 아쉽네요 ㅜ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 14, 17, 37),
#   0],
#  ['yutk****',
#   '10점주는건 자유지만 2만명의 수준에 경의를표합니다^^',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 11, 1, 2),
#   0],
#  ['star****',
#   '어이없다, 이런 중국영화가, CG 도 완전 꽝인데다, 결말도 최악인 영화',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 10, 10, 35),
#   0],
#  ['plqa****',
#   '아직은 많이 어설픈',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 8, 8, 47),
#   0],
#  ['vbum****',
#   '솔직히 왜 이렇게 까지 평점이 높은지 모르겠다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 7, 21, 5),
#   0],
#  ['crea****', '최고의영화', '1', '2', '0', datetime.datetime(2008, 6, 7, 7, 59), 0],
#  ['rnad****',
#   '재미없어별루그닥이게모야ㅡㅡ재미없어별루그닥이게모야ㅡㅡ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 6, 17, 24),
#   0],
#  ['sarv****',
#   '이 평점이 가당키나 하냐....',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 6, 16, 33),
#   0],
#  ['shee****',
#   '완전 진부한 스토리... 피아노나오면 다 멋있고 좋은거야?',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 5, 18, 36),
#   0],
#  ['nnwl****',
#   '지금만나러 갑니다 따라하기',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 5, 3, 50),
#   0],
#  ['semu****',
#   '유치찬란..평점에 속다!',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 3, 22, 5),
#   0],
#  ['sate****',
#   '내용에 비해 평점이...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 3, 19, 43),
#   0],
#  ['ssjs****', '별루던데', '1', '2', '0', datetime.datetime(2008, 6, 3, 16, 47), 0],
#  ['1yah****',
#   '진짜 재미없든디..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 2, 2, 54),
#   0],
#  ['kook****',
#   '1등은 말이안된다 재밌긴하다!',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 2, 2, 16),
#   0],
#  ['ekrk****',
#   '이건 말도 안되',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 1, 23, 6),
#   0],
#  ['gomt****',
#   '너무 기대했다 ㅠ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 1, 20, 25),
#   0],
#  ['uzza****',
#   '정말 이게 최고인지는 잘모르겠음;; 그냥 우리나라의 잔잔한 멜로가 훨 좋음',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 1, 16, 1),
#   0],
#  ['pike****',
#   '평점이 왜 이모양이야 거품작살이네 7점이 적당',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 1, 12, 50),
#   0],
#  ['alls****',
#   '좋은영화인정은 하겠는데 전체영화중4위라는게 인정못함..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 6, 1, 3, 39),
#   0],
#  ['pok1****',
#   '솔직히 6점영화, 난 그렇게생각한다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 31, 21, 47),
#   0],
#  ['0716****',
#   'ㅡㅡ말도안돼',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 30, 18, 33),
#   0],
#  ['zkeh****',
#   '신비한TV 서프라이즈 극장판 ㅅㄱ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 30, 14, 53),
#   0],
#  ['auge****',
#   '건방진 주걸륜 발언때문에 작품에 몰입이 안되잖아',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 30, 14, 44),
#   0],
#  ['itsu****',
#   '허접한 어린이용 로맨스',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 30, 14, 37),
#   0],
#  ['hyuk****',
#   '후반부의 억지스러움. 이건 만화도 아니고 뭐..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 30, 11, 4),
#   0],
#  ['kyou****',
#   '도대체 왜 평점이 높은지 이해할 수 없음...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 30, 4, 28),
#   0],
#  ['yhj8****',
#   '좋긴한데 평점이 너무 높다 한 7~8점이 적당한듯',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 29, 23, 11),
#   0],
#  ['jimi****',
#   '괜찮은편이긴한데... 온갖짜집기 느낌..역대영화랭킹1위는 말도안된다..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 29, 18, 2),
#   0],
#  ['sgi2****',
#   '주걸륜 자신을 위해 만든 영화...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 29, 16, 43),
#   0],
#  ['coco****',
#   '평점이 지나치게 높다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 29, 3, 20),
#   0],
#  ['mira****',
#   '재밌음.. 근데 평점이 너무 높아',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 29, 0, 40),
#   0],
#  ['rudf****',
#   '갠적으로 엄청실망... 왜케 평점이 높은지',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 28, 0, 20),
#   0],
#  ['sara****',
#   '뒤로 치는 묘기 짱',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 26, 21, 44),
#   0],
#  ['psyk****',
#   '솔직히 9점 이상은 너무했다 ㅡㅡ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 26, 19, 36),
#   0],
#  ['na01****',
#   '말도 안된다 이 영화가 9.20이라니 절대 아니다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 26, 18, 59),
#   0],
#  ['dkrl****',
#   '하하하하하핳너무재밌군',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 25, 20, 55),
#   0],
#  ['yoon****',
#   '멍미 ㅋㅋ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 25, 20, 47),
#   0],
#  ['bood****',
#   '음악밖에 들을게 없었다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 25, 17, 26),
#   0],
#  ['lege****',
#   '내게 많은 실망을 안겨줬다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 25, 14, 49),
#   0],
#  ['sola****',
#   "일본애니 '시간을 달리는 소녀'와 겹쳐보이는 건 나뿐?",
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 25, 13, 26),
#   0],
#  ['gana****',
#   '이영화보다 좋은작품이 너무많은데 1위라는게 쫌...;;;;',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 24, 17, 8),
#   0],
#  ['duat****',
#   '연기력이 조금 부족했고 스토리가 예측하기 굉장히 쉽군요',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 24, 15, 33),
#   0],
#  ['dand****',
#   '내 생애 최악의 영화',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 24, 15, 27),
#   0],
#  ['surf****',
#   '난 별로였다. 연기도 그랬고. 연기가 그런데 영화가 재미 있을 순 없다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 24, 12, 45),
#   0],
#  ['kjw5****',
#   '잼있긴한데 쫌 그런데 ㅋ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 24, 12, 2),
#   0],
#  ['eogs****',
#   '재미꽝 정말애들영화 소설틱 피아노만볼만한영화',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 24, 10, 50),
#   0],
#  ['oshk****', '애들용', '1', '2', '0', datetime.datetime(2008, 5, 24, 4, 36), 0],
#  ['yjwo****',
#   '아류지존',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 23, 18, 32),
#   0],
#  ['ggal****',
#   '반전이 없었다면 그나마 좀 봐줄만 했을텐데 반적덕에 쓰레기 영화로',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 23, 0, 31),
#   0],
#  ['qkrd****',
#   '재미있엇어 ``',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 22, 20, 28),
#   0],
#  ['ggal****',
#   '스토리 구성이 허접한 여중딩용 멜로영화',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 22, 13, 29),
#   0],
#  ['gegu****',
#   '보다가 중간에 엑스 눌른영화.ㅜㅜ 로맨스는 별로',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 22, 4, 35),
#   0],
#  ['chos****',
#   '너무나 대중성높은영화.. 부자연스러운 스토리도 맘에 안듬',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 22, 1, 52),
#   0],
#  ['shd0****', '버려', '1', '2', '0', datetime.datetime(2008, 5, 21, 22, 15), 0],
#  ['ulka****',
#   '저도... 영화는 좋지만, 이 정도 평점은 아님..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 21, 8, 20),
#   0],
#  ['jjsi****',
#   '영화는 좋았지만 이정도의 평점은 아니다..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 21, 7, 2),
#   0],
#  ['skr2****',
#   '평점이 너무 말이안돼게 높다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 21, 6, 45),
#   0],
#  ['bomy****',
#   '난별로..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 20, 22, 36),
#   0],
#  ['ura9****',
#   '진짜 재미없음...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 20, 22, 20),
#   0],
#  ['allu****',
#   '당신은 영화 시작 5분만에 반전을 눈치챌수있을것이다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 20, 19, 8),
#   0],
#  ['yynn****',
#   '정말 어이없는영화. 평점에속은영화다 망해라',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 20, 16, 22),
#   0],
#  ['pnn7****',
#   '이 영화 남자주인공은 한국 견제,비하하는 발언이나 해대는데ㅉㅉ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 20, 12, 33),
#   0],
#  ['nana****',
#   '한국에 대해 망말하는 저우제룬?이 나오는 영화라서 싫다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 20, 12, 6),
#   0],
#  ['sd24****', '별로', '1', '2', '0', datetime.datetime(2008, 5, 19, 21, 49), 0],
#  ['ikm1****',
#   '솔직히 재미없는건 아닌데 무슨 9점이 넘냐ㅡ,ㅡ 스토리 진짜 어이없다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 19, 21, 2),
#   0],
#  ['dkfk****',
#   '난 이해가 안가 이런영화 초딩만 본건가 뭐야 이거 귀여니네 완전',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 19, 12, 4),
#   0],
#  ['tony****',
#   '이상하군요....',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 19, 11, 25),
#   0],
#  ['glar****',
#   '이상하리만큼 평점이 높군요..말도안돼..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 19, 8, 49),
#   0],
#  ['park****',
#   '유치해ㅋㅋㅋ 이런게 1등이나하니 네이버가 개이버소리듣지',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 18, 18, 23),
#   0],
#  ['lluv****',
#   '판타지일거라고는 생각도 못했다... 재미도 없고 감동도 없었다.. 졸려죽는줄',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 18, 17, 10),
#   0],
#  ['math****',
#   '평점이 너무 오버된 듯...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 18, 16, 19),
#   0],
#  ['unis****',
#   '어이없는 평점',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 18, 1, 37),
#   0],
#  ['bsj9****',
#   '평점이 너무 높은 것 같아.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 18, 1, 22),
#   0],
#  ['park****',
#   '아무리 그래도 이 영화가 저 밑에 있는 수많은 명작들을 제치고 2위라는건 좀',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 18, 1, 0),
#   0],
#  ['rudd****',
#   '로맨스라........................',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 22, 37),
#   0],
#  ['linu****',
#   '8점정도가 적당해~~~~무슨 이게 9.2야~~?? 네이버1위라고해서 봤더니 최고는 아닌데',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 17, 21),
#   0],
#  ['asj0****',
#   '너무 높은듯',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 15, 37),
#   0],
#  ['thwj****',
#   '이정도??ㅡㅡ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 15, 34),
#   0],
#  ['k33i****',
#   '이게 왜 전체영화 2위?',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 12, 32),
#   0],
#  ['skyi****',
#   '스토리가 너무 엉성한데 이게10점?',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 0, 24),
#   0],
#  ['jplo****',
#   '이영화는 울나라 동감과 시월애를 짬뽕한듯한영화 1979년 1999년도 똑같고',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 0, 21),
#   0],
#  ['psyp****',
#   '웬 듣보잡이야....?',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 0, 9),
#   0],
#  ['kosm****',
#   '정말이지 어처구니 없는 평점이구나',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 17, 0, 1),
#   0],
#  ['shha****',
#   '이제 다른거 평점도내리네ㅋㅋㅋㅋ 제발 단순재밌는 영화랑 명작이랑 구분좀 하자',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 23, 59),
#   0],
#  ['k55i****',
#   '에휴~ 딴 영화 좀 그만 까라 ㅋㅋ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 23, 39),
#   0],
#  ['gabe****',
#   '이영화땜에딴영화1점주는거조금이라도 보상하기위해서.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 22, 28),
#   0],
#  ['eon1****',
#   '이건 아니잖아',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 21, 3),
#   0],
#  ['yoon****',
#   '이딴게 뭐가좋다고 =ㅅ=',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 20, 59),
#   0],
#  ['gold****',
#   '....재미없음...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 20, 58),
#   0],
#  ['geni****',
#   '대만 영화치고 잘 만들었으나 평점1등은 오버임..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 20, 58),
#   0],
#  ['jwcr****',
#   '아오 영화 졀라재미없더만',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 20, 43),
#   0],
#  ['king****',
#   '야야야 수준떨어진다. 뭐 이런 듣보잡이 어디서 감히...쯧...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 20, 43),
#   0],
#  ['over****',
#   '장난하나',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 20, 22),
#   0],
#  ['ssk5****',
#   '진짜 평점 1위는 개오바다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 16, 3, 37),
#   0],
#  ['dydd****',
#   '딱 인디영화 그 수준.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 15, 20, 32),
#   0],
#  ['trai****',
#   '한 5점은 되는 영화라고 생각하지만.. 이런영화가 1,2위를..너무 창피한 마음에 1점',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 15, 15, 36),
#   0],
#  ['gjtt****',
#   '이건 뭐...바보같다고만 말하자...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 14, 19, 50),
#   0],
#  ['fuck****',
#   '예전에 본영화 기억이 안나는데..그 영화들을 짜집기한거 같다..표절',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 14, 15, 49),
#   0],
#  ['gyeh****',
#   '이런 영화가 평점1위라니..;; 대한민국 망신이다..;;',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 14, 15, 46),
#   0],
#  ['01sm****',
#   '개거품점수다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 13, 21, 53),
#   0],
#  ['beas****',
#   '일본영화 너무따라했다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 13, 2, 45),
#   0],
#  ['cjy8****',
#   '아 뭔가 다른 영화 다 섞은거 아휴',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 12, 17, 36),
#   0],
#  ['lrs2****', '0점없나', '1', '2', '0', datetime.datetime(2008, 5, 12, 16, 3), 0],
#  ['myje****',
#   '솔직히 별루 근데 횡포가 너무 심해',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 12, 15, 38),
#   0],
#  ['zxc6****',
#   '재밌어서 10점주려 했으나 횡포때문에 1점 준다 ㅇ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 12, 15, 26),
#   0],
#  ['aran****',
#   '따분하다~~~~~~~~~~',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 12, 15, 13),
#   0],
#  ['kjr4****',
#   '점수가 이정도는 아닌데 넘 높다....조정들어감~',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 12, 14, 47),
#   0],
#  ['fund****', '구려', '1', '2', '0', datetime.datetime(2008, 5, 12, 2, 59), 0],
#  ['fenc****',
#   '중국영화치곤 볼만했지만 두번다신 보고싶지않다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 12, 0, 41),
#   0],
#  ['bomy****',
#   '난별로..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 11, 23, 2),
#   0],
#  ['doyu****',
#   '아랫분에 공감해서 1점',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 11, 20, 30),
#   0],
#  ['yuni****',
#   '좋은 영화지만 전체 1위라는 게 말이 안되서 1점 줘요',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 11, 20, 14),
#   0],
#  ['lord****',
#   '이거 뭐냐? 평점 왜이렇게 높냐?',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 11, 11, 55),
#   0],
#  ['boy9****',
#   '평점 최고인 이유는 최근개봉한영화라 관심이 집중된탓.잘만들엇지만 1위는 아닌듯',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 11, 2, 44),
#   0],
#  ['jjg3****', '1점', '1', '2', '0', datetime.datetime(2008, 5, 11, 0, 28), 0],
#  ['hss2****',
#   '추천해줘서 봤는데 떄려줬다!!',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 10, 18, 40),
#   0],
#  ['dn14****',
#   '평점에 속았다 !',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 10, 16, 47),
#   0],
#  ['theo****',
#   '또 다시 평점에 속았음.... 시월애 + 동감 + 해리포터냐ㅡㅡ;',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 10, 15, 40),
#   0],
#  ['cwon****', '별로', '1', '2', '0', datetime.datetime(2008, 5, 10, 13, 42), 0],
#  ['ghib****',
#   '너무 기대했나.......??',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 10, 1, 40),
#   0],
#  ['cogh****', '미안', '1', '2', '0', datetime.datetime(2008, 5, 9, 21, 55), 0],
#  ['milk****',
#   '재미업어 ㅠㅠ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 9, 12, 0),
#   0],
#  ['oklj****',
#   '너무한 평점이다.. 재미없는걸...이렇게나;',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 8, 18, 26),
#   0],
#  ['shes****',
#   '애절함 90점 논리-100점 나머지 0점',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 8, 7, 48),
#   0],
#  ['0982****',
#   '식상한 연애 스토리를 합쳐놓은 느낌이다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 7, 21, 31),
#   0],
#  ['pila****',
#   '이래서 12세관람가였군. 10대의 마음은 확실히 잡았으니 기획의 승리네.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 7, 5, 54),
#   0],
#  ['rael****',
#   '솔직히 이 영화가 1위인것이 이해가 가지않는다. 더 좋은 영화들이 많은데...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 7, 0, 1),
#   0],
#  ['ymle****',
#   '이게 레옹보다 잼나냐?',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 6, 22, 51),
#   0],
#  ['vmfl****',
#   'OOO 영화...연출력',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 6, 7, 50),
#   0],
#  ['tpem****',
#   '중고딩을 설레발치게만든 영화',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 5, 23, 30),
#   0],
#  ['k460****',
#   '중꿔는 맘놓고 한국인을 패고,, 머리빈 한국애들은 유치한 중꿔 영화에 환장하고..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 5, 22, 26),
#   0],
#  ['smel****',
#   '평점에 속았다 기대보단 진짜 별로..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 5, 17, 31),
#   0],
#  ['rlaw****',
#   '이딴 영화가 1위? 혐한 주걸륜 별로...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 3, 19, 17),
#   0],
#  ['expo****',
#   '괜찮은 영화지만 9점 이상은 못됨',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 3, 18, 17),
#   0],
#  ['wind****',
#   '평점주려고 로긴했다.  별로다 별로.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 3, 17, 36),
#   0],
#  ['dgsg****',
#   '정말 재미없습니다. 보면 정말 후회합니다. 이야기에 뭔가 빠졌어요.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 5, 1, 21, 3),
#   0],
#  ['chlw****',
#   '보통 드라마 수준 참내',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 30, 22, 42),
#   0],
#  ['cool****',
#   '아랫분 동감... 5점정도가 적당하다 원래는 5점주고싶은데 넘높아서 0.5점 줘야겠다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 30, 16, 57),
#   0],
#  ['fire****',
#   '볼만하긴 한데 9.20은 개오바',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 30, 16, 52),
#   0],
#  ['star****',
#   '전프로게이머 장진수,김민정,김태희 나오는거같았다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 30, 12, 43),
#   0],
#  ['twi_****',
#   '나비효과+시간을 달리는소녀+이제 만나러 갑니다=최고평점이냐?ㅋㅋㅋ',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 30, 0, 8),
#   0],
#  ['kcwe****',
#   '재밌게 보긴 했는데 평점은 좀 낮춰야겠다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 28, 21, 26),
#   0],
#  ['hero****',
#   '동감+데쓰노트 음악영화라 잔잔해서 좋긴한데 대만영화 다시봤다',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 28, 1, 9),
#   0],
#  ['jyj7****',
#   '평점도 좋고 해서 영화를 봤는데 전 너무 지루해서 잠을 잤습니다.;;',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 27, 20, 52),
#   0],
#  ['imbo****',
#   '원랜 2점 정도? 균형 맞추기',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 27, 3, 0),
#   0],
#  ['tare****',
#   "균형을 맞추자.....ㅡ.ㅡ' 이게 어떻게 9.20의점수를 받을 수 있단 말인가?",
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 27, 2, 45),
#   0],
#  ['make****',
#   '균형을 맞춘답시고 1점 주는 사람들을 비웃었었다.그러나 이젠 비웃을 수 없다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 27, 2, 43),
#   0],
#  ['happ****',
#   '나에겐 현실성이 중요하다.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 26, 20, 15),
#   0],
#  ['lcjl****',
#   '거품이 좀 심하군요 이게 9.2정도 되는 평점이라고 믿을수없음 네이버에 돈매겼나;;;',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 26, 19, 49),
#   0],
#  ['rlgn****',
#   '아니 이게 재미있어?? 완전 앞뒤 하나두 안맞는구만...',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 26, 18, 33),
#   0],
#  ['ltom****',
#   '완전 쓰레기...이것도 영화라고..',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 26, 13, 13),
#   0],
#  ['emx1****',
#   '개인적으로 별로임.',
#   '1',
#   '2',
#   '0',
#   datetime.datetime(2008, 4, 26, 8, 41),
#   0],
#  ['pian****',
#   '최악 아니지만 일부 개념없는 팬때문에 오늘도 1점.',
#   '1',
#   '2',
#   '0',
# ...
#   0],
#  ['GiHoonLee(giho****)',
#   '와 클래식에 긴장감더하긴 힘든데 보는 내내 심장이 쫄깃쫄깃했다',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 11, 16, 22, 1),
#   0],
#  ['lktk****',
#   '최고의 영화는 영혼을 일깨워주고 가슴속엔 열정을 마음엔 평화를주지 난 너에게서 그걸 얻었고. . . 잠만 이거 노트북 명대사인대',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 22, 2, 54),
#   0],
#  ['보라돌이(yoon****)',
#   '음악도좋고 스토리도 짱짱!피아노배틀~잊을수없음!',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 15, 14, 17),
#   0],
#  ['성진(hgsg****)',
#   '언제 봐도 소름돋는영화 죽기전에 봐서 다행이다라는 생각이 들정도로 내가 제일 좋아하는 영화',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 14, 23, 36),
#   0],
#  ['kljowj(shad****)',
#   '이영화를 본후로 내인생 최고의영화가 바뀌었다',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 7, 17, 32),
#   0],
#  ['놈(scvk****)',
#   '쪼우지에룬 와우 이정도로 잘만들어진 영화라 생각도못했네요',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 6, 5, 15),
#   0],
#  ['송송(dytj****)',
#   '이영화는정말말로표현할수없다 그냥최고!이번에 3번째보는데 또봐야지~ㅎ',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 5, 23, 26),
#   0],
#  ['하늬맘(2862****)',
#   '보고보고또봐도 질리지않는영화....!!',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 4, 22, 25),
#   0],
#  ['엿막어는반사(mins****)',
#   '짱짱맨입니다. 진짜 추천하고 감독에다 음악 제작에 배우까지.. 주걸륜 대박',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 10, 2, 16, 10),
#   0],
#  ['행복(1094****)',
#   '진짜 내 인생영화!몇 번을 본건지 모르겠다 봐도 봐도 질리지않는다',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 9, 28, 17, 21),
#   0],
#  ['영초리(ycch****)',
#   '진짜 명작이에요 꼭 보세요',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 9, 27, 3, 14),
#   0],
#  ['메이준7(juny****)',
#   '안보면 후회할 영화! 정말 명작이다. 음악도 너무 좋고 정말 잘 만든 영화다.',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 9, 24, 1, 47),
#   0],
#  ['김춘풍(skyc****)',
#   '피나노배틀로유명한영화이지만    이영화는 ost만으로도10점이다.   7년전당시극장에서못본사람들도많을뜻  .이번엔놓치지맙시다 , 감동과전율그자체를  느끼로갑시다.                              ...',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2015, 4, 2, 22, 35),
#   0],
#  ['신새암(bloc****)',
#   '후..시험기간인데 이거 보고있다.. 솔직히 유투브로 봤는데 이 영화는 무료로 보면 뺨 맞아야 됌..진짜; 돈도 영화표의 4배는 더 지불해야하고...짱이다 진짜 이런 영화를 왜 이제서야 봤지..ㅠㅠ',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2014, 7, 7, 3, 13),
#   0],
#  ['그리핀 코넬리(dwy0****)',
#   '와! 몇 OO에 한 번 나올 명작임.영화의 구성, 음악, 수십번을 보아도 언제나 이영화에 나는 동화되어 있고,하루, 1달, 1년이 지나도 이 영화를 보면서 느끼는 감동은 변하지 않는다.내 인생 최고의 아니, 그것뿐만...',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2014, 6, 7, 0, 49),
#   0],
#  ['로이드로어(zldq****)',
#   'ㅎㅎ',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2013, 7, 21, 18, 52),
#   0],
#  ['뿐(lees****)',
#   '그냥 이런 영화가 많이많이 있었으면 좋겠다는 생각뿐',
#   '10',
#   '5',
#   '3',
#   datetime.datetime(2013, 6, 25, 21, 13),
#   0],
#  ['라떼(chjy****)',
#   '참 거품끼어져 있는영화다 감동적이긴 하나 극적이지 않고 깊은 감동도 아니다 피아노 배틀 로 눈요기를 시킨 장면은 좋았으나 감동을 분배하는 전개가 허술했다 결과적으로는 시간여행으로 시간 낭비시킨 영화...',
#   '8',
#   '5',
#   '3',
#   datetime.datetime(2012, 12, 30, 18, 44),
#   0],
#  ['Fruit living(ghkf****)',
#   '개인적으로 봤던 모든 영화 중 엔딩이 가장  여운이 남는다. 아름답다',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2018, 11, 10, 16, 23),
#   0],
#  ['김예훈(kimy****)',
#   '워낙 명작이라해서 봤는데 너무 기대를해서 그런가?  유치한  연출에 지루한전개.. 반전도 그다지....',
#   '4',
#   '6',
#   '4',
#   datetime.datetime(2017, 12, 18, 23, 35),
#   0],
#  ['Runyoucleverboy(adri****)',
#   '아버지 불쌍해서 어떡함ㅠㅠㅠㅠ 아들 하나 믿고 사는데 아들이 사라졌어...',
#   '8',
#   '6',
#   '4',
#   datetime.datetime(2017, 9, 19, 2, 28),
#   0],
#  ['정다연(grty****)',
#   '또 다시 개봉한다고 하면 또 볼  영화이다.  계속  작은화면으로만 보다 영화관에서  웅장한 사운드로 다시보니 몇배 이상의 감동이었다.',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2016, 3, 23, 22, 1),
#   '관람객'],
#  ['MininalLife(sung****)',
#   '무엇보다도 황추생 팬으로서 아버지의 먹먹한 연기가 일품이었다.',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2016, 3, 17, 0, 48),
#   0],
#  ['kaddfsdf43(akan****)',
#   '아 계륜미 너무 신비로와서 여운이 안 가셔서힘들다ㅜ',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2016, 1, 17, 22, 15),
#   0],
#  ['wcg2****',
#   '하‥‥여운보소 10점으로 부족한 명작이다 이런 영화 또안나오나?',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2016, 1, 17, 20, 55),
#   0],
#  ['조물주(rach****)',
#   '명작이란 건 다시 봐도 재밌어야 한다고 생각하는데, 이 영화가 딱 그렇다..',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2015, 10, 21, 0, 10),
#   0],
#  ['MADE(dong****)',
#   '주걸륜은 천재. 계륜미와 케미가 넘 좋았어요 ㅜㅜㅜㅜ 너무 아련해요ㅠㅠ',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2015, 10, 8, 22, 57),
#   0],
#  ['울여보잠만보(vlsk****)',
#   '영화상영시간대도 좋으며 다양한 장르로 볼것이 많아요  시설도 깨끗하고 자리도 넓어요',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2015, 10, 2, 17, 22),
#   '관람객'],
#  ['ilob****',
#   '이야기는 약했지만, 아름답고  세련되게 그려낸 영화',
#   '8',
#   '6',
#   '4',
#   datetime.datetime(2015, 5, 29, 4, 41),
#   '관람객'],
#  ['ganjioyo(wjdg****)',
#   '10번넘게 봐도 재미있는영화!',
#   '10',
#   '6',
#   '4',
#   datetime.datetime(2013, 7, 16, 18, 49),
#   0],
#  ['ysan****', '와우', '10', '6', '4', datetime.datetime(2013, 7, 15, 1, 58), 0],
#  ['쇼타임(show****)',
#   '10점 이상 줄순 없나요?',
#   '10',
#   '7',
#   '5',
#   datetime.datetime(2016, 8, 2, 9, 21),
#   0],
#  ['달빛양치기(nobl****)',
#   '이만큼 재밌는 영화는 보기 힘들다.',
#   '10',
#   '7',
#   '5',
#   datetime.datetime(2015, 10, 10, 0, 39),
#   0],
#  ['B미술가(rudt****)',
#   '내 온몸을 소름돋게 하고 가슴이 옥죄어 오는 그런 영화. 아마 백만년에 한번 나올까 말까하는 영화일 것이다. 내 오감을 만족시킨 처음이자 마지막 영화가 될거같다. 그냥 죽을때 그순간마저도 생각날 영화 될거같다.',
#   '10',
#   '7',
#   '5',
#   datetime.datetime(2015, 10, 3, 22, 13),
#   0],
#  ['rlaw****',
#   '스토리만 꼼꼼햇음 좋았을텐데',
#   '6',
#   '7',
#   '5',
#   datetime.datetime(2013, 2, 23, 0, 32),
#   0],
#  ['스카이럽(tmdq****)',
#   '주인공 아빠 개발암이네 ㅋㅋ 상담은 절대비밀이 원칙이구만...',
#   '9',
#   '8',
#   '6',
#   datetime.datetime(2017, 7, 25, 14, 25),
#   0],
#  ['첼시에취한다(no_1****)',
#   '한번 더 봤다 인생작이다 진짜....',
#   '10',
#   '8',
#   '6',
#   datetime.datetime(2016, 6, 7, 1, 56),
#   0],
#  ['차칸남자(whdu****)',
#   '레전드 말이 필요 없다 사랑한다 이영화',
#   '10',
#   '8',
#   '6',
#   datetime.datetime(2016, 5, 14, 0, 36),
#   0],
#  ['망을가르는망갈라(kchl****)',
#   '후회합니다. 이 영화를 이제서 봤습니다.감사합니다. 이 영화를 볼수있게해주셔서',
#   '10',
#   '8',
#   '6',
#   datetime.datetime(2015, 12, 9, 8, 43),
#   0],
#  ['권유진(jin5****)',
#   '영화관 개봉이라 혼자보러갔습니다  여전히 아름다운 영상미는 좋았으나 반전을 알고 가지 마세요',
#   '9',
#   '8',
#   '6',
#   datetime.datetime(2015, 10, 15, 1, 14),
#   '관람객'],
#  ['wnsr****', '좋', '9', '8', '6', datetime.datetime(2013, 7, 26, 13, 19), 0],
#  ['폴양(kmh9****)',
#   '제가 평점 주러 온 영화는 이 영화가 처음이네요. 안 보신 분들은 꼭 보세요.',
#   '10',
#   '8',
#   '6',
#   datetime.datetime(2013, 6, 8, 17, 14),
#   0],
#  ['gall****',
#   '전형적인 1-20대 소년소녀들을 위한 영화.. 평점이 너무 과하군',
#   '1',
#   '8',
#   '6',
#   datetime.datetime(2008, 10, 12, 11, 26),
#   0],
#  ['symi****',
#   '타이타닉보다 높을순 없음 중2병영화 ㅁㅈㅎ',
#   '1',
#   '9',
#   '7',
#   datetime.datetime(2017, 7, 1, 22, 29),
#   0],
#  ['icis****',
#   '이거 공포영화임  여자귀신 나옴  보는내내 무서웠음  후덜덜',
#   '1',
#   '9',
#   '7',
#   datetime.datetime(2016, 12, 28, 22, 29),
#   0],
#  ['김광훈(nbam****)',
#   '와 진짜 소름돋네 최고다',
#   '10',
#   '9',
#   '7',
#   datetime.datetime(2015, 5, 10, 2, 25),
#   '관람객'],
#  ['zhzh****',
#   '진짜....짱......',
#   '10',
#   '9',
#   '7',
#   datetime.datetime(2013, 7, 21, 23, 56),
#   0],
#  ['flyt****',
#   '이걸보고 네이버 영화평점을 불신하게 되었다,',
#   '1',
#   '9',
#   '7',
#   datetime.datetime(2008, 12, 21, 16, 56),
#   0],
#  ['택이(tig0****)',
#   '대박이에요..ㅜㅜ이명작을 이제야봐서 죄송합니다정말감동적이고 여운이남네요ㅠㅠ',
#   '10',
#   '10',
#   '8',
#   datetime.datetime(2016, 6, 3, 11, 18),
#   0],
#  ['사과(dase****)',
#   '몇 번을 봤는지 모르겠음',
#   '10',
#   '10',
#   '8',
#   datetime.datetime(2016, 3, 30, 15, 8),
#   '관람객'],
#  ['폰노예(nexc****)',
#   '2016/03/13 EBS 에서 봤습니다. 정말 최고의 영화입니다. 이런 영화를 극장에서 구경 못했다는게 참 아깝다는..',
#   '10',
#   '10',
#   '8',
#   datetime.datetime(2016, 3, 14, 7, 58),
#   0],
#  ['쿤밤(psin****)',
#   'OCN에서 방금틀어줌 진짜 최고의영화다. 평론가 쟤네들은 멋부리면서 평점만 낮게주면 뭔가 있어보이는줄아나봄.. 레알..',
#   '10',
#   '10',
#   '8',
#   datetime.datetime(2016, 1, 15, 14, 29),
#   0],
#  ['ywp5****',
#   '열두번도 넘게 봤지만 극장에서 보니 새롭다. 보면 볼수록 설레고 봐도봐도 새로운 영화',
#   '10',
#   '10',
#   '8',
#   datetime.datetime(2015, 5, 10, 15, 2),
#   '관람객'],
#  ['초코틴틴(zxcv****)',
#   '내용은 이상함.... 크게감동은안왔음차라리 그시절우리가좋아했던이게 더 여운남음',
#   '6',
#   '10',
#   '8',
#   datetime.datetime(2015, 1, 22, 1, 3),
#   0],
#  ['호야(gado****)',
#   '최고의 영화중 하나.',
#   '10',
#   '10',
#   '8',
#   datetime.datetime(2013, 7, 16, 18, 26),
#   0],
#  ['깡랑(fkdb****)',
#   '감동백배',
#   '10',
#   '11',
#   '9',
#   datetime.datetime(2013, 7, 20, 0, 37),
#   0],
#  ['te(love****)',
#   '피아노를갑자기치고싶게했ㅇ....ㅇ.....재밌엉 ㅠㅠㅠㅠㅠ',
#   '10',
#   '11',
#   '9',
#   datetime.datetime(2013, 6, 30, 12, 35),
#   0],
#  ['멋진리쌍(alka****)',
#   '좋은 평만 보고 기대하고 봐서 그런가 막상 뚜껑을 열어보니 그저그럼. 좋다가도 순 억지 판타지 개연성 無, 결말? 혹자는 해피엔딩이라고 하는데... 남주 오케스트라 책임감 전무에 지 위해주는 아버지조차 안중에도 없고...',
#   '1',
#   '12',
#   '10',
#   datetime.datetime(2017, 5, 14, 2, 23),
#   0],
#  ['명품코(avp2****)',
#   '1점 줄영환 아니지만 평점이너무높네요 결말도 허무해서  깎습니다',
#   '1',
#   '12',
#   '10',
#   datetime.datetime(2016, 7, 22, 16, 59),
#   0],
#  ['송(hima****)',
#   '전체적 플롯은 괜찮아도 그 플롯을 이어줄때 개연성이 너무 없다 무슨 뚝뚝 끊겨서 영화 흐름 잘라먹고 영상미랑 피아노곡은 괜찮지만 판타지로 커버하는것도 너무 어이없어서 반전이라고 하기에 유치하고 결말도 여운보단 흐지부...',
#   '1',
#   '13',
#   '11',
#   datetime.datetime(2017, 4, 22, 15, 19),
#   0],
#  ['별명을뭘로해(olso****)',
#   '지금까지 살면서 봤던 영화들 중에 가장 여운이 많이 남는 영화. 오죽하면 핸드폰에 넣어놓고 심심할 때마다 틀어서 대사까지 다 외워버림...',
#   '10',
#   '13',
#   '11',
#   datetime.datetime(2015, 12, 16, 13, 38),
#   0],
#  ['kes3****',
#   '벌써6년이지났네...진짜다시봐도 명작',
#   '10',
#   '13',
#   '11',
#   datetime.datetime(2014, 3, 30, 11, 10),
#   0],
#  ['중년오덕(cree****)',
#   '볼만하지만 너무 과대평가된 느낌....',
#   '7',
#   '14',
#   '12',
#   datetime.datetime(2015, 9, 7, 15, 26),
#   0],
#  ['STNGLK KI(dmsd****)',
#   '최고의영화',
#   '10',
#   '14',
#   '12',
#   datetime.datetime(2013, 7, 19, 0, 6),
#   0],
#  ['메시1234(iueb****)',
#   '재미있고 감동적이다.',
#   '10',
#   '15',
#   '13',
#   datetime.datetime(2013, 7, 19, 0, 5),
#   0],
#  ['신구(eotl****)',
#   '마지막엔 이해하기 조금 어려웠지만, 그래도 너무 감동적이고,재밌는 영화였습니다. 더욱 충격적인건 감독이 주걸륜이였다는 겁니다. 이제와 봤지만 정말 재밌게 봤습니다.',
#   '10',
#   '15',
#   '13',
#   datetime.datetime(2013, 7, 16, 22, 23),
#   0],
#  ['뿅알(ae12****)',
#   '장르모르고 봣다가 반했네요',
#   '10',
#   '16',
#   '14',
#   datetime.datetime(2013, 7, 20, 16, 56),
#   0],
#  ['나르크(naks****)',
#   '말 할수 없을 만큼의 감동',
#   '10',
#   '16',
#   '14',
#   datetime.datetime(2013, 7, 18, 0, 26),
#   0],
#  ['gkdm****',
#   '줄거리도 제대로 모르고 기대안하고 봤는데ㅠㅠㅠㅠ대단함 주걸륜..',
#   '10',
#   '16',
#   '14',
#   datetime.datetime(2013, 7, 7, 20, 39),
#   0],
#  ['최고(yg04****)',
#   '제가 본 멜러 영화중 최곱니다',
#   '10',
#   '16',
#   '14',
#   datetime.datetime(2013, 6, 19, 19, 43),
#   0],
#  ['안녕야큐(hyek****)',
#   '이런 달달한 영화 또없나‥ 풋풋함♥',
#   '10',
#   '17',
#   '15',
#   datetime.datetime(2013, 7, 6, 2, 45),
#   0],
#  ['bang****',
#   '몇년만에 다시보네요ㅋ 근데 전문가 평점왜이러지? ㅋ평점의 기준이뭔지 궁금하네ㅡㅡ',
#   '10',
#   '18',
#   '16',
#   datetime.datetime(2013, 7, 21, 19, 6),
#   0],
#  ['밤비(holi****)',
#   '거의 열번은 보지않았나싶네요 ost듣고 싶으면 보는 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 10, 10, 14, 43),
#   0],
#  ['시냇가(roma****)',
#   '뻔한 스토리인 줄 알고 뒤늦게 봤다가 로맨틱 피아노 선율에 빠져버렸다.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2020, 10, 4, 21, 32),
#   0],
#  ['비비(mia3****)',
#   '대만이란 나라를 더 사랑하게 해준 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 9, 30, 1, 32),
#   0],
#  ['사랑과 소망(poou****)',
#   '미쳤다 ㄹㅇ... 진짜 띵작임 말이 필요없어 제발 꼭 보세요 10대인데 너무 좋아요 진짜',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 9, 21, 0, 59),
#   0],
#  ['차니아범(s5ng****)',
#   '그냥 꼭 봐야할 영화...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 9, 18, 10, 41),
#   0],
#  ['햇살이 눈부셔(ssuk****)',
#   '아름다운 영화입니다. 여러번 봐도 질리지 않는 영화입니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 9, 18, 7, 16),
#   0],
#  ['오민아(kk77****)',
#   '',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 7, 27, 2, 9),
#   0],
#  ['appl****', '', '10', '1', '0', datetime.datetime(2020, 7, 24, 3, 38), 0],
#  ['lims****',
#   '어후 다시 봐도 정말로 너무재밌어요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 7, 23, 22, 18),
#   0],
#  ['콩지(wlgu****)',
#   '진짜 말할 것도 없는 걸작입니다!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 7, 23, 10, 28),
#   0],
#  ['Lovely(xxx2****)',
#   '피아노 연주.. 두 남녀 주인공의 풋풋한 감정이 좋네요',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2020, 7, 21, 5, 6),
#   0],
#  ['때흥(tae-****)',
#   '나 판타지 엄창 좋아하는데 와.. 말이 안 나올 정도로 재밌슘다 ㅠㅠ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 7, 20, 13, 5),
#   0],
#  ['TDE(bada****)',
#   '계륜미 이쁘다 난 이영화를 왜 지금봤을까ㅠ',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 7, 18, 23, 14),
#   0],
#  ['손혜림(sh01****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 6, 1, 4, 11),
#   0],
#  ['peki****',
#   '스토리 연기 연출 ost까지 뭐 하나 빠지는게 없는 대작',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 29, 8, 50),
#   0],
#  ['손정훈(sjhw****)',
#   '아름다운 음악과 멜로 그리고 반전',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 23, 1, 8),
#   0],
#  ['min kyeong(esth****)',
#   '대만영화가 이렇게 재밌을줄 몰랐음',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 22, 23, 18),
#   0],
#  ['icar****',
#   '아 보기드문 명작 정말잼나내요 꼬보고싶은영화알바아님 정밀감동 여운 남는영화 계륜미 너무사랑스럽네요',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 21, 7, 9),
#   0],
#  ['Dana(0910****)',
#   '음..난 어릴적엔 운명이란 걸 믿지 않았지.. 그런데 사랑..을 해보니까 운명이 있더라.. 첫눈에 반한다라는 것도..있더라.. 인생의 많은 계획들은 아무것도 아니게 되고 나의 운명을 만났을때 이사람 내가 결혼 할 사...',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 5, 16, 5, 29),
#   0],
#  ['꿍이(ssou****)',
#   '왜 이제야 봤는지ㅠ 스토리 음악 연기  다 좋았다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2020, 4, 30, 2, 49),
#   0],
#  ['김동윤(dyki****)',
#   '피아노 배틀 장면은 지금 봐도 지린다...',
#   '7',
#   '1',
#   '0',
#   datetime.datetime(2020, 4, 7, 9, 25),
#   0],
#  ['기리보여(citi****)',
#   '스포일러가 포함된 감상평입니다. 감상평 보기',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2019, 12, 31, 1, 56),
#   0],
#  ['아뵤오(agai****)',
#   '이 영화를 봤으면 동감도 봐라. 배경 설정이 동감을 보고 많이 영향을 받은 듯 한데. 배경 년도도 1979년 1999년 똑같네. 오마주인가.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2019, 4, 19, 2, 45),
#   0],
#  ['가지각색(94hu****)',
#   '난 널 사랑해, 너도 날 사랑하니...ㅋㅋㅋ 너무 오그라들지만... 반전이 있어 뻔하지 않고 긴장감있게재미있었다! 단수이의 배경과 여주인공 그리고 음악이 너무나 아름다웠던 영화!',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 12, 29, 2, 48),
#   0],
#  ['soon****',
#   '인생작. 몇번을 봐도 명작. 재밌고 재밌고 감동적이고 독특하며..피아노곡들 음악도 인생음악. 명작',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 28, 1, 14),
#   0],
#  ['도렘(difo****)',
#   '이 명작을 10년후인 20OOO에 보게되다니 지금이라도 보게되어서다행입니다. 방금봣지만 또 보고싶은 그런영화입니다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 28, 0, 41),
#   0],
#  ['최다현(ashi****)',
#   '내 인생 명작이다 한번 보는 것보다 두세번씩 볼수록 더 감동적이다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 28, 0, 36),
#   0],
#  ['개미짱(koko****)',
#   '중간부터 봤는데 홀릭그래서 검색해 봄요 ㅎㅎ 완전 저아',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 28, 0, 30),
#   0],
#  ['Sammmm(bean****)',
#   '영화는 분석하는게 아니라, 느끼는거죠.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 28, 0, 29),
#   0],
#  ['설재윤(tjfw****)',
#   '계륜미 진짜 청초 그 자체네',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 11, 27, 14, 38),
#   0],
#  ['ones****',
#   '고등학교때 좋아하던 남자애 주걸륜을 닮아 오랜시간이 지났지만 문뜩 생각나서 이제서야 이 명작을 보게되었는데그 시절의 내 모습도 생각나고 그 친구도 생각이나고~늦었지만 안봤음 후회할 뻔한 영화 ㅠㅡㅠ',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 4, 14, 18, 22),
#   0],
#  ['다이노아스날(jong****)',
#   '초반은 좀 지루한 감이 없잖아 있었는데 중반 이후부터 소름이 쫙 돋으면서 어느 순간엔가 울고 있는 나의 모습을 발견했다.. 긴 여운도 남고..',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 4, 4, 18, 29),
#   0],
#  ['벚꽃샐러드(getl****)',
#   '피아노를 타고 온 영원한 첫사랑.----환상적이면서 반전있는 스토리가 매력적인 작품.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 3, 29, 19, 33),
#   0],
#  ['허임(hyye****)',
#   '피아노 연주는 두말하면 잔소리고 중후반쯤에 나오는 반전은 정말 소름끼칠 정도였다. 이 영화는 여운이 대단한 영화인듯 지금 다시 봐도 전혀 촌스럽지 않다.',
#   '8',
#   '1',
#   '0',
#   datetime.datetime(2018, 3, 27, 0, 54),
#   0],
#  ['문화재 대재앙(sang****)',
#   '이 영화 나올 때만 해도 주걸륜에 대해 거는 기대가 컸지만 이 작품이 다였다',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2018, 3, 19, 16, 25),
#   0],
#  ['pont****',
#   '주걸륜의 음악적 재능과 시간차로맨스가 세련되게 융합.',
#   '9',
#   '1',
#   '0',
#   datetime.datetime(2018, 3, 17, 10, 34),
#   0],
#  ['난 나야(jj81****)',
#   '대박!!!  한순간도 놓칠수 없어요~~ 눈과 귀가 호강하는 영화입니다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 24, 11, 18),
#   0],
#  ['김다희(tkfs****)',
#   '영화는 20OOO때봄  지금22살인데.. 어릴때 피아노 유튭영상만봤었는데..  영화로보니 순수하고 아련한 영화인듯.. 첫사랑이 떠오르는 명작',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 19, 23, 15),
#   0],
#  ['sky park(aodc****)',
#   '달달함도 이런 달달함이 없다. 이 영화 기억에 오래 남는다.',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 19, 20, 31),
#   0],
#  ['paulsoil2(paul****)',
#   '오랜만에 심장이 뛰는 영화를 봤다',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 16, 21, 53),
#   0],
#  ['중코중코(wjdx****)',
#   "'환상적이다' 라는 표현은 이럴 때 쓰라고 있는거같다.",
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 10, 16, 5),
#   0],
#  ['whaa****',
#   '대만 영화 특유의 달달함 말할수없는 비밀 그시절 우리가 좋아했던 소녀 인생영화 1,2위',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 9, 9, 19),
#   0],
#  ['1415(mms7****)',
#   '내 인생 최고의 로맨스 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 2, 9, 4, 42),
#   0],
#  ['fbwnsduf(gpwn****)',
#   '좀 무서웠는데.. 그래도 이런 영화는 진짜 대박이라고생각했어요!!!',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 1, 23, 18, 5),
#   0],
#  ['이정현(jh69****)',
#   '20점 줄게요 주걸륜 개사랑해',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 1, 22, 22, 49),
#   0],
#  ['바보(yuky****)',
#   '단언컨데 내 인생에서 가장 설레였던 영화',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 1, 22, 3, 10),
#   0],
#  ['STAR JUHA(wngk****)',
#   '노래 개 쩐다  평점 100이듯 명작 탄생',
#   '10',
#   '1',
#   '0',
#   datetime.datetime(2018, 1, 17, 17, 54),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                     0  ...    6
# 0      와리천재(gusw****)  ...    0
# 1       바나나(8745****)  ...    0
# 2         별(lya9****)  ...    0
# 3       김민영(myki****)  ...    0
# 4        하냥(chlt****)  ...    0
# ...               ...  ...  ...
# 37725   응억이(sehi****)  ...    0
# 37726   시네마(kpar****)  ...    0
# 37727  망고스틴(sonn****)  ...    0
# 37728   김윤희(kimy****)  ...  관람객
# 37729   모르텐(khyn****)  ...    0
#
# [37730 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#              nickname  ... watch_movie
# 0      와리천재(gusw****)  ...           0
# 1       바나나(8745****)  ...           0
# 2         별(lya9****)  ...           0
# 3       김민영(myki****)  ...           0
# 4        하냥(chlt****)  ...           0
# ...               ...  ...         ...
# 37725   응억이(sehi****)  ...           0
# 37726   시네마(kpar****)  ...           0
# 37727  망고스틴(sonn****)  ...           0
# 37728   김윤희(kimy****)  ...         관람객
# 37729   모르텐(khyn****)  ...           0
#
# [37730 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
