# %% [markdown]
# <a href="https://colab.research.google.com/github/Baekhyeonjeong/Baekhyeonjeong/blob/main/%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%9D%BC%EB%9D%BC%EB%9E%9C%EB%93%9C_%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 107924
total_count = 19653  ## 전체 크기=19,653

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1884
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1885
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1886
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1887
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1888
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1889
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1890
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1891
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1892
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1893
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1894
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1895
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1896
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1897
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1898
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1899
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1900
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1901
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1902
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1903
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1904
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1905
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1906
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1907
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1908
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1909
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1910
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1911
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1912
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1913
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1914
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1915
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1916
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1917
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1965

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20200417110808" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20200417110808" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20200417110808" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20200417110808" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="161967"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>36,529</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738216, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>brilliant_AKA_밝음(bril****)</span>
# </a>
# </em>
# <em>2019.05.30 15:58</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','bril****', 'CyNhpJ+qkjXfv8NY+ybBa3IwKx8Uf0vOBr+s8Bk5owM=', '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 ', '15738216', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738216">28791</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738216">1504</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>김희정(priv****)</span>
# </a>
# </em>
# <em>2019.05.30 12:25</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','priv****', 'jjv6qM3ZHF+lm+39Ztvra2Lo83lph6tORA6Ng1vSq7c=', '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데.. ', '15736627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736627">18779</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736627">1586</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737678, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>리오(papi****)</span>
# </a>
# </em>
# <em>2019.05.30 14:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','papi****', 'MTkAnDzFvty9bU2B71ZQzyRKjwY2JaVjKPdGGzAr/dg=', '지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다. ', '15737678', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737678">17453</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737678">1113</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738415, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>멍뭉이(sumi****)</span>
# </a>
# </em>
# <em>2019.05.30 16:28</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sumi****', 'sgYqpMep7dXfkS9MIe7PUYd7jFWtdgzLJkaBtub5awU=', '전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화 ', '15738415', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738415">17034</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738415">936</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737905, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>여행의 발견(riod****)</span>
# </a>
# </em>
# <em>2019.05.30 15:13</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','riod****', 'juqbdcsvFbC66hNLcJoPL915nTb3fG9phj/JBg2Onu4=', '황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다. ', '15737905', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737905">16034</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737905">802</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15743239, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>페르(sa02****)</span>
# </a>
# </em>
# <em>2019.05.31 01:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sa02****', 'oNASB02ZlvYtjSbLjY7Ad7LZYBuFnabVFbcmNshznE8=', '반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다. ', '15743239', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15743239">12886</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15743239">299</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15735958, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>크렙하스(powe****)</span>
# </a>
# </em>
# <em>2019.05.30 10:50</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','powe****', '9TuTPRPp8SJGxhDYjew+C/fTE2ULWMVtUC9FMuzzpY0=', '뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다. ', '15735958', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15735958">12245</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15735958">729</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736477, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>도미(dudd****)</span>
# </a>
# </em>
# <em>2019.05.30 12:05</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','dudd****', 'amVW2iA/7hvLRy9PjeSN9h5lJCLI6OoVWO3oTlzrJfg=', '누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다. ', '15736477', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736477">11199</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736477">493</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																박서준이 잘못했네ㅋㅋㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737802, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>구마(gym9****)</span>
# </a>
# </em>
# <em>2019.05.30 15:01</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gym9****', 'a9/eGsZ8229Knvoa9cSby+xkeIpPHG996qjVe+AagTY=', '박서준이 잘못했네ㅋㅋㅋㅋ ', '15737802', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737802">10863</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737802">443</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737882, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>블루이즈(cank****)</span>
# </a>
# </em>
# <em>2019.05.30 15:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','cank****', 'dPSPsRFbLOmFyijW3aatPuDcOm8ywHmehVCD+QR4qYw=', '나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나.. ', '15737882', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737882">10612</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737882">380</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "161967",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=161967#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=161967#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("161967", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738216, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>brilliant_AKA_밝음(bril****)</span>
# </a>
# </em>
# <em>2019.05.30 15:58</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','bril****', 'CyNhpJ+qkjXfv8NY+ybBa3IwKx8Uf0vOBr+s8Bk5owM=', '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 ', '15738216', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738216">28791</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738216">1504</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>김희정(priv****)</span>
# </a>
# </em>
# <em>2019.05.30 12:25</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','priv****', 'ia+L3ovTsOJOamiddckFuEgyDXZKv2w/A+UcZ4F0fPk=', '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데.. ', '15736627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736627">18753</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736627">1586</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 내용
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('28749', '1501')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'brilliant_AKA_밝음(bril****)'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2019, 5, 30, 15, 58)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 134963
total_count = 23467  ## 전체 크기=36524

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....
# 501 번째 페이지 parsing....
# 502 번째 페이지 parsing....
# 503 번째 페이지 parsing....
# 504 번째 페이지 parsing....
# 505 번째 페이지 parsing....
# 506 번째 페이지 parsing....
# 507 번째 페이지 parsing....
# 508 번째 페이지 parsing....
# 509 번째 페이지 parsing....
# 510 번째 페이지 parsing....
# 511 번째 페이지 parsing....
# 512 번째 페이지 parsing....
# 513 번째 페이지 parsing....
# 514 번째 페이지 parsing....
# 515 번째 페이지 parsing....
# 516 번째 페이지 parsing....
# 517 번째 페이지 parsing....
# 518 번째 페이지 parsing....
# 519 번째 페이지 parsing....
# 520 번째 페이지 parsing....
# 521 번째 페이지 parsing....
# 522 번째 페이지 parsing....
# 523 번째 페이지 parsing....
# 524 번째 페이지 parsing....
# 525 번째 페이지 parsing....
# 526 번째 페이지 parsing....
# 527 번째 페이지 parsing....
# 528 번째 페이지 parsing....
# 529 번째 페이지 parsing....
# 530 번째 페이지 parsing....
# 531 번째 페이지 parsing....
# 532 번째 페이지 parsing....
# 533 번째 페이지 parsing....
# 534 번째 페이지 parsing....
# 535 번째 페이지 parsing....
# 536 번째 페이지 parsing....
# 537 번째 페이지 parsing....
# 538 번째 페이지 parsing....
# 539 번째 페이지 parsing....
# 540 번째 페이지 parsing....
# 541 번째 페이지 parsing....
# 542 번째 페이지 parsing....
# 543 번째 페이지 parsing....
# 544 번째 페이지 parsing....
# 545 번째 페이지 parsing....
# 546 번째 페이지 parsing....
# 547 번째 페이지 parsing....
# 548 번째 페이지 parsing....
# 549 번째 페이지 parsing....
# 550 번째 페이지 parsing....
# 551 번째 페이지 parsing....
# 552 번째 페이지 parsing....
# 553 번째 페이지 parsing....
# 554 번째 페이지 parsing....
# 555 번째 페이지 parsing....
# 556 번째 페이지 parsing....
# 557 번째 페이지 parsing....
# 558 번째 페이지 parsing....
# 559 번째 페이지 parsing....
# 560 번째 페이지 parsing....
# 561 번째 페이지 parsing....
# 562 번째 페이지 parsing....
# 563 번째 페이지 parsing....
# 564 번째 페이지 parsing....
# 565 번째 페이지 parsing....
# 566 번째 페이지 parsing....
# 567 번째 페이지 parsing....
# 568 번째 페이지 parsing....
# 569 번째 페이지 parsing....
# 570 번째 페이지 parsing....
# 571 번째 페이지 parsing....
# 572 번째 페이지 parsing....
# 573 번째 페이지 parsing....
# 574 번째 페이지 parsing....
# 575 번째 페이지 parsing....
# 576 번째 페이지 parsing....
# 577 번째 페이지 parsing....
# 578 번째 페이지 parsing....
# 579 번째 페이지 parsing....
# 580 번째 페이지 parsing....
# 581 번째 페이지 parsing....
# 582 번째 페이지 parsing....
# 583 번째 페이지 parsing....
# 584 번째 페이지 parsing....
# 585 번째 페이지 parsing....
# 586 번째 페이지 parsing....
# 587 번째 페이지 parsing....
# 588 번째 페이지 parsing....
# 589 번째 페이지 parsing....
# 590 번째 페이지 parsing....
# 591 번째 페이지 parsing....
# 592 번째 페이지 parsing....
# 593 번째 페이지 parsing....
# 594 번째 페이지 parsing....
# 595 번째 페이지 parsing....
# 596 번째 페이지 parsing....
# 597 번째 페이지 parsing....
# 598 번째 페이지 parsing....
# 599 번째 페이지 parsing....
# 600 번째 페이지 parsing....
# 601 번째 페이지 parsing....
# 602 번째 페이지 parsing....
# 603 번째 페이지 parsing....
# 604 번째 페이지 parsing....
# 605 번째 페이지 parsing....
# 606 번째 페이지 parsing....
# 607 번째 페이지 parsing....
# 608 번째 페이지 parsing....
# 609 번째 페이지 parsing....
# 610 번째 페이지 parsing....
# 611 번째 페이지 parsing....
# 612 번째 페이지 parsing....
# 613 번째 페이지 parsing....
# 614 번째 페이지 parsing....
# 615 번째 페이지 parsing....
# 616 번째 페이지 parsing....
# 617 번째 페이지 parsing....
# 618 번째 페이지 parsing....
# 619 번째 페이지 parsing....
# 620 번째 페이지 parsing....
# 621 번째 페이지 parsing....
# 622 번째 페이지 parsing....
# 623 번째 페이지 parsing....
# 624 번째 페이지 parsing....
# 625 번째 페이지 parsing....
# 626 번째 페이지 parsing....
# 627 번째 페이지 parsing....
# 628 번째 페이지 parsing....
# 629 번째 페이지 parsing....
# 630 번째 페이지 parsing....
# 631 번째 페이지 parsing....
# 632 번째 페이지 parsing....
# 633 번째 페이지 parsing....
# 634 번째 페이지 parsing....
# 635 번째 페이지 parsing....
# 636 번째 페이지 parsing....
# 637 번째 페이지 parsing....
# 638 번째 페이지 parsing....
# 639 번째 페이지 parsing....
# 640 번째 페이지 parsing....
# 641 번째 페이지 parsing....
# 642 번째 페이지 parsing....
# 643 번째 페이지 parsing....
# 644 번째 페이지 parsing....
# 645 번째 페이지 parsing....
# 646 번째 페이지 parsing....
# 647 번째 페이지 parsing....
# 648 번째 페이지 parsing....
# 649 번째 페이지 parsing....
# 650 번째 페이지 parsing....
# 651 번째 페이지 parsing....
# 652 번째 페이지 parsing....
# 653 번째 페이지 parsing....
# 654 번째 페이지 parsing....
# 655 번째 페이지 parsing....
# 656 번째 페이지 parsing....
# 657 번째 페이지 parsing....
# 658 번째 페이지 parsing....
# 659 번째 페이지 parsing....
# 660 번째 페이지 parsing....
# 661 번째 페이지 parsing....
# 662 번째 페이지 parsing....
# 663 번째 페이지 parsing....
# 664 번째 페이지 parsing....
# 665 번째 페이지 parsing....
# 666 번째 페이지 parsing....
# 667 번째 페이지 parsing....
# 668 번째 페이지 parsing....
# 669 번째 페이지 parsing....
# 670 번째 페이지 parsing....
# 671 번째 페이지 parsing....
# 672 번째 페이지 parsing....
# 673 번째 페이지 parsing....
# 674 번째 페이지 parsing....
# 675 번째 페이지 parsing....
# 676 번째 페이지 parsing....
# 677 번째 페이지 parsing....
# 678 번째 페이지 parsing....
# 679 번째 페이지 parsing....
# 680 번째 페이지 parsing....
# 681 번째 페이지 parsing....
# 682 번째 페이지 parsing....
# 683 번째 페이지 parsing....
# 684 번째 페이지 parsing....
# 685 번째 페이지 parsing....
# 686 번째 페이지 parsing....
# 687 번째 페이지 parsing....
# 688 번째 페이지 parsing....
# 689 번째 페이지 parsing....
# 690 번째 페이지 parsing....
# 691 번째 페이지 parsing....
# 692 번째 페이지 parsing....
# 693 번째 페이지 parsing....
# 694 번째 페이지 parsing....
# 695 번째 페이지 parsing....
# 696 번째 페이지 parsing....
# 697 번째 페이지 parsing....
# 698 번째 페이지 parsing....
# 699 번째 페이지 parsing....
# 700 번째 페이지 parsing....
# 701 번째 페이지 parsing....
# 702 번째 페이지 parsing....
# 703 번째 페이지 parsing....
# 704 번째 페이지 parsing....
# 705 번째 페이지 parsing....
# 706 번째 페이지 parsing....
# 707 번째 페이지 parsing....
# 708 번째 페이지 parsing....
# 709 번째 페이지 parsing....
# 710 번째 페이지 parsing....
# 711 번째 페이지 parsing....
# 712 번째 페이지 parsing....
# 713 번째 페이지 parsing....
# 714 번째 페이지 parsing....
# 715 번째 페이지 parsing....
# 716 번째 페이지 parsing....
# 717 번째 페이지 parsing....
# 718 번째 페이지 parsing....
# 719 번째 페이지 parsing....
# 720 번째 페이지 parsing....
# 721 번째 페이지 parsing....
# 722 번째 페이지 parsing....
# 723 번째 페이지 parsing....
# 724 번째 페이지 parsing....
# 725 번째 페이지 parsing....
# 726 번째 페이지 parsing....
# 727 번째 페이지 parsing....
# 728 번째 페이지 parsing....
# 729 번째 페이지 parsing....
# 730 번째 페이지 parsing....
# 731 번째 페이지 parsing....
# 732 번째 페이지 parsing....
# 733 번째 페이지 parsing....
# 734 번째 페이지 parsing....
# 735 번째 페이지 parsing....
# 736 번째 페이지 parsing....
# 737 번째 페이지 parsing....
# 738 번째 페이지 parsing....
# 739 번째 페이지 parsing....
# 740 번째 페이지 parsing....
# 741 번째 페이지 parsing....
# 742 번째 페이지 parsing....
# 743 번째 페이지 parsing....
# 744 번째 페이지 parsing....
# 745 번째 페이지 parsing....
# 746 번째 페이지 parsing....
# 747 번째 페이지 parsing....
# 748 번째 페이지 parsing....
# 749 번째 페이지 parsing....
# 750 번째 페이지 parsing....
# 751 번째 페이지 parsing....
# 752 번째 페이지 parsing....
# 753 번째 페이지 parsing....
# 754 번째 페이지 parsing....
# 755 번째 페이지 parsing....
# 756 번째 페이지 parsing....
# 757 번째 페이지 parsing....
# 758 번째 페이지 parsing....
# 759 번째 페이지 parsing....
# 760 번째 페이지 parsing....
# 761 번째 페이지 parsing....
# 762 번째 페이지 parsing....
# 763 번째 페이지 parsing....
# 764 번째 페이지 parsing....
# 765 번째 페이지 parsing....
# 766 번째 페이지 parsing....
# 767 번째 페이지 parsing....
# 768 번째 페이지 parsing....
# 769 번째 페이지 parsing....
# 770 번째 페이지 parsing....
# 771 번째 페이지 parsing....
# 772 번째 페이지 parsing....
# 773 번째 페이지 parsing....
# 774 번째 페이지 parsing....
# 775 번째 페이지 parsing....
# 776 번째 페이지 parsing....
# 777 번째 페이지 parsing....
# 778 번째 페이지 parsing....
# 779 번째 페이지 parsing....
# 780 번째 페이지 parsing....
# 781 번째 페이지 parsing....
# 782 번째 페이지 parsing....
# 783 번째 페이지 parsing....
# 784 번째 페이지 parsing....
# 785 번째 페이지 parsing....
# 786 번째 페이지 parsing....
# 787 번째 페이지 parsing....
# 788 번째 페이지 parsing....
# 789 번째 페이지 parsing....
# 790 번째 페이지 parsing....
# 791 번째 페이지 parsing....
# 792 번째 페이지 parsing....
# 793 번째 페이지 parsing....
# 794 번째 페이지 parsing....
# 795 번째 페이지 parsing....
# 796 번째 페이지 parsing....
# 797 번째 페이지 parsing....
# 798 번째 페이지 parsing....
# 799 번째 페이지 parsing....
# 800 번째 페이지 parsing....
# 801 번째 페이지 parsing....
# 802 번째 페이지 parsing....
# 803 번째 페이지 parsing....
# 804 번째 페이지 parsing....
# 805 번째 페이지 parsing....
# 806 번째 페이지 parsing....
# 807 번째 페이지 parsing....
# 808 번째 페이지 parsing....
# 809 번째 페이지 parsing....
# 810 번째 페이지 parsing....
# 811 번째 페이지 parsing....
# 812 번째 페이지 parsing....
# 813 번째 페이지 parsing....
# 814 번째 페이지 parsing....
# 815 번째 페이지 parsing....
# 816 번째 페이지 parsing....
# 817 번째 페이지 parsing....
# 818 번째 페이지 parsing....
# 819 번째 페이지 parsing....
# 820 번째 페이지 parsing....
# 821 번째 페이지 parsing....
# 822 번째 페이지 parsing....
# 823 번째 페이지 parsing....
# 824 번째 페이지 parsing....
# 825 번째 페이지 parsing....
# 826 번째 페이지 parsing....
# 827 번째 페이지 parsing....
# 828 번째 페이지 parsing....
# 829 번째 페이지 parsing....
# 830 번째 페이지 parsing....
# 831 번째 페이지 parsing....
# 832 번째 페이지 parsing....
# 833 번째 페이지 parsing....
# 834 번째 페이지 parsing....
# 835 번째 페이지 parsing....
# 836 번째 페이지 parsing....
# 837 번째 페이지 parsing....
# 838 번째 페이지 parsing....
# 839 번째 페이지 parsing....
# 840 번째 페이지 parsing....
# 841 번째 페이지 parsing....
# 842 번째 페이지 parsing....
# 843 번째 페이지 parsing....
# 844 번째 페이지 parsing....
# 845 번째 페이지 parsing....
# 846 번째 페이지 parsing....
# 847 번째 페이지 parsing....
# 848 번째 페이지 parsing....
# 849 번째 페이지 parsing....
# 850 번째 페이지 parsing....
# 851 번째 페이지 parsing....
# 852 번째 페이지 parsing....
# 853 번째 페이지 parsing....
# 854 번째 페이지 parsing....
# 855 번째 페이지 parsing....
# 856 번째 페이지 parsing....
# 857 번째 페이지 parsing....
# 858 번째 페이지 parsing....
# 859 번째 페이지 parsing....
# 860 번째 페이지 parsing....
# 861 번째 페이지 parsing....
# 862 번째 페이지 parsing....
# 863 번째 페이지 parsing....
# 864 번째 페이지 parsing....
# 865 번째 페이지 parsing....
# 866 번째 페이지 parsing....
# 867 번째 페이지 parsing....
# 868 번째 페이지 parsing....
# 869 번째 페이지 parsing....
# 870 번째 페이지 parsing....
# 871 번째 페이지 parsing....
# 872 번째 페이지 parsing....
# 873 번째 페이지 parsing....
# 874 번째 페이지 parsing....
# 875 번째 페이지 parsing....
# 876 번째 페이지 parsing....
# 877 번째 페이지 parsing....
# 878 번째 페이지 parsing....
# 879 번째 페이지 parsing....
# 880 번째 페이지 parsing....
# 881 번째 페이지 parsing....
# 882 번째 페이지 parsing....
# 883 번째 페이지 parsing....
# 884 번째 페이지 parsing....
# 885 번째 페이지 parsing....
# 886 번째 페이지 parsing....
# 887 번째 페이지 parsing....
# 888 번째 페이지 parsing....
# 889 번째 페이지 parsing....
# 890 번째 페이지 parsing....
# 891 번째 페이지 parsing....
# 892 번째 페이지 parsing....
# 893 번째 페이지 parsing....
# 894 번째 페이지 parsing....
# 895 번째 페이지 parsing....
# 896 번째 페이지 parsing....
# 897 번째 페이지 parsing....
# 898 번째 페이지 parsing....
# 899 번째 페이지 parsing....
# 900 번째 페이지 parsing....
# 901 번째 페이지 parsing....
# 902 번째 페이지 parsing....
# 903 번째 페이지 parsing....
# 904 번째 페이지 parsing....
# 905 번째 페이지 parsing....
# 906 번째 페이지 parsing....
# 907 번째 페이지 parsing....
# 908 번째 페이지 parsing....
# 909 번째 페이지 parsing....
# 910 번째 페이지 parsing....
# 911 번째 페이지 parsing....
# 912 번째 페이지 parsing....
# 913 번째 페이지 parsing....
# 914 번째 페이지 parsing....
# 915 번째 페이지 parsing....
# 916 번째 페이지 parsing....
# 917 번째 페이지 parsing....
# 918 번째 페이지 parsing....
# 919 번째 페이지 parsing....
# 920 번째 페이지 parsing....
# 921 번째 페이지 parsing....
# 922 번째 페이지 parsing....
# 923 번째 페이지 parsing....
# 924 번째 페이지 parsing....
# 925 번째 페이지 parsing....
# 926 번째 페이지 parsing....
# 927 번째 페이지 parsing....
# 928 번째 페이지 parsing....
# 929 번째 페이지 parsing....
# 930 번째 페이지 parsing....
# 931 번째 페이지 parsing....
# 932 번째 페이지 parsing....
# 933 번째 페이지 parsing....
# 934 번째 페이지 parsing....
# 935 번째 페이지 parsing....
# 936 번째 페이지 parsing....
# 937 번째 페이지 parsing....
# 938 번째 페이지 parsing....
# 939 번째 페이지 parsing....
# 940 번째 페이지 parsing....
# 941 번째 페이지 parsing....
# 942 번째 페이지 parsing....
# 943 번째 페이지 parsing....
# 944 번째 페이지 parsing....
# 945 번째 페이지 parsing....
# 946 번째 페이지 parsing....
# 947 번째 페이지 parsing....
# 948 번째 페이지 parsing....
# 949 번째 페이지 parsing....
# 950 번째 페이지 parsing....
# 951 번째 페이지 parsing....
# 952 번째 페이지 parsing....
# 953 번째 페이지 parsing....
# 954 번째 페이지 parsing....
# 955 번째 페이지 parsing....
# 956 번째 페이지 parsing....
# 957 번째 페이지 parsing....
# 958 번째 페이지 parsing....
# 959 번째 페이지 parsing....
# 960 번째 페이지 parsing....
# 961 번째 페이지 parsing....
# 962 번째 페이지 parsing....
# 963 번째 페이지 parsing....
# 964 번째 페이지 parsing....
# 965 번째 페이지 parsing....
# 966 번째 페이지 parsing....
# 967 번째 페이지 parsing....
# 968 번째 페이지 parsing....
# 969 번째 페이지 parsing....
# 970 번째 페이지 parsing....
# 971 번째 페이지 parsing....
# 972 번째 페이지 parsing....
# 973 번째 페이지 parsing....
# 974 번째 페이지 parsing....
# 975 번째 페이지 parsing....
# 976 번째 페이지 parsing....
# 977 번째 페이지 parsing....
# 978 번째 페이지 parsing....
# 979 번째 페이지 parsing....
# 980 번째 페이지 parsing....
# 981 번째 페이지 parsing....
# 982 번째 페이지 parsing....
# 983 번째 페이지 parsing....
# 984 번째 페이지 parsing....
# 985 번째 페이지 parsing....
# 986 번째 페이지 parsing....
# 987 번째 페이지 parsing....
# 988 번째 페이지 parsing....
# 989 번째 페이지 parsing....
# 990 번째 페이지 parsing....
# 991 번째 페이지 parsing....
# 992 번째 페이지 parsing....
# 993 번째 페이지 parsing....
# 994 번째 페이지 parsing....
# 995 번째 페이지 parsing....
# 996 번째 페이지 parsing....
# 997 번째 페이지 parsing....
# 998 번째 페이지 parsing....
# 999 번째 페이지 parsing....
# 1000 번째 페이지 parsing....
# 1001 번째 페이지 parsing....
# 1002 번째 페이지 parsing....
# 1003 번째 페이지 parsing....
# 1004 번째 페이지 parsing....
# 1005 번째 페이지 parsing....
# 1006 번째 페이지 parsing....
# 1007 번째 페이지 parsing....
# 1008 번째 페이지 parsing....
# 1009 번째 페이지 parsing....
# 1010 번째 페이지 parsing....
# 1011 번째 페이지 parsing....
# 1012 번째 페이지 parsing....
# 1013 번째 페이지 parsing....
# 1014 번째 페이지 parsing....
# 1015 번째 페이지 parsing....
# 1016 번째 페이지 parsing....
# 1017 번째 페이지 parsing....
# 1018 번째 페이지 parsing....
# 1019 번째 페이지 parsing....
# 1020 번째 페이지 parsing....
# 1021 번째 페이지 parsing....
# 1022 번째 페이지 parsing....
# 1023 번째 페이지 parsing....
# 1024 번째 페이지 parsing....
# 1025 번째 페이지 parsing....
# 1026 번째 페이지 parsing....
# 1027 번째 페이지 parsing....
# 1028 번째 페이지 parsing....
# 1029 번째 페이지 parsing....
# 1030 번째 페이지 parsing....
# 1031 번째 페이지 parsing....
# 1032 번째 페이지 parsing....
# 1033 번째 페이지 parsing....
# 1034 번째 페이지 parsing....
# 1035 번째 페이지 parsing....
# 1036 번째 페이지 parsing....
# 1037 번째 페이지 parsing....
# 1038 번째 페이지 parsing....
# 1039 번째 페이지 parsing....
# 1040 번째 페이지 parsing....
# 1041 번째 페이지 parsing....
# 1042 번째 페이지 parsing....
# 1043 번째 페이지 parsing....
# 1044 번째 페이지 parsing....
# 1045 번째 페이지 parsing....
# 1046 번째 페이지 parsing....
# 1047 번째 페이지 parsing....
# 1048 번째 페이지 parsing....
# 1049 번째 페이지 parsing....
# 1050 번째 페이지 parsing....
# 1051 번째 페이지 parsing....
# 1052 번째 페이지 parsing....
# 1053 번째 페이지 parsing....
# 1054 번째 페이지 parsing....
# 1055 번째 페이지 parsing....
# 1056 번째 페이지 parsing....
# 1057 번째 페이지 parsing....
# 1058 번째 페이지 parsing....
# 1059 번째 페이지 parsing....
# 1060 번째 페이지 parsing....
# 1061 번째 페이지 parsing....
# 1062 번째 페이지 parsing....
# 1063 번째 페이지 parsing....
# 1064 번째 페이지 parsing....
# 1065 번째 페이지 parsing....
# 1066 번째 페이지 parsing....
# 1067 번째 페이지 parsing....
# 1068 번째 페이지 parsing....
# 1069 번째 페이지 parsing....
# 1070 번째 페이지 parsing....
# 1071 번째 페이지 parsing....
# 1072 번째 페이지 parsing....
# 1073 번째 페이지 parsing....
# 1074 번째 페이지 parsing....
# 1075 번째 페이지 parsing....
# 1076 번째 페이지 parsing....
# 1077 번째 페이지 parsing....
# 1078 번째 페이지 parsing....
# 1079 번째 페이지 parsing....
# 1080 번째 페이지 parsing....
# 1081 번째 페이지 parsing....
# 1082 번째 페이지 parsing....
# 1083 번째 페이지 parsing....
# 1084 번째 페이지 parsing....
# 1085 번째 페이지 parsing....
# 1086 번째 페이지 parsing....
# 1087 번째 페이지 parsing....
# 1088 번째 페이지 parsing....
# 1089 번째 페이지 parsing....
# 1090 번째 페이지 parsing....
# 1091 번째 페이지 parsing....
# 1092 번째 페이지 parsing....
# 1093 번째 페이지 parsing....
# 1094 번째 페이지 parsing....
# 1095 번째 페이지 parsing....
# 1096 번째 페이지 parsing....
# 1097 번째 페이지 parsing....
# 1098 번째 페이지 parsing....
# 1099 번째 페이지 parsing....
# 1100 번째 페이지 parsing....
# 1101 번째 페이지 parsing....
# 1102 번째 페이지 parsing....
# 1103 번째 페이지 parsing....
# 1104 번째 페이지 parsing....
# 1105 번째 페이지 parsing....
# 1106 번째 페이지 parsing....
# 1107 번째 페이지 parsing....
# 1108 번째 페이지 parsing....
# 1109 번째 페이지 parsing....
# 1110 번째 페이지 parsing....
# 1111 번째 페이지 parsing....
# 1112 번째 페이지 parsing....
# 1113 번째 페이지 parsing....
# 1114 번째 페이지 parsing....
# 1115 번째 페이지 parsing....
# 1116 번째 페이지 parsing....
# 1117 번째 페이지 parsing....
# 1118 번째 페이지 parsing....
# 1119 번째 페이지 parsing....
# 1120 번째 페이지 parsing....
# 1121 번째 페이지 parsing....
# 1122 번째 페이지 parsing....
# 1123 번째 페이지 parsing....
# 1124 번째 페이지 parsing....
# 1125 번째 페이지 parsing....
# 1126 번째 페이지 parsing....
# 1127 번째 페이지 parsing....
# 1128 번째 페이지 parsing....
# 1129 번째 페이지 parsing....
# 1130 번째 페이지 parsing....
# 1131 번째 페이지 parsing....
# 1132 번째 페이지 parsing....
# 1133 번째 페이지 parsing....
# 1134 번째 페이지 parsing....
# 1135 번째 페이지 parsing....
# 1136 번째 페이지 parsing....
# 1137 번째 페이지 parsing....
# 1138 번째 페이지 parsing....
# 1139 번째 페이지 parsing....
# 1140 번째 페이지 parsing....
# 1141 번째 페이지 parsing....
# 1142 번째 페이지 parsing....
# 1143 번째 페이지 parsing....
# 1144 번째 페이지 parsing....
# 1145 번째 페이지 parsing....
# 1146 번째 페이지 parsing....
# 1147 번째 페이지 parsing....
# 1148 번째 페이지 parsing....
# 1149 번째 페이지 parsing....
# 1150 번째 페이지 parsing....
# 1151 번째 페이지 parsing....
# 1152 번째 페이지 parsing....
# 1153 번째 페이지 parsing....
# 1154 번째 페이지 parsing....
# 1155 번째 페이지 parsing....
# 1156 번째 페이지 parsing....
# 1157 번째 페이지 parsing....
# 1158 번째 페이지 parsing....
# 1159 번째 페이지 parsing....
# 1160 번째 페이지 parsing....
# 1161 번째 페이지 parsing....
# 1162 번째 페이지 parsing....
# 1163 번째 페이지 parsing....
# 1164 번째 페이지 parsing....
# 1165 번째 페이지 parsing....
# 1166 번째 페이지 parsing....
# 1167 번째 페이지 parsing....
# 1168 번째 페이지 parsing....
# 1169 번째 페이지 parsing....
# 1170 번째 페이지 parsing....
# 1171 번째 페이지 parsing....
# 1172 번째 페이지 parsing....
# 1173 번째 페이지 parsing....
# 1174 번째 페이지 parsing....
# 1175 번째 페이지 parsing....
# 1176 번째 페이지 parsing....
# 1177 번째 페이지 parsing....
# 1178 번째 페이지 parsing....
# 1179 번째 페이지 parsing....
# 1180 번째 페이지 parsing....
# 1181 번째 페이지 parsing....
# 1182 번째 페이지 parsing....
# 1183 번째 페이지 parsing....
# 1184 번째 페이지 parsing....
# 1185 번째 페이지 parsing....
# 1186 번째 페이지 parsing....
# 1187 번째 페이지 parsing....
# 1188 번째 페이지 parsing....
# 1189 번째 페이지 parsing....
# 1190 번째 페이지 parsing....
# 1191 번째 페이지 parsing....
# 1192 번째 페이지 parsing....
# 1193 번째 페이지 parsing....
# 1194 번째 페이지 parsing....
# 1195 번째 페이지 parsing....
# 1196 번째 페이지 parsing....
# 1197 번째 페이지 parsing....
# 1198 번째 페이지 parsing....
# 1199 번째 페이지 parsing....
# 1200 번째 페이지 parsing....
# 1201 번째 페이지 parsing....
# 1202 번째 페이지 parsing....
# 1203 번째 페이지 parsing....
# 1204 번째 페이지 parsing....
# 1205 번째 페이지 parsing....
# 1206 번째 페이지 parsing....
# 1207 번째 페이지 parsing....
# 1208 번째 페이지 parsing....
# 1209 번째 페이지 parsing....
# 1210 번째 페이지 parsing....
# 1211 번째 페이지 parsing....
# 1212 번째 페이지 parsing....
# 1213 번째 페이지 parsing....
# 1214 번째 페이지 parsing....
# 1215 번째 페이지 parsing....
# 1216 번째 페이지 parsing....
# 1217 번째 페이지 parsing....
# 1218 번째 페이지 parsing....
# 1219 번째 페이지 parsing....
# 1220 번째 페이지 parsing....
# 1221 번째 페이지 parsing....
# 1222 번째 페이지 parsing....
# 1223 번째 페이지 parsing....
# 1224 번째 페이지 parsing....
# 1225 번째 페이지 parsing....
# 1226 번째 페이지 parsing....
# 1227 번째 페이지 parsing....
# 1228 번째 페이지 parsing....
# 1229 번째 페이지 parsing....
# 1230 번째 페이지 parsing....
# 1231 번째 페이지 parsing....
# 1232 번째 페이지 parsing....
# 1233 번째 페이지 parsing....
# 1234 번째 페이지 parsing....
# 1235 번째 페이지 parsing....
# 1236 번째 페이지 parsing....
# 1237 번째 페이지 parsing....
# 1238 번째 페이지 parsing....
# 1239 번째 페이지 parsing....
# 1240 번째 페이지 parsing....
# 1241 번째 페이지 parsing....
# 1242 번째 페이지 parsing....
# 1243 번째 페이지 parsing....
# 1244 번째 페이지 parsing....
# 1245 번째 페이지 parsing....
# 1246 번째 페이지 parsing....
# 1247 번째 페이지 parsing....
# 1248 번째 페이지 parsing....
# 1249 번째 페이지 parsing....
# 1250 번째 페이지 parsing....
# 1251 번째 페이지 parsing....
# 1252 번째 페이지 parsing....
# 1253 번째 페이지 parsing....
# 1254 번째 페이지 parsing....
# 1255 번째 페이지 parsing....
# 1256 번째 페이지 parsing....
# 1257 번째 페이지 parsing....
# 1258 번째 페이지 parsing....
# 1259 번째 페이지 parsing....
# 1260 번째 페이지 parsing....
# 1261 번째 페이지 parsing....
# 1262 번째 페이지 parsing....
# 1263 번째 페이지 parsing....
# 1264 번째 페이지 parsing....
# 1265 번째 페이지 parsing....
# 1266 번째 페이지 parsing....
# 1267 번째 페이지 parsing....
# 1268 번째 페이지 parsing....
# 1269 번째 페이지 parsing....
# 1270 번째 페이지 parsing....
# 1271 번째 페이지 parsing....
# 1272 번째 페이지 parsing....
# 1273 번째 페이지 parsing....
# 1274 번째 페이지 parsing....
# 1275 번째 페이지 parsing....
# 1276 번째 페이지 parsing....
# 1277 번째 페이지 parsing....
# 1278 번째 페이지 parsing....
# 1279 번째 페이지 parsing....
# 1280 번째 페이지 parsing....
# 1281 번째 페이지 parsing....
# 1282 번째 페이지 parsing....
# 1283 번째 페이지 parsing....
# 1284 번째 페이지 parsing....
# 1285 번째 페이지 parsing....
# 1286 번째 페이지 parsing....
# 1287 번째 페이지 parsing....
# 1288 번째 페이지 parsing....
# 1289 번째 페이지 parsing....
# 1290 번째 페이지 parsing....
# 1291 번째 페이지 parsing....
# 1292 번째 페이지 parsing....
# 1293 번째 페이지 parsing....
# 1294 번째 페이지 parsing....
# 1295 번째 페이지 parsing....
# 1296 번째 페이지 parsing....
# 1297 번째 페이지 parsing....
# 1298 번째 페이지 parsing....
# 1299 번째 페이지 parsing....
# 1300 번째 페이지 parsing....
# 1301 번째 페이지 parsing....
# 1302 번째 페이지 parsing....
# 1303 번째 페이지 parsing....
# 1304 번째 페이지 parsing....
# 1305 번째 페이지 parsing....
# 1306 번째 페이지 parsing....
# 1307 번째 페이지 parsing....
# 1308 번째 페이지 parsing....
# 1309 번째 페이지 parsing....
# 1310 번째 페이지 parsing....
# 1311 번째 페이지 parsing....
# 1312 번째 페이지 parsing....
# 1313 번째 페이지 parsing....
# 1314 번째 페이지 parsing....
# 1315 번째 페이지 parsing....
# 1316 번째 페이지 parsing....
# 1317 번째 페이지 parsing....
# 1318 번째 페이지 parsing....
# 1319 번째 페이지 parsing....
# 1320 번째 페이지 parsing....
# 1321 번째 페이지 parsing....
# 1322 번째 페이지 parsing....
# 1323 번째 페이지 parsing....
# 1324 번째 페이지 parsing....
# 1325 번째 페이지 parsing....
# 1326 번째 페이지 parsing....
# 1327 번째 페이지 parsing....
# 1328 번째 페이지 parsing....
# 1329 번째 페이지 parsing....
# 1330 번째 페이지 parsing....
# 1331 번째 페이지 parsing....
# 1332 번째 페이지 parsing....
# 1333 번째 페이지 parsing....
# 1334 번째 페이지 parsing....
# 1335 번째 페이지 parsing....
# 1336 번째 페이지 parsing....
# 1337 번째 페이지 parsing....
# 1338 번째 페이지 parsing....
# 1339 번째 페이지 parsing....
# 1340 번째 페이지 parsing....
# 1341 번째 페이지 parsing....
# 1342 번째 페이지 parsing....
# 1343 번째 페이지 parsing....
# 1344 번째 페이지 parsing....
# 1345 번째 페이지 parsing....
# 1346 번째 페이지 parsing....
# 1347 번째 페이지 parsing....
# 1348 번째 페이지 parsing....
# 1349 번째 페이지 parsing....
# 1350 번째 페이지 parsing....
# 1351 번째 페이지 parsing....
# 1352 번째 페이지 parsing....
# 1353 번째 페이지 parsing....
# 1354 번째 페이지 parsing....
# 1355 번째 페이지 parsing....
# 1356 번째 페이지 parsing....
# 1357 번째 페이지 parsing....
# 1358 번째 페이지 parsing....
# 1359 번째 페이지 parsing....
# 1360 번째 페이지 parsing....
# 1361 번째 페이지 parsing....
# 1362 번째 페이지 parsing....
# 1363 번째 페이지 parsing....
# 1364 번째 페이지 parsing....
# 1365 번째 페이지 parsing....
# 1366 번째 페이지 parsing....
# 1367 번째 페이지 parsing....
# 1368 번째 페이지 parsing....
# 1369 번째 페이지 parsing....
# 1370 번째 페이지 parsing....
# 1371 번째 페이지 parsing....
# 1372 번째 페이지 parsing....
# 1373 번째 페이지 parsing....
# 1374 번째 페이지 parsing....
# 1375 번째 페이지 parsing....
# 1376 번째 페이지 parsing....
# 1377 번째 페이지 parsing....
# 1378 번째 페이지 parsing....
# 1379 번째 페이지 parsing....
# 1380 번째 페이지 parsing....
# 1381 번째 페이지 parsing....
# 1382 번째 페이지 parsing....
# 1383 번째 페이지 parsing....
# 1384 번째 페이지 parsing....
# 1385 번째 페이지 parsing....
# 1386 번째 페이지 parsing....
# 1387 번째 페이지 parsing....
# 1388 번째 페이지 parsing....
# 1389 번째 페이지 parsing....
# 1390 번째 페이지 parsing....
# 1391 번째 페이지 parsing....
# 1392 번째 페이지 parsing....
# 1393 번째 페이지 parsing....
# 1394 번째 페이지 parsing....
# 1395 번째 페이지 parsing....
# 1396 번째 페이지 parsing....
# 1397 번째 페이지 parsing....
# 1398 번째 페이지 parsing....
# 1399 번째 페이지 parsing....
# 1400 번째 페이지 parsing....
# 1401 번째 페이지 parsing....
# 1402 번째 페이지 parsing....
# 1403 번째 페이지 parsing....
# 1404 번째 페이지 parsing....
# 1405 번째 페이지 parsing....
# 1406 번째 페이지 parsing....
# 1407 번째 페이지 parsing....
# 1408 번째 페이지 parsing....
# 1409 번째 페이지 parsing....
# 1410 번째 페이지 parsing....
# 1411 번째 페이지 parsing....
# 1412 번째 페이지 parsing....
# 1413 번째 페이지 parsing....
# 1414 번째 페이지 parsing....
# 1415 번째 페이지 parsing....
# 1416 번째 페이지 parsing....
# 1417 번째 페이지 parsing....
# 1418 번째 페이지 parsing....
# 1419 번째 페이지 parsing....
# 1420 번째 페이지 parsing....
# 1421 번째 페이지 parsing....
# 1422 번째 페이지 parsing....
# 1423 번째 페이지 parsing....
# 1424 번째 페이지 parsing....
# 1425 번째 페이지 parsing....
# 1426 번째 페이지 parsing....
# 1427 번째 페이지 parsing....
# 1428 번째 페이지 parsing....
# 1429 번째 페이지 parsing....
# 1430 번째 페이지 parsing....
# 1431 번째 페이지 parsing....
# 1432 번째 페이지 parsing....
# 1433 번째 페이지 parsing....
# 1434 번째 페이지 parsing....
# 1435 번째 페이지 parsing....
# 1436 번째 페이지 parsing....
# 1437 번째 페이지 parsing....
# 1438 번째 페이지 parsing....
# 1439 번째 페이지 parsing....
# 1440 번째 페이지 parsing....
# 1441 번째 페이지 parsing....
# 1442 번째 페이지 parsing....
# 1443 번째 페이지 parsing....
# 1444 번째 페이지 parsing....
# 1445 번째 페이지 parsing....
# 1446 번째 페이지 parsing....
# 1447 번째 페이지 parsing....
# 1448 번째 페이지 parsing....
# 1449 번째 페이지 parsing....
# 1450 번째 페이지 parsing....
# 1451 번째 페이지 parsing....
# 1452 번째 페이지 parsing....
# 1453 번째 페이지 parsing....
# 1454 번째 페이지 parsing....
# 1455 번째 페이지 parsing....
# 1456 번째 페이지 parsing....
# 1457 번째 페이지 parsing....
# 1458 번째 페이지 parsing....
# 1459 번째 페이지 parsing....
# 1460 번째 페이지 parsing....
# 1461 번째 페이지 parsing....
# 1462 번째 페이지 parsing....
# 1463 번째 페이지 parsing....
# 1464 번째 페이지 parsing....
# 1465 번째 페이지 parsing....
# 1466 번째 페이지 parsing....
# 1467 번째 페이지 parsing....
# 1468 번째 페이지 parsing....
# 1469 번째 페이지 parsing....
# 1470 번째 페이지 parsing....
# 1471 번째 페이지 parsing....
# 1472 번째 페이지 parsing....
# 1473 번째 페이지 parsing....
# 1474 번째 페이지 parsing....
# 1475 번째 페이지 parsing....
# 1476 번째 페이지 parsing....
# 1477 번째 페이지 parsing....
# 1478 번째 페이지 parsing....
# 1479 번째 페이지 parsing....
# 1480 번째 페이지 parsing....
# 1481 번째 페이지 parsing....
# 1482 번째 페이지 parsing....
# 1483 번째 페이지 parsing....
# 1484 번째 페이지 parsing....
# 1485 번째 페이지 parsing....
# 1486 번째 페이지 parsing....
# 1487 번째 페이지 parsing....
# 1488 번째 페이지 parsing....
# 1489 번째 페이지 parsing....
# 1490 번째 페이지 parsing....
# 1491 번째 페이지 parsing....
# 1492 번째 페이지 parsing....
# 1493 번째 페이지 parsing....
# 1494 번째 페이지 parsing....
# 1495 번째 페이지 parsing....
# 1496 번째 페이지 parsing....
# 1497 번째 페이지 parsing....
# 1498 번째 페이지 parsing....
# 1499 번째 페이지 parsing....
# 1500 번째 페이지 parsing....
# 1501 번째 페이지 parsing....
# 1502 번째 페이지 parsing....
# 1503 번째 페이지 parsing....
# 1504 번째 페이지 parsing....
# 1505 번째 페이지 parsing....
# 1506 번째 페이지 parsing....
# 1507 번째 페이지 parsing....
# 1508 번째 페이지 parsing....
# 1509 번째 페이지 parsing....
# 1510 번째 페이지 parsing....
# 1511 번째 페이지 parsing....
# 1512 번째 페이지 parsing....
# 1513 번째 페이지 parsing....
# 1514 번째 페이지 parsing....
# 1515 번째 페이지 parsing....
# 1516 번째 페이지 parsing....
# 1517 번째 페이지 parsing....
# 1518 번째 페이지 parsing....
# 1519 번째 페이지 parsing....
# 1520 번째 페이지 parsing....
# 1521 번째 페이지 parsing....
# 1522 번째 페이지 parsing....
# 1523 번째 페이지 parsing....
# 1524 번째 페이지 parsing....
# 1525 번째 페이지 parsing....
# 1526 번째 페이지 parsing....
# 1527 번째 페이지 parsing....
# 1528 번째 페이지 parsing....
# 1529 번째 페이지 parsing....
# 1530 번째 페이지 parsing....
# 1531 번째 페이지 parsing....
# 1532 번째 페이지 parsing....
# 1533 번째 페이지 parsing....
# 1534 번째 페이지 parsing....
# 1535 번째 페이지 parsing....
# 1536 번째 페이지 parsing....
# 1537 번째 페이지 parsing....
# 1538 번째 페이지 parsing....
# 1539 번째 페이지 parsing....
# 1540 번째 페이지 parsing....
# 1541 번째 페이지 parsing....
# 1542 번째 페이지 parsing....
# 1543 번째 페이지 parsing....
# 1544 번째 페이지 parsing....
# 1545 번째 페이지 parsing....
# 1546 번째 페이지 parsing....
# 1547 번째 페이지 parsing....
# 1548 번째 페이지 parsing....
# 1549 번째 페이지 parsing....
# 1550 번째 페이지 parsing....
# 1551 번째 페이지 parsing....
# 1552 번째 페이지 parsing....
# 1553 번째 페이지 parsing....
# 1554 번째 페이지 parsing....
# 1555 번째 페이지 parsing....
# 1556 번째 페이지 parsing....
# 1557 번째 페이지 parsing....
# 1558 번째 페이지 parsing....
# 1559 번째 페이지 parsing....
# 1560 번째 페이지 parsing....
# 1561 번째 페이지 parsing....
# 1562 번째 페이지 parsing....
# 1563 번째 페이지 parsing....
# 1564 번째 페이지 parsing....
# 1565 번째 페이지 parsing....
# 1566 번째 페이지 parsing....
# 1567 번째 페이지 parsing....
# 1568 번째 페이지 parsing....
# 1569 번째 페이지 parsing....
# 1570 번째 페이지 parsing....
# 1571 번째 페이지 parsing....
# 1572 번째 페이지 parsing....
# 1573 번째 페이지 parsing....
# 1574 번째 페이지 parsing....
# 1575 번째 페이지 parsing....
# 1576 번째 페이지 parsing....
# 1577 번째 페이지 parsing....
# 1578 번째 페이지 parsing....
# 1579 번째 페이지 parsing....
# 1580 번째 페이지 parsing....
# 1581 번째 페이지 parsing....
# 1582 번째 페이지 parsing....
# 1583 번째 페이지 parsing....
# 1584 번째 페이지 parsing....
# 1585 번째 페이지 parsing....
# 1586 번째 페이지 parsing....
# 1587 번째 페이지 parsing....
# 1588 번째 페이지 parsing....
# 1589 번째 페이지 parsing....
# 1590 번째 페이지 parsing....
# 1591 번째 페이지 parsing....
# 1592 번째 페이지 parsing....
# 1593 번째 페이지 parsing....
# 1594 번째 페이지 parsing....
# 1595 번째 페이지 parsing....
# 1596 번째 페이지 parsing....
# 1597 번째 페이지 parsing....
# 1598 번째 페이지 parsing....
# 1599 번째 페이지 parsing....
# 1600 번째 페이지 parsing....
# 1601 번째 페이지 parsing....
# 1602 번째 페이지 parsing....
# 1603 번째 페이지 parsing....
# 1604 번째 페이지 parsing....
# 1605 번째 페이지 parsing....
# 1606 번째 페이지 parsing....
# 1607 번째 페이지 parsing....
# 1608 번째 페이지 parsing....
# 1609 번째 페이지 parsing....
# 1610 번째 페이지 parsing....
# 1611 번째 페이지 parsing....
# 1612 번째 페이지 parsing....
# 1613 번째 페이지 parsing....
# 1614 번째 페이지 parsing....
# 1615 번째 페이지 parsing....
# 1616 번째 페이지 parsing....
# 1617 번째 페이지 parsing....
# 1618 번째 페이지 parsing....
# 1619 번째 페이지 parsing....
# 1620 번째 페이지 parsing....
# 1621 번째 페이지 parsing....
# 1622 번째 페이지 parsing....
# 1623 번째 페이지 parsing....
# 1624 번째 페이지 parsing....
# 1625 번째 페이지 parsing....
# 1626 번째 페이지 parsing....
# 1627 번째 페이지 parsing....
# 1628 번째 페이지 parsing....
# 1629 번째 페이지 parsing....
# 1630 번째 페이지 parsing....
# 1631 번째 페이지 parsing....
# 1632 번째 페이지 parsing....
# 1633 번째 페이지 parsing....
# 1634 번째 페이지 parsing....
# 1635 번째 페이지 parsing....
# 1636 번째 페이지 parsing....
# 1637 번째 페이지 parsing....
# 1638 번째 페이지 parsing....
# 1639 번째 페이지 parsing....
# 1640 번째 페이지 parsing....
# 1641 번째 페이지 parsing....
# 1642 번째 페이지 parsing....
# 1643 번째 페이지 parsing....
# 1644 번째 페이지 parsing....
# 1645 번째 페이지 parsing....
# 1646 번째 페이지 parsing....
# 1647 번째 페이지 parsing....
# 1648 번째 페이지 parsing....
# 1649 번째 페이지 parsing....
# 1650 번째 페이지 parsing....
# 1651 번째 페이지 parsing....
# 1652 번째 페이지 parsing....
# 1653 번째 페이지 parsing....
# 1654 번째 페이지 parsing....
# 1655 번째 페이지 parsing....
# 1656 번째 페이지 parsing....
# 1657 번째 페이지 parsing....
# 1658 번째 페이지 parsing....
# 1659 번째 페이지 parsing....
# 1660 번째 페이지 parsing....
# 1661 번째 페이지 parsing....
# 1662 번째 페이지 parsing....
# 1663 번째 페이지 parsing....
# 1664 번째 페이지 parsing....
# 1665 번째 페이지 parsing....
# 1666 번째 페이지 parsing....
# 1667 번째 페이지 parsing....
# 1668 번째 페이지 parsing....
# 1669 번째 페이지 parsing....
# 1670 번째 페이지 parsing....
# 1671 번째 페이지 parsing....
# 1672 번째 페이지 parsing....
# 1673 번째 페이지 parsing....
# 1674 번째 페이지 parsing....
# 1675 번째 페이지 parsing....
# 1676 번째 페이지 parsing....
# 1677 번째 페이지 parsing....
# 1678 번째 페이지 parsing....
# 1679 번째 페이지 parsing....
# 1680 번째 페이지 parsing....
# 1681 번째 페이지 parsing....
# 1682 번째 페이지 parsing....
# 1683 번째 페이지 parsing....
# 1684 번째 페이지 parsing....
# 1685 번째 페이지 parsing....
# 1686 번째 페이지 parsing....
# 1687 번째 페이지 parsing....
# 1688 번째 페이지 parsing....
# 1689 번째 페이지 parsing....
# 1690 번째 페이지 parsing....
# 1691 번째 페이지 parsing....
# 1692 번째 페이지 parsing....
# 1693 번째 페이지 parsing....
# 1694 번째 페이지 parsing....
# 1695 번째 페이지 parsing....
# 1696 번째 페이지 parsing....
# 1697 번째 페이지 parsing....
# 1698 번째 페이지 parsing....
# 1699 번째 페이지 parsing....
# 1700 번째 페이지 parsing....
# 1701 번째 페이지 parsing....
# 1702 번째 페이지 parsing....
# 1703 번째 페이지 parsing....
# 1704 번째 페이지 parsing....
# 1705 번째 페이지 parsing....
# 1706 번째 페이지 parsing....
# 1707 번째 페이지 parsing....
# 1708 번째 페이지 parsing....
# 1709 번째 페이지 parsing....
# 1710 번째 페이지 parsing....
# 1711 번째 페이지 parsing....
# 1712 번째 페이지 parsing....
# 1713 번째 페이지 parsing....
# 1714 번째 페이지 parsing....
# 1715 번째 페이지 parsing....
# 1716 번째 페이지 parsing....
# 1717 번째 페이지 parsing....
# 1718 번째 페이지 parsing....
# 1719 번째 페이지 parsing....
# 1720 번째 페이지 parsing....
# 1721 번째 페이지 parsing....
# 1722 번째 페이지 parsing....
# 1723 번째 페이지 parsing....
# 1724 번째 페이지 parsing....
# 1725 번째 페이지 parsing....
# 1726 번째 페이지 parsing....
# 1727 번째 페이지 parsing....
# 1728 번째 페이지 parsing....
# 1729 번째 페이지 parsing....
# 1730 번째 페이지 parsing....
# 1731 번째 페이지 parsing....
# 1732 번째 페이지 parsing....
# 1733 번째 페이지 parsing....
# 1734 번째 페이지 parsing....
# 1735 번째 페이지 parsing....
# 1736 번째 페이지 parsing....
# 1737 번째 페이지 parsing....
# 1738 번째 페이지 parsing....
# 1739 번째 페이지 parsing....
# 1740 번째 페이지 parsing....
# 1741 번째 페이지 parsing....
# 1742 번째 페이지 parsing....
# 1743 번째 페이지 parsing....
# 1744 번째 페이지 parsing....
# 1745 번째 페이지 parsing....
# 1746 번째 페이지 parsing....
# 1747 번째 페이지 parsing....
# 1748 번째 페이지 parsing....
# 1749 번째 페이지 parsing....
# 1750 번째 페이지 parsing....
# 1751 번째 페이지 parsing....
# 1752 번째 페이지 parsing....
# 1753 번째 페이지 parsing....
# 1754 번째 페이지 parsing....
# 1755 번째 페이지 parsing....
# 1756 번째 페이지 parsing....
# 1757 번째 페이지 parsing....
# 1758 번째 페이지 parsing....
# 1759 번째 페이지 parsing....
# 1760 번째 페이지 parsing....
# 1761 번째 페이지 parsing....
# 1762 번째 페이지 parsing....
# 1763 번째 페이지 parsing....
# 1764 번째 페이지 parsing....
# 1765 번째 페이지 parsing....
# 1766 번째 페이지 parsing....
# 1767 번째 페이지 parsing....
# 1768 번째 페이지 parsing....
# 1769 번째 페이지 parsing....
# 1770 번째 페이지 parsing....
# 1771 번째 페이지 parsing....
# 1772 번째 페이지 parsing....
# 1773 번째 페이지 parsing....
# 1774 번째 페이지 parsing....
# 1775 번째 페이지 parsing....
# 1776 번째 페이지 parsing....
# 1777 번째 페이지 parsing....
# 1778 번째 페이지 parsing....
# 1779 번째 페이지 parsing....
# 1780 번째 페이지 parsing....
# 1781 번째 페이지 parsing....
# 1782 번째 페이지 parsing....
# 1783 번째 페이지 parsing....
# 1784 번째 페이지 parsing....
# 1785 번째 페이지 parsing....
# 1786 번째 페이지 parsing....
# 1787 번째 페이지 parsing....
# 1788 번째 페이지 parsing....
# 1789 번째 페이지 parsing....
# 1790 번째 페이지 parsing....
# 1791 번째 페이지 parsing....
# 1792 번째 페이지 parsing....
# 1793 번째 페이지 parsing....
# 1794 번째 페이지 parsing....
# 1795 번째 페이지 parsing....
# 1796 번째 페이지 parsing....
# 1797 번째 페이지 parsing....
# 1798 번째 페이지 parsing....
# 1799 번째 페이지 parsing....
# 1800 번째 페이지 parsing....
# 1801 번째 페이지 parsing....
# 1802 번째 페이지 parsing....
# 1803 번째 페이지 parsing....
# 1804 번째 페이지 parsing....
# 1805 번째 페이지 parsing....
# 1806 번째 페이지 parsing....
# 1807 번째 페이지 parsing....
# 1808 번째 페이지 parsing....
# 1809 번째 페이지 parsing....
# 1810 번째 페이지 parsing....
# 1811 번째 페이지 parsing....
# 1812 번째 페이지 parsing....
# 1813 번째 페이지 parsing....
# 1814 번째 페이지 parsing....
# 1815 번째 페이지 parsing....
# 1816 번째 페이지 parsing....
# 1817 번째 페이지 parsing....
# 1818 번째 페이지 parsing....
# 1819 번째 페이지 parsing....
# 1820 번째 페이지 parsing....
# 1821 번째 페이지 parsing....
# 1822 번째 페이지 parsing....
# 1823 번째 페이지 parsing....
# 1824 번째 페이지 parsing....
# 1825 번째 페이지 parsing....
# 1826 번째 페이지 parsing....
# 1827 번째 페이지 parsing....
# 1828 번째 페이지 parsing....
# 1829 번째 페이지 parsing....
# 1830 번째 페이지 parsing....
# 1831 번째 페이지 parsing....
# 1832 번째 페이지 parsing....
# 1833 번째 페이지 parsing....
# 1834 번째 페이지 parsing....
# 1835 번째 페이지 parsing....
# 1836 번째 페이지 parsing....
# 1837 번째 페이지 parsing....
# 1838 번째 페이지 parsing....
# 1839 번째 페이지 parsing....
# 1840 번째 페이지 parsing....
# 1841 번째 페이지 parsing....
# 1842 번째 페이지 parsing....
# 1843 번째 페이지 parsing....
# 1844 번째 페이지 parsing....
# 1845 번째 페이지 parsing....
# 1846 번째 페이지 parsing....
# 1847 번째 페이지 parsing....
# 1848 번째 페이지 parsing....
# 1849 번째 페이지 parsing....
# 1850 번째 페이지 parsing....
# 1851 번째 페이지 parsing....
# 1852 번째 페이지 parsing....
# 1853 번째 페이지 parsing....
# 1854 번째 페이지 parsing....
# 1855 번째 페이지 parsing....
# 1856 번째 페이지 parsing....
# 1857 번째 페이지 parsing....
# 1858 번째 페이지 parsing....
# 1859 번째 페이지 parsing....
# 1860 번째 페이지 parsing....
# 1861 번째 페이지 parsing....
# 1862 번째 페이지 parsing....
# 1863 번째 페이지 parsing....
# 1864 번째 페이지 parsing....
# 1865 번째 페이지 parsing....
# 1866 번째 페이지 parsing....
# 1867 번째 페이지 parsing....
# 1868 번째 페이지 parsing....
# 1869 번째 페이지 parsing....
# 1870 번째 페이지 parsing....
# 1871 번째 페이지 parsing....
# 1872 번째 페이지 parsing....
# 1873 번째 페이지 parsing....
# 1874 번째 페이지 parsing....
# 1875 번째 페이지 parsing....
# 1876 번째 페이지 parsing....
# 1877 번째 페이지 parsing....
# 1878 번째 페이지 parsing....
# 1879 번째 페이지 parsing....
# 1880 번째 페이지 parsing....
# 1881 번째 페이지 parsing....
# 1882 번째 페이지 parsing....
# 1883 번째 페이지 parsing....
# 1884 번째 페이지 parsing....
# 1885 번째 페이지 parsing....
# 1886 번째 페이지 parsing....
# 1887 번째 페이지 parsing....
# 1888 번째 페이지 parsing....
# 1889 번째 페이지 parsing....
# 1890 번째 페이지 parsing....
# 1891 번째 페이지 parsing....
# 1892 번째 페이지 parsing....
# 1893 번째 페이지 parsing....
# 1894 번째 페이지 parsing....
# 1895 번째 페이지 parsing....
# 1896 번째 페이지 parsing....
# 1897 번째 페이지 parsing....
# 1898 번째 페이지 parsing....
# 1899 번째 페이지 parsing....
# 1900 번째 페이지 parsing....
# 1901 번째 페이지 parsing....
# 1902 번째 페이지 parsing....
# 1903 번째 페이지 parsing....
# 1904 번째 페이지 parsing....
# 1905 번째 페이지 parsing....
# 1906 번째 페이지 parsing....
# 1907 번째 페이지 parsing....
# 1908 번째 페이지 parsing....
# 1909 번째 페이지 parsing....
# 1910 번째 페이지 parsing....
# 1911 번째 페이지 parsing....
# 1912 번째 페이지 parsing....
# 1913 번째 페이지 parsing....
# 1914 번째 페이지 parsing....
# 1915 번째 페이지 parsing....
# 1916 번째 페이지 parsing....
# 1917 번째 페이지 parsing....
# 1918 번째 페이지 parsing....
# 1919 번째 페이지 parsing....
# 1920 번째 페이지 parsing....
# 1921 번째 페이지 parsing....
# 1922 번째 페이지 parsing....
# 1923 번째 페이지 parsing....
# 1924 번째 페이지 parsing....
# 1925 번째 페이지 parsing....
# 1926 번째 페이지 parsing....
# 1927 번째 페이지 parsing....
# 1928 번째 페이지 parsing....
# 1929 번째 페이지 parsing....
# 1930 번째 페이지 parsing....
# 1931 번째 페이지 parsing....
# 1932 번째 페이지 parsing....
# 1933 번째 페이지 parsing....
# 1934 번째 페이지 parsing....
# 1935 번째 페이지 parsing....
# 1936 번째 페이지 parsing....
# 1937 번째 페이지 parsing....
# 1938 번째 페이지 parsing....
# 1939 번째 페이지 parsing....
# 1940 번째 페이지 parsing....
# 1941 번째 페이지 parsing....
# 1942 번째 페이지 parsing....
# 1943 번째 페이지 parsing....
# 1944 번째 페이지 parsing....
# 1945 번째 페이지 parsing....
# 1946 번째 페이지 parsing....
# 1947 번째 페이지 parsing....
# 1948 번째 페이지 parsing....
# 1949 번째 페이지 parsing....
# 1950 번째 페이지 parsing....
# 1951 번째 페이지 parsing....
# 1952 번째 페이지 parsing....
# 1953 번째 페이지 parsing....
# 1954 번째 페이지 parsing....
# 1955 번째 페이지 parsing....
# 1956 번째 페이지 parsing....
# 1957 번째 페이지 parsing....
# 1958 번째 페이지 parsing....
# 1959 번째 페이지 parsing....
# 1960 번째 페이지 parsing....
# 1961 번째 페이지 parsing....
# 1962 번째 페이지 parsing....
# 1963 번째 페이지 parsing....
# 1964 번째 페이지 parsing....
# 1965 번째 페이지 parsing....
# 1966 번째 페이지 parsing....
# 1967 번째 페이지 parsing....
# 1968 번째 페이지 parsing....
# 1969 번째 페이지 parsing....
# 1970 번째 페이지 parsing....
# 1971 번째 페이지 parsing....
# 1972 번째 페이지 parsing....
# 1973 번째 페이지 parsing....
# 1974 번째 페이지 parsing....
# 1975 번째 페이지 parsing....
# 1976 번째 페이지 parsing....
# 1977 번째 페이지 parsing....
# 1978 번째 페이지 parsing....
# 1979 번째 페이지 parsing....
# 1980 번째 페이지 parsing....
# 1981 번째 페이지 parsing....
# 1982 번째 페이지 parsing....
# 1983 번째 페이지 parsing....
# 1984 번째 페이지 parsing....
# 1985 번째 페이지 parsing....
# 1986 번째 페이지 parsing....
# 1987 번째 페이지 parsing....
# 1988 번째 페이지 parsing....
# 1989 번째 페이지 parsing....
# 1990 번째 페이지 parsing....
# 1991 번째 페이지 parsing....
# 1992 번째 페이지 parsing....
# 1993 번째 페이지 parsing....
# 1994 번째 페이지 parsing....
# 1995 번째 페이지 parsing....
# 1996 번째 페이지 parsing....
# 1997 번째 페이지 parsing....
# 1998 번째 페이지 parsing....
# 1999 번째 페이지 parsing....
# 2000 번째 페이지 parsing....
# 2001 번째 페이지 parsing....
# 2002 번째 페이지 parsing....
# 2003 번째 페이지 parsing....
# 2004 번째 페이지 parsing....
# 2005 번째 페이지 parsing....
# 2006 번째 페이지 parsing....
# 2007 번째 페이지 parsing....
# 2008 번째 페이지 parsing....
# 2009 번째 페이지 parsing....
# 2010 번째 페이지 parsing....
# 2011 번째 페이지 parsing....
# 2012 번째 페이지 parsing....
# 2013 번째 페이지 parsing....
# 2014 번째 페이지 parsing....
# 2015 번째 페이지 parsing....
# 2016 번째 페이지 parsing....
# 2017 번째 페이지 parsing....
# 2018 번째 페이지 parsing....
# 2019 번째 페이지 parsing....
# 2020 번째 페이지 parsing....
# 2021 번째 페이지 parsing....
# 2022 번째 페이지 parsing....
# 2023 번째 페이지 parsing....
# 2024 번째 페이지 parsing....
# 2025 번째 페이지 parsing....
# 2026 번째 페이지 parsing....
# 2027 번째 페이지 parsing....
# 2028 번째 페이지 parsing....
# 2029 번째 페이지 parsing....
# 2030 번째 페이지 parsing....
# 2031 번째 페이지 parsing....
# 2032 번째 페이지 parsing....
# 2033 번째 페이지 parsing....
# 2034 번째 페이지 parsing....
# 2035 번째 페이지 parsing....
# 2036 번째 페이지 parsing....
# 2037 번째 페이지 parsing....
# 2038 번째 페이지 parsing....
# 2039 번째 페이지 parsing....
# 2040 번째 페이지 parsing....
# 2041 번째 페이지 parsing....
# 2042 번째 페이지 parsing....
# 2043 번째 페이지 parsing....
# 2044 번째 페이지 parsing....
# 2045 번째 페이지 parsing....
# 2046 번째 페이지 parsing....
# 2047 번째 페이지 parsing....
# 2048 번째 페이지 parsing....
# 2049 번째 페이지 parsing....
# 2050 번째 페이지 parsing....
# 2051 번째 페이지 parsing....
# 2052 번째 페이지 parsing....
# 2053 번째 페이지 parsing....
# 2054 번째 페이지 parsing....
# 2055 번째 페이지 parsing....
# 2056 번째 페이지 parsing....
# 2057 번째 페이지 parsing....
# 2058 번째 페이지 parsing....
# 2059 번째 페이지 parsing....
# 2060 번째 페이지 parsing....
# 2061 번째 페이지 parsing....
# 2062 번째 페이지 parsing....
# 2063 번째 페이지 parsing....
# 2064 번째 페이지 parsing....
# 2065 번째 페이지 parsing....
# 2066 번째 페이지 parsing....
# 2067 번째 페이지 parsing....
# 2068 번째 페이지 parsing....
# 2069 번째 페이지 parsing....
# 2070 번째 페이지 parsing....
# 2071 번째 페이지 parsing....
# 2072 번째 페이지 parsing....
# 2073 번째 페이지 parsing....
# 2074 번째 페이지 parsing....
# 2075 번째 페이지 parsing....
# 2076 번째 페이지 parsing....
# 2077 번째 페이지 parsing....
# 2078 번째 페이지 parsing....
# 2079 번째 페이지 parsing....
# 2080 번째 페이지 parsing....
# 2081 번째 페이지 parsing....
# 2082 번째 페이지 parsing....
# 2083 번째 페이지 parsing....
# 2084 번째 페이지 parsing....
# 2085 번째 페이지 parsing....
# 2086 번째 페이지 parsing....
# 2087 번째 페이지 parsing....
# 2088 번째 페이지 parsing....
# 2089 번째 페이지 parsing....
# 2090 번째 페이지 parsing....
# 2091 번째 페이지 parsing....
# 2092 번째 페이지 parsing....
# 2093 번째 페이지 parsing....
# 2094 번째 페이지 parsing....
# 2095 번째 페이지 parsing....
# 2096 번째 페이지 parsing....
# 2097 번째 페이지 parsing....
# 2098 번째 페이지 parsing....
# 2099 번째 페이지 parsing....
# 2100 번째 페이지 parsing....
# 2101 번째 페이지 parsing....
# 2102 번째 페이지 parsing....
# 2103 번째 페이지 parsing....
# 2104 번째 페이지 parsing....
# 2105 번째 페이지 parsing....
# 2106 번째 페이지 parsing....
# 2107 번째 페이지 parsing....
# 2108 번째 페이지 parsing....
# 2109 번째 페이지 parsing....
# 2110 번째 페이지 parsing....
# 2111 번째 페이지 parsing....
# 2112 번째 페이지 parsing....
# 2113 번째 페이지 parsing....
# 2114 번째 페이지 parsing....
# 2115 번째 페이지 parsing....
# 2116 번째 페이지 parsing....
# 2117 번째 페이지 parsing....
# 2118 번째 페이지 parsing....
# 2119 번째 페이지 parsing....
# 2120 번째 페이지 parsing....
# 2121 번째 페이지 parsing....
# 2122 번째 페이지 parsing....
# 2123 번째 페이지 parsing....
# 2124 번째 페이지 parsing....
# 2125 번째 페이지 parsing....
# 2126 번째 페이지 parsing....
# 2127 번째 페이지 parsing....
# 2128 번째 페이지 parsing....
# 2129 번째 페이지 parsing....
# 2130 번째 페이지 parsing....
# 2131 번째 페이지 parsing....
# 2132 번째 페이지 parsing....
# 2133 번째 페이지 parsing....
# 2134 번째 페이지 parsing....
# 2135 번째 페이지 parsing....
# 2136 번째 페이지 parsing....
# 2137 번째 페이지 parsing....
# 2138 번째 페이지 parsing....
# 2139 번째 페이지 parsing....
# 2140 번째 페이지 parsing....
# 2141 번째 페이지 parsing....
# 2142 번째 페이지 parsing....
# 2143 번째 페이지 parsing....
# 2144 번째 페이지 parsing....
# 2145 번째 페이지 parsing....
# 2146 번째 페이지 parsing....
# 2147 번째 페이지 parsing....
# 2148 번째 페이지 parsing....
# 2149 번째 페이지 parsing....
# 2150 번째 페이지 parsing....
# 2151 번째 페이지 parsing....
# 2152 번째 페이지 parsing....
# 2153 번째 페이지 parsing....
# 2154 번째 페이지 parsing....
# 2155 번째 페이지 parsing....
# 2156 번째 페이지 parsing....
# 2157 번째 페이지 parsing....
# 2158 번째 페이지 parsing....
# 2159 번째 페이지 parsing....
# 2160 번째 페이지 parsing....
# 2161 번째 페이지 parsing....
# 2162 번째 페이지 parsing....
# 2163 번째 페이지 parsing....
# 2164 번째 페이지 parsing....
# 2165 번째 페이지 parsing....
# 2166 번째 페이지 parsing....
# 2167 번째 페이지 parsing....
# 2168 번째 페이지 parsing....
# 2169 번째 페이지 parsing....
# 2170 번째 페이지 parsing....
# 2171 번째 페이지 parsing....
# 2172 번째 페이지 parsing....
# 2173 번째 페이지 parsing....
# 2174 번째 페이지 parsing....
# 2175 번째 페이지 parsing....
# 2176 번째 페이지 parsing....
# 2177 번째 페이지 parsing....
# 2178 번째 페이지 parsing....
# 2179 번째 페이지 parsing....
# 2180 번째 페이지 parsing....
# 2181 번째 페이지 parsing....
# 2182 번째 페이지 parsing....
# 2183 번째 페이지 parsing....
# 2184 번째 페이지 parsing....
# 2185 번째 페이지 parsing....
# 2186 번째 페이지 parsing....
# 2187 번째 페이지 parsing....
# 2188 번째 페이지 parsing....
# 2189 번째 페이지 parsing....
# 2190 번째 페이지 parsing....
# 2191 번째 페이지 parsing....
# 2192 번째 페이지 parsing....
# 2193 번째 페이지 parsing....
# 2194 번째 페이지 parsing....
# 2195 번째 페이지 parsing....
# 2196 번째 페이지 parsing....
# 2197 번째 페이지 parsing....
# 2198 번째 페이지 parsing....
# 2199 번째 페이지 parsing....
# 2200 번째 페이지 parsing....
# 2201 번째 페이지 parsing....
# 2202 번째 페이지 parsing....
# 2203 번째 페이지 parsing....
# 2204 번째 페이지 parsing....
# 2205 번째 페이지 parsing....
# 2206 번째 페이지 parsing....
# 2207 번째 페이지 parsing....
# 2208 번째 페이지 parsing....
# 2209 번째 페이지 parsing....
# 2210 번째 페이지 parsing....
# 2211 번째 페이지 parsing....
# 2212 번째 페이지 parsing....
# 2213 번째 페이지 parsing....
# 2214 번째 페이지 parsing....
# 2215 번째 페이지 parsing....
# 2216 번째 페이지 parsing....
# 2217 번째 페이지 parsing....
# 2218 번째 페이지 parsing....
# 2219 번째 페이지 parsing....
# 2220 번째 페이지 parsing....
# 2221 번째 페이지 parsing....
# 2222 번째 페이지 parsing....
# 2223 번째 페이지 parsing....
# 2224 번째 페이지 parsing....
# 2225 번째 페이지 parsing....
# 2226 번째 페이지 parsing....
# 2227 번째 페이지 parsing....
# 2228 번째 페이지 parsing....
# 2229 번째 페이지 parsing....
# 2230 번째 페이지 parsing....
# 2231 번째 페이지 parsing....
# 2232 번째 페이지 parsing....
# 2233 번째 페이지 parsing....
# 2234 번째 페이지 parsing....
# 2235 번째 페이지 parsing....
# 2236 번째 페이지 parsing....
# 2237 번째 페이지 parsing....
# 2238 번째 페이지 parsing....
# 2239 번째 페이지 parsing....
# 2240 번째 페이지 parsing....
# 2241 번째 페이지 parsing....
# 2242 번째 페이지 parsing....
# 2243 번째 페이지 parsing....
# 2244 번째 페이지 parsing....
# 2245 번째 페이지 parsing....
# 2246 번째 페이지 parsing....
# 2247 번째 페이지 parsing....
# 2248 번째 페이지 parsing....
# 2249 번째 페이지 parsing....
# 2250 번째 페이지 parsing....
# 2251 번째 페이지 parsing....
# 2252 번째 페이지 parsing....
# 2253 번째 페이지 parsing....
# 2254 번째 페이지 parsing....
# 2255 번째 페이지 parsing....
# 2256 번째 페이지 parsing....
# 2257 번째 페이지 parsing....
# 2258 번째 페이지 parsing....
# 2259 번째 페이지 parsing....
# 2260 번째 페이지 parsing....
# 2261 번째 페이지 parsing....
# 2262 번째 페이지 parsing....
# 2263 번째 페이지 parsing....
# 2264 번째 페이지 parsing....
# 2265 번째 페이지 parsing....
# 2266 번째 페이지 parsing....
# 2267 번째 페이지 parsing....
# 2268 번째 페이지 parsing....
# 2269 번째 페이지 parsing....
# 2270 번째 페이지 parsing....
# 2271 번째 페이지 parsing....
# 2272 번째 페이지 parsing....
# 2273 번째 페이지 parsing....
# 2274 번째 페이지 parsing....
# 2275 번째 페이지 parsing....
# 2276 번째 페이지 parsing....
# 2277 번째 페이지 parsing....
# 2278 번째 페이지 parsing....
# 2279 번째 페이지 parsing....
# 2280 번째 페이지 parsing....
# 2281 번째 페이지 parsing....
# 2282 번째 페이지 parsing....
# 2283 번째 페이지 parsing....
# 2284 번째 페이지 parsing....
# 2285 번째 페이지 parsing....
# 2286 번째 페이지 parsing....
# 2287 번째 페이지 parsing....
# 2288 번째 페이지 parsing....
# 2289 번째 페이지 parsing....
# 2290 번째 페이지 parsing....
# 2291 번째 페이지 parsing....
# 2292 번째 페이지 parsing....
# 2293 번째 페이지 parsing....
# 2294 번째 페이지 parsing....
# 2295 번째 페이지 parsing....
# 2296 번째 페이지 parsing....
# 2297 번째 페이지 parsing....
# 2298 번째 페이지 parsing....
# 2299 번째 페이지 parsing....
# 2300 번째 페이지 parsing....
# 2301 번째 페이지 parsing....
# 2302 번째 페이지 parsing....
# 2303 번째 페이지 parsing....
# 2304 번째 페이지 parsing....
# 2305 번째 페이지 parsing....
# 2306 번째 페이지 parsing....
# 2307 번째 페이지 parsing....
# 2308 번째 페이지 parsing....
# 2309 번째 페이지 parsing....
# 2310 번째 페이지 parsing....
# 2311 번째 페이지 parsing....
# 2312 번째 페이지 parsing....
# 2313 번째 페이지 parsing....
# 2314 번째 페이지 parsing....
# 2315 번째 페이지 parsing....
# 2316 번째 페이지 parsing....
# 2317 번째 페이지 parsing....
# 2318 번째 페이지 parsing....
# 2319 번째 페이지 parsing....
# 2320 번째 페이지 parsing....
# 2321 번째 페이지 parsing....
# 2322 번째 페이지 parsing....
# 2323 번째 페이지 parsing....
# 2324 번째 페이지 parsing....
# 2325 번째 페이지 parsing....
# 2326 번째 페이지 parsing....
# 2327 번째 페이지 parsing....
# 2328 번째 페이지 parsing....
# 2329 번째 페이지 parsing....
# 2330 번째 페이지 parsing....
# 2331 번째 페이지 parsing....
# 2332 번째 페이지 parsing....
# 2333 번째 페이지 parsing....
# 2334 번째 페이지 parsing....
# 2335 번째 페이지 parsing....
# 2336 번째 페이지 parsing....
# 2337 번째 페이지 parsing....
# 2338 번째 페이지 parsing....
# 2339 번째 페이지 parsing....
# 2340 번째 페이지 parsing....
# 2341 번째 페이지 parsing....
# 2342 번째 페이지 parsing....
# 2343 번째 페이지 parsing....
# 2344 번째 페이지 parsing....
# 2345 번째 페이지 parsing....
# 2346 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['wche****',
#   "'그래도 우리 잘 해냈지?'라고 말하는 듯한 마지막 눈빛교환이 잊혀지질 않는다",
#   '9',
#   '13148',
#   '885',
#   datetime.datetime(2016, 12, 7, 10, 48),
#   0],
#  ['우훌루후후(dngk****)',
#   '와..그냥 감탄밖엔 안 나온다. 영상미며 음악이며..조폭, 건달, 검사, 신파 좋아하고 실험을 꺼리는 한국의 기성 영화인들 반성해라. 이제 겨우 두 편 만든 신인감독이 이 정도다',
#   '9',
#   '9145',
#   '1103',
#   datetime.datetime(2016, 12, 7, 8, 57),
#   0],
#  ['유인나연(ssss****)',
#   '처음 들을때는 몰랐다 이 음악이 슬퍼질거란걸',
#   '7',
#   '8118',
#   '498',
#   datetime.datetime(2016, 12, 7, 11, 20),
#   0],
#  ['Casofhjkl(kidi****)',
#   '꿈과 사랑, 우리는 항상 성공인지 실패인지 평가만 해왔다. 하지만 라라랜드는 말해준다. "봐! 꿈과 사랑, 그 흔들리는 파도가 얼마나 아름다운지"',
#   '10',
#   '7122',
#   '429',
#   datetime.datetime(2016, 12, 7, 1, 23),
#   0],
#  ['키돌(doon****)',
#   '마지막 회상신에서 처음과 달리 키스신으로 스토리시작될때 진짜 소리지를뻔...',
#   '9',
#   '6576',
#   '401',
#   datetime.datetime(2016, 12, 7, 19, 19),
#   0],
#  ['쇼생크 탈출(chri****)',
#   '내일 죽으면 오늘 보러 갈만한 영화',
#   '10',
#   '7240',
#   '1516',
#   datetime.datetime(2016, 12, 7, 0, 16),
#   0],
#  ['fsli****',
#   '마지막 10분 동안 휘몰아치는 감정의 소용돌이에 결국 눈물이 흐르게 만드는 마법같은 영화. 노트북 때에도 그렇고 라이언 고슬링은 이런 역할에 도가 튼 것 같다.',
#   '10',
#   '5914',
#   '293',
#   datetime.datetime(2016, 12, 7, 5, 48),
#   0],
#  ['gracie(dhff****)',
#   '연인들을 위한 영화가 아니다. 여성관객들을 위한 영화도 아니다. 이 영화는 꿈꾸는 모든 이들을 위한 영화. 인생을 논하는 영화.',
#   '10',
#   '5876',
#   '280',
#   datetime.datetime(2016, 12, 8, 16, 27),
#   '관람객'],
#  ['김유리(dbsl****)',
#   '운행종료한 놀이공원에 노래가 계속 나오는 것같다.',
#   '10',
#   '4855',
#   '137',
#   datetime.datetime(2016, 12, 10, 15, 53),
#   '관람객'],
#  ['hard****',
#   '재즈가 이토록 설레고 이렇게 슬프다니.라라랜드는 슬픔과 환희의 설레임이다.',
#   '10',
#   '4294',
#   '282',
#   datetime.datetime(2016, 12, 7, 12, 11),
#   '관람객'],
#  ['Joon(chro****)',
#   '이 영화의 백미는 마지막 부분에 남녀 주인공들의 IF 장면들... 이렇게 되지 못한 결말을 맞지만 그래도 서로의 꿈을 이루고 인정하는 듯한 둘만의 미소,,,, 뭔가 가슴 찡했다...',
#   '10',
#   '3893',
#   '135',
#   datetime.datetime(2016, 12, 8, 14, 55),
#   0],
#  ['777(leey****)',
#   '슬프기 짝이 없는 상상.',
#   '7',
#   '3343',
#   '237',
#   datetime.datetime(2016, 12, 7, 11, 22),
#   '관람객'],
#  ['꿈꾸는하늘(suni****)',
#   '위플래시가 음악에 대한 광기라면 이 영화는 열정이다. 같은날 개봉되는 삼류 국산영화는 범접조차 할수 없다',
#   '10',
#   '3500',
#   '441',
#   datetime.datetime(2016, 12, 7, 0, 4),
#   0],
#  ['pado****',
#   '아이러니컬하게도, 꿈이라는 건 이루고 난 뒤보다 이루기 전까지가 실은 가장 행복했다는 걸, 이루고 난 뒤에야 깨닫는다는 인생의 진실을 가슴 아프게 그리고 아름답게 보여주는 영화',
#   '9',
#   '2975',
#   '70',
#   datetime.datetime(2016, 12, 14, 11, 28),
#   '관람객'],
#  ['김지호(jh58****)',
#   '다시 돌아간다면 지금과 달랐을까?',
#   '8',
#   '2380',
#   '95',
#   datetime.datetime(2016, 12, 9, 1, 6),
#   '관람객'],
#  ['dkwj****',
#   '왤케눈물이나오는지..ㅠㅠ',
#   '10',
#   '2387',
#   '134',
#   datetime.datetime(2016, 12, 8, 22, 25),
#   '관람객'],
#  ['희곡범생(whaq****)',
#   '서로의 꿈을 돌보아주고 키워가며 각자의 길을 응원하는 최고의 뮤지컬.',
#   '10',
#   '2377',
#   '143',
#   datetime.datetime(2016, 12, 7, 16, 21),
#   '관람객'],
#  ['아지뱀(yhoc****)',
#   '다미엔 차젤레 감독은 관객에게 황홀한 마법을 걸었다. 재즈에 대한 애정을 담아 연출했고 꿈 꾸는 모든 이들을 위한 영화. 롱테이크 오프닝 시퀀스, OST부터 이미 매료되었고 엔딩까지 한 편의 동화 같은 현실 이야기....',
#   '10',
#   '2282',
#   '178',
#   datetime.datetime(2016, 12, 7, 0, 19),
#   0],
#  ['휴멘(dudd****)',
#   '영화 시작부터 깜짝놀랐다. 지금까지 본 음악영화 중에서 최고다.',
#   '10',
#   '1956',
#   '166',
#   datetime.datetime(2016, 12, 7, 17, 53),
#   '관람객'],
#  ['chlt****',
#   '거의 마지막쯤에 나왔던 "흐르는대로가자" 라는 대사가 이 영화를 잘 나타내주었던 말인것 같다. 고민되고 힘이들땐 너무 많은 것을 생각하기보다는  내맘이 끌리는 대로 흐르는대로 가자!',
#   '8',
#   '1800',
#   '69',
#   datetime.datetime(2016, 12, 10, 0, 58),
#   '관람객'],
#  ['프라이드(only****)',
#   '시간이 지나도 우리가 함께 꿈꾸었다는 사실은 변하지 않을 것이다. 그것이 비록 서로 다른 꿈이었을지라도...',
#   '10',
#   '1744',
#   '68',
#   datetime.datetime(2016, 12, 7, 21, 7),
#   0],
#  ['sunn****',
#   '기대안하고봤는데 엔딩때 울었음..두번보세요',
#   '9',
#   '1457',
#   '115',
#   datetime.datetime(2016, 12, 7, 14, 50),
#   0],
#  ['브루스올마이티(tarz****)',
#   '초반부는 그냥 음악이 있는 로맨스겠구나 싶었다. 중반 이후로 넘어가면서 무모할것 같은 꿈을 쫓는 그들의 이야기가   꿈을 포기하고  살고 있는  나의 가슴을 때리고 있었다.  아마도 꿈을 쫓고 있거나 포기한 경험을 ...',
#   '10',
#   '1347',
#   '79',
#   datetime.datetime(2016, 12, 7, 22, 34),
#   0],
#  ['켈리(song****)',
#   '아름디운 영화~라이언고슬링 연기 조으다',
#   '9',
#   '1326',
#   '140',
#   datetime.datetime(2016, 12, 7, 12, 13),
#   '관람객'],
#  ['smoo****',
#   '어른을 위한 꿈의 동화~시간이 후딱 갔네요.엔딩은 현실로 여운을 남기는..보면 후회하지 않을거임~',
#   '8',
#   '1277',
#   '119',
#   datetime.datetime(2016, 12, 7, 18, 4),
#   '관람객'],
#  ['기리닝(wjdx****)',
#   '이런영화가 흥행해야 함. 맨날 스타 배우진만 보고 강제 흥행하려는 영화관독점영화말고',
#   '10',
#   '1216',
#   '79',
#   datetime.datetime(2016, 12, 8, 17, 41),
#   '관람객'],
#  ['달리안(curt****)',
#   '내생애 최고의 뮤지컬영화로 뽑음ㅠㅠ 넘넘 재밌음!!!',
#   '10',
#   '1073',
#   '130',
#   datetime.datetime(2016, 12, 7, 16, 31),
#   '관람객'],
#  ['피케미남(jein****)',
#   '다른사람들이 평을 너무 잘썼다 내마음도 똑같고 아 ㅅ 바 눈물좀 멈춰줘',
#   '10',
#   '984',
#   '55',
#   datetime.datetime(2016, 12, 8, 23, 1),
#   '관람객'],
#  ['김명주(kmj_****)',
#   '영화보다가 박수칠뻔ㅜㅜ',
#   '10',
#   '882',
#   '63',
#   datetime.datetime(2016, 12, 8, 22, 58),
#   '관람객'],
#  ['권애교(rnjs****)',
#   '끝나고도 계속 생각나네요 황홀하다는 느낌이 이런느낌이랄까  영상도 너무이쁘고 마지막10분정도는 오래 기억에 남을것같네요 배우들 표정연기도 너무 좋았고 엠마스톤이 너무 사랑스러웠고 ㅎㅎ city of stars 바로 ...',
#   '10',
#   '888',
#   '78',
#   datetime.datetime(2016, 12, 7, 9, 14),
#   0],
#  ['rela****',
#   '오히려 더 현실적이라 재밌었다.',
#   '10',
#   '749',
#   '42',
#   datetime.datetime(2016, 12, 7, 17, 30),
#   '관람객'],
#  ['문희(uuuu****)',
#   '꿈꾸는 모든 이를 위하여, 꿈을 꾸는 이들이 꿈이라는 열망앞에서 현재와 미래 그리고 과거에 대하여 마주하게되는 수천개의 감정들을 로맨스로 말해주는 영화',
#   '9',
#   '759',
#   '60',
#   datetime.datetime(2016, 12, 7, 13, 17),
#   '관람객'],
#  ['첼이(qkrc****)',
#   '사람들은 현실같은 영화를 지루하다고 한다 그리고 온갖 영화스러움이 가득한 영화를 현실 같다고 하곤 한다. 라라랜드 보고 지루하다는 사람들은 그냥 블록버스터나 보러 가길. 이 영화야말로 우리 삶을, 청춘을 가장 잘 보...',
#   '10',
#   '722',
#   '76',
#   datetime.datetime(2016, 12, 8, 23, 49),
#   '관람객'],
#  ['진경리(xzsa****)',
#   '마지막 엔딩에 피아노 치는 순간부터 영화관 나올때까지 계속 이유모를 눈물이 나왔다.내 인생 최고의 영화가 되었다',
#   '10',
#   '673',
#   '32',
#   datetime.datetime(2016, 12, 7, 19, 45),
#   0],
#  ['dasexperiment(shad****)',
#   '한국은 도대체 왜 이런영화를 못만드는가!',
#   '10',
#   '731',
#   '111',
#   datetime.datetime(2016, 12, 7, 15, 38),
#   0],
#  ['Borami Park(juke****)',
#   '나에게 나보다 더 믿음을 가지고 있는 사람을 만나는건 엄청난 복인것. 어쩌나 저쩌나 라이언 고슬링은 사랑입니딘',
#   '8',
#   '637',
#   '19',
#   datetime.datetime(2016, 12, 9, 23, 43),
#   '관람객'],
#  ['블가리(whit****)',
#   '인생영화 하나 또 탄생했네~ 롱테이크 촬영이 예술, 영상이 넘나 아름답고, 라이언고슬링의 멋진 피아노 연주, 엠마스톤과의 춤과 노래..눈과 귀가 호강한다..재미를 기대하면 약간 실망할수도 있지만 충분히 훌륭한 영화!...',
#   '9',
#   '647',
#   '63',
#   datetime.datetime(2016, 12, 7, 5, 32),
#   0],
#  ['영오(dlgh****)',
#   '호불호 딱 갈릴영화. 나는 좋았지만 지루해할 틈이 분명 있긴하다...',
#   '8',
#   '728',
#   '166',
#   datetime.datetime(2016, 12, 8, 16, 48),
#   0],
#  ['브라이언(huma****)',
#   '이 영화는 마법이다.첫 장면에 기대감에 설레였고,보면서 들떴고,엔딩엔 슬펐다.자막이 올라갈땐 움직일 수 없었다...',
#   '10',
#   '599',
#   '42',
#   datetime.datetime(2016, 12, 7, 14, 39),
#   0],
#  ['간지폭발민수(feru****)',
#   '마지막 피아노 치고 해고당하는 장면에서 키스신은 정말 .. 나도모르게 여자친구의 손을 꽉 잡아버렸다 너무 아름다운영화',
#   '10',
#   '606',
#   '76',
#   datetime.datetime(2016, 12, 8, 14, 11),
#   '관람객'],
#  ['1_1(kmg3****)',
#   '아이맥스시사회당첨으로 보고왔는데 영화가 예쁘다는건 라라랜드를 말하는것같아요  진짜장면하나하나가 감동이고 영화보는 시간내내 즐겁고 황홀하고 힐링되는 영화였어요',
#   '10',
#   '602',
#   '81',
#   datetime.datetime(2016, 12, 7, 0, 48),
#   0],
#  ['클레멘타인(7886****)',
#   '우리는 지금 어디에 있는걸까,',
#   '10',
#   '521',
#   '28',
#   datetime.datetime(2016, 12, 13, 0, 57),
#   '관람객'],
#  ['베라티르(ragr****)',
#   '영상미 사운드 빠지지 않는 인생영화.',
#   '10',
#   '449',
#   '48',
#   datetime.datetime(2016, 12, 7, 0, 36),
#   0],
#  ['곰(muu0****)',
#   '꿈꾸고 싶어지는 영화 라라랜드',
#   '8',
#   '440',
#   '50',
#   datetime.datetime(2016, 12, 7, 15, 2),
#   '관람객'],
#  ['이돌진(bvka****)',
#   '마지막 5분의 여운이 아직도... 펑펑울며 나가던 여자아이 ..',
#   '10',
#   '402',
#   '29',
#   datetime.datetime(2016, 12, 8, 18, 22),
#   '관람객'],
#  ['고라니(1597****)',
#   '영화가 내 주변에서 스윙댄스 추고 휙 가버린 기분이다. 기분이 둥둥. 색감 음악 의상 모두 다 좋았다 ㅠㅠ',
#   '10',
#   '376',
#   '30',
#   datetime.datetime(2016, 12, 8, 22, 41),
#   '관람객'],
#  ['미쓰블룸(luvm****)',
#   '10점이 아깝지 않은 영화 . 방금 보고 나왔는데 예상만큼 좋았어요. 다시 보고 싶네요',
#   '10',
#   '382',
#   '37',
#   datetime.datetime(2016, 12, 7, 14, 16),
#   '관람객'],
#  ['콩(o0os****)',
#   '인생영화가 하나 추가되었다.',
#   '10',
#   '364',
#   '43',
#   datetime.datetime(2016, 12, 7, 12, 53),
#   0],
#  ['썸데이(hjch****)',
#   '영화를 보는 도중에 이미 사랑에 빠져버리는 경험',
#   '10',
#   '324',
#   '35',
#   datetime.datetime(2016, 12, 7, 2, 17),
#   0],
#  ['메리엘(dhtm****)',
#   '지루한 영화가 아닌 섬세한 영화예요.',
#   '10',
#   '323',
#   '35',
#   datetime.datetime(2016, 12, 9, 23, 59),
#   0],
#  ['닝기리(kisc****)',
#   '배경이 너무 아름답고 음악이 너무좋고 재미있습니다',
#   '10',
#   '328',
#   '46',
#   datetime.datetime(2016, 12, 7, 15, 48),
#   '관람객'],
#  ['minororo(tari****)',
#   '곡성 이후 오랜만에 박평식이 7점 준 영화가 나오는구나  극장각이다',
#   '10',
#   '347',
#   '69',
#   datetime.datetime(2016, 12, 7, 0, 17),
#   0],
#  ['박소람(vrsr****)',
#   '마지막 장면 남자배우의 표정이 잊히지 않네요..',
#   '10',
#   '280',
#   '16',
#   datetime.datetime(2016, 12, 16, 14, 13),
#   '관람객'],
#  ['kktj****',
#   '이 감독은 위플래쉬에 이어 엔딩 장인인듯',
#   '9',
#   '286',
#   '29',
#   datetime.datetime(2016, 12, 7, 15, 18),
#   0],
#  ['삼냥이집사(duna****)',
#   '꿈과 성공, 그리고 사랑을 인생의 선 상에서 아름답게  표현했다. 춤과 노래가 어우러져 더욱 극적으로 다가옴. 한편의 느낀 점 많은 성장영화였음.',
#   '10',
#   '288',
#   '32',
#   datetime.datetime(2016, 12, 7, 14, 43),
#   '관람객'],
#  ['임준혁(sson****)',
#   '제목 오지게 잘 지었다. 영화의 배경인 la를 뜻하면서도 꿈꾸는 청년들의 동화같은 이야기. 기분 좋은 오프닝부터 bitter sweet한 엔딩까지 심장이 멈추질 않게 합니다. 영화가 끝난 지금까지. 음악과 춤 그리고...',
#   '10',
#   '281',
#   '30',
#   datetime.datetime(2016, 12, 10, 12, 25),
#   0],
#  ['LP(ogr5****)',
#   '반짝이며 사라지는 황홀한 꿈같은 사계절의 무대.',
#   '10',
#   '286',
#   '35',
#   datetime.datetime(2016, 12, 7, 0, 59),
#   0],
#  ['gksw****',
#   '후회야 말로 사랑을 보다 값지게 만드는 마법의 마지막 재료!!',
#   '10',
#   '278',
#   '35',
#   datetime.datetime(2016, 12, 7, 12, 26),
#   0],
#  ['hebi****',
#   '자극적인 영화가 주류인 요즘 같은 시대엔좀 촌스럽고 고루해보일수 있겠지만 그렇기때문에더 담백하고 새로운 기분으로 본 영화였어요',
#   '8',
#   '229',
#   '34',
#   datetime.datetime(2016, 12, 7, 19, 18),
#   '관람객'],
#  ['문돌이(kevi****)',
#   '다미안 차질레는 할리우드 최고의 감독중 하나로 기억될 것이다. 이제 겨우 장편영화 두 개인데, 두 작품 모두 관객평과 비평가평 최상이다. 거기다 시상식 결과까지 좋다니',
#   '10',
#   '215',
#   '24',
#   datetime.datetime(2016, 12, 7, 15, 42),
#   0],
#  ['데인드한(hhl2****)',
#   '조따 빡쳐서 댓글쓴다. 판도라 알바들 영화 보지도않고 1점줘서 별점 깎고 10점 비추누름국내영화시장 극혐;; 외화 잘될까봐 부들부들 덜덜떨면서 별점이나 깎고 이딴짓 몇년하고도 지겹지도 않나.. 창피하다 창피해 이러니...',
#   '10',
#   '242',
#   '65',
#   datetime.datetime(2016, 12, 8, 19, 9),
#   0],
#  ['어썸(urid****)',
#   '오프닝부터 엔딩까지 황홀 그 자체',
#   '10',
#   '207',
#   '36',
#   datetime.datetime(2016, 12, 7, 0, 31),
#   0],
#  ['eatemotgre(yona****)',
#   '솔직히 위플래시같은 긴장감이나 비긴어게인같은 로맨틱함 기대하고 보면 많이 지루하다. 차라리 우디앨런 스타일과  비슷한 예술영화 느낌. 특히 카페 소사이어티랑 많이 비슷함.',
#   '7',
#   '230',
#   '80',
#   datetime.datetime(2016, 12, 7, 22, 45),
#   0],
#  ['sequoia(eme1****)',
#   '재즈 속에서 그들은 다시 꿈꾸는 바보가 된다.',
#   '10',
#   '172',
#   '26',
#   datetime.datetime(2016, 12, 7, 22, 41),
#   0],
#  ['김서영(skk2****)',
#   '인생 영화 또 하나 탄생. 보고 나서 여운이 몇날 며칠은 갈 것 같은 영화. 마지막 라이언 고슬링과 엠마스톤의 눈빛이 모든 걸 말해주는.. 영화의 내용과 색감 음악 까지 완벽하게 어우러져서 보는 내내 힐링 되고 보고...',
#   '10',
#   '167',
#   '26',
#   datetime.datetime(2016, 12, 7, 16, 42),
#   0],
#  ['호시노코(inse****)',
#   '남친있는 상태에서 남자주인공으로 환승 남주 꿈 존중하는 듯 하더니 은근슬적 압박줘서 남주가 하기싫은 일하게 되는데 성공하고 바쁘니 싸우고 집나옴 결국 남주가 여자주인공 꿈 이루게 도와줬는데 5년후 꿈이루고 돈많은 딴...',
#   '1',
#   '272',
#   '139',
#   datetime.datetime(2017, 1, 4, 11, 53),
#   0],
#  ['해피트리(happ****)',
#   '정말 최고의영화다80년대 감성에내용도.노래도긴영화임에도 결코 눈을 뗄 수 없는 영화였다',
#   '10',
#   '161',
#   '32',
#   datetime.datetime(2016, 12, 8, 12, 17),
#   '관람객'],
#  ['매직가이(nano****)',
#   '영화 영상미 음악은 좋았지만 스토리는 부진특히 극중 미아는 마음이 너무 헤퍼보인다. 첫 남친에게서 남주로 갈아타는 것도 바람난거고 주인공 덕분에 성공한건데 감사의 마음도 너무 적어보이고 인성이 별로다.성공하고 남자를...',
#   '1',
#   '368',
#   '244',
#   datetime.datetime(2016, 12, 10, 21, 35),
#   0],
#  ['스피릿(spy_****)',
#   '나만재미없냐 솔직히말해봐라',
#   '1',
#   '458',
#   '336',
#   datetime.datetime(2016, 12, 18, 18, 33),
#   0],
#  ['아우치(vhfh****)',
#   '최고의 영화다 감동적이고 아름답다 .우리가 영화를 보는 이유',
#   '10',
#   '157',
#   '36',
#   datetime.datetime(2016, 12, 7, 14, 20),
#   0],
#  ['박사장(j121****)',
#   '뭐가 재밌다는 건지..여자 주인공 왤케 의리 없는지 이해 안 감..음악이랑 춤은 좋지만 스토리 라인이 너무 빈약;;;뮤직 비디오로 따로 편집해서 보면 좋을 듯합니다.와이프랑 중간에 졸기까지..이런 류 좋아하시는 분 ...',
#   '1',
#   '324',
#   '203',
#   datetime.datetime(2016, 12, 11, 17, 52),
#   0],
#  ['ㄸ(skye****)',
#   '어.... 왜 이게 인생영화라는건지 1도 모르겠어영ㅠ  노래도 좋긴한데 전체적으로 쫌 지겨운느낌..',
#   '1',
#   '488',
#   '367',
#   datetime.datetime(2016, 12, 19, 19, 16),
#   '관람객'],
#  ['박한솔(hans****)',
#   '나는 개인적으로 별로 재미 없었어요....',
#   '1',
#   '682',
#   '561',
#   datetime.datetime(2016, 12, 9, 17, 42),
#   '관람객'],
#  ['아메바(2bz_****)',
#   '저랑은 안맞는영화인것같네요',
#   '1',
#   '483',
#   '366',
#   datetime.datetime(2016, 12, 18, 15, 27),
#   '관람객'],
#  ['어리버리(cos_****)',
#   '부정할 수 없는 감독이네..몇 번이나 다시 보게 될지',
#   '10',
#   '150',
#   '34',
#   datetime.datetime(2016, 12, 7, 12, 6),
#   0],
#  ['lgtl****',
#   '어떤 노래건 어색함이 없었던 음악영화. 한 해를 마무리하는 영화로 충분합니다.',
#   '8',
#   '151',
#   '35',
#   datetime.datetime(2016, 12, 7, 16, 41),
#   '관람객'],
#  ['빙봉(lee_****)',
#   '저만 재미없나봐요 ;;',
#   '1',
#   '687',
#   '571',
#   datetime.datetime(2016, 12, 19, 23, 32),
#   '관람객'],
#  ['명성재(mmh0****)',
#   '제스타일의영화가아니였습니다',
#   '1',
#   '768',
#   '652',
#   datetime.datetime(2016, 12, 11, 22, 12),
#   '관람객'],
#  ['가나다(stre****)',
#   '내 인생작이라 할만큼 재밌게봤음',
#   '10',
#   '151',
#   '37',
#   datetime.datetime(2016, 12, 9, 23, 43),
#   '관람객'],
#  ['유정(jbyj****)',
#   '너무나도 평점이 좋은 영화여서 너무 기대를했지만 이렇게 지루하고 재미없는 영화는 처음이였다.중간에 영화를 그만보고 나가고 싶다는 생각을 하였고 영화보는내내 의자가 불편하고 딱딱한적은 처음이였다.전체적으로 너무 재미없...',
#   '1',
#   '382',
#   '276',
#   datetime.datetime(2016, 12, 18, 14, 16),
#   0],
#  ['대법관(rjaa****)',
#   '5년후 뜬금없이 진행된 스토리는 대체 뭐냐?',
#   '1',
#   '271',
#   '172',
#   datetime.datetime(2016, 12, 18, 8, 41),
#   0],
#  ['shel****',
#   "라라랜드가 재미없다고 생각하는 사람들을 '진정한 예술을 모르는, 한국의 싸구려 영화에만 익숙해져있는 사람들' 이라고 인식하는 게 참 우습다",
#   '1',
#   '196',
#   '99',
#   datetime.datetime(2017, 2, 2, 23, 35),
#   0],
#  ['ㅎㅎㅎㅎ(jsid****)',
#   '어지러운 시국에 이런 일탈이라도 필요하다',
#   '10',
#   '131',
#   '35',
#   datetime.datetime(2016, 12, 7, 19, 0),
#   '관람객'],
#  ['김수진(ksj0****)',
#   '호불호 많이 갈릴 듯. 개인적으로는 모든 게 다 별로.',
#   '1',
#   '273',
#   '179',
#   datetime.datetime(2016, 12, 18, 18, 42),
#   0],
#  ['31정승호(seun****)',
#   '나만 재미없었나 왤케 평점이 높은 건가요',
#   '1',
#   '320',
#   '226',
#   datetime.datetime(2016, 12, 12, 19, 31),
#   0],
#  ['엄윤진(eum9****)',
#   '평점보고  이 영화를  기대하며 보았지만  내용은  실망하기  딱  좋았고,  엔딩이 아주 허무하기  짝이  없었다.  중독성  있는  노래는 좋았지만  모든것이  아쉽고  잠자기 딱  좋다.  돈  낸게  아까워 ...',
#   '1',
#   '270',
#   '177',
#   datetime.datetime(2016, 12, 18, 14, 52),
#   0],
#  ['피아란(chl2****)',
#   '처음에는 당황, 중간에는 만족, 끝에는 헐...흑흑 눈물이 나와버린 영화.',
#   '10',
#   '122',
#   '31',
#   datetime.datetime(2016, 12, 8, 13, 18),
#   '관람객'],
#  ['Inss(leej****)',
#   '난괜찮아. 이정도면 우리 잘 해냈어.',
#   '10',
#   '111',
#   '21',
#   datetime.datetime(2016, 12, 10, 0, 5),
#   0],
#  ['살랑살랑(mmin****)',
#   '계절바뀔때마다 일어나야하나 고민함지루...',
#   '1',
#   '297',
#   '207',
#   datetime.datetime(2016, 12, 17, 20, 55),
#   0],
#  ['꿀꿀(ebki****)',
#   '10점대준놈들은 양심도없다. 사운드 영상 화려한 껍데기만 그럴싸할뿐 스토리 씹진부 그자체. 반복된 우연으로 만나서 자기타입아니라고 으르렁대다 결국사랑에빠지고는 꿈은 간절히 꾸면 이루어진다고 정말 할리우드여배우가되는 ...',
#   '1',
#   '303',
#   '213',
#   datetime.datetime(2016, 12, 15, 10, 36),
#   0],
#  ['킹캉콩(kry0****)',
#   '울지도 웃지도 않았다. 졸려서 죽을뻔;; 개연성이 없음. 여자는 5년동안 딴남자랑 결혼해서 애까지있음.  평점 높은사람들은 이 영화가 뭘 전달하고 싶은지 알긴 앎?',
#   '1',
#   '357',
#   '268',
#   datetime.datetime(2016, 12, 12, 18, 17),
#   0],
#  ['레몬티(nabi****)',
#   '평점이 너무 높아 실망한 영화.. 현대시대에 고전적 복고패션을, 판타지 뮤지컬에 로맨스를, 맘마미아에 노트북에 미드나잇 인더 파리를 짬뽕시킨 듯 한 영화..춤...다리가 쫙 안펴지면 어째 그냥 귀염..노래는 민망할 ...',
#   '1',
#   '227',
#   '143',
#   datetime.datetime(2016, 12, 10, 23, 41),
#   0],
#  ['박유민(park****)',
#   '많은 영화를 봐왔지만 이영화가 날 처음으로 당혹스러움과 혼라스러움을 느끼게해준 영화',
#   '1',
#   '228',
#   '144',
#   datetime.datetime(2016, 12, 11, 22, 22),
#   0],
#  ['석봉(leej****)',
#   '엄마는 잠이 드셨고  재밌어야 하는데... 황홀 하댔는데... 인생영화,,, 너도 느끼란말야...!스스로 다그치고 주문을 걸다 끝나버린영화연기, 음악과 춤, 영상미,어느 포인트에도  동요하지 않는 마음에 당황했던 영...',
#   '1',
#   '174',
#   '92',
#   datetime.datetime(2016, 12, 18, 12, 40),
#   0],
#  ['내밍(namh****)',
#   '10번 보면 10번 모두 다른 감동을 느낄 수 있을 거 같네요. 그런 의미에서 또 보러갑니다',
#   '10',
#   '118',
#   '39',
#   datetime.datetime(2016, 12, 7, 20, 15),
#   '관람객'],
#  ['gg(skek****)',
#   '여자가 남자한테 접근하고 성공하기 위해서 해어진다음 딴남자랑 결혼하는 영화',
#   '1',
#   '204',
#   '125',
#   datetime.datetime(2016, 12, 18, 17, 32),
#   0],
#  ['뚜오슈아이(duos****)',
#   '최악입니다 곡 하나로 너무 우려먹음중간에 cg처리한 우주에서 춤추는 부분이 겁나 웃겨서 진심 빵 터져서 웃었네요평점 믿을거 못된다는거 배웠네요돈도 돈이지만 시간이 너무 아깝다',
#   '1',
#   '250',
#   '171',
#   datetime.datetime(2016, 12, 19, 23, 56),
#   0],
#  ['네모탐락(skyf****)',
#   '이영화를 보고또보고 몇번을 봤다. ..  .남자의 꿈에는 여자가 있었고 여자의 꿈에는 남자가 없었던거 같다.',
#   '1',
#   '100',
#   '24',
#   datetime.datetime(2017, 3, 19, 13, 43),
#   0],
#  ['ily(thun****)',
#   '호불호 많이 갈릴듯한 영화임. 앞 부분 전개가 너무 느려서 졸렸음. 러브스토리라고 하기도 뭐하고 약간 장르도 애매한게 노잼. 최근 본 영화중에가 가장 노잼이었음...신중한 선택하시길;;',
#   '1',
#   '266',
#   '191',
#   datetime.datetime(2016, 12, 8, 14, 53),
#   0],
#  ['하원(mhw0****)',
#   '낭만적인 사랑스런 영화입니다',
#   '10',
#   '104',
#   '30',
#   datetime.datetime(2016, 12, 9, 16, 31),
#   '관람객'],
#  ['강의과단(gjk1****)',
#   '평점 조정 필요함 베댓보고낰임 내일 죽는다면 오늘 볼영화라더니 보고나니 오늘 죽고싶어짐',
#   '1',
#   '224',
#   '152',
#   datetime.datetime(2016, 12, 18, 20, 0),
#   0],
#  ['훈민짱(wjsg****)',
#   '아 솔직히 저는 너무 지루하고 재미없었어요ㅜㅜ어떤부분이 맘에 안들었다 딱꼬집어 못말하겠는데 걍 이런장르를 싫어 하시는분은 안보시는것도..ㅎ',
#   '1',
#   '173',
#   '102',
#   datetime.datetime(2016, 12, 23, 2, 47),
#   '관람객'],
#  ['yhw4****',
#   '시덥잖은 멜로에 127분짜리 음악만 듣다온기분',
#   '1',
#   '174',
#   '103',
#   datetime.datetime(2016, 12, 18, 20, 52),
#   0],
#  ['밤비(xin7****)',
#   '개봉 첫날 첫 상영을 본 보람이 있는 영화에요!!!보는내내 마법같은 영화에 푹 빠질 수 있었어요!!!한번보기에 아쉬운 영화라서 음향이 좋은 상영관에서 한번 더 봐야겠어요!!!',
#   '10',
#   '98',
#   '28',
#   datetime.datetime(2016, 12, 7, 17, 54),
#   '관람객'],
#  ['와우렁(kim9****)',
#   '꿈에 대한 영화인지 사랑에 대한건지 애매모호함. 마지막에 남자의 상상신은 진짜 너무 남자를 비참하게 만들었음.',
#   '1',
#   '154',
#   '84',
#   datetime.datetime(2017, 1, 2, 1, 16),
#   '관람객'],
#  ['JH(beew****)',
#   '한줄평 : 여주 = 자기 사정에 따라 남자 갈아타기 좋아함',
#   '1',
#   '157',
#   '87',
#   datetime.datetime(2016, 12, 11, 1, 17),
#   0],
#  ['무명들풀(k000****)',
#   '제취향은 아님....',
#   '1',
#   '245',
#   '175',
#   datetime.datetime(2016, 12, 9, 7, 51),
#   0],
#  ['stso****',
#   '결말이 개 짜증나는 영화',
#   '1',
#   '128',
#   '60',
#   datetime.datetime(2016, 12, 13, 12, 54),
#   0],
#  ['쓰마일(hesu****)',
#   '나갈뻔한걸 참은 내자신이 대단하다고 느낌',
#   '1',
#   '180',
#   '112',
#   datetime.datetime(2016, 12, 13, 21, 47),
#   0],
#  ['CSH(wldy****)',
#   '평점 처음 남겨보는데 남겨야 할거같음스토리도 이해 안가고 난해한 영화였음 진심 노잼 요즘 잠안오는데 그영화보면 잠잘올듯 지루한 영화였음',
#   '1',
#   '170',
#   '104',
#   datetime.datetime(2016, 12, 11, 13, 50),
#   0],
#  ['rex(lhc1****)',
#   '어디서 감명을 받아야 하는지를 모르겠네. 꿈을 좇아라? 돈을 좇아라? 던지는 메시지도 없음. 남주가 불쌍하진 않지만 내가 남주라면 기분 씁쓸할듯. 그냥 밴드나 계속하지',
#   '1',
#   '200',
#   '138',
#   datetime.datetime(2016, 12, 24, 0, 36),
#   '관람객'],
#  ['guts****',
#   '멋부리지 않고 순수한 마음 그대로를 잘 표현한 영화였다 집착이 아닌 각자의 성공을 진심으로 빌어주는 그마음이 참 보기 좋았다.섹스신이 없는것도 좋았고..',
#   '9',
#   '73',
#   '12',
#   datetime.datetime(2016, 12, 12, 18, 57),
#   '관람객'],
#  ['김(epql****)',
#   '정말 재미있게봤다 남주와 여주의 감성?을 뮤지컬처럼 표현한게 정말 인상깊었다 마지막 장면에진짜 울뻔함',
#   '10',
#   '86',
#   '25',
#   datetime.datetime(2016, 12, 7, 13, 24),
#   0],
#  ['프리지아(ador****)',
#   '비긴어게인에 감히 갖다대지 말길 바람. 이 영화에 눈물 흘리는 사람들은 조건 더 좋은 남자에게 여친 뺏겨본 경험 있는 남자나, 만나던 남자 버리고 더 좋은 조건의 남자랑 결혼 한 여자일듯. 진심 올 해 나의 최악의 ...',
#   '1',
#   '231',
#   '171',
#   datetime.datetime(2016, 12, 18, 14, 9),
#   0],
#  ['ROINAT(yomg****)',
#   'the end 영화가 끝나는 순간 일어나서 박수를 치고 싶었다',
#   '10',
#   '74',
#   '15',
#   datetime.datetime(2016, 12, 14, 2, 46),
#   '관람객'],
#  ['사과향비누(miny****)',
#   '산만하고 재미도없고 감동도없고 끝은 더 뭔가싶음',
#   '1',
#   '205',
#   '146',
#   datetime.datetime(2016, 12, 9, 0, 4),
#   0],
#  ['에곳먼은(gva1****)',
#   '시각 청각적으로 정말 즐거워요 그냥 구두 소리도 매우 좋아요 마지막 필름 부분 개쩜',
#   '9',
#   '74',
#   '16',
#   datetime.datetime(2016, 12, 7, 17, 36),
#   '관람객'],
#  ['란동(tara****)',
#   '올해 최악의 영화. 낭만으로 포장된 LA신데렐라.',
#   '1',
#   '122',
#   '64',
#   datetime.datetime(2016, 12, 17, 13, 57),
#   0],
#  ['시혜(wkrd****)',
#   '사람들의 평이 이해가 되지 않는 영화',
#   '1',
#   '98',
#   '41',
#   datetime.datetime(2016, 12, 20, 11, 50),
#   0],
#  ['mijeong(topt****)',
#   '진짜 호불호 갈리는듯ㅠ 보가 중간에 나옴',
#   '1',
#   '147',
#   '90',
#   datetime.datetime(2016, 12, 15, 21, 3),
#   '관람객'],
#  ['채이맘(ange****)',
#   '기대를많이해서구런지.. 솔직히별로',
#   '6',
#   '201',
#   '144',
#   datetime.datetime(2016, 12, 7, 20, 22),
#   '관람객'],
#  ['슈퍼에디(envy****)',
#   '결국 현실극복을 못하고 각자 갈길간다는 스토리라 연인끼리 딱가면헤어지란 소리인거같음  정신나간 감독임',
#   '1',
#   '104',
#   '48',
#   datetime.datetime(2016, 12, 18, 17, 7),
#   0],
#  ['별명뭐지(lmsm****)',
#   '잘 모르겠다. 그냥 현란한 음악과 영상에 감동해 달라는 압박만 두시간여 받다가 나온듯한 느낌?',
#   '1',
#   '102',
#   '47',
#   datetime.datetime(2016, 12, 19, 0, 20),
#   0],
#  ['구미앤초코(crus****)',
#   '영화가 전달하고자 하는것이 무엇인가? 열정인가 사랑인가. 재즈인가 뮤지컬인가. 장면간의 흐름이 어색하고, 여주인공의 연기는 더 이상하다. 특히 홀로 노래할때 쏟아지는 졸음을 막을 길이 없음.  그래서 이 영화가 말하...',
#   '3',
#   '110',
#   '55',
#   datetime.datetime(2016, 12, 8, 9, 53),
#   0],
#  ['룰루(qls1****)',
#   '알바를얼마나 썼으면 별점이 1점10점 인영화는 처음봤어요. 연출 분위기 괜찮은데 스토리와 계절로 나눴는데도 꽉차지 못한 느낌에 2시간이나 되면서 내용도 흐지부지 여자가 남자 세번갈아타면서 자기성공만 찾는 이기적인면을...',
#   '1',
#   '91',
#   '37',
#   datetime.datetime(2017, 1, 2, 23, 0),
#   0],
#  ['라빈(rhdm****)',
#   '아무리 호불호가있다지만정말 끔찍하게도 힘든시간이었다 중간에 나오고싶은걸 참고보느라 곤욕이었음지루함의 그 자체 내 시간을 투자해 본게 화가난다',
#   '1',
#   '115',
#   '61',
#   datetime.datetime(2016, 12, 15, 23, 31),
#   0],
#  ['잘생긴남자(seoh****)',
#   '결론은 남자덕에 성공하자 배신때림. 영원히 사랑할거란것도 뻥. 남녀가 바꼈으면 욕 바가지로 먹었을영화. 음악은 좋은데 분노가 치민다.',
#   '1',
#   '78',
#   '25',
#   datetime.datetime(2017, 2, 4, 21, 18),
#   0],
#  ['김로이(lawl****)',
#   '진부하고 지루하고 과잉이다...',
#   '1',
#   '101',
#   '48',
#   datetime.datetime(2016, 12, 11, 19, 53),
#   0],
#  ['쥬떼(jyjj****)',
#   '역시 네이버 평점은 믿을게 못된다..뭐가 도대체 괜찮다는거지???',
#   '1',
#   '104',
#   '52',
#   datetime.datetime(2016, 12, 18, 2, 37),
#   0],
#  ['stella(mado****)',
#   '지나치게 과대평가 되었다. 나쁘지는 않지만 역대 뮤지컬영화들에 비하면 그리 훌륭하지도 대단하지도 않다. 영화사에 길이 남을 명작은 절대 아니다. 헐리웃 배우들이 원색의 잔치속에서 노래하고 춤추면 다 걸작인가.  결정...',
#   '1',
#   '73',
#   '22',
#   datetime.datetime(2017, 2, 3, 12, 1),
#   0],
#  ['퀀(monk****)',
#   '평점알바가 있을 것만같은 평점을 가진 영화. 연출이 좋다고하는데 외려 어지럽고 눈아팠음. 에세이를 영화한 느낌이자 하이스쿨 뮤지컬의 성인버전같았음. 춤추는 장면들이 어색하다고 느낌. Waste of time wast...',
#   '1',
#   '159',
#   '108',
#   datetime.datetime(2016, 12, 11, 20, 22),
#   0],
#  ['ehgu****',
#   '잘잤습니다... 중간에 보다 나오기는 처음이네요..',
#   '1',
#   '193',
#   '142',
#   datetime.datetime(2016, 12, 18, 19, 15),
#   '관람객'],
#  ['just****',
#   '평점 너무높음  관객들 절반을졸게만드는영화',
#   '1',
#   '208',
#   '157',
#   datetime.datetime(2016, 12, 8, 23, 2),
#   0],
#  ['루키(geni****)',
#   '음‥‥ 취향에 따라 다르겠지만 정말이지 지루함이 거의 끝판왕 수준이고 아무리 뮤지컬영화지만 시도때도없이 불러대는통에 흐름끊기고 메시지도 없고 결국 결말은 개떡 진짜 연인이랑 보든 부부가 보든 남자 입장에서 기분 더러...',
#   '1',
#   '85',
#   '35',
#   datetime.datetime(2017, 6, 11, 16, 18),
#   0],
#  ['빈녹(zene****)',
#   '감성이 매말랐나봐요 별로요',
#   '1',
#   '159',
#   '109',
#   datetime.datetime(2016, 12, 21, 0, 35),
#   '관람객'],
#  ['송치영(youn****)',
#   '도대체 무슨 영화인지 모르겠다 ... 정말 난해하고 무슨 스토리와 의미를 전달하고자 한것인지 ... ^^',
#   '1',
#   '241',
#   '191',
#   datetime.datetime(2016, 12, 12, 17, 51),
#   '관람객'],
#  ['강하다(g_hd****)',
#   '마지막 10분이 똥을줌',
#   '1',
#   '87',
#   '39',
#   datetime.datetime(2016, 12, 17, 22, 48),
#   0],
#  ['젬마(wani****)',
#   '호불호갈리는영화 첨에 갑자기 인도영화인줄ㅋㅋㅋㅋ 졸린거간신히참고봣는데별거없음',
#   '1',
#   '93',
#   '45',
#   datetime.datetime(2016, 12, 18, 18, 10),
#   0],
#  ['sign(heal****)',
#   '네 잘봤구요 잘잤습니다 불면증 치료에 딱이네요 ㅎㅎㅎ',
#   '1',
#   '147',
#   '99',
#   datetime.datetime(2016, 12, 8, 1, 32),
#   0],
#  ['나임(s2lo****)',
#   '여주는 처음부터 끝까지 극혐역할에다가 마지막 결말까지 역겹던데 이게 왜 평점이 높은지 모르겠네; siva랄라랜드로 제목을 바꿔야한다고 생각이 듦. 새해 처음 본 영화가 이거라는게 나 자신에게 안타까울정도..',
#   '1',
#   '66',
#   '19',
#   datetime.datetime(2017, 1, 4, 2, 38),
#   0],
#  ['나다나(qq33****)',
#   '별 한개도 아까움.. 보다가 잠. 내 옆에 앉은 사람들은 보다가 재미없다고 중간에 나감.',
#   '1',
#   '77',
#   '30',
#   datetime.datetime(2016, 12, 18, 23, 45),
#   0],
#  ['도도리(petd****)',
#   '길고 지루하고 잠오는 영화. 영상미에 비해 내용 없음.',
#   '1',
#   '88',
#   '41',
#   datetime.datetime(2016, 12, 11, 23, 6),
#   0],
#  ['썽주(gaso****)',
#   '뭔 말인지...전첵적인 연결이 안되다가 마지막에 맞추려고 노력하는데...',
#   '1',
#   '92',
#   '45',
#   datetime.datetime(2016, 12, 11, 13, 52),
#   0],
#  ['ji03****',
#   '뮤지컬영화도 아니고 정체성이 뭐냐 이건 진짜... 뜬금없는 상황에 춤추고 노래하고 스토리는 중구난방.안보신분들 신중하게 생각하세요 여러분의 돈은 소중하니까요.',
#   '1',
#   '106',
#   '59',
#   datetime.datetime(2016, 12, 10, 21, 51),
#   0],
#  ['권소희(mave****)',
#   '음악,영상미, 연출이다한영화. 스토리의 한방이 없다.',
#   '4',
#   '111',
#   '64',
#   datetime.datetime(2016, 12, 7, 17, 1),
#   0],
#  ['jiho****',
#   '솔직히 태어나서 처음으로 영화보다가 나왔다. 내가 이상한가? 감동도 재미도 개연성도 없다. 최악이었다',
#   '1',
#   '136',
#   '89',
#   datetime.datetime(2016, 12, 25, 22, 23),
#   '관람객'],
#  ['아르샤(stea****)',
#   '꿈? 사랑? 음악? 세가지가 따로놈 ㅋㅋㅋ',
#   '1',
#   '63',
#   '17',
#   datetime.datetime(2017, 1, 2, 5, 8),
#   0],
#  ['김지원(uhoo****)',
#   '지루하고 노잼이었음영상미 어쩌고 하길래 개츠비급 영상미 기대하고 갔는데 천문대에서 걍 기절할뻔 함 ㅋㅋ',
#   '1',
#   '71',
#   '25',
#   datetime.datetime(2016, 12, 16, 22, 58),
#   0],
#  ['이강산(1004****)',
#   '이거안보면 내일 죽는대도 안보러갈 영화 런닝타임 절반은 잤다',
#   '1',
#   '128',
#   '82',
#   datetime.datetime(2016, 12, 8, 20, 41),
#   0],
#  ['ANN(dkfm****)',
#   '재미가 없었습니다...',
#   '1',
#   '75',
#   '30',
#   datetime.datetime(2016, 12, 18, 17, 3),
#   0],
#  ['Sugar Cane(apro****)',
#   '현실에 잠든 당신을 깨워줄  그런영화!',
#   '9',
#   '60',
#   '16',
#   datetime.datetime(2016, 12, 7, 16, 20),
#   0],
#  ['일곡직업학교(happ****)',
#   '영상미.. 남자배우..등은 좋았으나..  감정이입이 되지 않았다.. 노래도 그렇고 전개가 매우 뜬금없고 지루했다..  중반이후에나 이야기가 전개되는 느낌을 받았고 보고나서 멍한 느낌밖에 없었다.. 제5침공인가.. 그...',
#   '1',
#   '73',
#   '29',
#   datetime.datetime(2016, 12, 18, 17, 15),
#   0],
#  ['무내(2stu****)',
#   '영화수익금 전부 댓글알바시키는데 쓴건가',
#   '1',
#   '88',
#   '44',
#   datetime.datetime(2016, 12, 15, 16, 36),
#   0],
#  ['cafe AO(cafe****)',
#   '연말에는 음악과 황홀하게 사랑에 빠지고 싶다면',
#   '10',
#   '60',
#   '17',
#   datetime.datetime(2016, 12, 7, 5, 36),
#   0],
#  ['장성혁(aleh****)',
#   '간신히 참고 봤지만.. 정말 졸리고 재미없었어요. 처음 평점 써봅니다.',
#   '1',
#   '61',
#   '18',
#   datetime.datetime(2016, 12, 19, 11, 21),
#   0],
#  ['pnny****',
#   '시작할때부터 잠들수 있는 마법의 영화 재미도 없고 감동도 없어요ㅋㅋㅋㅋ  정말 푹 자다 왔네요',
#   '1',
#   '81',
#   '38',
#   datetime.datetime(2016, 12, 9, 20, 2),
#   0],
#  ['jood****',
#   '평점이너무높음....그렇게재밋지는않았어요 평점좀내리죠',
#   '1',
#   '85',
#   '42',
#   datetime.datetime(2016, 12, 11, 23, 27),
#   0],
#  ['여하나(abca****)',
#   '영상미가 확 도르러지는것도 아니고 음악은 좋긴 한데 다양하지 않으며 색감이 확 와닿는것도 아니고 스토리도 중구 난방이고 진짜 완전 별루',
#   '1',
#   '90',
#   '47',
#   datetime.datetime(2016, 12, 11, 15, 20),
#   0],
#  ['rmsw****',
#   '진짜 재미없음.. 돈아까움..',
#   '1',
#   '95',
#   '52',
#   datetime.datetime(2016, 12, 11, 18, 11),
#   0],
#  ['황다니(tnsx****)',
#   '마지막 라이언 고슬링의 표정은 잊을 수 없다...지금 내 곁에 있는 여자를 지캬내야겠다는굳은 의지로 쉽게 극장을 벗어날 수 없었던 영화.',
#   '8',
#   '60',
#   '18',
#   datetime.datetime(2016, 12, 11, 17, 45),
#   '관람객'],
#  ['오렌지하늘(wjdt****)',
#   '내 자신의 감성과 맞지 않는 영화는 보면 안된다는 사실을 다시 한번 느꼈습니다. 어휴...!!!!',
#   '1',
#   '69',
#   '27',
#   datetime.datetime(2016, 12, 15, 13, 35),
#   0],
#  ['이카루스(jega****)',
#   '재즈와 뮤지컬의 향연, 반짝반짝 빛나는 영상미까지 황홀한 꿈을 꾼 느낌이었다.',
#   '10',
#   '54',
#   '13',
#   datetime.datetime(2016, 12, 7, 15, 36),
#   0],
#  ['조현정(if10****)',
#   '초반에 현남친 있는 상태에서 남주에게 갈아타다가 남주덕에 성공 했더만 야바리없게 다른남자로 또 갈아타버리기 이거밖에 기억안남 굳이 장점 말하자면 노래는 좋았다',
#   '1',
#   '56',
#   '15',
#   datetime.datetime(2017, 5, 23, 7, 14),
#   0],
#  ['샹바(wand****)',
#   '개노잼인데 이게왜? ㅡㅡ 카페소사이어티랑 결말 똑같은데 훨씬 슬퍼할 당위성없고 그냥 씁쓸정도지 옆에서 훌쩍대는 인간들 이해를 못하겠던데 같이 함께할 기회가 얼마든지 있었는데 서로 갈길 가놓고 나중에 뭐 어쩌자는거지?...',
#   '1',
#   '62',
#   '22',
#   datetime.datetime(2016, 12, 28, 20, 32),
#   0],
#  ['치느(dlrl****)',
#   '제 스타일 영화는 아니었던거 같아요',
#   '1',
#   '68',
#   '28',
#   datetime.datetime(2017, 2, 5, 16, 9),
#   '관람객'],
#  ['chae yu jin(pict****)',
#   '기대를 너무 많이해서인지 전 별로였어요. 개연성 떨어지고 스토리 진부하고..영상미가 그렇게 뛰어난 것 같지도 않고. 배우 연기와 메인노래 하나는 좋았네요.',
#   '1',
#   '99',
#   '59',
#   datetime.datetime(2016, 12, 22, 1, 27),
#   '관람객'],
#  ['서나(jsa7****)',
#   '노잼그자체..평점 좋아서 봤드만',
#   '1',
#   '176',
#   '136',
#   datetime.datetime(2016, 12, 10, 0, 27),
#   '관람객'],
#  ['노숙자(gold****)',
#   '간만에 숙면했습니다.',
#   '1',
#   '61',
#   '22',
#   datetime.datetime(2016, 12, 18, 17, 12),
#   0],
#  ['yah8****',
#   '취향이아니다ㅠㅠ노잼',
#   '1',
#   '129',
#   '90',
#   datetime.datetime(2016, 12, 9, 23, 20),
#   '관람객'],
#  ['정재경(beth****)',
#   '굿입니다오열자열자열',
#   '10',
#   '63',
#   '25',
#   datetime.datetime(2016, 12, 7, 12, 22),
#   '관람객'],
#  ['안용민(sswd****)',
#   '연애하려면 절대음감에 노래실력에 탭댄스에 순발력에 야간에 천문박물관 정도는 통째로 빌려야한다는 점을 이에 더해 공중부양 능력까지 필요함을 느끼게 한 핵 쓰레기 영화',
#   '1',
#   '70',
#   '32',
#   datetime.datetime(2016, 12, 19, 17, 33),
#   0],
#  ['후라(gogo****)',
#   '내용이 산으로 갔다 바다로 갔다...',
#   '1',
#   '123',
#   '85',
#   datetime.datetime(2016, 12, 14, 23, 12),
#   '관람객'],
#  ['파닥몬(whit****)',
#   '호불호 많이 갈리는 영화 진짜로. 솔직히 평점 이해못하겠음 영화 끝나고 별로라고하는 사람 많았음 주위 친구들도 핵노잼이라는 친구 3이면 인생영화라는 친구 1? 이정도',
#   '1',
#   '50',
#   '13',
#   datetime.datetime(2016, 12, 25, 2, 43),
#   0],
#  ['솜(song****)',
#   '역시 2번째 봤는데도 존잼',
#   '10',
#   '52',
#   '15',
#   datetime.datetime(2016, 12, 16, 10, 6),
#   '관람객'],
#  ['sinj****',
#   '처음 봤을때는 몰랐다 이 영화가 이렇게 재미없을줄은',
#   '1',
#   '53',
#   '16',
#   datetime.datetime(2016, 12, 29, 17, 30),
#   0],
#  ['구성점(trad****)',
#   '전개 꽝 뜬끔 없는 스토리 결말 !! 워플레시 1/10 재미.. 관람하는데 뒤에서 나가자고 이야기 듣고 집중도 않되고 왜보는가 생각만 하다 나옴 ㅋㅋ',
#   '1',
#   '58',
#   '21',
#   datetime.datetime(2016, 12, 13, 0, 18),
#   0],
#  ['낭만몽상가(fjqm****)',
#   '이렇게 재미1도없는  영화는 처음보는데 다들 왜 재밌다는거징?',
#   '1',
#   '59',
#   '22',
#   datetime.datetime(2016, 12, 22, 12, 59),
#   0],
#  ['뿌우(kjy9****)',
#   '예매율 높길래 무슨영화인지도 모르고봤는데개지루하고 진짜 최악.. 엠마스톤 미모가 다했음',
#   '1',
#   '59',
#   '22',
#   datetime.datetime(2016, 12, 11, 1, 40),
#   0],
#  ['공주(9015****)',
#   '무료로한다해도 안볼래..',
#   '1',
#   '68',
#   '31',
#   datetime.datetime(2016, 12, 9, 9, 7),
#   0],
#  ['Dndb(tjsd****)',
#   '정말보지마세요 제가 여러분께 드리는 크리스마스 선물이에요',
#   '1',
#   '109',
#   '72',
#   datetime.datetime(2016, 12, 8, 22, 29),
#   0],
#  ['JLC(pssl****)',
#   '여자친구랑  주말에  기분  좋게  영화보러  가서  잠잣다고  헤어질  위기에  처했습니다',
#   '1',
#   '49',
#   '13',
#   datetime.datetime(2017, 1, 14, 2, 41),
#   0],
#  ['fobs(fobs****)',
#   '이 영화는 스릴러 영화다.같이간 친구가 재미없다고 나가자고 할까봐 손에 땀을쥐고 봤다. 절교가 예상되는 박진감넘친 시간이었다.',
#   '1',
#   '49',
#   '13',
#   datetime.datetime(2017, 1, 1, 5, 32),
#   0],
#  ['빽(thau****)',
#   '음악도 좋아하고. 재즈도 좋아하고. 뮤지컬도 좋아한다. 근데 이 영화는 저 삼요소를 모두 갖추고도 내게 노잼을 선사했다.',
#   '1',
#   '51',
#   '15',
#   datetime.datetime(2017, 1, 9, 19, 13),
#   0],
#  ['화학이(usyp****)',
#   '어...일단 한시간쯤잤고,지루하고재미없었어요!',
#   '1',
#   '53',
#   '17',
#   datetime.datetime(2016, 12, 18, 19, 51),
#   0],
#  ['bark****',
#   '두 남녀다 각자만의 인생을 찾았음에도 불구하고 불행해보였다.마지막에 남주의 눈빛이 너무 슬퍼보였음.정말 두 사람은 행복한 인생을 찾은거였는지 잘 모르겠다..',
#   '1',
#   '46',
#   '11',
#   datetime.datetime(2017, 3, 25, 15, 38),
#   0],
#  ['룽이(dkfm****)',
#   '예고편보고 기대했는데...',
#   '1',
#   '83',
#   '48',
#   datetime.datetime(2016, 12, 12, 23, 50),
#   '관람객'],
#  ['히용이(mmm5****)',
#   '정말 노잼...너무 지루했어요',
#   '1',
#   '60',
#   '26',
#   datetime.datetime(2017, 2, 9, 21, 50),
#   '관람객'],
#  ['zzz(kimn****)',
#   '시작부터 중간까지 너무 지루해서 잘뻔했어요영상미 음악 빼면 남는게하나도 없는 영화 꿈찾는 영화 너무 뻔해도 스토리잘채워주면 잘보는데 그것도 아니고 그냥 지루하기만 한 영화 내 돈내고안본게 다행이었어요',
#   '1',
#   '75',
#   '41',
#   datetime.datetime(2016, 12, 9, 23, 50),
#   0],
#  ['쪼쪼(sais****)',
#   '여자친구는 숙면했고 저는 눈물흘리며 봤네요',
#   '9',
#   '40',
#   '7',
#   datetime.datetime(2016, 12, 17, 16, 31),
#   '관람객'],
#  ['yanz****',
#   '이딴걸 인생영화라고,  여주  개짜증나는 스타일이다,남주는 밴드나  그냥하지,중간중간  졸린걸  참고봤는데  엔딩보고  욕나왔다.',
#   '1',
#   '45',
#   '12',
#   datetime.datetime(2017, 1, 1, 10, 18),
#   0],
#  ['강민규(lucy****)',
#   '여자친구와 봤는데  서로 인생 최악의 영화라고 뽑아씁니다.  고민핮마시고 다른거 보세요안보시면 저에게 감사하게 될거예요',
#   '1',
#   '97',
#   '64',
#   datetime.datetime(2016, 12, 8, 21, 39),
#   0],
#  ['배고파여(rmsd****)',
#   '스토리부터시작해서 전부 개판인데 음악빨로 가는 영화를 재미없다했다고 인생을즐기지못하느니 성격에 문제있니없니  크으 하긴 대가리에 든게없으니 이딴영화빨아대는거지',
#   '1',
#   '48',
#   '16',
#   datetime.datetime(2017, 1, 25, 13, 37),
#   0],
#  ['yves(yves****)',
#   '후...잘잣다..불면증치료에 좋네요',
#   '1',
#   '55',
#   '23',
#   datetime.datetime(2016, 12, 18, 19, 57),
#   0],
#  ['gkrt****',
#   '인생최악... 집중도안되고 이게영화인지',
#   '1',
#   '71',
#   '39',
#   datetime.datetime(2016, 12, 24, 16, 50),
#   '관람객'],
#  ['밈지(8775****)',
#   '난 정말 재미없었음.. 전개가 너무 거지같았음 지루해서 계속 졸고.. 돈아까움',
#   '1',
#   '78',
#   '46',
#   datetime.datetime(2016, 12, 11, 15, 1),
#   0],
#  ['바다(rlag****)',
#   "현실적인 '척' 하는 비현실적인 영화 여주 캐릭터 매력없고 재즈피아노 좋아하는데 처음엔 좋았으나 너무 반복해서 나중엔 듣기 싫을정도 특히 스토리 혐 그렇다고 영상미,음악,뮤지컬,내용,연기 모 하나 뛰어...",
#   '1',
#   '47',
#   '16',
#   datetime.datetime(2016, 12, 25, 21, 10),
#   0],
#  ['홀맨(holl****)',
#   '난 잘모르겠다...  호불호가 갈린다 넘재미없엇다',
#   '1',
#   '53',
#   '22',
#   datetime.datetime(2017, 3, 9, 23, 27),
#   '관람객'],
#  ['dans****',
#   '배뎃 존나 오글거리네. ㅋㅋㅋ 진짜 진지감성충들 참 많네..물론 감성적인 것은 좋지만, 영화는 흡입력이 있어야되는데.. 진짜 지루하고 졸린 영화.',
#   '1',
#   '55',
#   '24',
#   datetime.datetime(2016, 12, 15, 9, 47),
#   0],
#  ['오징어칩(pgpa****)',
#   '불면증이 치유됬어요^^ 모두들 축하해 주세요ㅎㅎ',
#   '1',
#   '55',
#   '24',
#   datetime.datetime(2016, 12, 11, 13, 29),
#   0],
#  ['신 바람(wody****)',
#   '저는 솔직히 별로 였어요',
#   '2',
#   '74',
#   '43',
#   datetime.datetime(2016, 12, 16, 18, 49),
#   '관람객'],
#  ['조원영(dnjs****)',
#   '뭐지이영화는....진짜 내가 이상한건지모르겟는데 너무재미없엇음....기대하고봣는데 너무지루해서 처음으로영화관에서 잤음....노래만좋았음..',
#   '1',
#   '82',
#   '51',
#   datetime.datetime(2016, 12, 8, 16, 31),
#   0],
#  ['syb0****',
#   '이건 정말 아름다운영화다 라고 보여지고 싶어서 작정하고 오바한 영화. 댓글알바들 다 쏴버리고 싶다. 극중 삼바&타파스처럼 재즈도 로맨스도 아닌 잡탕. 누가 비긴어게인에 견줄만한영화라 함...? 퐉씨..',
#   '1',
#   '119',
#   '88',
#   datetime.datetime(2016, 12, 8, 23, 40),
#   0],
#  ['kisa****',
#   '영화 보는 내내 환상속에 둥둥 떠다니는 느낌이었다. 사랑을 해 본 사람이라면 눈물없이 보지 못할 영화 아닐까...  우리나라도 이런 영화를 만들었음 좋겠다는 생각을 문득 했지만 역시... 스케일의 차이랄까...',
#   '9',
#   '46',
#   '16',
#   datetime.datetime(2016, 12, 7, 21, 44),
#   0],
#  ['초콜렛(magi****)',
#   '아우 잠와미치겠네 뭐 내일죽으면 오늘보러올영화?개뿔진짜 평점알바가 존재하는구나',
#   '1',
#   '99',
#   '69',
#   datetime.datetime(2016, 12, 7, 22, 14),
#   0],
#  ['열공모드(tlsw****)',
#   '스토리 개연성 노답,  천문대 CG 개 유치 노답, 여주는 배신자',
#   '1',
#   '40',
#   '11',
#   datetime.datetime(2017, 1, 2, 13, 49),
#   0],
#  ['잇힝(rvds****)',
#   '어바웃타임 비긴어게인 재밌게봤어요 이런거 안좋아하나부다 싶어하지마세요 이 영화가 이상한거예요....',
#   '1',
#   '42',
#   '13',
#   datetime.datetime(2016, 12, 25, 22, 54),
#   0],
#  ['luff****',
#   '세상의 모든 예술가, 사랑하는 연인들, 바보처럼 꿈꾸는 사람들, 현실에 지친 이들, 감성을 잃어가는 사람들을 위한 영화.지친 현실 속에서 머리로만 꿈꾸던 아름다움을 스크린에 담았다.뮤지컬에 대한 생각이 바뀌었다.너무...',
#   '10',
#   '42',
#   '13',
#   datetime.datetime(2016, 12, 9, 1, 2),
#   '관람객'],
#  ['잭(dhks****)',
#   '재미없다. 정말이다.',
#   '1',
#   '47',
#   '18',
#   datetime.datetime(2016, 12, 18, 19, 0),
#   0],
#  ['순대킬러(wsc1****)',
#   '생각보다 너무 별로....전개가....',
#   '1',
#   '52',
#   '23',
#   datetime.datetime(2017, 1, 15, 20, 56),
#   '관람객'],
#  ['Kwon(skyg****)',
#   '라이언의 마지막 미소가 너무 슬펐다....',
#   '1',
#   '33',
#   '5',
#   datetime.datetime(2017, 1, 27, 0, 28),
#   0],
#  ['국고도리(gost****)',
#   '평점알바가 존재한단걸 알려준 영화',
#   '1',
#   '42',
#   '14',
#   datetime.datetime(2017, 1, 2, 2, 45),
#   0],
#  ['윤정하(ting****)',
#   '여주가 성공한게 남주덕분인데 남주 버리고 돈많은 남자만나 애낳고. 여주 포장하는 영화임. 영화알바가 정말 존재하네요. 내일 죽는다면 이 영화보지마시고 그 돈으로 맛있는거 사먹는게 백배 천배 낫습니다.',
#   '1',
#   '44',
#   '16',
#   datetime.datetime(2017, 1, 15, 11, 56),
#   0],
#  ['ekwn****',
#   '보지마세요 OOO기입니다 여자주인공 배신함 천하의 라헬같은색기',
#   '1',
#   '44',
#   '16',
#   datetime.datetime(2016, 12, 18, 17, 16),
#   0],
#  ['박현정(qkrg****)',
#   '색감이 이쁘다고 해서 봤는데 정말 색감만 이쁨 나랑 안맞는듯',
#   '1',
#   '51',
#   '23',
#   datetime.datetime(2017, 1, 9, 18, 54),
#   '관람객'],
#  ['햄(saum****)',
#   '난 정말 별루...내스타일이 아님',
#   '1',
#   '53',
#   '25',
#   datetime.datetime(2016, 12, 25, 22, 17),
#   '관람객'],
#  ['ekaq****',
#   '진심... 궁금하신분들 금방 내릴거같으니 몇주만 참고 집에서 보세요이건뭐 뻔한 한국 재난영화 피했다가 제대로 똥밟았네요뭐 실험적인 예술영화 찍고싶은 감독의 의도로 나온 쓰레기..빙우,롤러코스터 이후로 진짜 오랜만에 ...',
#   '1',
#   '57',
#   '29',
#   datetime.datetime(2016, 12, 11, 23, 12),
#   0],
#  ['아하하(sjar****)',
#   '뻔한스토리. 지루함. Ost랑 엠마만 괜찮음',
#   '1',
#   '90',
#   '62',
#   datetime.datetime(2016, 12, 12, 20, 29),
#   '관람객'],
#  ['뿌(yhj8****)',
#   '기대하고갔는데 정말 별로였습니다내용도 딱히 탄탄하고 재밌는구성은아니구요좀 지루한? 영화가말하고자하는 메시지는 좋은데 재미없게봤습니다 약간어설픈것같은느낌도 들고 감동적인 장면은 별로 안감동적이예요. 엠마스톤은여전히매력...',
#   '3',
#   '106',
#   '78',
#   datetime.datetime(2016, 12, 8, 12, 6),
#   0],
#  ['sanv****',
#   '진심보지마세요진심그냥무한도전보세요',
#   '1',
#   '55',
#   '28',
#   datetime.datetime(2017, 1, 9, 1, 45),
#   '관람객'],
#  ['난난난(hsh9****)',
#   '두번째보니 더 재밌다..',
#   '10',
#   '27',
#   '1',
#   datetime.datetime(2017, 10, 8, 0, 16),
#   0],
#  ['박우유(qkrr****)',
#   '화면은 예쁜데 스토리 바닥',
#   '1',
#   '36',
#   '10',
#   datetime.datetime(2017, 1, 19, 14, 43),
#   0],
#  ['카루스(karo****)',
#   '진부한 스토리, 뻔한 뮤지컬형식, 난잡한 진행, 개연성 증발, 전달하고자 하는 의미 상실, 마지막 상상씬은 감독이 뭘 말하고자 하는건지 ㅋㅋ 진심 별점 안다는데 이영화는 오랜만에 단다 별점 조작했는지 의심스럽다.',
#   '1',
#   '37',
#   '11',
#   datetime.datetime(2017, 1, 2, 22, 10),
#   0],
#  ['kiku****',
#   '졸렸어요... 생각보다 실망...',
#   '1',
#   '39',
#   '13',
#   datetime.datetime(2017, 1, 3, 11, 27),
#   '관람객'],
#  ['lala****',
#   '지루하고 생각보다 재미없었어요',
#   '1',
#   '43',
#   '17',
#   datetime.datetime(2017, 2, 17, 18, 20),
#   '관람객'],
#  ['밤비(bamb****)',
#   '인생영화는 아니였음 나만그런가',
#   '1',
#   '45',
#   '19',
#   datetime.datetime(2017, 1, 14, 18, 27),
#   '관람객'],
#  ['yeah****',
#   '두번 봐도 아깝지 않을 영화.',
#   '9',
#   '45',
#   '19',
#   datetime.datetime(2016, 12, 14, 19, 26),
#   '관람객'],
#  ['보랏(zldn****)',
#   '감성에 젖은 나라.  유행에 민감한 나라에게 최적화된 영화.  평론가들이 점수 높게 주면 세뇌당해서 명품영화로 보는 한국인들에게 딱인 영화.',
#   '1',
#   '46',
#   '20',
#   datetime.datetime(2017, 6, 17, 12, 26),
#   0],
#  ['김연경(celi****)',
#   '졸음을 참아가면서 봄....와... 핵 노잼...',
#   '1',
#   '49',
#   '23',
#   datetime.datetime(2017, 1, 22, 12, 21),
#   '관람객'],
#  ['ing6****',
#   '이번년도 본 영화중 최악의 영화...',
#   '1',
#   '164',
#   '138',
#   datetime.datetime(2016, 12, 8, 21, 56),
#   '관람객'],
#  ['수박(bana****)',
#   '재즈 완전조아하고 (음반수집), 감독 전작 위플래시 세번봤고, 일상생활에서 색감중요시 여기고, 뮤지컬 영화는 딱히 조아하진않지만.... 진짜 재미없다 졸다가 결국 도중하차함... 기대엄청하고 봤는데 영화의 메세지를 ...',
#   '1',
#   '30',
#   '5',
#   datetime.datetime(2017, 2, 5, 14, 33),
#   0],
#  ['장친구(jang****)',
#   '하....영화에 감각이 없어서 그런지 시간과 돈이 많이 아깝네요..유투브가 더 교훈과 재미, 감동이 있는 것 같아요ㅠㅠㅠ그리고 카메라가 빙글빙글 돌 때...속이 울렁거려서 콜라를 다 먹었네요..처음으로..ㅠ',
#   '1',
#   '30',
#   '5',
#   datetime.datetime(2016, 12, 19, 20, 14),
#   0],
#  ['sososong(kail****)',
#   '이 영화 평점 너무 이상해요;; 졸린거 참고 참았는데 결국 끝까지 못봤어요',
#   '1',
#   '33',
#   '8',
#   datetime.datetime(2017, 5, 29, 15, 47),
#   0],
#  ['호이(whdd****)',
#   '정확히 하품 17번 나왔다',
#   '1',
#   '36',
#   '11',
#   datetime.datetime(2016, 12, 25, 23, 30),
#   0],
#  ['사라라라라(mone****)',
#   '이영화만든 새1끼 존ㄴ 때리고싶다오글거리고 뜬금없이 갑자기 왜춤추는지?재즈에대해 얘기하는데 이해하나도안가고자기들끼리 존나바쁘던데 무슨얘기를하는건지내머리가 나쁜건지 노래도별루고자고싶어도 스1바 존1나게 시끄러워서 잠도...',
#   '1',
#   '43',
#   '18',
#   datetime.datetime(2016, 12, 26, 1, 55),
#   0],
#  ['jjo2****',
#   '재즈가 싫어지는 영화. 정신없고 지루함',
#   '1',
#   '61',
#   '36',
#   datetime.datetime(2016, 12, 16, 23, 57),
#   '관람객'],
#  ['Gen(sun1****)',
#   '이거 누가 조작하냐ㅋㅋㅋㅋ오후에 본 영화인데 잠들고 중간에 나가고 싶었던 영화는 처음이다 지루하게 짝이없고 무분별한 스토리에 그냥 노잼',
#   '1',
#   '70',
#   '45',
#   datetime.datetime(2016, 12, 11, 20, 35),
#   0],
#  ['토옥(xhdh****)',
#   '내일 죽는다면 이 영화를 보지 마시고 그 돈으로 맛있는거나 먹는게 200배 나을거같아요ㅎㅎㅎ',
#   '1',
#   '82',
#   '57',
#   datetime.datetime(2016, 12, 8, 12, 8),
#   0],
#  ['미쉘(zzun****)',
#   '첫장면부터 오글거리는 뮤지컬 클리셰 범벅~ 노래 자체도 별론데다가 배우들은 노래를 못함 심지어 탭댄스도 잘 못춤 와이어액션 보다가 헛웃음 나옴 ㅋㅋ 인간들이 개눈박이인건지 아님 후기 알바인건지 나원참 아무튼 지루해서...',
#   '1',
#   '130',
#   '105',
#   datetime.datetime(2016, 12, 8, 22, 2),
#   0],
#  ['핵전문(tpdu****)',
#   '영화에서 전달하고자 하는게 뭔지 도통모르겠네 전혀남는게없음 그냥 아파트 베란다에서 사람사는거 2시간동안 구경한느낌 이게더재밌을수도',
#   '1',
#   '29',
#   '5',
#   datetime.datetime(2017, 3, 17, 18, 10),
#   0],
#  ['벚꽃엔딩S2(bon3****)',
#   '1점도 아깝다 시작하자마자 고속도로에서 OO하는거부터 노잼이라생각하고 30분보자마자 집가고싶어서안달낫음 엄마생신이라 가족끼리단체로보러갓는데 다들졸려죽을라고함 돈주고보기아까움 영상미좋다는거 몇분나옴ㅋㅋㅋㅋ 나올락말락하...',
#   '1',
#   '32',
#   '8',
#   datetime.datetime(2017, 1, 15, 23, 16),
#   0],
#  ['Beave(ljim****)',
#   '춤추고 음악 한다고 다 걸작은 아니다. 솔직하게 재미는 없다.음악도 그리 훌륭하거나 감동적이지 않다. 평론가들의 잘난체는 역시 불변의 진리다.',
#   '1',
#   '35',
#   '11',
#   datetime.datetime(2017, 2, 3, 12, 27),
#   0],
#  ['나나공주(kimy****)',
#   '보다보다 이렇게 재미없는 영화는 처음이다.내용도 메세지도 없는 어설픈 뮤지컬 영화. 찰나적인 감각에만 호소하는 영화.남는 것 하나없는 영화.킬링타임도 안 되는 영화.돈 아깝다.',
#   '1',
#   '37',
#   '13',
#   datetime.datetime(2017, 6, 10, 7, 6),
#   0],
#  ['이동환(dhor****)',
#   '와 정말 지루하고 졸린 영화...',
#   '1',
#   '37',
#   '13',
#   datetime.datetime(2017, 1, 2, 14, 38),
#   '관람객'],
#  ['망퉁이(addi****)',
#   '내가 뮤지컬 참 좋아하는데, 이런류의 영화 참 좋아하는데, 막 재미없는 정도는 아니지만 지금 평점 너무 높아 평점 낮추기위해 1점 줍니다. 평점 6.5 적절',
#   '1',
#   '37',
#   '13',
#   datetime.datetime(2016, 12, 17, 20, 45),
#   0],
#  ['웅시기(toto****)',
#   '호불호가 갈리는 이 영화 난 솔직히 별로였음. 뭐 인생영화라는데 점점 지루해져가는 영화. 영화관사람들 나와 같은반응들. 내가 뭘 본거지? 이런반응',
#   '1',
#   '38',
#   '14',
#   datetime.datetime(2017, 1, 10, 2, 10),
#   0],
#  ['김이끼(thdd****)',
#   '불호 노잼; 비추함;;',
#   '1',
#   '38',
#   '14',
#   datetime.datetime(2017, 1, 4, 2, 43),
#   '관람객'],
#  ['하코(asho****)',
#   '이렇게 재미없는 영화는 오랫만이다. 노래는 좋지만 그외에 모든게 글쎄.',
#   '1',
#   '42',
#   '18',
#   datetime.datetime(2017, 1, 17, 0, 57),
#   '관람객'],
#  ['wlgu****',
#   '이거를 도대체 왜보는건가요?',
#   '1',
#   '49',
#   '25',
#   datetime.datetime(2016, 12, 20, 16, 15),
#   '관람객'],
#  ['이승찬(fact****)',
#   '별루..별로야 진짜 그냥 구렸어..',
#   '1',
#   '52',
#   '28',
#   datetime.datetime(2016, 12, 28, 20, 42),
#   '관람객'],
#  ['제이큐(june****)',
#   '올해최악의 영화네요. 10점준 리뷰들 다 알바인듯?',
#   '1',
#   '82',
#   '58',
#   datetime.datetime(2016, 12, 25, 1, 42),
#   '관람객'],
#  ['ㅋㅋㅋ(rlaw****)',
#   'Winter ㅈㄴ 기다림,,',
#   '1',
#   '25',
#   '2',
#   datetime.datetime(2017, 1, 2, 15, 25),
#   0],
#  ['지현(gjqm****)',
#   '평점 남긴 유일한 영화. 재미 1도없고 너무 늘어짐 게다가 어떤 부분이 슬프다는건지? 애기 나이보면 고슬링이랑 헤어지고 얼마 되지도 않아서 남편만든거 같은데 걍 스쳐지나간 인연을 너무 꿈처럼 그려놓음 결말 뭐 어쩌라...',
#   '1',
#   '32',
#   '9',
#   datetime.datetime(2017, 1, 1, 7, 44),
#   0],
#  ['CLYM(news****)',
#   '인생 최악의 영화. 본영화중에 제일 ㅅㄹㄱ라고할정도',
#   '1',
#   '34',
#   '11',
#   datetime.datetime(2016, 12, 18, 23, 26),
#   0],
#  ['스키피오(hehe****)',
#   '개지루  겁나 잼없음  자다가 나옴',
#   '1',
#   '35',
#   '12',
#   datetime.datetime(2017, 1, 5, 13, 28),
#   '관람객'],
#  ['dyea****',
#   '지루하고 개연성없음...',
#   '1',
#   '36',
#   '13',
#   datetime.datetime(2017, 1, 21, 22, 5),
#   '관람객'],
#  ['386c****',
#   '그냥 그래요. 스토리가 신통치 않음',
#   '5',
#   '36',
#   '13',
#   datetime.datetime(2016, 12, 18, 15, 15),
#   '관람객'],
#  ['써니(hiph****)',
#   '썸남이랑 보러 가서 둘다 졸다가 망했구나 싶었는데 너무 재미없어서 스킨십하다가 1일됨 -_- 로맨틱영화 맞네요 결과가 어찌됐든 ㅋㅋㅋ',
#   '1',
#   '38',
#   '15',
#   datetime.datetime(2016, 12, 12, 10, 4),
#   0],
#  ['바어규야애(lh07****)',
#   '도대체 이게 평점이 높은 이유가 뭐지 내 마인드가 구닥다리인가 남친하고 한참 사귈때 미안하다하고 나가서 딴남자랑 키스하질 않나 꿈으로 포장해 바람을 정당화하고 그리고 무슨 사랑을 속삭이며 꿈때문에 헤어지고 5년뒤 애...',
#   '1',
#   '42',
#   '19',
#   datetime.datetime(2017, 9, 2, 20, 34),
#   0],
#  ['연금술사(alch****)',
#   '아 여주 진짜 너무 싫음 -_-',
#   '1',
#   '43',
#   '20',
#   datetime.datetime(2016, 12, 11, 19, 55),
#   0],
#  ['아침의눈(illu****)',
#   '음...주관적으로 봤을 떄 추천 하고 싶진 않음..',
#   '1',
#   '50',
#   '27',
#   datetime.datetime(2016, 12, 18, 11, 54),
#   '관람객'],
#  ['mido****',
#   '한마디로 기대이하의 최악의 영화네요.네티즌 과 기자단 평점이 좋아서 기대하고 갔는데,줄거리가 너무 형편없어서 아주 실망했습니다. 추천하고 싶지않습니다.',
#   '1',
#   '56',
#   '33',
#   datetime.datetime(2016, 12, 24, 21, 24),
#   '관람객'],
#  ['kr65****',
#   '재미도없고감동도없고밑도끝도없고뭥미',
#   '1',
#   '28',
#   '6',
#   datetime.datetime(2017, 1, 2, 1, 15),
#   '관람객'],
#  ['이수진(popo****)',
#   '호불호가 갈리네요... 전 굉장히 재미없게봤어요 흥행했다고 해서 기대하고봤는데.. 중간에 나올뻔했어요 내용이 자꾸 끊기는느낌...',
#   '1',
#   '29',
#   '7',
#   datetime.datetime(2017, 3, 16, 1, 6),
#   0],
#  ['zzoo****',
#   '재미는 없더라. 솔직히... 그저 무난한 뮤지컬일뿐. 평론가라는 이들 어디 대단한 영화 하나 나온것처럼 호들갑 떨던데 지들도 오버인건 속으로는 알겠지. 역겹다.특정영화에 나란히 줄서 물고빠는거.',
#   '1',
#   '30',
#   '8',
#   datetime.datetime(2017, 2, 3, 12, 10),
#   0],
#  ['초코바(rusi****)',
#   '우주로 날아가는 장면에서 내 영혼도 영화관밖으로 날아가버렸다',
#   '1',
#   '30',
#   '8',
#   datetime.datetime(2017, 1, 25, 20, 12),
#   0],
#  ['이주희(gija****)',
#   '구조는 느슨하고 전개도 재미없고 네티즌평보고 갔다가 급 실망...',
#   '1',
#   '30',
#   '8',
#   datetime.datetime(2017, 1, 1, 15, 29),
#   '관람객'],
#  ['qwej****',
#   '네이버 평점보고 내가 미친넘인줄 알았다 내 인생 최악의 영화가 이런 평점이라니 충격이다',
#   '1',
#   '30',
#   '8',
#   datetime.datetime(2016, 12, 23, 19, 51),
#   0],
#  ['촌놈(jo__****)',
#   '재미없엉..ㅜㅜㅜㅜ',
#   '1',
#   '32',
#   '10',
#   datetime.datetime(2016, 12, 25, 21, 44),
#   '관람객'],
#  ['soutely(penc****)',
#   '생애처음으로 영화에 평점이란걸 달아본다스토리는 뻔하고(이건뭐그럴수밖에없다고생각)  감동이 전달되지않는다개연성도 전혀없고몰입이안되서 하품만난다왜 이걸 돈주고봐야하는지 이해가안간다왜이렇게 평이좋은지 알수없는영화이다',
#   '1',
#   '33',
#   '11',
#   datetime.datetime(2016, 12, 21, 17, 44),
#   0],
#  ['pupu****',
#   '하도 재밌다고 주변에서 몇번이나 봤다길래 기대하고 봤는데;;  차라리 그냥 단순 로맨스 영화였다면 더 나았을지도;;;  여주인공 과한 클로즈업도 부담스럽고;;; 엠마왓슨이 안하길 잘한듯.... 오랫만에 뮤지컬 영화라...',
#   '1',
#   '34',
#   '12',
#   datetime.datetime(2017, 5, 11, 20, 42),
#   0],
#  ['hope(qlal****)',
#   '평점 댓글 사기꾼같다 나랑 내친구랑 너무 재미없어서 충격받았는데 5분만에집에가고싶어지던데....',
#   '1',
#   '37',
#   '15',
#   datetime.datetime(2016, 12, 17, 13, 29),
#   0],
#  ['qudg****',
#   '안될영화입니다보지마세여',
#   '1',
#   '39',
#   '17',
#   datetime.datetime(2017, 1, 2, 0, 36),
#   '관람객'],
#  ['세미뉴오(semi****)',
#   '진심 최악의 영화..개연성도 없고 스토리는 굉장히 지루..계절하나하나 나올때마다 설마 겨울까지 가는건가 나를 공포로 떨게만듬.. 클리셰 덩어리의 끝장판;;;;',
#   '1',
#   '40',
#   '18',
#   datetime.datetime(2016, 12, 26, 17, 22),
#   0],
#  ['원더풀베리(sh49****)',
#   '실망 그자체 왜 평점이 높은지 솔직히 결말도 실망이고 0점 주고 싶네요 여자친구도 너무 재미 없다고 하네요.',
#   '1',
#   '41',
#   '19',
#   datetime.datetime(2017, 1, 16, 1, 14),
#   '관람객'],
#  ['geelady(adoj****)',
#   '건축학개론 이후로 역대급 ㅆㄴ캐릭',
#   '1',
#   '42',
#   '20',
#   datetime.datetime(2017, 3, 4, 23, 26),
#   '관람객'],
#  ['주찬혁(cksg****)',
#   '보는 내내 졸리고 별루..',
#   '2',
#   '48',
#   '26',
#   datetime.datetime(2016, 12, 12, 14, 11),
#   '관람객'],
#  ['최근경(love****)',
#   '기대 많이 했는데..영화보면서 오랜만에 졸았네요.제 취향은 아닙니다. 무슨 스토리인지 너무 정신없고 지루하고...제가 이상한건지...같이본 친구는 잼있다고 하더라구요.',
#   '1',
#   '24',
#   '3',
#   datetime.datetime(2017, 3, 9, 14, 32),
#   0],
#  ['엘로이즈(hong****)',
#   '호불호가 매우 갈리는 영화.. 엄마는 영화같은 영화 한편 잘 봤다고 좋아하시고, 나는 두시간 내내 지루했다',
#   '6',
#   '26',
#   '5',
#   datetime.datetime(2016, 12, 18, 13, 34),
#   '관람객'],
#  ['오윤희(jjjl****)',
#   '보는내내넘지루했네요. .ㅡㅡ;;;눈물이없는거아닌데. .도대체어느포인트에서눈물이나는건지;;;',
#   '1',
#   '27',
#   '6',
#   datetime.datetime(2017, 1, 20, 21, 6),
#   0],
#  ['dzod(govl****)',
#   '이게 진짜로 그렇게 재밌어? 허...내가 OOO인건가',
#   '1',
#   '28',
#   '7',
#   datetime.datetime(2017, 2, 8, 23, 20),
#   0],
#  ['채미니아빠(moa0****)',
#   '노래만 나오고 재미도 없고 끝도 허무',
#   '1',
#   '28',
#   '7',
#   datetime.datetime(2017, 1, 5, 1, 45),
#   '관람객'],
#  ['또로로(iris****)',
#   '영화 도중 그냥 나갈까 생각한 첫 영화',
#   '1',
#   '29',
#   '8',
#   datetime.datetime(2017, 1, 4, 15, 22),
#   0],
#  ['plus****',
#   '같은 노래의 반복. 그저 그런 스토리. 원스처럼 애잔한 감동도 없고 비긴어게인처럼 화이팅하는 분위기도 없고..물랑루즈 처럼 화려함도 없고..흥겨움도 없다. 그냥..마케팅의 승리인듯.',
#   '1',
#   '30',
#   '9',
#   datetime.datetime(2017, 2, 3, 14, 31),
#   0],
#  ['메르시몰리(merc****)',
#   '남녀 주인공의 매력 참신한 영상미  빼면갠적으로 노래도 별로고  지루해서참고보기  힘든영화 였습니다',
#   '1',
#   '31',
#   '10',
#   datetime.datetime(2016, 12, 18, 14, 51),
#   0],
#  ['nul(llsz****)',
#   '이 영화 또라이같은건 나만그런건가?... 되게 못하는 뮤지컬 영화같은 느낌....? 내용도 이상하고  전개도 이상하고 뜬금없는 결말 나만 들었나 여기저기 한숨소리?... 삼류 뮤지컬영화같음 아... 피곤하다...',
#   '1',
#   '32',
#   '11',
#   datetime.datetime(2017, 1, 6, 0, 23),
#   0],
#  ['cimo****',
#   '낚였음.. 계절이 바뀔 때마다 집에 가고 싶은 강한 충동을 느꼈음',
#   '1',
#   '33',
#   '12',
#   datetime.datetime(2016, 12, 17, 20, 13),
#   0],
#  ['이봐개(inyh****)',
#   '웃기는 짬뽕같은 영화... 이들 사랑엔 개연성이 없고, 이들의 꿈 역시 깊이가 없다. 아무 이유없이 사랑하고, 헤어지며 별다른 노력없이 성공한다. 차라리 모아나 가 100만배쯤 더 뛰어난 뮤지컬 애니메이션인듯...',
#   '1',
#   '34',
#   '13',
#   datetime.datetime(2017, 1, 30, 1, 35),
#   0],
#  ['재무니(orol****)',
#   '별로 재미없어요...',
#   '1',
#   '34',
#   '13',
#   datetime.datetime(2016, 12, 20, 17, 8),
#   '관람객'],
#  ['박종헌(vnfm****)',
#   '평점이 너무높아 내가 비정상인줄 알았다. 인생영화 하나 건졌다. 친구들한테 추천해야겠다. 나만엿먹을수 없다. 특히 공중부양 진심 죽여버린다 ㅋㅋ...',
#   '1',
#   '35',
#   '14',
#   datetime.datetime(2017, 1, 28, 1, 22),
#   0],
#  ['최예슬(ysys****)',
#   '기대 안 하고 봤는데 기대 이하',
#   '1',
#   '36',
#   '15',
#   datetime.datetime(2016, 12, 26, 10, 10),
#   '관람객'],
#  ['안만들것임(pear****)',
#   '별로에요 힘들고 기빨려서 나왔어요',
#   '1',
#   '36',
#   '15',
#   datetime.datetime(2016, 12, 25, 17, 1),
#   '관람객'],
#  ['Kross(ckck****)',
#   'ㅆㅆㄹㄱ 영호ㅏ돈아깝다',
#   '1',
#   '45',
#   '24',
#   datetime.datetime(2016, 12, 10, 20, 21),
#   '관람객'],
#  ['minu****',
#   '흠... 흔한 스토리에 특별할거 없는 음악... 무엇보다 엔딩이 ㅜㅜ',
#   '1',
#   '48',
#   '27',
#   datetime.datetime(2016, 12, 21, 0, 39),
#   '관람객'],
#  ['코베인(shin****)',
#   '전형적인 코요테어글리식 신파극',
#   '1',
#   '48',
#   '27',
#   datetime.datetime(2016, 12, 18, 12, 59),
#   '관람객'],
#  ['dbst****',
#   '누가 본다고하면 발목을 부셔서라도 말리고 싶다.',
#   '1',
#   '52',
#   '31',
#   datetime.datetime(2016, 12, 28, 23, 34),
#   '관람객'],
#  ['될놈(patr****)',
#   '솔직히 재미가 없네요..',
#   '5',
#   '83',
#   '62',
#   datetime.datetime(2016, 12, 8, 7, 53),
#   '관람객'],
#  ['John Doe(mein****)',
#   '이게 지루하다는 사람은 착각아닌 진짜 사랑이란걸 못했본 사람이고 꿈이란건 잠잘때만 꿔본 사람이다.',
#   '10',
#   '23',
#   '3',
#   datetime.datetime(2017, 8, 16, 0, 29),
#   '관람객'],
#  ['허태경(gjwl****)',
#   '영상미는 좋았으나 노잼',
#   '1',
#   '26',
#   '6',
#   datetime.datetime(2016, 12, 31, 14, 36),
#   '관람객'],
#  ['라랄라(wjda****)',
#   '세기의 졸작. 이쁠거라고 장담하면서 찍었을 듯한 장면 하나하나에서 영상미를 도저히 찾아볼 수 없을 지경이었고 70년대 싸구려 영화보다도 못한 연출이 없는 영상미를 더 줄여줌. 맨 처음 나온 뮤지컬 씬은 의도와 영상미...',
#   '1',
#   '27',
#   '7',
#   datetime.datetime(2017, 1, 9, 16, 19),
#   0],
#  ['바다때문야(ldkl****)',
#   '이거 누가 잼있다고 했냐? 맘마미아 안봤냐?? 진짜 개연성 없게 잼없게 만들었고만 ㅡㅡ;;',
#   '1',
#   '28',
#   '8',
#   datetime.datetime(2017, 1, 25, 0, 35),
#   0],
#  ['mkj1****',
#   '호불호가 갈리네요. 맘마미아 같은 영환줄 알았는데 스토리가 지루하네요...나만 재미 없나?',
#   '1',
#   '28',
#   '8',
#   datetime.datetime(2017, 1, 2, 22, 3),
#   0],
#  ['물결처럼(pjm9****)',
#   '에이~극찬 받을만큼 잘 만든건 아니네, 보실분은 겉멋들린후기 같은거 읽지 마시고 스스로 느끼보세요~',
#   '6',
#   '29',
#   '9',
#   datetime.datetime(2016, 12, 10, 3, 46),
#   0],
#  ['pkju****',
#   '인생영화가 아니라 인생 최악의 영화. 영상미는 좋았지만 싸우는 장면 빼곤 지루하기 짝이 없음. 결말도 너무나 어이없었음. 평점,후기 보고 기대했는데 어떻게 내 생각과 이렇게 반대일 수 있는지.. 시간,돈이 아까웠다',
#   '1',
#   '30',
#   '10',
#   datetime.datetime(2016, 12, 25, 19, 9),
#   0],
#  ['away****',
#   '영상미 음악성있는건 알겠는데 너무 루즈해서 관객들중 반정도는 졸고있음..',
#   '1',
#   '30',
#   '10',
#   datetime.datetime(2016, 12, 17, 23, 16),
#   0],
#  ['BbTree(qkrr****)',
#   "'난 뮤지컬영화야!' 라며 중구난방으로 막 튀어나오는 의미 없는 노래들 듣기 싫다. 분위기, 상황에 마춰서 나와줘야 돼지 멱따는 소리라도 들을수 있는데 노래가 좋던 잘부르던 상황에 맞지 않으니 듣기 싫...",
#   '1',
#   '31',
#   '11',
#   datetime.datetime(2017, 7, 7, 8, 34),
#   0],
#  ['앤셜리(jins****)',
#   '솔직히 그닥이었음 내용도 그닥남이하면 불륜 내가하면 사랑? 이것도 싫고그럼 잘되던지 뒤에가서 현실적인건 뭔 조합인지뮤지컬영화 좋아했지만 이건 아닌데 의외의평들이 많아서 다소 놀랍지만 어쨌든 난 별로',
#   '1',
#   '32',
#   '12',
#   datetime.datetime(2016, 12, 12, 14, 29),
#   0],
#  ['chae(chae****)',
#   '내 인생 손꼽히는 돈아까운 영화... 개연성도 없고, 진부하기 짝이 없고, 게다가 노래랑 춤도 별로라니;',
#   '1',
#   '42',
#   '22',
#   datetime.datetime(2017, 1, 31, 10, 44),
#   '관람객'],
#  ['전호석(luck****)',
#   '미술 좋구요, 메시지 좋아요, 다만 스토리, 연출, 뮤지컬 부분이 그렇게 뛰어나지는 않습니다.',
#   '8',
#   '62',
#   '42',
#   datetime.datetime(2016, 12, 7, 18, 5),
#   0],
#  ['Nexen Heroes(chak****)',
#   '감점요인이 없어서 꽉찬 10점 드립니다 세번봤다 진짜 내 인생영화...',
#   '10',
#   '21',
#   '2',
#   datetime.datetime(2017, 10, 8, 0, 16),
#   0],
#  ['IKONIC(us03****)',
#   '나도자고 옆사람도자고 내친구도자고 친구옆사람도잤음',
#   '1',
#   '23',
#   '4',
#   datetime.datetime(2017, 3, 13, 21, 30),
#   0],
#  ['Goldmedal(lhou****)',
#   '특별한 사건없이 인생 편안하게 사는 인간들이 있어보이고 싶어서 극찬하는 최악의 영화 내가 웬만한 뮤지컬 영화는 단한번도 실망한 적이 없는데 와 뮤지컬 영화도 지루할 수도 있구나를 느낌 이 영화 왜 인기 있는지 정말 ...',
#   '1',
#   '24',
#   '5',
#   datetime.datetime(2017, 12, 27, 20, 27),
#   0],
#  ['Barbie(olee****)',
#   '진짜 영화보다 존적 처음.. 하품나오는데 돈아까워사 끝까지봤다..근데 끝까지노잼. 평점왜이리높은지 이해불가.. 노잼 보지마요 돈아까움. 밑에어떤분이 말한것처럼 스쳐지나간 인연을 꿈처럼 그려놓은영화 남주만 불쌍',
#   '1',
#   '24',
#   '5',
#   datetime.datetime(2017, 1, 1, 15, 43),
#   0],
#  ['gywjd(klee****)',
#   '1점도 아깝다 시작부터 몰입이 전혀 안됨 정말 중간에 너무나가고 싶었다. 이미 예정된 노래를 장면 중간중간 억지로 끼워 넣은 느낌. 인생 최악의 영화다 도저히 어느 부분에서 감동을 느끼고 놀라워야 하는지..높은 평점...',
#   '1',
#   '25',
#   '6',
#   datetime.datetime(2017, 1, 3, 20, 9),
#   0],
#  ['dnch****',
#   '여친사귀고 처음본영화입니다 싸웠어요',
#   '1',
#   '25',
#   '6',
#   datetime.datetime(2016, 12, 26, 12, 31),
#   0],
#  ['와니(gags****)',
#   '뮤지컬스런 영화라 취향에 안맞는 사람이 봤을때는 핵노잼인 영화인듯...보다가 나온영화는 정말 처음이네요 작품성,예술성 그런거 좋아 하는 분들이나 평점 높은듯..전 그딴거 몰라서 보다가 생애 첨으로 중간에 나왔네요',
#   '1',
#   '27',
#   '8',
# ...
#   0],
#  ['맨 날져 유(mced****)',
#   '성차별적인 영화입니다',
#   '1',
#   '16',
#   '8',
#   datetime.datetime(2017, 5, 22, 0, 24),
#   0],
#  ['whynot(alka****)',
#   '진짜 졸렸다픠픠픺,;',
#   '1',
#   '16',
#   '8',
#   datetime.datetime(2017, 1, 25, 10, 54),
#   0],
#  ['김희영(rlag****)',
#   '참나  알바가 왜이리많은지! 진짜 오버에 자다나 나옴!메세지도 하나도없음 다신안봄!',
#   '1',
#   '16',
#   '8',
#   datetime.datetime(2017, 1, 16, 2, 4),
#   0],
#  ['팬긴(pang****)',
#   '으...호불호 너무갈리',
#   '1',
#   '16',
#   '8',
#   datetime.datetime(2017, 1, 6, 15, 27),
#   '관람객'],
#  ['지원(dbwl****)',
#   '나는 진짜 재미없게봤는데 보는 내내 집에 갈까 수없이 생각하고 너무 졸렸던 영화. 내 입장에서 바람으로 시작해서 바람으로 끝난 영화. 솔직히 바람을 엄청나게 아름답게 미화시킨 영화 아닌가',
#   '1',
#   '16',
#   '8',
#   datetime.datetime(2016, 12, 19, 23, 58),
#   0],
#  ['kzal****',
#   "이해할수 없는 남녀 주인공의 심리주인공인 사랑한건 재즈가 아닌 스윙. 밥 일뿐...미셸 카밀리오, 스탄게츠, 안토니오 까를로스 조빔 같은 '라틴재즈 뮤지션'에 대한 완벽한 모독..",
#   '1',
#   '16',
#   '8',
#   datetime.datetime(2016, 12, 11, 1, 37),
#   0],
#  ['rhae****',
#   '아 이거 내가 이상한건가  자괴감 한참 들다가 뒤로 갈 수록 리뷰가 1점이 많아 안심하고 간다.  진심 피로 회복제 영화다 잘잤다.',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2017, 4, 24, 17, 33),
#   0],
#  ['linsanity(shyu****)',
#   '여자친구는 좋아하던데 나는 ㄹㅇ 졸다가 나왔다. 호불호 심하게 갈림. 진짜 지루해도 너무 지루했음. 노래도 존나 별로. 그나마 괜찮았던건 존레전드꺼.. 진짜  최악의 영화',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2017, 2, 11, 2, 37),
#   0],
#  ['행보꾸(gnlf****)',
#   '평점이 너무 높은거같아 일점줍니다. 앞부분에서 지루해서미치는줄알았어요. 진짜 최초로 중간에나가는 영화가 될것같았져. 그래도 평점이넢으니까 참고보자 참고보자 하고참고봤는데. 그냥 마지막에 정말 상상치도못하게 새드엔딩이...',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2017, 1, 30, 9, 42),
#   0],
#  ['나영(nayo****)',
#   '오 영화보면서 여태까지 자본적이없는데 처음으로 잤어요...ㅎ 처음에 도로에서 노래부를때부터 인도영화인줄알았네요 처음부터 노잼냄새맡고 그냥 보다가 잠들었네요',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2017, 1, 17, 18, 30),
#   0],
#  ['cind****',
#   '영상미 빼고 볼게 없는 영화 개연성이 너무 떨어짐',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2016, 12, 12, 1, 37),
#   0],
#  ['비밀(19th****)',
#   '시끄럽고 난잡하다....',
#   '1',
#   '17',
#   '9',
#   datetime.datetime(2016, 12, 9, 22, 2),
#   0],
#  ['jlgm****',
#   '극장에서 안보길 잘한영화.',
#   '1',
#   '19',
#   '11',
#   datetime.datetime(2019, 2, 14, 15, 33),
#   0],
#  ['노란아이4044(dbsd****)',
#   '내가본 최악의 영화, 진짜 이걸 보고 있던 내 시간이 아깝다. 지루하고 재미없고 결말도 너무 너무 싫음 진짜 영화보고 화나긴 첨인듯.',
#   '1',
#   '19',
#   '11',
#   datetime.datetime(2018, 12, 24, 3, 54),
#   0],
#  ['JINI33(eunz****)',
#   '너무 비현실적인 영화네... 꼭 보라고들 하길래 봤는데... 완전실망... 비현실적인 감성주의자들이나 좋아할 영화.... 대중적으로 좋아할만한건 아니었네.. 아 시간 아깝다...',
#   '1',
#   '19',
#   '11',
#   datetime.datetime(2017, 2, 20, 11, 28),
#   0],
#  ['꼬르따도(pano****)',
#   '진심으로 평점8점대를 의심하게 되는 영화',
#   '1',
#   '20',
#   '12',
#   datetime.datetime(2016, 12, 14, 19, 41),
#   0],
#  ['쯔쯔(afte****)',
#   '예쁜 쓰레기 영화. 평점들이 당최 이해가안감',
#   '1',
#   '23',
#   '15',
#   datetime.datetime(2016, 12, 12, 2, 3),
#   0],
#  ['햄버거(sgr2****)',
#   '호불호가 많이갈리는영화. 상많이받아서 기대했지만 나한테는0점...은근 고평가되는영화같다.이런거보다 타이타닉이 훨명작 취향차이겠지만...',
#   '1',
#   '26',
#   '18',
#   datetime.datetime(2017, 10, 8, 2, 47),
#   0],
#  ['티지이(wodl****)',
#   '여운이 오래 남는 영화.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 9, 25, 20, 30),
#   0],
#  ['시체(zipa****)',
#   '첨엔 어색했지만 보다 보니 빠져들더라',
#   '8',
#   '7',
#   '0',
#   datetime.datetime(2019, 9, 19, 15, 19),
#   0],
#  ['jkli****',
#   '앞으로가 계속 기대되는 감독 . 마지막 연출은 레전드.',
#   '9',
#   '7',
#   '0',
#   datetime.datetime(2019, 9, 15, 21, 17),
#   0],
#  ['wik3****',
#   '왜 이제 본거야  진짜 인생영화라는 이유를 알겠다 ㅠㅠㅠㅠ',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 8, 6, 21, 10),
#   0],
#  ['최광수(ss77****)',
#   '만감이 교차한다...',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 7, 31, 3, 50),
#   0],
#  ['에버베리(ava1****)',
#   '아직까지 인생영화네요.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 7, 19, 15, 16),
#   0],
#  ['송중현(song****)',
#   '두 사람과 두 사람의 시간들.. 현실.. 모든게 이해되어.. 너무 마음이 아팠습니다.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 7, 19, 0, 20),
#   0],
#  ['몽돌해변(mira****)',
#   '이 영화는 꿈꾸는 자들의 위한 노래이다.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 7, 16, 23, 12),
#   0],
#  ['눈이큰아이(sehe****)',
#   '영화 초중반에는 지루한 부분이 없잖아 있었다. 하지만 영화가 끝났을 때 내 마음속은 공허로 가득찼고, 그 결말과 여운은 몇달이 지났음에도 불구하고 불현듯 머릿속에서 떠오른다.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 7, 10, 10, 41),
#   0],
#  ['라즈알굴(dlwo****)',
#   '지독하게 아름다운 영화.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 6, 23, 12, 18),
#   0],
#  ['justgood(ichr****)',
#   '꿈꾸는 바보들 - 오디션 중 미아가 부른 노래',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 6, 22, 8, 28),
#   0],
#  ['남신(hyeu****)',
#   '정말 인생은 그 순간 내가 어떤 선택을 하느냐에 따라 많이 달라지는 듯. 지금 그 인생을 항해 중이라 더이상 조언을 못하겠음.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2019, 5, 15, 3, 50),
#   0],
#  ['혁스타(jere****)',
#   '마지막 10분은 괜시리 눈물이 흘렀네요. . 상상속의 라이언고슬링과 엠마스톤... 엠마스톤의 꿈을 이루는데 큰 용기를 준 라이언..그리고 엠마스톤이 지어준 가게 이름 ...분명 호불호가 갈리는 영화라고 생각이들지만 ...',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 12, 6, 2, 16),
#   0],
#  ['지니지니(gsj3****)',
#   '그냥 흘러가는대로 가 보자. 선택의 연속 그리고 만약 그때 그랬더라면...',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 12, 6, 2, 2),
#   0],
#  ['이대훈(wjdw****)',
#   '왜영화관에서 안봤을까 두고두고 후회한 영화',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 11, 25, 15, 46),
#   0],
#  ['슈슈(ssun****)',
#   '함께는 아니지만 각자의 해피엔딩.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 10, 22, 13, 51),
#   0],
#  ['레나(fpsk****)',
#   '좋다. 좋은데. 배우의 꿈을 이루기 위해서 위선적인 사랑을 선택하게 만든 엠마 스톤 역은 최악이였다. 감동 하나 주자고 고슬링을 슬프게 만들어?!',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2018, 5, 9, 0, 54),
#   0],
#  ['호라(answ****)',
#   '호불호가 갈린다는 말을 이해할 수 있었다, 잘 만들어진 것은 의심할 여지 없지만..',
#   '6',
#   '7',
#   '0',
#   datetime.datetime(2017, 12, 22, 11, 42),
#   '관람객'],
#  ['혜이(hlee****)',
#   '인생 최고의 영화, 영화관에서만 2번 보고, 집에서도 5번 보았던 영화. 마지막 장면은 12번정도 돌려봤던 것 같다.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2017, 11, 22, 15, 48),
#   '관람객'],
#  ['레인레어(love****)',
#   '명작이지 더는 할 말 없다',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2017, 10, 31, 21, 37),
#   '관람객'],
#  ['esht****',
#   '마지막 라이언고슬링의 눈빛은 잊을수가없음.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2017, 10, 15, 14, 44),
#   0],
#  ['eekr****',
#   '니가 사는 그 집. 그 집이 내 집이었어야 해. 니가 타는 그 차. 그 차가 내 차였어야해. 니가 차린 음식, 니가 낳은 그 아이까지도 모두 내 것이었어야 해. 모두가 내 아이었어야 해.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2017, 10, 15, 3, 49),
#   0],
#  ['김한울(gks9****)',
#   '26년인생 살아오면서 한 영화를 이렇게 많이 본 적은 처음임 스크린으로만 10번넘게 봤음...',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2017, 9, 23, 19, 20),
#   '관람객'],
#  ['동동그리(jaeh****)',
#   '흘러가도록 둔다는것이 그 상황에 현실에 어쩔 수 없음을 알지만 지나가 버리면 이토록 가슴 아픈것.',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2016, 12, 19, 1, 16),
#   '관람객'],
#  ['톨킨(tolk****)',
#   '올해 봤던 최고의 영화..',
#   '10',
#   '7',
#   '0',
#   datetime.datetime(2016, 12, 16, 9, 50),
#   '관람객'],
#  ['dbst****',
#   '초반부터 지루하고 내용이 진부그자체..',
#   '2',
#   '7',
#   '0',
#   datetime.datetime(2016, 12, 11, 20, 18),
#   0],
#  ['figu****',
#   '와 이게 9점대가 안나온다고?   씁쓸하구만  10점도 모자란 영화같은데 말야',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2020, 1, 26, 17, 28),
#   0],
#  ['유민(dbal****)',
#   '울면서 평점 쓰고 있네요. 여운이 긴 영화... 후',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2019, 9, 22, 21, 26),
#   0],
#  ['Inuyashajjjanng(6rov****)',
#   '최고명작... 뮤지컬영화의 한획을 그었다',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2019, 9, 1, 21, 35),
#   0],
#  ['gkst****',
#   '영화 보면서: 괜찮은 영화네. 근데 이 정도로 찬사 받을 정도야?마지막 결말 5분 보면서 : 찬양 받을만하구나! 대박이다!',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2019, 7, 13, 14, 17),
#   0],
#  ['dbwls12(jhj4****)',
#   '근데 너무 뻔한 스토리아닌가? ㅜㅜㅜ 영상미와 노래들이 신나긴했는데 뭔가 .. 극찬할정도는 아닌거같음',
#   '6',
#   '8',
#   '1',
#   datetime.datetime(2018, 12, 27, 18, 59),
#   0],
#  ['Yhgdnllt(mool****)',
#   '인생의 영화.이영화는 고전이될것이다',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2018, 11, 21, 13, 58),
#   0],
#  ['CK_b(allo****)',
#   '꿈을 위해 사랑을 포기했는데,그 사랑이 꿈이 되어버렸다.',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2018, 9, 5, 12, 17),
#   0],
#  ['sen0****',
#   '마지막에 나도 모르게 눈물이 나온 영화.. 슬퍼서도 감동여서도 아닌데 도통 무슨 감정인지 눈물이났다',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2018, 4, 29, 3, 15),
#   0],
#  ['조연제(nick****)',
#   '꿈과 사랑에 대한 나의 인생영화... 사람마다 취향차는 존재하지만 이 영화 별로라는 사람들이랑은 영화 얘기 깊게 못 함',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2018, 1, 3, 1, 17),
#   0],
#  ['다롱열매(jiso****)',
#   '선택한 꿈의 길에서 방황하고 힘들어하는 그런 이들의 눈물을 흘리게하는 영화..마지막 그 짧은 장면들에서 영화의 모든 것을 보여준느낌ㅠㅠ  마지막에 눈마주치는 장면과 새롭게 이야기가 쓰여지는 장면은 아마 평생 잊지못할...',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 8, 0, 15),
#   0],
#  ['쵸피(kimk****)',
#   '그 마지막 10분이 휘몰아치는데 미치도록 황홀하면서도 슬펐다',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 8, 0, 13),
#   0],
#  ['zyxwvut(poop****)',
#   'TV에서 해줘서 또 봤다~ 마치 첨 본것처럼 집중해서 봤다~ 역시 또봐도 좋다~',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 8, 0, 12),
#   0],
#  ['음악대장(min0****)',
#   '개봉전부터 호불호가 심한영화일거라고 생각한 사람중1인 예상은 적중 본인은 극호',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 8, 0, 11),
#   0],
#  ['꿀꿀(dlwj****)',
#   '다시 봐도 슬프다.. 아련하고 공허한 느낌이 계속 든다',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 8, 0, 10),
#   0],
#  ['divide life(gorh****)',
#   '감독은 진정 재즈 매니아 일거야. 위플래쉬도 그렇고',
#   '8',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 7, 23, 35),
#   0],
#  ['gkal****',
#   '이 영화는 이해를 하지 못하면 재미없기 그지없는 영화지만 이해만 할  수 있다면 진짜 인생영화라고 할 수 있을것입니다. 강추!',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 10, 7, 18, 53),
#   0],
#  ['dubJ(wild****)',
#   '몇번을 봐도 좋네요 감동이 배가됐어요',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2017, 9, 30, 12, 0),
#   '관람객'],
#  ['안양천에빠진공(28li****)',
#   '영화뿐아니라 그 외 것들에 대한 애정이 느껴짐',
#   '8',
#   '8',
#   '1',
#   datetime.datetime(2016, 12, 14, 2, 5),
#   '관람객'],
#  ['모노(life****)',
#   '영화는 이쁜데, 이입이 안됌 극장에서 볼 필요없음몇몇 장면만 조금 로맨틱  네이버 평점 너무 높네요',
#   '3',
#   '8',
#   '1',
#   datetime.datetime(2016, 12, 12, 15, 51),
#   0],
#  ['채봄삐(bomb****)',
#   '최애영화음악 영상 연기 시나리오 빠지는게없다',
#   '10',
#   '8',
#   '1',
#   datetime.datetime(2016, 12, 9, 23, 46),
#   0],
#  ['Ruimy(nigh****)',
#   '마지막 5분이 잊혀지지 않는다',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2018, 11, 11, 3, 25),
#   0],
#  ['ny(any9****)',
#   '어느 부분이 지루하고 재미없게 느껴졌는지 알겠는데 엔딩이 다 씹어먹어버림 가슴이 아직도 먹먹하네 마지막에 눈빛교환에서 정말... 진국이다 이 영화',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2017, 10, 8, 0, 14),
#   0],
#  ['매미(memo****)',
#   '잘 모르던 재즈란 장르의 음악까지 싫어지게 한 영화',
#   '1',
#   '9',
#   '2',
#   datetime.datetime(2016, 12, 31, 23, 55),
#   0],
#  ['카나(shin****)',
#   '엔딩 때문에 짜증나서 1점...',
#   '1',
#   '9',
#   '2',
#   datetime.datetime(2016, 12, 31, 1, 41),
#   0],
#  ['키구15(21fl****)',
#   '마지막 10분 동안 휘몰아치는  가정법. 그랬었더 라면...',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2016, 12, 18, 11, 39),
#   0],
#  ['나재호(jhna****)',
#   '꿈이 있는 사람은 격하게 공감할 것이다.',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2016, 12, 11, 10, 2),
#   0],
#  ['개굴짱(wlkr****)',
#   '이렇게 하나도 빠짐없이 완벽한 영화는 처음이다.. 너무 행복하면서도 이렇게 슬픈 감정을 영화보면서 느낄 수 있다는 것에 놀랐다',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2016, 12, 10, 12, 20),
#   0],
#  ['곰금(hjso****)',
#   '진짜 잘만들었다 최근 본것중 제일 재밌었음',
#   '10',
#   '9',
#   '2',
#   datetime.datetime(2016, 12, 7, 22, 5),
#   0],
#  ['seeyou(seey****)',
#   '꿈을 쫓아 방황하는 모습도 사랑도 현실적이라 더 맘이 먹먹하다.작년 크리스마스 이브때 이 영화보고 나와 추웠던 신촌거리를 걸으며 맘을 달랬던 기억이 난다.',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2017, 10, 8, 3, 51),
#   0],
#  ['초코초코(now1****)',
#   '서로가 있었기에 꿈을 놓지 않을 수 있었던 그들.. 나보다 나를 더 잘 알고 믿어주는 사람이 있다면 얼마나 든든할까. 재즈가 좋아지고 꿈을 갖고 싶어지는 영화.',
#   '9',
#   '10',
#   '3',
#   datetime.datetime(2017, 10, 8, 1, 0),
#   0],
#  ['헬로우(son6****)',
#   '위플애쉬 감독의 영화는 나와 맞지않는듯...처음에 어? 중간에 어??끝에 어????만나오는 영화...',
#   '1',
#   '10',
#   '3',
#   datetime.datetime(2016, 12, 25, 11, 3),
#   0],
#  ['호이짜(rbdh****)',
#   '정말 좋은 영화연출 배우 다 좋았다',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2016, 12, 14, 1, 17),
#   '관람객'],
#  ['물로보마(hwaw****)',
#   '꿈을 쫓는 사랑. 꿈을 이룬 사랑. 마지막 미소.',
#   '10',
#   '10',
#   '3',
#   datetime.datetime(2016, 12, 8, 0, 33),
#   0],
#  ['김대영(eodu****)',
#   '엠비씨가 더빙 안한거에 9점 드림영화로만 봐도 9점급',
#   '10',
#   '11',
#   '4',
#   datetime.datetime(2017, 10, 8, 5, 3),
#   0],
#  ['설레임(dkfm****)',
#   '볼수록 생각과 여운이 짙어지는 영화네요..',
#   '10',
#   '11',
#   '4',
#   datetime.datetime(2017, 10, 8, 1, 5),
#   0],
#  ['ARIEL(arie****)',
#   '가슴이 너무 찡하다. 끝까지 멋진 커플이였으면 좋았을텐데...먹먹하다',
#   '10',
#   '11',
#   '4',
#   datetime.datetime(2017, 10, 8, 0, 42),
#   0],
#  ['끼룩(somi****)',
#   'if....만약에..',
#   '10',
#   '11',
#   '4',
#   datetime.datetime(2017, 10, 8, 0, 42),
#   0],
#  ['민누(lala****)',
#   '나도 1점짜린 아니지만 평균 깎으려고 올림....대체 왜이렇게 평점이 높은건지 모르겠네욬ㅋㅋ 여자가 너무 예쁘고 음색도 좋다! 라는 생각만으로 본 영화... 진짜 노잼 원래도 영화를 별로 좋아하진 않지만 시간아까웠어...',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 31, 18, 49),
#   0],
#  ['김은석(ange****)',
#   '난 막눈인가보다 지루했다. ㅠㅠㅋ',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 30, 14, 21),
#   0],
#  ['웅하하로(rbdl****)',
#   '영화보다 나옴.. 시도때도 없이 어이없게 노래만 부름내 스탈이 아님.예술적 영화라 평점 높은듯',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 29, 11, 5),
#   0],
#  ['지소시(sss2****)',
#   '진부한 내용을 가지도 의도가 다 보이게 연출해서 실망했습니다',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 29, 9, 41),
#   0],
#  ['sds0****',
#   '내용과 전개 연기력 모두 실망...왠만하면 집중을 잘하는편인데 ㅜ.ㅜ . . 오랫만의 영화였는데 판도라나 볼걸~후회됨',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 28, 20, 31),
#   0],
#  ['ab24****',
#   '엠마스톤은  초록색눈동자와 초록색원피스, 푸른빛레드입술은 정말 최고였지만 보는내내 지루했고 졸렸다 무었을 말하려는지 잘모르겠음  .. 그냥 스타워즈나 볼걸 : (',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 28, 16, 29),
#   0],
#  ['아아아ㄷㄷㄷ(wwwc****)',
#   '박진영에 니가 사는 그집 내용이네요',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 28, 12, 19),
#   0],
#  ['엔젤하트(sang****)',
#   '보다가 정말 졸려 혼난영화. 옛날 뮤지컬영화가 얼마나 잘 만든건지 알게해준 영화임',
#   '1',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 24, 3, 46),
#   0],
#  ['블랙맘바(stil****)',
#   '라라랜드가 뭔가 했는데 LA였구나. GTA5에서 나오는 장소들이 많아서 신기했음.',
#   '9',
#   '11',
#   '4',
#   datetime.datetime(2016, 12, 9, 18, 48),
#   0],
#  ['Aiden(aldi****)',
#   '개연성없고 건너뛰듯 얼렁뚱땅 넘어가는 전개 너무 진부한 사랑 3류 스토리 꿈과 사랑을 이야기하다가 급마무리;;;',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2018, 4, 28, 22, 15),
#   0],
#  ['sooe****',
#   '말이 필요없습니다. 경험한 사람만이 이해할 수 있는 영화... 볼때마다 저도 모르게 눈물이 뚝 떨어집니다.',
#   '10',
#   '12',
#   '5',
#   datetime.datetime(2017, 10, 8, 0, 25),
#   0],
#  ['황다혜(dh95****)',
#   '0점을 줄 수 없는게 아쉽다',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2017, 3, 18, 19, 10),
#   0],
#  ['JSK(kjs9****)',
#   'OOO기 이보다 쓰레기일 수가없다',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2017, 1, 3, 21, 32),
#   0],
#  ['라벨르(ann8****)',
#   '너무루즈함...엠마스톤 몸매만보고옴',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2016, 12, 28, 16, 17),
#   0],
#  ['잇츠라임(jjeo****)',
#   '몇년만에 영화보다 잠들정도네요...',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2016, 12, 25, 19, 37),
#   0],
#  ['oliv****',
#   '러닝타임 왜 질질끌어 두시간인지 모르겠네요. 엠마스톤 특유의 입삐죽내밀고 말하거나 특히 노래할때 두시간내내 거슬렸어요. 정말 극장에서 세번정도 뛰쳐나올뻔했음.',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2016, 12, 24, 17, 25),
#   0],
#  ['Froza Milan(pdss****)',
#   '한국에7광구가 있다면 외국은 이 영화',
#   '1',
#   '12',
#   '5',
#   datetime.datetime(2016, 12, 21, 0, 3),
#   0],
#  ['유타쿠(wint****)',
#   '라이언 고슬링과 엠마스톤 조합이라 기대했던 탓인지 별로 였습니다.다른 사람의 후기대로 영상미와 음악은 뛰어났지만 뜬금없는 스토리전개와 억지스러운 뮤지컬 장면들.그리고 뻔하디 뻔한 스토리 입니다.하지만 배우들의 연기는...',
#   '5',
#   '12',
#   '5',
#   datetime.datetime(2016, 12, 8, 15, 34),
#   0],
#  ['쥬쥬(jiwo****)',
#   '음 딱히 내 스타일은 아닌것같다.',
#   '1',
#   '13',
#   '6',
#   datetime.datetime(2020, 3, 1, 16, 52),
#   0],
#  ['Cosmos(prom****)',
#   '평점 보고 봤다가 낭패 봤네요. 넘 지루해서 중간에 뛰쳐나왔음..',
#   '1',
#   '13',
#   '6',
#   datetime.datetime(2017, 3, 15, 12, 7),
#   0],
#  ['신예현(youn****)',
#   '이게 왜 로맨스야 여자는 자기 기분끌릴때마다 남자를 바꾸고 마지막 회상씬은 왜? 자기하고 싶은대로 다했으면서 애까지 있으신분이.. 지루하고 짜임새도없고 ost가 그나마좋았는데 그마저도 없었으면 이 영화볼돈으로 길바닥...',
#   '1',
#   '13',
#   '6',
#   datetime.datetime(2017, 1, 8, 17, 43),
#   0],
#  ['Na(nbr8****)',
#   '앞부분 너무 지루해요. 개연성도 없고..판타지 예술영화 너무 좋아하는데 졸았어요. 끝나기 30분전부터 스토리 볼만 하더라구요. 배경 영상 음악 세박자 다 좋은데 아쉽습니다. 그리고 배우얼굴 클로즈업 될때마다 집중이 ...',
#   '1',
#   '13',
#   '6',
#   datetime.datetime(2016, 12, 26, 16, 58),
#   0],
#  ['그냥하겠습니다(wkdn****)',
#   '이 영화보고  무서워서 연애하겠나ㅋㅋ아 영화남자주인공처럼 널 사랑해 말했다가 끝부분보고 두들겨맞았다',
#   '1',
#   '13',
#   '6',
#   datetime.datetime(2016, 12, 14, 17, 41),
#   0],
#  ['청아우쭈쭈(xxdl****)',
#   '와나 ㅠ 보는내내 집가고 싶었음 길기는 또 왤케길어ㅡㅡ진짜 1도 재미없ㅡㅡ',
#   '1',
#   '13',
#   '6',
#   datetime.datetime(2016, 12, 12, 20, 51),
#   0],
#  ['바나나킥우유(1555****)',
#   '모든나라의현실과 거리가 매우먼 과대망상 허언증환자들의 위한영화 비싼돈내고 라라랜드 인콘서트를 보러간게 후회스러움 그돈으로 비싸게외식이나할껄 ㅠㅠ',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2018, 12, 30, 12, 46),
#   0],
#  ['바람(smjd****)',
#   '솔직히 ㄱㅊㄴ 양성영화 아님?? 남주는 순회공연하는거 막아놓고 지는 프랑스가서 다른남자로 갈아타는건 좀...',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2017, 1, 23, 3, 30),
#   0],
#  ['여행(spqj****)',
#   '무슨 내용인지 모르겠다',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2017, 1, 20, 17, 21),
#   0],
#  ['ㅇㅇㅇ(grea****)',
#   '이게 영화냐? 10자10자',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2017, 1, 16, 19, 31),
#   0],
#  ['Lennon(tahi****)',
#   '진짜 재미없었어요 진짜로',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2017, 1, 6, 17, 37),
#   0],
#  ['애프리(dldy****)',
#   '9천원이 아깝다 사람들 엿맥이려고 만든거임? 개노잼',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2016, 12, 25, 16, 47),
#   0],
#  ['팔선생(jooh****)',
#   '내가 영화댓글 보고 가서 처음으로 낚시당했다 OO',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2016, 12, 17, 2, 21),
#   0],
#  ['내일또(long****)',
#   '제취향은 아닙니다 ;;;',
#   '1',
#   '14',
#   '7',
#   datetime.datetime(2016, 12, 14, 20, 54),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                          0  ...  6
# 0                 wche****  ...  0
# 1          우훌루후후(dngk****)  ...  0
# 2           유인나연(ssss****)  ...  0
# 3      Casofhjkl(kidi****)  ...  0
# 4             키돌(doon****)  ...  0
# ...                    ...  ... ..
# 23455     가을바람한컵(jkl5****)  ...  0
# 23456        그린장(duds****)  ...  0
# 23457             hite****  ...  0
# 23458      ddddr(djse****)  ...  0
# 23459        호루망(dkng****)  ...  0
#
# [23460 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                   nickname  ... watch_movie
# 0                 wche****  ...           0
# 1          우훌루후후(dngk****)  ...           0
# 2           유인나연(ssss****)  ...           0
# 3      Casofhjkl(kidi****)  ...           0
# 4             키돌(doon****)  ...           0
# ...                    ...  ...         ...
# 23455     가을바람한컵(jkl5****)  ...           0
# 23456        그린장(duds****)  ...           0
# 23457             hite****  ...           0
# 23458      ddddr(djse****)  ...           0
# 23459        호루망(dkng****)  ...           0
#
# [23460 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
