# %% [markdown]
# <a href="https://colab.research.google.com/github/Baekhyeonjeong/Baekhyeonjeong/blob/main/%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91_%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%B3%B4%ED%97%A4%EB%AF%B8%EC%95%88%EB%9E%A9%EC%86%8C%EB%94%94_%EB%8C%93%EA%B8%80_%EC%88%98%EC%A7%91_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 영화 댓글 수집
#
# -- 영화 메인
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967
#
#
#
# -- 덧글 리스트
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
#
#
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2

# %% [markdown]
# ## 맛보기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 페이지 전환

# %%
movieid = 107924
total_count = 19653  ## 전체 크기=19,653

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(url)
# Out:
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=3
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=4
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=5
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=6
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=7
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=8
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=9
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=10
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=11
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=12
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=13
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=14
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=15
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=16
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=17
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=18
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=19
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=20
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=21
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=22
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=23
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=24
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=25
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=26
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=27
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=28
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=29
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=30
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=31
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=32
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=33
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=34
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=35
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=36
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=37
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=38
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=39
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=40
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=41
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=42
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=43
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=44
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=45
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=46
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=47
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=48
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=49
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=50
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=51
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=52
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=53
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=54
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=55
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=56
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=57
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=58
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=59
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=60
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=61
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=62
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=63
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=64
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=65
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=66
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=67
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=68
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=69
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=70
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=71
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=72
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=73
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=74
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=75
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=76
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=77
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=78
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=79
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=80
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=81
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=82
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=83
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=84
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=85
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=86
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=87
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=88
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=89
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=90
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=91
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=92
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=93
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=94
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=95
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=96
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=97
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=98
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=99
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=100
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=101
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=102
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=103
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=104
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=105
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=106
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=107
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=108
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=109
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=110
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=111
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=112
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=113
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=114
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=115
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=116
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=117
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=118
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=119
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=120
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=121
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=122
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=123
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=124
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=125
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=126
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=127
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=128
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=129
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=130
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=131
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=132
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=133
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=134
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=135
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=136
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=137
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=138
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=139
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=140
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=141
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=142
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=143
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=144
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=145
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=146
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=147
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=148
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=149
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=150
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=151
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=152
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=153
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=154
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=155
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=156
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=157
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=158
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=159
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=160
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=161
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=162
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=163
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=164
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=165
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=166
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=167
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=168
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=169
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=170
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=171
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=172
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=173
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=174
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=175
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=176
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=177
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=178
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=179
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=180
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=181
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=182
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=183
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=184
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=185
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=186
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=187
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=188
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=189
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=190
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=191
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=192
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=193
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=194
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=195
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=196
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=197
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=198
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=199
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=200
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=201
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=202
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=203
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=204
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=205
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=206
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=207
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=208
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=209
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=210
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=211
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=212
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=213
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=214
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=215
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=216
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=217
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=218
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=219
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=220
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=221
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=222
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=223
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=224
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=225
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=226
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=227
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=228
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=229
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=230
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=231
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=232
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=233
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=234
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=235
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=236
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=237
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=238
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=239
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=240
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=241
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=242
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=243
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=244
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=245
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=246
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=247
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=248
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=249
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=250
# ...
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1884
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1885
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1886
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1887
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1888
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1889
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1890
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1891
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1892
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1893
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1894
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1895
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1896
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1897
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1898
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1899
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1900
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1901
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1902
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1903
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1904
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1905
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1906
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1907
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1908
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1909
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1910
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1911
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1912
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1913
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1914
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1915
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1916
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1917
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1918
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1919
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1920
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1921
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1922
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1923
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1924
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1925
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1926
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1927
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1928
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1929
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1930
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1931
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1932
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1933
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1934
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1935
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1936
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1937
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1938
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1939
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1940
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1941
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1942
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1943
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1944
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1945
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1946
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1947
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1948
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1949
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1950
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1951
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1952
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1953
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1954
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1955
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1956
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1957
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1958
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1959
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1960
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1961
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1962
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1963
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1964
# https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=107924&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1965

# %% [markdown]
# ### 개별 리뷰 세부 사항

# %%
## 해당 페이지의 html FULL
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20200417110808" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20200417110808" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20200417110808" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20200417110808" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="161967"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="1"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>36,529</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738216, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>brilliant_AKA_밝음(bril****)</span>
# </a>
# </em>
# <em>2019.05.30 15:58</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','bril****', 'CyNhpJ+qkjXfv8NY+ybBa3IwKx8Uf0vOBr+s8Bk5owM=', '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 ', '15738216', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738216">28791</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738216">1504</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>김희정(priv****)</span>
# </a>
# </em>
# <em>2019.05.30 12:25</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','priv****', 'jjv6qM3ZHF+lm+39Ztvra2Lo83lph6tORA6Ng1vSq7c=', '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데.. ', '15736627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736627">18779</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736627">1586</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737678, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>리오(papi****)</span>
# </a>
# </em>
# <em>2019.05.30 14:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','papi****', 'MTkAnDzFvty9bU2B71ZQzyRKjwY2JaVjKPdGGzAr/dg=', '지하철이라는 단어가 언급되는 순간, 대다수의 관객은 자신이 어디에 이입할 지를 안다. ', '15737678', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737678">17453</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737678">1113</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738415, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>멍뭉이(sumi****)</span>
# </a>
# </em>
# <em>2019.05.30 16:28</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sumi****', 'sgYqpMep7dXfkS9MIe7PUYd7jFWtdgzLJkaBtub5awU=', '전 가정부가 집 벨 누를 때 부터 이 영화는 장르가 바뀐다... 역대급 꿀잼영화 ', '15738415', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738415">17034</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738415">936</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737905, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>여행의 발견(riod****)</span>
# </a>
# </em>
# <em>2019.05.30 15:13</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','riod****', 'juqbdcsvFbC66hNLcJoPL915nTb3fG9phj/JBg2Onu4=', '황금종려상 수상작을 자막 없이 볼 수 있다는 것 자체로 좋다. ', '15737905', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737905">16034</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737905">802</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:90.0%"></span></span><em>9</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15743239, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>페르(sa02****)</span>
# </a>
# </em>
# <em>2019.05.31 01:41</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sa02****', 'oNASB02ZlvYtjSbLjY7Ad7LZYBuFnabVFbcmNshznE8=', '반지하가 제일 아래인줄 알았다. 내려가보니 지하도 있었다. ', '15743239', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15743239">12886</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15743239">299</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15735958, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>크렙하스(powe****)</span>
# </a>
# </em>
# <em>2019.05.30 10:50</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','powe****', '9TuTPRPp8SJGxhDYjew+C/fTE2ULWMVtUC9FMuzzpY0=', '뭔가 모를 불쾌한 영화였다. 영화가 불쾌하다는게 아니라 보는 내내 가슴에 뭔가 영화에서 나오는 수석이 얹혀져있는 영화다. ', '15735958', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15735958">12245</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15735958">729</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736477, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>도미(dudd****)</span>
# </a>
# </em>
# <em>2019.05.30 12:05</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','dudd****', 'amVW2iA/7hvLRy9PjeSN9h5lJCLI6OoVWO3oTlzrJfg=', '누군가의 냄새를 맡고, 평가하고, 묘사할 수 있는 것 또한 권력. 냄새로 서로를 알아보고 경계하고 구분짓는 동물들의 세계와 우리 사회는 참 닮아있다. ', '15736477', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736477">11199</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736477">493</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_8">
#
#
#
# 																박서준이 잘못했네ㅋㅋㅋㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737802, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>구마(gym9****)</span>
# </a>
# </em>
# <em>2019.05.30 15:01</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gym9****', 'a9/eGsZ8229Knvoa9cSby+xkeIpPHG996qjVe+AagTY=', '박서준이 잘못했네ㅋㅋㅋㅋ ', '15737802', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737802">10863</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737802">443</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:80.0%"></span></span><em>8</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15737882, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>블루이즈(cank****)</span>
# </a>
# </em>
# <em>2019.05.30 15:11</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','cank****', 'dPSPsRFbLOmFyijW3aatPuDcOm8ywHmehVCD+QR4qYw=', '나 또한 누군가의 사람 사는 냄새에 얼굴 찌푸리진 않았었나.. ', '15737882', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15737882">10612</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15737882">380</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=161967&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '1');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "161967",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=161967#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=161967&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=161967#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("161967", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %%
## 1번째 덧글 FULL
# /html/body/div/div/div[5]/ul/li[1] --> 1번째 덧글 전체
# /html/body/div/div/div[5]/ul/li[2] --> 2번째 덧글 전체

score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[0]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15738216, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>brilliant_AKA_밝음(bril****)</span>
# </a>
# </em>
# <em>2019.05.30 15:58</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','bril****', 'CyNhpJ+qkjXfv8NY+ybBa3IwKx8Uf0vOBr+s8Bk5owM=', '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 ', '15738216', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15738216">28791</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15738216">1504</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[2]

## 2번째 덧글 FULL
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
lis[1]
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_1">
#
#
#
# 																최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(15736627, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>김희정(priv****)</span>
# </a>
# </em>
# <em>2019.05.30 12:25</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','priv****', 'ia+L3ovTsOJOamiddckFuEgyDXZKv2w/A+UcZ4F0fPk=', '최근 본 영화중 가장 충격적이었음... 근데 보니까 15세말고 19세 걸어야될것같던데.. ', '15736627', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_15736627">18753</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_15736627">1586</strong>
# </a>
# </div>
# </li>

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용
review_text = lis[0].find('p').find('span').getText()
review_text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구 \r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/p/span/text()

## 덧글 내용 -- 부호 빼고 깨끗하게!
review_text = lis[0].find('p').find('span').getText().strip()
review_text
# Out:
# '비에 젖지 않는 고급 장난감 텐트와, 비에 젖다 못해 잠겨버리는 반지하 가구'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[1]/em

## 평점 내용
score = lis[0].find('em').getText()
score
# Out:
# '10'

# %%
#/html/body/div/div/div[5]/ul/li[1]/div[3]/a[1]/strong --> 좋아요. 
# /html/body/div/div/div[5]/ul/li[1]/div[3]/a[2]/strong --> 싫어요

## 좋아요/싫어요 점수
like = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[0].getText()
dislike = lis[0].find('div', {'class': 'btn_area'}).findAll('strong')[1].getText()
like, dislike
# Out:
# ('28749', '1501')

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[1]/a/span

## 덧글 작성자 닉네임
nickname = lis[0].findAll('a')[0].find('span').getText()
nickname
# Out:
# 'brilliant_AKA_밝음(bril****)'

# %%
# /html/body/div/div/div[5]/ul/li[1]/div[2]/dl/dt/em[2]

from datetime import datetime
created_at = datetime.strptime(lis[0].find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
created_at
# Out:
# datetime.datetime(2019, 5, 30, 15, 58)

# %% [markdown]
# ## 본 게임

# %%
# 필요 라이브러리 불러오기
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd

# %%
## 데이터 수집

movieid = 156464
total_count = 38787  ## 전체 크기=36524

urlfit = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+str(movieid)+'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false'

segment=[]

for i in range(1, int(total_count / 10) + 1):
    url = urlfit + '&page=' + str(i)
    print(str(i) + ' 번째 페이지 parsing....')

    resp = requests.get(url)
    html = BeautifulSoup(resp.content, 'html.parser')
    score_result = html.find('div', {'class': 'score_result'})
    lis = score_result.findAll('li')
    for li in lis:
        try:
          watch_movie = li.find('span', {'class':'ico_viewer'}).extract().getText()
        except:
          watch_movie = 0
        nickname = li.findAll('em')[1].find('a').find('span').getText()
        created_at = datetime.strptime(li.find('dt').findAll('em')[1].getText(), "%Y.%m.%d %H:%M")
        review_text = li.find('p').find('span').getText().strip()
        score = li.find('em').getText()
        btn_likes = li.find('div', {'class': 'btn_area'}).findAll('strong')
        like = btn_likes[0].getText()
        dislike = btn_likes[1].getText()


        fullinfo = [nickname, review_text, score, like, dislike, created_at, watch_movie]
        segment.append(fullinfo)
# Out:
# 1 번째 페이지 parsing....
# 2 번째 페이지 parsing....
# 3 번째 페이지 parsing....
# 4 번째 페이지 parsing....
# 5 번째 페이지 parsing....
# 6 번째 페이지 parsing....
# 7 번째 페이지 parsing....
# 8 번째 페이지 parsing....
# 9 번째 페이지 parsing....
# 10 번째 페이지 parsing....
# 11 번째 페이지 parsing....
# 12 번째 페이지 parsing....
# 13 번째 페이지 parsing....
# 14 번째 페이지 parsing....
# 15 번째 페이지 parsing....
# 16 번째 페이지 parsing....
# 17 번째 페이지 parsing....
# 18 번째 페이지 parsing....
# 19 번째 페이지 parsing....
# 20 번째 페이지 parsing....
# 21 번째 페이지 parsing....
# 22 번째 페이지 parsing....
# 23 번째 페이지 parsing....
# 24 번째 페이지 parsing....
# 25 번째 페이지 parsing....
# 26 번째 페이지 parsing....
# 27 번째 페이지 parsing....
# 28 번째 페이지 parsing....
# 29 번째 페이지 parsing....
# 30 번째 페이지 parsing....
# 31 번째 페이지 parsing....
# 32 번째 페이지 parsing....
# 33 번째 페이지 parsing....
# 34 번째 페이지 parsing....
# 35 번째 페이지 parsing....
# 36 번째 페이지 parsing....
# 37 번째 페이지 parsing....
# 38 번째 페이지 parsing....
# 39 번째 페이지 parsing....
# 40 번째 페이지 parsing....
# 41 번째 페이지 parsing....
# 42 번째 페이지 parsing....
# 43 번째 페이지 parsing....
# 44 번째 페이지 parsing....
# 45 번째 페이지 parsing....
# 46 번째 페이지 parsing....
# 47 번째 페이지 parsing....
# 48 번째 페이지 parsing....
# 49 번째 페이지 parsing....
# 50 번째 페이지 parsing....
# 51 번째 페이지 parsing....
# 52 번째 페이지 parsing....
# 53 번째 페이지 parsing....
# 54 번째 페이지 parsing....
# 55 번째 페이지 parsing....
# 56 번째 페이지 parsing....
# 57 번째 페이지 parsing....
# 58 번째 페이지 parsing....
# 59 번째 페이지 parsing....
# 60 번째 페이지 parsing....
# 61 번째 페이지 parsing....
# 62 번째 페이지 parsing....
# 63 번째 페이지 parsing....
# 64 번째 페이지 parsing....
# 65 번째 페이지 parsing....
# 66 번째 페이지 parsing....
# 67 번째 페이지 parsing....
# 68 번째 페이지 parsing....
# 69 번째 페이지 parsing....
# 70 번째 페이지 parsing....
# 71 번째 페이지 parsing....
# 72 번째 페이지 parsing....
# 73 번째 페이지 parsing....
# 74 번째 페이지 parsing....
# 75 번째 페이지 parsing....
# 76 번째 페이지 parsing....
# 77 번째 페이지 parsing....
# 78 번째 페이지 parsing....
# 79 번째 페이지 parsing....
# 80 번째 페이지 parsing....
# 81 번째 페이지 parsing....
# 82 번째 페이지 parsing....
# 83 번째 페이지 parsing....
# 84 번째 페이지 parsing....
# 85 번째 페이지 parsing....
# 86 번째 페이지 parsing....
# 87 번째 페이지 parsing....
# 88 번째 페이지 parsing....
# 89 번째 페이지 parsing....
# 90 번째 페이지 parsing....
# 91 번째 페이지 parsing....
# 92 번째 페이지 parsing....
# 93 번째 페이지 parsing....
# 94 번째 페이지 parsing....
# 95 번째 페이지 parsing....
# 96 번째 페이지 parsing....
# 97 번째 페이지 parsing....
# 98 번째 페이지 parsing....
# 99 번째 페이지 parsing....
# 100 번째 페이지 parsing....
# 101 번째 페이지 parsing....
# 102 번째 페이지 parsing....
# 103 번째 페이지 parsing....
# 104 번째 페이지 parsing....
# 105 번째 페이지 parsing....
# 106 번째 페이지 parsing....
# 107 번째 페이지 parsing....
# 108 번째 페이지 parsing....
# 109 번째 페이지 parsing....
# 110 번째 페이지 parsing....
# 111 번째 페이지 parsing....
# 112 번째 페이지 parsing....
# 113 번째 페이지 parsing....
# 114 번째 페이지 parsing....
# 115 번째 페이지 parsing....
# 116 번째 페이지 parsing....
# 117 번째 페이지 parsing....
# 118 번째 페이지 parsing....
# 119 번째 페이지 parsing....
# 120 번째 페이지 parsing....
# 121 번째 페이지 parsing....
# 122 번째 페이지 parsing....
# 123 번째 페이지 parsing....
# 124 번째 페이지 parsing....
# 125 번째 페이지 parsing....
# 126 번째 페이지 parsing....
# 127 번째 페이지 parsing....
# 128 번째 페이지 parsing....
# 129 번째 페이지 parsing....
# 130 번째 페이지 parsing....
# 131 번째 페이지 parsing....
# 132 번째 페이지 parsing....
# 133 번째 페이지 parsing....
# 134 번째 페이지 parsing....
# 135 번째 페이지 parsing....
# 136 번째 페이지 parsing....
# 137 번째 페이지 parsing....
# 138 번째 페이지 parsing....
# 139 번째 페이지 parsing....
# 140 번째 페이지 parsing....
# 141 번째 페이지 parsing....
# 142 번째 페이지 parsing....
# 143 번째 페이지 parsing....
# 144 번째 페이지 parsing....
# 145 번째 페이지 parsing....
# 146 번째 페이지 parsing....
# 147 번째 페이지 parsing....
# 148 번째 페이지 parsing....
# 149 번째 페이지 parsing....
# 150 번째 페이지 parsing....
# 151 번째 페이지 parsing....
# 152 번째 페이지 parsing....
# 153 번째 페이지 parsing....
# 154 번째 페이지 parsing....
# 155 번째 페이지 parsing....
# 156 번째 페이지 parsing....
# 157 번째 페이지 parsing....
# 158 번째 페이지 parsing....
# 159 번째 페이지 parsing....
# 160 번째 페이지 parsing....
# 161 번째 페이지 parsing....
# 162 번째 페이지 parsing....
# 163 번째 페이지 parsing....
# 164 번째 페이지 parsing....
# 165 번째 페이지 parsing....
# 166 번째 페이지 parsing....
# 167 번째 페이지 parsing....
# 168 번째 페이지 parsing....
# 169 번째 페이지 parsing....
# 170 번째 페이지 parsing....
# 171 번째 페이지 parsing....
# 172 번째 페이지 parsing....
# 173 번째 페이지 parsing....
# 174 번째 페이지 parsing....
# 175 번째 페이지 parsing....
# 176 번째 페이지 parsing....
# 177 번째 페이지 parsing....
# 178 번째 페이지 parsing....
# 179 번째 페이지 parsing....
# 180 번째 페이지 parsing....
# 181 번째 페이지 parsing....
# 182 번째 페이지 parsing....
# 183 번째 페이지 parsing....
# 184 번째 페이지 parsing....
# 185 번째 페이지 parsing....
# 186 번째 페이지 parsing....
# 187 번째 페이지 parsing....
# 188 번째 페이지 parsing....
# 189 번째 페이지 parsing....
# 190 번째 페이지 parsing....
# 191 번째 페이지 parsing....
# 192 번째 페이지 parsing....
# 193 번째 페이지 parsing....
# 194 번째 페이지 parsing....
# 195 번째 페이지 parsing....
# 196 번째 페이지 parsing....
# 197 번째 페이지 parsing....
# 198 번째 페이지 parsing....
# 199 번째 페이지 parsing....
# 200 번째 페이지 parsing....
# 201 번째 페이지 parsing....
# 202 번째 페이지 parsing....
# 203 번째 페이지 parsing....
# 204 번째 페이지 parsing....
# 205 번째 페이지 parsing....
# 206 번째 페이지 parsing....
# 207 번째 페이지 parsing....
# 208 번째 페이지 parsing....
# 209 번째 페이지 parsing....
# 210 번째 페이지 parsing....
# 211 번째 페이지 parsing....
# 212 번째 페이지 parsing....
# 213 번째 페이지 parsing....
# 214 번째 페이지 parsing....
# 215 번째 페이지 parsing....
# 216 번째 페이지 parsing....
# 217 번째 페이지 parsing....
# 218 번째 페이지 parsing....
# 219 번째 페이지 parsing....
# 220 번째 페이지 parsing....
# 221 번째 페이지 parsing....
# 222 번째 페이지 parsing....
# 223 번째 페이지 parsing....
# 224 번째 페이지 parsing....
# 225 번째 페이지 parsing....
# 226 번째 페이지 parsing....
# 227 번째 페이지 parsing....
# 228 번째 페이지 parsing....
# 229 번째 페이지 parsing....
# 230 번째 페이지 parsing....
# 231 번째 페이지 parsing....
# 232 번째 페이지 parsing....
# 233 번째 페이지 parsing....
# 234 번째 페이지 parsing....
# 235 번째 페이지 parsing....
# 236 번째 페이지 parsing....
# 237 번째 페이지 parsing....
# 238 번째 페이지 parsing....
# 239 번째 페이지 parsing....
# 240 번째 페이지 parsing....
# 241 번째 페이지 parsing....
# 242 번째 페이지 parsing....
# 243 번째 페이지 parsing....
# 244 번째 페이지 parsing....
# 245 번째 페이지 parsing....
# 246 번째 페이지 parsing....
# 247 번째 페이지 parsing....
# 248 번째 페이지 parsing....
# 249 번째 페이지 parsing....
# 250 번째 페이지 parsing....
# 251 번째 페이지 parsing....
# 252 번째 페이지 parsing....
# 253 번째 페이지 parsing....
# 254 번째 페이지 parsing....
# 255 번째 페이지 parsing....
# 256 번째 페이지 parsing....
# 257 번째 페이지 parsing....
# 258 번째 페이지 parsing....
# 259 번째 페이지 parsing....
# 260 번째 페이지 parsing....
# 261 번째 페이지 parsing....
# 262 번째 페이지 parsing....
# 263 번째 페이지 parsing....
# 264 번째 페이지 parsing....
# 265 번째 페이지 parsing....
# 266 번째 페이지 parsing....
# 267 번째 페이지 parsing....
# 268 번째 페이지 parsing....
# 269 번째 페이지 parsing....
# 270 번째 페이지 parsing....
# 271 번째 페이지 parsing....
# 272 번째 페이지 parsing....
# 273 번째 페이지 parsing....
# 274 번째 페이지 parsing....
# 275 번째 페이지 parsing....
# 276 번째 페이지 parsing....
# 277 번째 페이지 parsing....
# 278 번째 페이지 parsing....
# 279 번째 페이지 parsing....
# 280 번째 페이지 parsing....
# 281 번째 페이지 parsing....
# 282 번째 페이지 parsing....
# 283 번째 페이지 parsing....
# 284 번째 페이지 parsing....
# 285 번째 페이지 parsing....
# 286 번째 페이지 parsing....
# 287 번째 페이지 parsing....
# 288 번째 페이지 parsing....
# 289 번째 페이지 parsing....
# 290 번째 페이지 parsing....
# 291 번째 페이지 parsing....
# 292 번째 페이지 parsing....
# 293 번째 페이지 parsing....
# 294 번째 페이지 parsing....
# 295 번째 페이지 parsing....
# 296 번째 페이지 parsing....
# 297 번째 페이지 parsing....
# 298 번째 페이지 parsing....
# 299 번째 페이지 parsing....
# 300 번째 페이지 parsing....
# 301 번째 페이지 parsing....
# 302 번째 페이지 parsing....
# 303 번째 페이지 parsing....
# 304 번째 페이지 parsing....
# 305 번째 페이지 parsing....
# 306 번째 페이지 parsing....
# 307 번째 페이지 parsing....
# 308 번째 페이지 parsing....
# 309 번째 페이지 parsing....
# 310 번째 페이지 parsing....
# 311 번째 페이지 parsing....
# 312 번째 페이지 parsing....
# 313 번째 페이지 parsing....
# 314 번째 페이지 parsing....
# 315 번째 페이지 parsing....
# 316 번째 페이지 parsing....
# 317 번째 페이지 parsing....
# 318 번째 페이지 parsing....
# 319 번째 페이지 parsing....
# 320 번째 페이지 parsing....
# 321 번째 페이지 parsing....
# 322 번째 페이지 parsing....
# 323 번째 페이지 parsing....
# 324 번째 페이지 parsing....
# 325 번째 페이지 parsing....
# 326 번째 페이지 parsing....
# 327 번째 페이지 parsing....
# 328 번째 페이지 parsing....
# 329 번째 페이지 parsing....
# 330 번째 페이지 parsing....
# 331 번째 페이지 parsing....
# 332 번째 페이지 parsing....
# 333 번째 페이지 parsing....
# 334 번째 페이지 parsing....
# 335 번째 페이지 parsing....
# 336 번째 페이지 parsing....
# 337 번째 페이지 parsing....
# 338 번째 페이지 parsing....
# 339 번째 페이지 parsing....
# 340 번째 페이지 parsing....
# 341 번째 페이지 parsing....
# 342 번째 페이지 parsing....
# 343 번째 페이지 parsing....
# 344 번째 페이지 parsing....
# 345 번째 페이지 parsing....
# 346 번째 페이지 parsing....
# 347 번째 페이지 parsing....
# 348 번째 페이지 parsing....
# 349 번째 페이지 parsing....
# 350 번째 페이지 parsing....
# 351 번째 페이지 parsing....
# 352 번째 페이지 parsing....
# 353 번째 페이지 parsing....
# 354 번째 페이지 parsing....
# 355 번째 페이지 parsing....
# 356 번째 페이지 parsing....
# 357 번째 페이지 parsing....
# 358 번째 페이지 parsing....
# 359 번째 페이지 parsing....
# 360 번째 페이지 parsing....
# 361 번째 페이지 parsing....
# 362 번째 페이지 parsing....
# 363 번째 페이지 parsing....
# 364 번째 페이지 parsing....
# 365 번째 페이지 parsing....
# 366 번째 페이지 parsing....
# 367 번째 페이지 parsing....
# 368 번째 페이지 parsing....
# 369 번째 페이지 parsing....
# 370 번째 페이지 parsing....
# 371 번째 페이지 parsing....
# 372 번째 페이지 parsing....
# 373 번째 페이지 parsing....
# 374 번째 페이지 parsing....
# 375 번째 페이지 parsing....
# 376 번째 페이지 parsing....
# 377 번째 페이지 parsing....
# 378 번째 페이지 parsing....
# 379 번째 페이지 parsing....
# 380 번째 페이지 parsing....
# 381 번째 페이지 parsing....
# 382 번째 페이지 parsing....
# 383 번째 페이지 parsing....
# 384 번째 페이지 parsing....
# 385 번째 페이지 parsing....
# 386 번째 페이지 parsing....
# 387 번째 페이지 parsing....
# 388 번째 페이지 parsing....
# 389 번째 페이지 parsing....
# 390 번째 페이지 parsing....
# 391 번째 페이지 parsing....
# 392 번째 페이지 parsing....
# 393 번째 페이지 parsing....
# 394 번째 페이지 parsing....
# 395 번째 페이지 parsing....
# 396 번째 페이지 parsing....
# 397 번째 페이지 parsing....
# 398 번째 페이지 parsing....
# 399 번째 페이지 parsing....
# 400 번째 페이지 parsing....
# 401 번째 페이지 parsing....
# 402 번째 페이지 parsing....
# 403 번째 페이지 parsing....
# 404 번째 페이지 parsing....
# 405 번째 페이지 parsing....
# 406 번째 페이지 parsing....
# 407 번째 페이지 parsing....
# 408 번째 페이지 parsing....
# 409 번째 페이지 parsing....
# 410 번째 페이지 parsing....
# 411 번째 페이지 parsing....
# 412 번째 페이지 parsing....
# 413 번째 페이지 parsing....
# 414 번째 페이지 parsing....
# 415 번째 페이지 parsing....
# 416 번째 페이지 parsing....
# 417 번째 페이지 parsing....
# 418 번째 페이지 parsing....
# 419 번째 페이지 parsing....
# 420 번째 페이지 parsing....
# 421 번째 페이지 parsing....
# 422 번째 페이지 parsing....
# 423 번째 페이지 parsing....
# 424 번째 페이지 parsing....
# 425 번째 페이지 parsing....
# 426 번째 페이지 parsing....
# 427 번째 페이지 parsing....
# 428 번째 페이지 parsing....
# 429 번째 페이지 parsing....
# 430 번째 페이지 parsing....
# 431 번째 페이지 parsing....
# 432 번째 페이지 parsing....
# 433 번째 페이지 parsing....
# 434 번째 페이지 parsing....
# 435 번째 페이지 parsing....
# 436 번째 페이지 parsing....
# 437 번째 페이지 parsing....
# 438 번째 페이지 parsing....
# 439 번째 페이지 parsing....
# 440 번째 페이지 parsing....
# 441 번째 페이지 parsing....
# 442 번째 페이지 parsing....
# 443 번째 페이지 parsing....
# 444 번째 페이지 parsing....
# 445 번째 페이지 parsing....
# 446 번째 페이지 parsing....
# 447 번째 페이지 parsing....
# 448 번째 페이지 parsing....
# 449 번째 페이지 parsing....
# 450 번째 페이지 parsing....
# 451 번째 페이지 parsing....
# 452 번째 페이지 parsing....
# 453 번째 페이지 parsing....
# 454 번째 페이지 parsing....
# 455 번째 페이지 parsing....
# 456 번째 페이지 parsing....
# 457 번째 페이지 parsing....
# 458 번째 페이지 parsing....
# 459 번째 페이지 parsing....
# 460 번째 페이지 parsing....
# 461 번째 페이지 parsing....
# 462 번째 페이지 parsing....
# 463 번째 페이지 parsing....
# 464 번째 페이지 parsing....
# 465 번째 페이지 parsing....
# 466 번째 페이지 parsing....
# 467 번째 페이지 parsing....
# 468 번째 페이지 parsing....
# 469 번째 페이지 parsing....
# 470 번째 페이지 parsing....
# 471 번째 페이지 parsing....
# 472 번째 페이지 parsing....
# 473 번째 페이지 parsing....
# 474 번째 페이지 parsing....
# 475 번째 페이지 parsing....
# 476 번째 페이지 parsing....
# 477 번째 페이지 parsing....
# 478 번째 페이지 parsing....
# 479 번째 페이지 parsing....
# 480 번째 페이지 parsing....
# 481 번째 페이지 parsing....
# 482 번째 페이지 parsing....
# 483 번째 페이지 parsing....
# 484 번째 페이지 parsing....
# 485 번째 페이지 parsing....
# 486 번째 페이지 parsing....
# 487 번째 페이지 parsing....
# 488 번째 페이지 parsing....
# 489 번째 페이지 parsing....
# 490 번째 페이지 parsing....
# 491 번째 페이지 parsing....
# 492 번째 페이지 parsing....
# 493 번째 페이지 parsing....
# 494 번째 페이지 parsing....
# 495 번째 페이지 parsing....
# 496 번째 페이지 parsing....
# 497 번째 페이지 parsing....
# 498 번째 페이지 parsing....
# 499 번째 페이지 parsing....
# 500 번째 페이지 parsing....
# 501 번째 페이지 parsing....
# 502 번째 페이지 parsing....
# 503 번째 페이지 parsing....
# 504 번째 페이지 parsing....
# 505 번째 페이지 parsing....
# 506 번째 페이지 parsing....
# 507 번째 페이지 parsing....
# 508 번째 페이지 parsing....
# 509 번째 페이지 parsing....
# 510 번째 페이지 parsing....
# 511 번째 페이지 parsing....
# 512 번째 페이지 parsing....
# 513 번째 페이지 parsing....
# 514 번째 페이지 parsing....
# 515 번째 페이지 parsing....
# 516 번째 페이지 parsing....
# 517 번째 페이지 parsing....
# 518 번째 페이지 parsing....
# 519 번째 페이지 parsing....
# 520 번째 페이지 parsing....
# 521 번째 페이지 parsing....
# 522 번째 페이지 parsing....
# 523 번째 페이지 parsing....
# 524 번째 페이지 parsing....
# 525 번째 페이지 parsing....
# 526 번째 페이지 parsing....
# 527 번째 페이지 parsing....
# 528 번째 페이지 parsing....
# 529 번째 페이지 parsing....
# 530 번째 페이지 parsing....
# 531 번째 페이지 parsing....
# 532 번째 페이지 parsing....
# 533 번째 페이지 parsing....
# 534 번째 페이지 parsing....
# 535 번째 페이지 parsing....
# 536 번째 페이지 parsing....
# 537 번째 페이지 parsing....
# 538 번째 페이지 parsing....
# 539 번째 페이지 parsing....
# 540 번째 페이지 parsing....
# 541 번째 페이지 parsing....
# 542 번째 페이지 parsing....
# 543 번째 페이지 parsing....
# 544 번째 페이지 parsing....
# 545 번째 페이지 parsing....
# 546 번째 페이지 parsing....
# 547 번째 페이지 parsing....
# 548 번째 페이지 parsing....
# 549 번째 페이지 parsing....
# 550 번째 페이지 parsing....
# 551 번째 페이지 parsing....
# 552 번째 페이지 parsing....
# 553 번째 페이지 parsing....
# 554 번째 페이지 parsing....
# 555 번째 페이지 parsing....
# 556 번째 페이지 parsing....
# 557 번째 페이지 parsing....
# 558 번째 페이지 parsing....
# 559 번째 페이지 parsing....
# 560 번째 페이지 parsing....
# 561 번째 페이지 parsing....
# 562 번째 페이지 parsing....
# 563 번째 페이지 parsing....
# 564 번째 페이지 parsing....
# 565 번째 페이지 parsing....
# 566 번째 페이지 parsing....
# 567 번째 페이지 parsing....
# 568 번째 페이지 parsing....
# 569 번째 페이지 parsing....
# 570 번째 페이지 parsing....
# 571 번째 페이지 parsing....
# 572 번째 페이지 parsing....
# 573 번째 페이지 parsing....
# 574 번째 페이지 parsing....
# 575 번째 페이지 parsing....
# 576 번째 페이지 parsing....
# 577 번째 페이지 parsing....
# 578 번째 페이지 parsing....
# 579 번째 페이지 parsing....
# 580 번째 페이지 parsing....
# 581 번째 페이지 parsing....
# 582 번째 페이지 parsing....
# 583 번째 페이지 parsing....
# 584 번째 페이지 parsing....
# 585 번째 페이지 parsing....
# 586 번째 페이지 parsing....
# 587 번째 페이지 parsing....
# 588 번째 페이지 parsing....
# 589 번째 페이지 parsing....
# 590 번째 페이지 parsing....
# 591 번째 페이지 parsing....
# 592 번째 페이지 parsing....
# 593 번째 페이지 parsing....
# 594 번째 페이지 parsing....
# 595 번째 페이지 parsing....
# 596 번째 페이지 parsing....
# 597 번째 페이지 parsing....
# 598 번째 페이지 parsing....
# 599 번째 페이지 parsing....
# 600 번째 페이지 parsing....
# 601 번째 페이지 parsing....
# 602 번째 페이지 parsing....
# 603 번째 페이지 parsing....
# 604 번째 페이지 parsing....
# 605 번째 페이지 parsing....
# 606 번째 페이지 parsing....
# 607 번째 페이지 parsing....
# 608 번째 페이지 parsing....
# 609 번째 페이지 parsing....
# 610 번째 페이지 parsing....
# 611 번째 페이지 parsing....
# 612 번째 페이지 parsing....
# 613 번째 페이지 parsing....
# 614 번째 페이지 parsing....
# 615 번째 페이지 parsing....
# 616 번째 페이지 parsing....
# 617 번째 페이지 parsing....
# 618 번째 페이지 parsing....
# 619 번째 페이지 parsing....
# 620 번째 페이지 parsing....
# 621 번째 페이지 parsing....
# 622 번째 페이지 parsing....
# 623 번째 페이지 parsing....
# 624 번째 페이지 parsing....
# 625 번째 페이지 parsing....
# 626 번째 페이지 parsing....
# 627 번째 페이지 parsing....
# 628 번째 페이지 parsing....
# 629 번째 페이지 parsing....
# 630 번째 페이지 parsing....
# 631 번째 페이지 parsing....
# 632 번째 페이지 parsing....
# 633 번째 페이지 parsing....
# 634 번째 페이지 parsing....
# 635 번째 페이지 parsing....
# 636 번째 페이지 parsing....
# 637 번째 페이지 parsing....
# 638 번째 페이지 parsing....
# 639 번째 페이지 parsing....
# 640 번째 페이지 parsing....
# 641 번째 페이지 parsing....
# 642 번째 페이지 parsing....
# 643 번째 페이지 parsing....
# 644 번째 페이지 parsing....
# 645 번째 페이지 parsing....
# 646 번째 페이지 parsing....
# 647 번째 페이지 parsing....
# 648 번째 페이지 parsing....
# 649 번째 페이지 parsing....
# 650 번째 페이지 parsing....
# 651 번째 페이지 parsing....
# 652 번째 페이지 parsing....
# 653 번째 페이지 parsing....
# 654 번째 페이지 parsing....
# 655 번째 페이지 parsing....
# 656 번째 페이지 parsing....
# 657 번째 페이지 parsing....
# 658 번째 페이지 parsing....
# 659 번째 페이지 parsing....
# 660 번째 페이지 parsing....
# 661 번째 페이지 parsing....
# 662 번째 페이지 parsing....
# 663 번째 페이지 parsing....
# 664 번째 페이지 parsing....
# 665 번째 페이지 parsing....
# 666 번째 페이지 parsing....
# 667 번째 페이지 parsing....
# 668 번째 페이지 parsing....
# 669 번째 페이지 parsing....
# 670 번째 페이지 parsing....
# 671 번째 페이지 parsing....
# 672 번째 페이지 parsing....
# 673 번째 페이지 parsing....
# 674 번째 페이지 parsing....
# 675 번째 페이지 parsing....
# 676 번째 페이지 parsing....
# 677 번째 페이지 parsing....
# 678 번째 페이지 parsing....
# 679 번째 페이지 parsing....
# 680 번째 페이지 parsing....
# 681 번째 페이지 parsing....
# 682 번째 페이지 parsing....
# 683 번째 페이지 parsing....
# 684 번째 페이지 parsing....
# 685 번째 페이지 parsing....
# 686 번째 페이지 parsing....
# 687 번째 페이지 parsing....
# 688 번째 페이지 parsing....
# 689 번째 페이지 parsing....
# 690 번째 페이지 parsing....
# 691 번째 페이지 parsing....
# 692 번째 페이지 parsing....
# 693 번째 페이지 parsing....
# 694 번째 페이지 parsing....
# 695 번째 페이지 parsing....
# 696 번째 페이지 parsing....
# 697 번째 페이지 parsing....
# 698 번째 페이지 parsing....
# 699 번째 페이지 parsing....
# 700 번째 페이지 parsing....
# 701 번째 페이지 parsing....
# 702 번째 페이지 parsing....
# 703 번째 페이지 parsing....
# 704 번째 페이지 parsing....
# 705 번째 페이지 parsing....
# 706 번째 페이지 parsing....
# 707 번째 페이지 parsing....
# 708 번째 페이지 parsing....
# 709 번째 페이지 parsing....
# 710 번째 페이지 parsing....
# 711 번째 페이지 parsing....
# 712 번째 페이지 parsing....
# 713 번째 페이지 parsing....
# 714 번째 페이지 parsing....
# 715 번째 페이지 parsing....
# 716 번째 페이지 parsing....
# 717 번째 페이지 parsing....
# 718 번째 페이지 parsing....
# 719 번째 페이지 parsing....
# 720 번째 페이지 parsing....
# 721 번째 페이지 parsing....
# 722 번째 페이지 parsing....
# 723 번째 페이지 parsing....
# 724 번째 페이지 parsing....
# 725 번째 페이지 parsing....
# 726 번째 페이지 parsing....
# 727 번째 페이지 parsing....
# 728 번째 페이지 parsing....
# 729 번째 페이지 parsing....
# 730 번째 페이지 parsing....
# 731 번째 페이지 parsing....
# 732 번째 페이지 parsing....
# 733 번째 페이지 parsing....
# 734 번째 페이지 parsing....
# 735 번째 페이지 parsing....
# 736 번째 페이지 parsing....
# 737 번째 페이지 parsing....
# 738 번째 페이지 parsing....
# 739 번째 페이지 parsing....
# 740 번째 페이지 parsing....
# 741 번째 페이지 parsing....
# 742 번째 페이지 parsing....
# 743 번째 페이지 parsing....
# 744 번째 페이지 parsing....
# 745 번째 페이지 parsing....
# 746 번째 페이지 parsing....
# 747 번째 페이지 parsing....
# 748 번째 페이지 parsing....
# 749 번째 페이지 parsing....
# 750 번째 페이지 parsing....
# 751 번째 페이지 parsing....
# 752 번째 페이지 parsing....
# 753 번째 페이지 parsing....
# 754 번째 페이지 parsing....
# 755 번째 페이지 parsing....
# 756 번째 페이지 parsing....
# 757 번째 페이지 parsing....
# 758 번째 페이지 parsing....
# 759 번째 페이지 parsing....
# 760 번째 페이지 parsing....
# 761 번째 페이지 parsing....
# 762 번째 페이지 parsing....
# 763 번째 페이지 parsing....
# 764 번째 페이지 parsing....
# 765 번째 페이지 parsing....
# 766 번째 페이지 parsing....
# 767 번째 페이지 parsing....
# 768 번째 페이지 parsing....
# 769 번째 페이지 parsing....
# 770 번째 페이지 parsing....
# 771 번째 페이지 parsing....
# 772 번째 페이지 parsing....
# 773 번째 페이지 parsing....
# 774 번째 페이지 parsing....
# 775 번째 페이지 parsing....
# 776 번째 페이지 parsing....
# 777 번째 페이지 parsing....
# 778 번째 페이지 parsing....
# 779 번째 페이지 parsing....
# 780 번째 페이지 parsing....
# 781 번째 페이지 parsing....
# 782 번째 페이지 parsing....
# 783 번째 페이지 parsing....
# 784 번째 페이지 parsing....
# 785 번째 페이지 parsing....
# 786 번째 페이지 parsing....
# 787 번째 페이지 parsing....
# 788 번째 페이지 parsing....
# 789 번째 페이지 parsing....
# 790 번째 페이지 parsing....
# 791 번째 페이지 parsing....
# 792 번째 페이지 parsing....
# 793 번째 페이지 parsing....
# 794 번째 페이지 parsing....
# 795 번째 페이지 parsing....
# 796 번째 페이지 parsing....
# 797 번째 페이지 parsing....
# 798 번째 페이지 parsing....
# 799 번째 페이지 parsing....
# 800 번째 페이지 parsing....
# 801 번째 페이지 parsing....
# 802 번째 페이지 parsing....
# 803 번째 페이지 parsing....
# 804 번째 페이지 parsing....
# 805 번째 페이지 parsing....
# 806 번째 페이지 parsing....
# 807 번째 페이지 parsing....
# 808 번째 페이지 parsing....
# 809 번째 페이지 parsing....
# 810 번째 페이지 parsing....
# 811 번째 페이지 parsing....
# 812 번째 페이지 parsing....
# 813 번째 페이지 parsing....
# 814 번째 페이지 parsing....
# 815 번째 페이지 parsing....
# 816 번째 페이지 parsing....
# 817 번째 페이지 parsing....
# 818 번째 페이지 parsing....
# 819 번째 페이지 parsing....
# 820 번째 페이지 parsing....
# 821 번째 페이지 parsing....
# 822 번째 페이지 parsing....
# 823 번째 페이지 parsing....
# 824 번째 페이지 parsing....
# 825 번째 페이지 parsing....
# 826 번째 페이지 parsing....
# 827 번째 페이지 parsing....
# 828 번째 페이지 parsing....
# 829 번째 페이지 parsing....
# 830 번째 페이지 parsing....
# 831 번째 페이지 parsing....
# 832 번째 페이지 parsing....
# 833 번째 페이지 parsing....
# 834 번째 페이지 parsing....
# 835 번째 페이지 parsing....
# 836 번째 페이지 parsing....
# 837 번째 페이지 parsing....
# 838 번째 페이지 parsing....
# 839 번째 페이지 parsing....
# 840 번째 페이지 parsing....
# 841 번째 페이지 parsing....
# 842 번째 페이지 parsing....
# 843 번째 페이지 parsing....
# 844 번째 페이지 parsing....
# 845 번째 페이지 parsing....
# 846 번째 페이지 parsing....
# 847 번째 페이지 parsing....
# 848 번째 페이지 parsing....
# 849 번째 페이지 parsing....
# 850 번째 페이지 parsing....
# 851 번째 페이지 parsing....
# 852 번째 페이지 parsing....
# 853 번째 페이지 parsing....
# 854 번째 페이지 parsing....
# 855 번째 페이지 parsing....
# 856 번째 페이지 parsing....
# 857 번째 페이지 parsing....
# 858 번째 페이지 parsing....
# 859 번째 페이지 parsing....
# 860 번째 페이지 parsing....
# 861 번째 페이지 parsing....
# 862 번째 페이지 parsing....
# 863 번째 페이지 parsing....
# 864 번째 페이지 parsing....
# 865 번째 페이지 parsing....
# 866 번째 페이지 parsing....
# 867 번째 페이지 parsing....
# 868 번째 페이지 parsing....
# 869 번째 페이지 parsing....
# 870 번째 페이지 parsing....
# 871 번째 페이지 parsing....
# 872 번째 페이지 parsing....
# 873 번째 페이지 parsing....
# 874 번째 페이지 parsing....
# 875 번째 페이지 parsing....
# 876 번째 페이지 parsing....
# 877 번째 페이지 parsing....
# 878 번째 페이지 parsing....
# 879 번째 페이지 parsing....
# 880 번째 페이지 parsing....
# 881 번째 페이지 parsing....
# 882 번째 페이지 parsing....
# 883 번째 페이지 parsing....
# 884 번째 페이지 parsing....
# 885 번째 페이지 parsing....
# 886 번째 페이지 parsing....
# 887 번째 페이지 parsing....
# 888 번째 페이지 parsing....
# 889 번째 페이지 parsing....
# 890 번째 페이지 parsing....
# 891 번째 페이지 parsing....
# 892 번째 페이지 parsing....
# 893 번째 페이지 parsing....
# 894 번째 페이지 parsing....
# 895 번째 페이지 parsing....
# 896 번째 페이지 parsing....
# 897 번째 페이지 parsing....
# 898 번째 페이지 parsing....
# 899 번째 페이지 parsing....
# 900 번째 페이지 parsing....
# 901 번째 페이지 parsing....
# 902 번째 페이지 parsing....
# 903 번째 페이지 parsing....
# 904 번째 페이지 parsing....
# 905 번째 페이지 parsing....
# 906 번째 페이지 parsing....
# 907 번째 페이지 parsing....
# 908 번째 페이지 parsing....
# 909 번째 페이지 parsing....
# 910 번째 페이지 parsing....
# 911 번째 페이지 parsing....
# 912 번째 페이지 parsing....
# 913 번째 페이지 parsing....
# 914 번째 페이지 parsing....
# 915 번째 페이지 parsing....
# 916 번째 페이지 parsing....
# 917 번째 페이지 parsing....
# 918 번째 페이지 parsing....
# 919 번째 페이지 parsing....
# 920 번째 페이지 parsing....
# 921 번째 페이지 parsing....
# 922 번째 페이지 parsing....
# 923 번째 페이지 parsing....
# 924 번째 페이지 parsing....
# 925 번째 페이지 parsing....
# 926 번째 페이지 parsing....
# 927 번째 페이지 parsing....
# 928 번째 페이지 parsing....
# 929 번째 페이지 parsing....
# 930 번째 페이지 parsing....
# 931 번째 페이지 parsing....
# 932 번째 페이지 parsing....
# 933 번째 페이지 parsing....
# 934 번째 페이지 parsing....
# 935 번째 페이지 parsing....
# 936 번째 페이지 parsing....
# 937 번째 페이지 parsing....
# 938 번째 페이지 parsing....
# 939 번째 페이지 parsing....
# 940 번째 페이지 parsing....
# 941 번째 페이지 parsing....
# 942 번째 페이지 parsing....
# 943 번째 페이지 parsing....
# 944 번째 페이지 parsing....
# 945 번째 페이지 parsing....
# 946 번째 페이지 parsing....
# 947 번째 페이지 parsing....
# 948 번째 페이지 parsing....
# 949 번째 페이지 parsing....
# 950 번째 페이지 parsing....
# 951 번째 페이지 parsing....
# 952 번째 페이지 parsing....
# 953 번째 페이지 parsing....
# 954 번째 페이지 parsing....
# 955 번째 페이지 parsing....
# 956 번째 페이지 parsing....
# 957 번째 페이지 parsing....
# 958 번째 페이지 parsing....
# 959 번째 페이지 parsing....
# 960 번째 페이지 parsing....
# 961 번째 페이지 parsing....
# 962 번째 페이지 parsing....
# 963 번째 페이지 parsing....
# 964 번째 페이지 parsing....
# 965 번째 페이지 parsing....
# 966 번째 페이지 parsing....
# 967 번째 페이지 parsing....
# 968 번째 페이지 parsing....
# 969 번째 페이지 parsing....
# 970 번째 페이지 parsing....
# 971 번째 페이지 parsing....
# 972 번째 페이지 parsing....
# 973 번째 페이지 parsing....
# 974 번째 페이지 parsing....
# 975 번째 페이지 parsing....
# 976 번째 페이지 parsing....
# 977 번째 페이지 parsing....
# 978 번째 페이지 parsing....
# 979 번째 페이지 parsing....
# 980 번째 페이지 parsing....
# 981 번째 페이지 parsing....
# 982 번째 페이지 parsing....
# 983 번째 페이지 parsing....
# 984 번째 페이지 parsing....
# 985 번째 페이지 parsing....
# 986 번째 페이지 parsing....
# 987 번째 페이지 parsing....
# 988 번째 페이지 parsing....
# 989 번째 페이지 parsing....
# 990 번째 페이지 parsing....
# 991 번째 페이지 parsing....
# 992 번째 페이지 parsing....
# 993 번째 페이지 parsing....
# 994 번째 페이지 parsing....
# 995 번째 페이지 parsing....
# 996 번째 페이지 parsing....
# 997 번째 페이지 parsing....
# 998 번째 페이지 parsing....
# 999 번째 페이지 parsing....
# 1000 번째 페이지 parsing....
# 1001 번째 페이지 parsing....
# 1002 번째 페이지 parsing....
# 1003 번째 페이지 parsing....
# 1004 번째 페이지 parsing....
# 1005 번째 페이지 parsing....
# 1006 번째 페이지 parsing....
# 1007 번째 페이지 parsing....
# 1008 번째 페이지 parsing....
# 1009 번째 페이지 parsing....
# 1010 번째 페이지 parsing....
# 1011 번째 페이지 parsing....
# 1012 번째 페이지 parsing....
# 1013 번째 페이지 parsing....
# 1014 번째 페이지 parsing....
# 1015 번째 페이지 parsing....
# 1016 번째 페이지 parsing....
# 1017 번째 페이지 parsing....
# 1018 번째 페이지 parsing....
# 1019 번째 페이지 parsing....
# 1020 번째 페이지 parsing....
# 1021 번째 페이지 parsing....
# 1022 번째 페이지 parsing....
# 1023 번째 페이지 parsing....
# 1024 번째 페이지 parsing....
# 1025 번째 페이지 parsing....
# 1026 번째 페이지 parsing....
# 1027 번째 페이지 parsing....
# 1028 번째 페이지 parsing....
# 1029 번째 페이지 parsing....
# 1030 번째 페이지 parsing....
# 1031 번째 페이지 parsing....
# 1032 번째 페이지 parsing....
# 1033 번째 페이지 parsing....
# 1034 번째 페이지 parsing....
# 1035 번째 페이지 parsing....
# 1036 번째 페이지 parsing....
# 1037 번째 페이지 parsing....
# 1038 번째 페이지 parsing....
# 1039 번째 페이지 parsing....
# 1040 번째 페이지 parsing....
# 1041 번째 페이지 parsing....
# 1042 번째 페이지 parsing....
# 1043 번째 페이지 parsing....
# 1044 번째 페이지 parsing....
# 1045 번째 페이지 parsing....
# 1046 번째 페이지 parsing....
# 1047 번째 페이지 parsing....
# 1048 번째 페이지 parsing....
# 1049 번째 페이지 parsing....
# 1050 번째 페이지 parsing....
# 1051 번째 페이지 parsing....
# 1052 번째 페이지 parsing....
# 1053 번째 페이지 parsing....
# 1054 번째 페이지 parsing....
# 1055 번째 페이지 parsing....
# 1056 번째 페이지 parsing....
# 1057 번째 페이지 parsing....
# 1058 번째 페이지 parsing....
# 1059 번째 페이지 parsing....
# 1060 번째 페이지 parsing....
# 1061 번째 페이지 parsing....
# 1062 번째 페이지 parsing....
# 1063 번째 페이지 parsing....
# 1064 번째 페이지 parsing....
# 1065 번째 페이지 parsing....
# 1066 번째 페이지 parsing....
# 1067 번째 페이지 parsing....
# 1068 번째 페이지 parsing....
# 1069 번째 페이지 parsing....
# 1070 번째 페이지 parsing....
# 1071 번째 페이지 parsing....
# 1072 번째 페이지 parsing....
# 1073 번째 페이지 parsing....
# 1074 번째 페이지 parsing....
# 1075 번째 페이지 parsing....
# 1076 번째 페이지 parsing....
# 1077 번째 페이지 parsing....
# 1078 번째 페이지 parsing....
# 1079 번째 페이지 parsing....
# 1080 번째 페이지 parsing....
# 1081 번째 페이지 parsing....
# 1082 번째 페이지 parsing....
# 1083 번째 페이지 parsing....
# 1084 번째 페이지 parsing....
# 1085 번째 페이지 parsing....
# 1086 번째 페이지 parsing....
# 1087 번째 페이지 parsing....
# 1088 번째 페이지 parsing....
# 1089 번째 페이지 parsing....
# 1090 번째 페이지 parsing....
# 1091 번째 페이지 parsing....
# 1092 번째 페이지 parsing....
# 1093 번째 페이지 parsing....
# 1094 번째 페이지 parsing....
# 1095 번째 페이지 parsing....
# 1096 번째 페이지 parsing....
# 1097 번째 페이지 parsing....
# 1098 번째 페이지 parsing....
# 1099 번째 페이지 parsing....
# 1100 번째 페이지 parsing....
# 1101 번째 페이지 parsing....
# 1102 번째 페이지 parsing....
# 1103 번째 페이지 parsing....
# 1104 번째 페이지 parsing....
# 1105 번째 페이지 parsing....
# 1106 번째 페이지 parsing....
# 1107 번째 페이지 parsing....
# 1108 번째 페이지 parsing....
# 1109 번째 페이지 parsing....
# 1110 번째 페이지 parsing....
# 1111 번째 페이지 parsing....
# 1112 번째 페이지 parsing....
# 1113 번째 페이지 parsing....
# 1114 번째 페이지 parsing....
# 1115 번째 페이지 parsing....
# 1116 번째 페이지 parsing....
# 1117 번째 페이지 parsing....
# 1118 번째 페이지 parsing....
# 1119 번째 페이지 parsing....
# 1120 번째 페이지 parsing....
# 1121 번째 페이지 parsing....
# 1122 번째 페이지 parsing....
# 1123 번째 페이지 parsing....
# 1124 번째 페이지 parsing....
# 1125 번째 페이지 parsing....
# 1126 번째 페이지 parsing....
# 1127 번째 페이지 parsing....
# 1128 번째 페이지 parsing....
# 1129 번째 페이지 parsing....
# 1130 번째 페이지 parsing....
# 1131 번째 페이지 parsing....
# 1132 번째 페이지 parsing....
# 1133 번째 페이지 parsing....
# 1134 번째 페이지 parsing....
# 1135 번째 페이지 parsing....
# 1136 번째 페이지 parsing....
# 1137 번째 페이지 parsing....
# 1138 번째 페이지 parsing....
# 1139 번째 페이지 parsing....
# 1140 번째 페이지 parsing....
# 1141 번째 페이지 parsing....
# 1142 번째 페이지 parsing....
# 1143 번째 페이지 parsing....
# 1144 번째 페이지 parsing....
# 1145 번째 페이지 parsing....
# 1146 번째 페이지 parsing....
# 1147 번째 페이지 parsing....
# 1148 번째 페이지 parsing....
# 1149 번째 페이지 parsing....
# 1150 번째 페이지 parsing....
# 1151 번째 페이지 parsing....
# 1152 번째 페이지 parsing....
# 1153 번째 페이지 parsing....
# 1154 번째 페이지 parsing....
# 1155 번째 페이지 parsing....
# 1156 번째 페이지 parsing....
# 1157 번째 페이지 parsing....
# 1158 번째 페이지 parsing....
# 1159 번째 페이지 parsing....
# 1160 번째 페이지 parsing....
# 1161 번째 페이지 parsing....
# 1162 번째 페이지 parsing....
# 1163 번째 페이지 parsing....
# 1164 번째 페이지 parsing....
# 1165 번째 페이지 parsing....
# 1166 번째 페이지 parsing....
# 1167 번째 페이지 parsing....
# 1168 번째 페이지 parsing....
# 1169 번째 페이지 parsing....
# 1170 번째 페이지 parsing....
# 1171 번째 페이지 parsing....
# 1172 번째 페이지 parsing....
# 1173 번째 페이지 parsing....
# 1174 번째 페이지 parsing....
# 1175 번째 페이지 parsing....
# 1176 번째 페이지 parsing....
# 1177 번째 페이지 parsing....
# 1178 번째 페이지 parsing....
# 1179 번째 페이지 parsing....
# 1180 번째 페이지 parsing....
# 1181 번째 페이지 parsing....
# 1182 번째 페이지 parsing....
# 1183 번째 페이지 parsing....
# 1184 번째 페이지 parsing....
# 1185 번째 페이지 parsing....
# 1186 번째 페이지 parsing....
# 1187 번째 페이지 parsing....
# 1188 번째 페이지 parsing....
# 1189 번째 페이지 parsing....
# 1190 번째 페이지 parsing....
# 1191 번째 페이지 parsing....
# 1192 번째 페이지 parsing....
# 1193 번째 페이지 parsing....
# 1194 번째 페이지 parsing....
# 1195 번째 페이지 parsing....
# 1196 번째 페이지 parsing....
# 1197 번째 페이지 parsing....
# 1198 번째 페이지 parsing....
# 1199 번째 페이지 parsing....
# 1200 번째 페이지 parsing....
# 1201 번째 페이지 parsing....
# 1202 번째 페이지 parsing....
# 1203 번째 페이지 parsing....
# 1204 번째 페이지 parsing....
# 1205 번째 페이지 parsing....
# 1206 번째 페이지 parsing....
# 1207 번째 페이지 parsing....
# 1208 번째 페이지 parsing....
# 1209 번째 페이지 parsing....
# 1210 번째 페이지 parsing....
# 1211 번째 페이지 parsing....
# 1212 번째 페이지 parsing....
# 1213 번째 페이지 parsing....
# 1214 번째 페이지 parsing....
# 1215 번째 페이지 parsing....
# 1216 번째 페이지 parsing....
# 1217 번째 페이지 parsing....
# 1218 번째 페이지 parsing....
# 1219 번째 페이지 parsing....
# 1220 번째 페이지 parsing....
# 1221 번째 페이지 parsing....
# 1222 번째 페이지 parsing....
# 1223 번째 페이지 parsing....
# 1224 번째 페이지 parsing....
# 1225 번째 페이지 parsing....
# 1226 번째 페이지 parsing....
# 1227 번째 페이지 parsing....
# 1228 번째 페이지 parsing....
# 1229 번째 페이지 parsing....
# 1230 번째 페이지 parsing....
# 1231 번째 페이지 parsing....
# 1232 번째 페이지 parsing....
# 1233 번째 페이지 parsing....
# 1234 번째 페이지 parsing....
# 1235 번째 페이지 parsing....
# 1236 번째 페이지 parsing....
# 1237 번째 페이지 parsing....
# 1238 번째 페이지 parsing....
# 1239 번째 페이지 parsing....
# 1240 번째 페이지 parsing....
# 1241 번째 페이지 parsing....
# 1242 번째 페이지 parsing....
# 1243 번째 페이지 parsing....
# 1244 번째 페이지 parsing....
# 1245 번째 페이지 parsing....
# 1246 번째 페이지 parsing....
# 1247 번째 페이지 parsing....
# 1248 번째 페이지 parsing....
# 1249 번째 페이지 parsing....
# 1250 번째 페이지 parsing....
# 1251 번째 페이지 parsing....
# 1252 번째 페이지 parsing....
# 1253 번째 페이지 parsing....
# 1254 번째 페이지 parsing....
# 1255 번째 페이지 parsing....
# 1256 번째 페이지 parsing....
# 1257 번째 페이지 parsing....
# 1258 번째 페이지 parsing....
# 1259 번째 페이지 parsing....
# 1260 번째 페이지 parsing....
# 1261 번째 페이지 parsing....
# 1262 번째 페이지 parsing....
# 1263 번째 페이지 parsing....
# 1264 번째 페이지 parsing....
# 1265 번째 페이지 parsing....
# 1266 번째 페이지 parsing....
# 1267 번째 페이지 parsing....
# 1268 번째 페이지 parsing....
# 1269 번째 페이지 parsing....
# 1270 번째 페이지 parsing....
# 1271 번째 페이지 parsing....
# 1272 번째 페이지 parsing....
# 1273 번째 페이지 parsing....
# 1274 번째 페이지 parsing....
# 1275 번째 페이지 parsing....
# 1276 번째 페이지 parsing....
# 1277 번째 페이지 parsing....
# 1278 번째 페이지 parsing....
# 1279 번째 페이지 parsing....
# 1280 번째 페이지 parsing....
# 1281 번째 페이지 parsing....
# 1282 번째 페이지 parsing....
# 1283 번째 페이지 parsing....
# 1284 번째 페이지 parsing....
# 1285 번째 페이지 parsing....
# 1286 번째 페이지 parsing....
# 1287 번째 페이지 parsing....
# 1288 번째 페이지 parsing....
# 1289 번째 페이지 parsing....
# 1290 번째 페이지 parsing....
# 1291 번째 페이지 parsing....
# 1292 번째 페이지 parsing....
# 1293 번째 페이지 parsing....
# 1294 번째 페이지 parsing....
# 1295 번째 페이지 parsing....
# 1296 번째 페이지 parsing....
# 1297 번째 페이지 parsing....
# 1298 번째 페이지 parsing....
# 1299 번째 페이지 parsing....
# 1300 번째 페이지 parsing....
# 1301 번째 페이지 parsing....
# 1302 번째 페이지 parsing....
# 1303 번째 페이지 parsing....
# 1304 번째 페이지 parsing....
# 1305 번째 페이지 parsing....
# 1306 번째 페이지 parsing....
# 1307 번째 페이지 parsing....
# 1308 번째 페이지 parsing....
# 1309 번째 페이지 parsing....
# 1310 번째 페이지 parsing....
# 1311 번째 페이지 parsing....
# 1312 번째 페이지 parsing....
# 1313 번째 페이지 parsing....
# 1314 번째 페이지 parsing....
# 1315 번째 페이지 parsing....
# 1316 번째 페이지 parsing....
# 1317 번째 페이지 parsing....
# 1318 번째 페이지 parsing....
# 1319 번째 페이지 parsing....
# 1320 번째 페이지 parsing....
# 1321 번째 페이지 parsing....
# 1322 번째 페이지 parsing....
# 1323 번째 페이지 parsing....
# 1324 번째 페이지 parsing....
# 1325 번째 페이지 parsing....
# 1326 번째 페이지 parsing....
# 1327 번째 페이지 parsing....
# 1328 번째 페이지 parsing....
# 1329 번째 페이지 parsing....
# 1330 번째 페이지 parsing....
# 1331 번째 페이지 parsing....
# 1332 번째 페이지 parsing....
# 1333 번째 페이지 parsing....
# 1334 번째 페이지 parsing....
# 1335 번째 페이지 parsing....
# 1336 번째 페이지 parsing....
# 1337 번째 페이지 parsing....
# 1338 번째 페이지 parsing....
# 1339 번째 페이지 parsing....
# 1340 번째 페이지 parsing....
# 1341 번째 페이지 parsing....
# 1342 번째 페이지 parsing....
# 1343 번째 페이지 parsing....
# 1344 번째 페이지 parsing....
# 1345 번째 페이지 parsing....
# 1346 번째 페이지 parsing....
# 1347 번째 페이지 parsing....
# 1348 번째 페이지 parsing....
# 1349 번째 페이지 parsing....
# 1350 번째 페이지 parsing....
# 1351 번째 페이지 parsing....
# 1352 번째 페이지 parsing....
# 1353 번째 페이지 parsing....
# 1354 번째 페이지 parsing....
# 1355 번째 페이지 parsing....
# 1356 번째 페이지 parsing....
# 1357 번째 페이지 parsing....
# 1358 번째 페이지 parsing....
# 1359 번째 페이지 parsing....
# 1360 번째 페이지 parsing....
# 1361 번째 페이지 parsing....
# 1362 번째 페이지 parsing....
# 1363 번째 페이지 parsing....
# 1364 번째 페이지 parsing....
# 1365 번째 페이지 parsing....
# 1366 번째 페이지 parsing....
# 1367 번째 페이지 parsing....
# 1368 번째 페이지 parsing....
# 1369 번째 페이지 parsing....
# 1370 번째 페이지 parsing....
# 1371 번째 페이지 parsing....
# 1372 번째 페이지 parsing....
# 1373 번째 페이지 parsing....
# 1374 번째 페이지 parsing....
# 1375 번째 페이지 parsing....
# 1376 번째 페이지 parsing....
# 1377 번째 페이지 parsing....
# 1378 번째 페이지 parsing....
# 1379 번째 페이지 parsing....
# 1380 번째 페이지 parsing....
# 1381 번째 페이지 parsing....
# 1382 번째 페이지 parsing....
# 1383 번째 페이지 parsing....
# 1384 번째 페이지 parsing....
# 1385 번째 페이지 parsing....
# 1386 번째 페이지 parsing....
# 1387 번째 페이지 parsing....
# 1388 번째 페이지 parsing....
# 1389 번째 페이지 parsing....
# 1390 번째 페이지 parsing....
# 1391 번째 페이지 parsing....
# 1392 번째 페이지 parsing....
# 1393 번째 페이지 parsing....
# 1394 번째 페이지 parsing....
# 1395 번째 페이지 parsing....
# 1396 번째 페이지 parsing....
# 1397 번째 페이지 parsing....
# 1398 번째 페이지 parsing....
# 1399 번째 페이지 parsing....
# 1400 번째 페이지 parsing....
# 1401 번째 페이지 parsing....
# 1402 번째 페이지 parsing....
# 1403 번째 페이지 parsing....
# 1404 번째 페이지 parsing....
# 1405 번째 페이지 parsing....
# 1406 번째 페이지 parsing....
# 1407 번째 페이지 parsing....
# 1408 번째 페이지 parsing....
# 1409 번째 페이지 parsing....
# 1410 번째 페이지 parsing....
# 1411 번째 페이지 parsing....
# 1412 번째 페이지 parsing....
# 1413 번째 페이지 parsing....
# 1414 번째 페이지 parsing....
# 1415 번째 페이지 parsing....
# 1416 번째 페이지 parsing....
# 1417 번째 페이지 parsing....
# 1418 번째 페이지 parsing....
# 1419 번째 페이지 parsing....
# 1420 번째 페이지 parsing....
# 1421 번째 페이지 parsing....
# 1422 번째 페이지 parsing....
# 1423 번째 페이지 parsing....
# 1424 번째 페이지 parsing....
# 1425 번째 페이지 parsing....
# 1426 번째 페이지 parsing....
# 1427 번째 페이지 parsing....
# 1428 번째 페이지 parsing....
# 1429 번째 페이지 parsing....
# 1430 번째 페이지 parsing....
# 1431 번째 페이지 parsing....
# 1432 번째 페이지 parsing....
# 1433 번째 페이지 parsing....
# 1434 번째 페이지 parsing....
# 1435 번째 페이지 parsing....
# 1436 번째 페이지 parsing....
# 1437 번째 페이지 parsing....
# 1438 번째 페이지 parsing....
# 1439 번째 페이지 parsing....
# 1440 번째 페이지 parsing....
# 1441 번째 페이지 parsing....
# 1442 번째 페이지 parsing....
# 1443 번째 페이지 parsing....
# 1444 번째 페이지 parsing....
# 1445 번째 페이지 parsing....
# 1446 번째 페이지 parsing....
# 1447 번째 페이지 parsing....
# 1448 번째 페이지 parsing....
# 1449 번째 페이지 parsing....
# 1450 번째 페이지 parsing....
# 1451 번째 페이지 parsing....
# 1452 번째 페이지 parsing....
# 1453 번째 페이지 parsing....
# 1454 번째 페이지 parsing....
# 1455 번째 페이지 parsing....
# 1456 번째 페이지 parsing....
# 1457 번째 페이지 parsing....
# 1458 번째 페이지 parsing....
# 1459 번째 페이지 parsing....
# 1460 번째 페이지 parsing....
# 1461 번째 페이지 parsing....
# 1462 번째 페이지 parsing....
# 1463 번째 페이지 parsing....
# 1464 번째 페이지 parsing....
# 1465 번째 페이지 parsing....
# 1466 번째 페이지 parsing....
# 1467 번째 페이지 parsing....
# 1468 번째 페이지 parsing....
# 1469 번째 페이지 parsing....
# 1470 번째 페이지 parsing....
# 1471 번째 페이지 parsing....
# 1472 번째 페이지 parsing....
# 1473 번째 페이지 parsing....
# 1474 번째 페이지 parsing....
# 1475 번째 페이지 parsing....
# 1476 번째 페이지 parsing....
# 1477 번째 페이지 parsing....
# 1478 번째 페이지 parsing....
# 1479 번째 페이지 parsing....
# 1480 번째 페이지 parsing....
# 1481 번째 페이지 parsing....
# 1482 번째 페이지 parsing....
# 1483 번째 페이지 parsing....
# 1484 번째 페이지 parsing....
# 1485 번째 페이지 parsing....
# 1486 번째 페이지 parsing....
# 1487 번째 페이지 parsing....
# 1488 번째 페이지 parsing....
# 1489 번째 페이지 parsing....
# 1490 번째 페이지 parsing....
# 1491 번째 페이지 parsing....
# 1492 번째 페이지 parsing....
# 1493 번째 페이지 parsing....
# 1494 번째 페이지 parsing....
# 1495 번째 페이지 parsing....
# 1496 번째 페이지 parsing....
# 1497 번째 페이지 parsing....
# 1498 번째 페이지 parsing....
# 1499 번째 페이지 parsing....
# 1500 번째 페이지 parsing....
# 1501 번째 페이지 parsing....
# 1502 번째 페이지 parsing....
# 1503 번째 페이지 parsing....
# 1504 번째 페이지 parsing....
# 1505 번째 페이지 parsing....
# 1506 번째 페이지 parsing....
# 1507 번째 페이지 parsing....
# 1508 번째 페이지 parsing....
# 1509 번째 페이지 parsing....
# 1510 번째 페이지 parsing....
# 1511 번째 페이지 parsing....
# 1512 번째 페이지 parsing....
# 1513 번째 페이지 parsing....
# 1514 번째 페이지 parsing....
# 1515 번째 페이지 parsing....
# 1516 번째 페이지 parsing....
# 1517 번째 페이지 parsing....
# 1518 번째 페이지 parsing....
# 1519 번째 페이지 parsing....
# 1520 번째 페이지 parsing....
# 1521 번째 페이지 parsing....
# 1522 번째 페이지 parsing....
# 1523 번째 페이지 parsing....
# 1524 번째 페이지 parsing....
# 1525 번째 페이지 parsing....
# 1526 번째 페이지 parsing....
# 1527 번째 페이지 parsing....
# 1528 번째 페이지 parsing....
# 1529 번째 페이지 parsing....
# 1530 번째 페이지 parsing....
# 1531 번째 페이지 parsing....
# 1532 번째 페이지 parsing....
# 1533 번째 페이지 parsing....
# 1534 번째 페이지 parsing....
# 1535 번째 페이지 parsing....
# 1536 번째 페이지 parsing....
# 1537 번째 페이지 parsing....
# 1538 번째 페이지 parsing....
# 1539 번째 페이지 parsing....
# 1540 번째 페이지 parsing....
# 1541 번째 페이지 parsing....
# 1542 번째 페이지 parsing....
# 1543 번째 페이지 parsing....
# 1544 번째 페이지 parsing....
# 1545 번째 페이지 parsing....
# 1546 번째 페이지 parsing....
# 1547 번째 페이지 parsing....
# 1548 번째 페이지 parsing....
# 1549 번째 페이지 parsing....
# 1550 번째 페이지 parsing....
# 1551 번째 페이지 parsing....
# 1552 번째 페이지 parsing....
# 1553 번째 페이지 parsing....
# 1554 번째 페이지 parsing....
# 1555 번째 페이지 parsing....
# 1556 번째 페이지 parsing....
# 1557 번째 페이지 parsing....
# 1558 번째 페이지 parsing....
# 1559 번째 페이지 parsing....
# 1560 번째 페이지 parsing....
# 1561 번째 페이지 parsing....
# 1562 번째 페이지 parsing....
# 1563 번째 페이지 parsing....
# 1564 번째 페이지 parsing....
# 1565 번째 페이지 parsing....
# 1566 번째 페이지 parsing....
# 1567 번째 페이지 parsing....
# 1568 번째 페이지 parsing....
# 1569 번째 페이지 parsing....
# 1570 번째 페이지 parsing....
# 1571 번째 페이지 parsing....
# 1572 번째 페이지 parsing....
# 1573 번째 페이지 parsing....
# 1574 번째 페이지 parsing....
# 1575 번째 페이지 parsing....
# 1576 번째 페이지 parsing....
# 1577 번째 페이지 parsing....
# 1578 번째 페이지 parsing....
# 1579 번째 페이지 parsing....
# 1580 번째 페이지 parsing....
# 1581 번째 페이지 parsing....
# 1582 번째 페이지 parsing....
# 1583 번째 페이지 parsing....
# 1584 번째 페이지 parsing....
# 1585 번째 페이지 parsing....
# 1586 번째 페이지 parsing....
# 1587 번째 페이지 parsing....
# 1588 번째 페이지 parsing....
# 1589 번째 페이지 parsing....
# 1590 번째 페이지 parsing....
# 1591 번째 페이지 parsing....
# 1592 번째 페이지 parsing....
# 1593 번째 페이지 parsing....
# 1594 번째 페이지 parsing....
# 1595 번째 페이지 parsing....
# 1596 번째 페이지 parsing....
# 1597 번째 페이지 parsing....
# 1598 번째 페이지 parsing....
# 1599 번째 페이지 parsing....
# 1600 번째 페이지 parsing....
# 1601 번째 페이지 parsing....
# 1602 번째 페이지 parsing....
# 1603 번째 페이지 parsing....
# 1604 번째 페이지 parsing....
# 1605 번째 페이지 parsing....
# 1606 번째 페이지 parsing....
# 1607 번째 페이지 parsing....
# 1608 번째 페이지 parsing....
# 1609 번째 페이지 parsing....
# 1610 번째 페이지 parsing....
# 1611 번째 페이지 parsing....
# 1612 번째 페이지 parsing....
# 1613 번째 페이지 parsing....
# 1614 번째 페이지 parsing....
# 1615 번째 페이지 parsing....
# 1616 번째 페이지 parsing....
# 1617 번째 페이지 parsing....
# 1618 번째 페이지 parsing....
# 1619 번째 페이지 parsing....
# 1620 번째 페이지 parsing....
# 1621 번째 페이지 parsing....
# 1622 번째 페이지 parsing....
# 1623 번째 페이지 parsing....
# 1624 번째 페이지 parsing....
# 1625 번째 페이지 parsing....
# 1626 번째 페이지 parsing....
# 1627 번째 페이지 parsing....
# 1628 번째 페이지 parsing....
# 1629 번째 페이지 parsing....
# 1630 번째 페이지 parsing....
# 1631 번째 페이지 parsing....
# 1632 번째 페이지 parsing....
# 1633 번째 페이지 parsing....
# 1634 번째 페이지 parsing....
# 1635 번째 페이지 parsing....
# 1636 번째 페이지 parsing....
# 1637 번째 페이지 parsing....
# 1638 번째 페이지 parsing....
# 1639 번째 페이지 parsing....
# 1640 번째 페이지 parsing....
# 1641 번째 페이지 parsing....
# 1642 번째 페이지 parsing....
# 1643 번째 페이지 parsing....
# 1644 번째 페이지 parsing....
# 1645 번째 페이지 parsing....
# 1646 번째 페이지 parsing....
# 1647 번째 페이지 parsing....
# 1648 번째 페이지 parsing....
# 1649 번째 페이지 parsing....
# 1650 번째 페이지 parsing....
# 1651 번째 페이지 parsing....
# 1652 번째 페이지 parsing....
# 1653 번째 페이지 parsing....
# 1654 번째 페이지 parsing....
# 1655 번째 페이지 parsing....
# 1656 번째 페이지 parsing....
# 1657 번째 페이지 parsing....
# 1658 번째 페이지 parsing....
# 1659 번째 페이지 parsing....
# 1660 번째 페이지 parsing....
# 1661 번째 페이지 parsing....
# 1662 번째 페이지 parsing....
# 1663 번째 페이지 parsing....
# 1664 번째 페이지 parsing....
# 1665 번째 페이지 parsing....
# 1666 번째 페이지 parsing....
# 1667 번째 페이지 parsing....
# 1668 번째 페이지 parsing....
# 1669 번째 페이지 parsing....
# 1670 번째 페이지 parsing....
# 1671 번째 페이지 parsing....
# 1672 번째 페이지 parsing....
# 1673 번째 페이지 parsing....
# 1674 번째 페이지 parsing....
# 1675 번째 페이지 parsing....
# 1676 번째 페이지 parsing....
# 1677 번째 페이지 parsing....
# 1678 번째 페이지 parsing....
# 1679 번째 페이지 parsing....
# 1680 번째 페이지 parsing....
# 1681 번째 페이지 parsing....
# 1682 번째 페이지 parsing....
# 1683 번째 페이지 parsing....
# 1684 번째 페이지 parsing....
# 1685 번째 페이지 parsing....
# 1686 번째 페이지 parsing....
# 1687 번째 페이지 parsing....
# 1688 번째 페이지 parsing....
# 1689 번째 페이지 parsing....
# 1690 번째 페이지 parsing....
# 1691 번째 페이지 parsing....
# 1692 번째 페이지 parsing....
# 1693 번째 페이지 parsing....
# 1694 번째 페이지 parsing....
# 1695 번째 페이지 parsing....
# 1696 번째 페이지 parsing....
# 1697 번째 페이지 parsing....
# 1698 번째 페이지 parsing....
# 1699 번째 페이지 parsing....
# 1700 번째 페이지 parsing....
# 1701 번째 페이지 parsing....
# 1702 번째 페이지 parsing....
# 1703 번째 페이지 parsing....
# 1704 번째 페이지 parsing....
# 1705 번째 페이지 parsing....
# 1706 번째 페이지 parsing....
# 1707 번째 페이지 parsing....
# 1708 번째 페이지 parsing....
# 1709 번째 페이지 parsing....
# 1710 번째 페이지 parsing....
# 1711 번째 페이지 parsing....
# 1712 번째 페이지 parsing....
# 1713 번째 페이지 parsing....
# 1714 번째 페이지 parsing....
# 1715 번째 페이지 parsing....
# 1716 번째 페이지 parsing....
# 1717 번째 페이지 parsing....
# 1718 번째 페이지 parsing....
# 1719 번째 페이지 parsing....
# 1720 번째 페이지 parsing....
# 1721 번째 페이지 parsing....
# 1722 번째 페이지 parsing....
# 1723 번째 페이지 parsing....
# 1724 번째 페이지 parsing....
# 1725 번째 페이지 parsing....
# 1726 번째 페이지 parsing....
# 1727 번째 페이지 parsing....
# 1728 번째 페이지 parsing....
# 1729 번째 페이지 parsing....
# 1730 번째 페이지 parsing....
# 1731 번째 페이지 parsing....
# 1732 번째 페이지 parsing....
# 1733 번째 페이지 parsing....
# 1734 번째 페이지 parsing....
# 1735 번째 페이지 parsing....
# 1736 번째 페이지 parsing....
# 1737 번째 페이지 parsing....
# 1738 번째 페이지 parsing....
# 1739 번째 페이지 parsing....
# 1740 번째 페이지 parsing....
# 1741 번째 페이지 parsing....
# 1742 번째 페이지 parsing....
# 1743 번째 페이지 parsing....
# 1744 번째 페이지 parsing....
# 1745 번째 페이지 parsing....
# 1746 번째 페이지 parsing....
# 1747 번째 페이지 parsing....
# 1748 번째 페이지 parsing....
# 1749 번째 페이지 parsing....
# 1750 번째 페이지 parsing....
# 1751 번째 페이지 parsing....
# 1752 번째 페이지 parsing....
# 1753 번째 페이지 parsing....
# 1754 번째 페이지 parsing....
# 1755 번째 페이지 parsing....
# 1756 번째 페이지 parsing....
# 1757 번째 페이지 parsing....
# 1758 번째 페이지 parsing....
# 1759 번째 페이지 parsing....
# 1760 번째 페이지 parsing....
# 1761 번째 페이지 parsing....
# 1762 번째 페이지 parsing....
# 1763 번째 페이지 parsing....
# 1764 번째 페이지 parsing....
# 1765 번째 페이지 parsing....
# 1766 번째 페이지 parsing....
# 1767 번째 페이지 parsing....
# 1768 번째 페이지 parsing....
# 1769 번째 페이지 parsing....
# 1770 번째 페이지 parsing....
# 1771 번째 페이지 parsing....
# 1772 번째 페이지 parsing....
# 1773 번째 페이지 parsing....
# 1774 번째 페이지 parsing....
# 1775 번째 페이지 parsing....
# 1776 번째 페이지 parsing....
# 1777 번째 페이지 parsing....
# 1778 번째 페이지 parsing....
# 1779 번째 페이지 parsing....
# 1780 번째 페이지 parsing....
# 1781 번째 페이지 parsing....
# 1782 번째 페이지 parsing....
# 1783 번째 페이지 parsing....
# 1784 번째 페이지 parsing....
# 1785 번째 페이지 parsing....
# 1786 번째 페이지 parsing....
# 1787 번째 페이지 parsing....
# 1788 번째 페이지 parsing....
# 1789 번째 페이지 parsing....
# 1790 번째 페이지 parsing....
# 1791 번째 페이지 parsing....
# 1792 번째 페이지 parsing....
# 1793 번째 페이지 parsing....
# 1794 번째 페이지 parsing....
# 1795 번째 페이지 parsing....
# 1796 번째 페이지 parsing....
# 1797 번째 페이지 parsing....
# 1798 번째 페이지 parsing....
# 1799 번째 페이지 parsing....
# 1800 번째 페이지 parsing....
# 1801 번째 페이지 parsing....
# 1802 번째 페이지 parsing....
# 1803 번째 페이지 parsing....
# 1804 번째 페이지 parsing....
# 1805 번째 페이지 parsing....
# 1806 번째 페이지 parsing....
# 1807 번째 페이지 parsing....
# 1808 번째 페이지 parsing....
# 1809 번째 페이지 parsing....
# 1810 번째 페이지 parsing....
# 1811 번째 페이지 parsing....
# 1812 번째 페이지 parsing....
# 1813 번째 페이지 parsing....
# 1814 번째 페이지 parsing....
# 1815 번째 페이지 parsing....
# 1816 번째 페이지 parsing....
# 1817 번째 페이지 parsing....
# 1818 번째 페이지 parsing....
# 1819 번째 페이지 parsing....
# 1820 번째 페이지 parsing....
# 1821 번째 페이지 parsing....
# 1822 번째 페이지 parsing....
# 1823 번째 페이지 parsing....
# 1824 번째 페이지 parsing....
# 1825 번째 페이지 parsing....
# 1826 번째 페이지 parsing....
# 1827 번째 페이지 parsing....
# 1828 번째 페이지 parsing....
# 1829 번째 페이지 parsing....
# 1830 번째 페이지 parsing....
# 1831 번째 페이지 parsing....
# 1832 번째 페이지 parsing....
# 1833 번째 페이지 parsing....
# 1834 번째 페이지 parsing....
# 1835 번째 페이지 parsing....
# 1836 번째 페이지 parsing....
# 1837 번째 페이지 parsing....
# 1838 번째 페이지 parsing....
# 1839 번째 페이지 parsing....
# 1840 번째 페이지 parsing....
# 1841 번째 페이지 parsing....
# 1842 번째 페이지 parsing....
# 1843 번째 페이지 parsing....
# 1844 번째 페이지 parsing....
# 1845 번째 페이지 parsing....
# 1846 번째 페이지 parsing....
# 1847 번째 페이지 parsing....
# 1848 번째 페이지 parsing....
# 1849 번째 페이지 parsing....
# 1850 번째 페이지 parsing....
# 1851 번째 페이지 parsing....
# 1852 번째 페이지 parsing....
# 1853 번째 페이지 parsing....
# 1854 번째 페이지 parsing....
# 1855 번째 페이지 parsing....
# 1856 번째 페이지 parsing....
# 1857 번째 페이지 parsing....
# 1858 번째 페이지 parsing....
# 1859 번째 페이지 parsing....
# 1860 번째 페이지 parsing....
# 1861 번째 페이지 parsing....
# 1862 번째 페이지 parsing....
# 1863 번째 페이지 parsing....
# 1864 번째 페이지 parsing....
# 1865 번째 페이지 parsing....
# 1866 번째 페이지 parsing....
# 1867 번째 페이지 parsing....
# 1868 번째 페이지 parsing....
# 1869 번째 페이지 parsing....
# 1870 번째 페이지 parsing....
# 1871 번째 페이지 parsing....
# 1872 번째 페이지 parsing....
# 1873 번째 페이지 parsing....
# 1874 번째 페이지 parsing....
# 1875 번째 페이지 parsing....
# 1876 번째 페이지 parsing....
# 1877 번째 페이지 parsing....
# 1878 번째 페이지 parsing....
# 1879 번째 페이지 parsing....
# 1880 번째 페이지 parsing....
# 1881 번째 페이지 parsing....
# 1882 번째 페이지 parsing....
# 1883 번째 페이지 parsing....
# 1884 번째 페이지 parsing....
# 1885 번째 페이지 parsing....
# 1886 번째 페이지 parsing....
# 1887 번째 페이지 parsing....
# 1888 번째 페이지 parsing....
# 1889 번째 페이지 parsing....
# 1890 번째 페이지 parsing....
# 1891 번째 페이지 parsing....
# 1892 번째 페이지 parsing....
# 1893 번째 페이지 parsing....
# 1894 번째 페이지 parsing....
# 1895 번째 페이지 parsing....
# 1896 번째 페이지 parsing....
# 1897 번째 페이지 parsing....
# 1898 번째 페이지 parsing....
# 1899 번째 페이지 parsing....
# 1900 번째 페이지 parsing....
# 1901 번째 페이지 parsing....
# 1902 번째 페이지 parsing....
# 1903 번째 페이지 parsing....
# 1904 번째 페이지 parsing....
# 1905 번째 페이지 parsing....
# 1906 번째 페이지 parsing....
# 1907 번째 페이지 parsing....
# 1908 번째 페이지 parsing....
# 1909 번째 페이지 parsing....
# 1910 번째 페이지 parsing....
# 1911 번째 페이지 parsing....
# 1912 번째 페이지 parsing....
# 1913 번째 페이지 parsing....
# 1914 번째 페이지 parsing....
# 1915 번째 페이지 parsing....
# 1916 번째 페이지 parsing....
# 1917 번째 페이지 parsing....
# 1918 번째 페이지 parsing....
# 1919 번째 페이지 parsing....
# 1920 번째 페이지 parsing....
# 1921 번째 페이지 parsing....
# 1922 번째 페이지 parsing....
# 1923 번째 페이지 parsing....
# 1924 번째 페이지 parsing....
# 1925 번째 페이지 parsing....
# 1926 번째 페이지 parsing....
# 1927 번째 페이지 parsing....
# 1928 번째 페이지 parsing....
# 1929 번째 페이지 parsing....
# 1930 번째 페이지 parsing....
# 1931 번째 페이지 parsing....
# 1932 번째 페이지 parsing....
# 1933 번째 페이지 parsing....
# 1934 번째 페이지 parsing....
# 1935 번째 페이지 parsing....
# 1936 번째 페이지 parsing....
# 1937 번째 페이지 parsing....
# 1938 번째 페이지 parsing....
# 1939 번째 페이지 parsing....
# 1940 번째 페이지 parsing....
# 1941 번째 페이지 parsing....
# 1942 번째 페이지 parsing....
# 1943 번째 페이지 parsing....
# 1944 번째 페이지 parsing....
# 1945 번째 페이지 parsing....
# 1946 번째 페이지 parsing....
# 1947 번째 페이지 parsing....
# 1948 번째 페이지 parsing....
# 1949 번째 페이지 parsing....
# 1950 번째 페이지 parsing....
# 1951 번째 페이지 parsing....
# 1952 번째 페이지 parsing....
# 1953 번째 페이지 parsing....
# 1954 번째 페이지 parsing....
# 1955 번째 페이지 parsing....
# 1956 번째 페이지 parsing....
# 1957 번째 페이지 parsing....
# 1958 번째 페이지 parsing....
# 1959 번째 페이지 parsing....
# 1960 번째 페이지 parsing....
# 1961 번째 페이지 parsing....
# 1962 번째 페이지 parsing....
# 1963 번째 페이지 parsing....
# 1964 번째 페이지 parsing....
# 1965 번째 페이지 parsing....
# 1966 번째 페이지 parsing....
# 1967 번째 페이지 parsing....
# 1968 번째 페이지 parsing....
# 1969 번째 페이지 parsing....
# 1970 번째 페이지 parsing....
# 1971 번째 페이지 parsing....
# 1972 번째 페이지 parsing....
# 1973 번째 페이지 parsing....
# 1974 번째 페이지 parsing....
# 1975 번째 페이지 parsing....
# 1976 번째 페이지 parsing....
# 1977 번째 페이지 parsing....
# 1978 번째 페이지 parsing....
# 1979 번째 페이지 parsing....
# 1980 번째 페이지 parsing....
# 1981 번째 페이지 parsing....
# 1982 번째 페이지 parsing....
# 1983 번째 페이지 parsing....
# 1984 번째 페이지 parsing....
# 1985 번째 페이지 parsing....
# 1986 번째 페이지 parsing....
# 1987 번째 페이지 parsing....
# 1988 번째 페이지 parsing....
# 1989 번째 페이지 parsing....
# 1990 번째 페이지 parsing....
# 1991 번째 페이지 parsing....
# 1992 번째 페이지 parsing....
# 1993 번째 페이지 parsing....
# 1994 번째 페이지 parsing....
# 1995 번째 페이지 parsing....
# 1996 번째 페이지 parsing....
# 1997 번째 페이지 parsing....
# 1998 번째 페이지 parsing....
# 1999 번째 페이지 parsing....
# 2000 번째 페이지 parsing....
# 2001 번째 페이지 parsing....
# 2002 번째 페이지 parsing....
# 2003 번째 페이지 parsing....
# 2004 번째 페이지 parsing....
# 2005 번째 페이지 parsing....
# 2006 번째 페이지 parsing....
# 2007 번째 페이지 parsing....
# 2008 번째 페이지 parsing....
# 2009 번째 페이지 parsing....
# 2010 번째 페이지 parsing....
# 2011 번째 페이지 parsing....
# 2012 번째 페이지 parsing....
# 2013 번째 페이지 parsing....
# 2014 번째 페이지 parsing....
# 2015 번째 페이지 parsing....
# 2016 번째 페이지 parsing....
# 2017 번째 페이지 parsing....
# 2018 번째 페이지 parsing....
# 2019 번째 페이지 parsing....
# 2020 번째 페이지 parsing....
# 2021 번째 페이지 parsing....
# 2022 번째 페이지 parsing....
# 2023 번째 페이지 parsing....
# 2024 번째 페이지 parsing....
# 2025 번째 페이지 parsing....
# 2026 번째 페이지 parsing....
# 2027 번째 페이지 parsing....
# 2028 번째 페이지 parsing....
# 2029 번째 페이지 parsing....
# 2030 번째 페이지 parsing....
# 2031 번째 페이지 parsing....
# 2032 번째 페이지 parsing....
# 2033 번째 페이지 parsing....
# 2034 번째 페이지 parsing....
# 2035 번째 페이지 parsing....
# 2036 번째 페이지 parsing....
# 2037 번째 페이지 parsing....
# 2038 번째 페이지 parsing....
# 2039 번째 페이지 parsing....
# 2040 번째 페이지 parsing....
# 2041 번째 페이지 parsing....
# 2042 번째 페이지 parsing....
# 2043 번째 페이지 parsing....
# 2044 번째 페이지 parsing....
# 2045 번째 페이지 parsing....
# 2046 번째 페이지 parsing....
# ...
# 3213 번째 페이지 parsing....
# 3214 번째 페이지 parsing....
# 3215 번째 페이지 parsing....
# 3216 번째 페이지 parsing....
# 3217 번째 페이지 parsing....
# 3218 번째 페이지 parsing....
# 3219 번째 페이지 parsing....
# 3220 번째 페이지 parsing....
# 3221 번째 페이지 parsing....
# 3222 번째 페이지 parsing....
# 3223 번째 페이지 parsing....
# 3224 번째 페이지 parsing....
# 3225 번째 페이지 parsing....
# 3226 번째 페이지 parsing....
# 3227 번째 페이지 parsing....
# 3228 번째 페이지 parsing....
# 3229 번째 페이지 parsing....
# 3230 번째 페이지 parsing....
# 3231 번째 페이지 parsing....
# 3232 번째 페이지 parsing....
# 3233 번째 페이지 parsing....
# 3234 번째 페이지 parsing....
# 3235 번째 페이지 parsing....
# 3236 번째 페이지 parsing....
# 3237 번째 페이지 parsing....
# 3238 번째 페이지 parsing....
# 3239 번째 페이지 parsing....
# 3240 번째 페이지 parsing....
# 3241 번째 페이지 parsing....
# 3242 번째 페이지 parsing....
# 3243 번째 페이지 parsing....
# 3244 번째 페이지 parsing....
# 3245 번째 페이지 parsing....
# 3246 번째 페이지 parsing....
# 3247 번째 페이지 parsing....
# 3248 번째 페이지 parsing....
# 3249 번째 페이지 parsing....
# 3250 번째 페이지 parsing....
# 3251 번째 페이지 parsing....
# 3252 번째 페이지 parsing....
# 3253 번째 페이지 parsing....
# 3254 번째 페이지 parsing....
# 3255 번째 페이지 parsing....
# 3256 번째 페이지 parsing....
# 3257 번째 페이지 parsing....
# 3258 번째 페이지 parsing....
# 3259 번째 페이지 parsing....
# 3260 번째 페이지 parsing....
# 3261 번째 페이지 parsing....
# 3262 번째 페이지 parsing....
# 3263 번째 페이지 parsing....
# 3264 번째 페이지 parsing....
# 3265 번째 페이지 parsing....
# 3266 번째 페이지 parsing....
# 3267 번째 페이지 parsing....
# 3268 번째 페이지 parsing....
# 3269 번째 페이지 parsing....
# 3270 번째 페이지 parsing....
# 3271 번째 페이지 parsing....
# 3272 번째 페이지 parsing....
# 3273 번째 페이지 parsing....
# 3274 번째 페이지 parsing....
# 3275 번째 페이지 parsing....
# 3276 번째 페이지 parsing....
# 3277 번째 페이지 parsing....
# 3278 번째 페이지 parsing....
# 3279 번째 페이지 parsing....
# 3280 번째 페이지 parsing....
# 3281 번째 페이지 parsing....
# 3282 번째 페이지 parsing....
# 3283 번째 페이지 parsing....
# 3284 번째 페이지 parsing....
# 3285 번째 페이지 parsing....
# 3286 번째 페이지 parsing....
# 3287 번째 페이지 parsing....
# 3288 번째 페이지 parsing....
# 3289 번째 페이지 parsing....
# 3290 번째 페이지 parsing....
# 3291 번째 페이지 parsing....
# 3292 번째 페이지 parsing....
# 3293 번째 페이지 parsing....
# 3294 번째 페이지 parsing....
# 3295 번째 페이지 parsing....
# 3296 번째 페이지 parsing....
# 3297 번째 페이지 parsing....
# 3298 번째 페이지 parsing....
# 3299 번째 페이지 parsing....
# 3300 번째 페이지 parsing....
# 3301 번째 페이지 parsing....
# 3302 번째 페이지 parsing....
# 3303 번째 페이지 parsing....
# 3304 번째 페이지 parsing....
# 3305 번째 페이지 parsing....
# 3306 번째 페이지 parsing....
# 3307 번째 페이지 parsing....
# 3308 번째 페이지 parsing....
# 3309 번째 페이지 parsing....
# 3310 번째 페이지 parsing....
# 3311 번째 페이지 parsing....
# 3312 번째 페이지 parsing....
# 3313 번째 페이지 parsing....
# 3314 번째 페이지 parsing....
# 3315 번째 페이지 parsing....
# 3316 번째 페이지 parsing....
# 3317 번째 페이지 parsing....
# 3318 번째 페이지 parsing....
# 3319 번째 페이지 parsing....
# 3320 번째 페이지 parsing....
# 3321 번째 페이지 parsing....
# 3322 번째 페이지 parsing....
# 3323 번째 페이지 parsing....
# 3324 번째 페이지 parsing....
# 3325 번째 페이지 parsing....
# 3326 번째 페이지 parsing....
# 3327 번째 페이지 parsing....
# 3328 번째 페이지 parsing....
# 3329 번째 페이지 parsing....
# 3330 번째 페이지 parsing....
# 3331 번째 페이지 parsing....
# 3332 번째 페이지 parsing....
# 3333 번째 페이지 parsing....
# 3334 번째 페이지 parsing....
# 3335 번째 페이지 parsing....
# 3336 번째 페이지 parsing....
# 3337 번째 페이지 parsing....
# 3338 번째 페이지 parsing....
# 3339 번째 페이지 parsing....
# 3340 번째 페이지 parsing....
# 3341 번째 페이지 parsing....
# 3342 번째 페이지 parsing....
# 3343 번째 페이지 parsing....
# 3344 번째 페이지 parsing....
# 3345 번째 페이지 parsing....
# 3346 번째 페이지 parsing....
# 3347 번째 페이지 parsing....
# 3348 번째 페이지 parsing....
# 3349 번째 페이지 parsing....
# 3350 번째 페이지 parsing....
# 3351 번째 페이지 parsing....
# 3352 번째 페이지 parsing....
# 3353 번째 페이지 parsing....
# 3354 번째 페이지 parsing....
# 3355 번째 페이지 parsing....
# 3356 번째 페이지 parsing....
# 3357 번째 페이지 parsing....
# 3358 번째 페이지 parsing....
# 3359 번째 페이지 parsing....
# 3360 번째 페이지 parsing....
# 3361 번째 페이지 parsing....
# 3362 번째 페이지 parsing....
# 3363 번째 페이지 parsing....
# 3364 번째 페이지 parsing....
# 3365 번째 페이지 parsing....
# 3366 번째 페이지 parsing....
# 3367 번째 페이지 parsing....
# 3368 번째 페이지 parsing....
# 3369 번째 페이지 parsing....
# 3370 번째 페이지 parsing....
# 3371 번째 페이지 parsing....
# 3372 번째 페이지 parsing....
# 3373 번째 페이지 parsing....
# 3374 번째 페이지 parsing....
# 3375 번째 페이지 parsing....
# 3376 번째 페이지 parsing....
# 3377 번째 페이지 parsing....
# 3378 번째 페이지 parsing....
# 3379 번째 페이지 parsing....
# 3380 번째 페이지 parsing....
# 3381 번째 페이지 parsing....
# 3382 번째 페이지 parsing....
# 3383 번째 페이지 parsing....
# 3384 번째 페이지 parsing....
# 3385 번째 페이지 parsing....
# 3386 번째 페이지 parsing....
# 3387 번째 페이지 parsing....
# 3388 번째 페이지 parsing....
# 3389 번째 페이지 parsing....
# 3390 번째 페이지 parsing....
# 3391 번째 페이지 parsing....
# 3392 번째 페이지 parsing....
# 3393 번째 페이지 parsing....
# 3394 번째 페이지 parsing....
# 3395 번째 페이지 parsing....
# 3396 번째 페이지 parsing....
# 3397 번째 페이지 parsing....
# 3398 번째 페이지 parsing....
# 3399 번째 페이지 parsing....
# 3400 번째 페이지 parsing....
# 3401 번째 페이지 parsing....
# 3402 번째 페이지 parsing....
# 3403 번째 페이지 parsing....
# 3404 번째 페이지 parsing....
# 3405 번째 페이지 parsing....
# 3406 번째 페이지 parsing....
# 3407 번째 페이지 parsing....
# 3408 번째 페이지 parsing....
# 3409 번째 페이지 parsing....
# 3410 번째 페이지 parsing....
# 3411 번째 페이지 parsing....
# 3412 번째 페이지 parsing....
# 3413 번째 페이지 parsing....
# 3414 번째 페이지 parsing....
# 3415 번째 페이지 parsing....
# 3416 번째 페이지 parsing....
# 3417 번째 페이지 parsing....
# 3418 번째 페이지 parsing....
# 3419 번째 페이지 parsing....
# 3420 번째 페이지 parsing....
# 3421 번째 페이지 parsing....
# 3422 번째 페이지 parsing....
# 3423 번째 페이지 parsing....
# 3424 번째 페이지 parsing....
# 3425 번째 페이지 parsing....
# 3426 번째 페이지 parsing....
# 3427 번째 페이지 parsing....
# 3428 번째 페이지 parsing....
# 3429 번째 페이지 parsing....
# 3430 번째 페이지 parsing....
# 3431 번째 페이지 parsing....
# 3432 번째 페이지 parsing....
# 3433 번째 페이지 parsing....
# 3434 번째 페이지 parsing....
# 3435 번째 페이지 parsing....
# 3436 번째 페이지 parsing....
# 3437 번째 페이지 parsing....
# 3438 번째 페이지 parsing....
# 3439 번째 페이지 parsing....
# 3440 번째 페이지 parsing....
# 3441 번째 페이지 parsing....
# 3442 번째 페이지 parsing....
# 3443 번째 페이지 parsing....
# 3444 번째 페이지 parsing....
# 3445 번째 페이지 parsing....
# 3446 번째 페이지 parsing....
# 3447 번째 페이지 parsing....
# 3448 번째 페이지 parsing....
# 3449 번째 페이지 parsing....
# 3450 번째 페이지 parsing....
# 3451 번째 페이지 parsing....
# 3452 번째 페이지 parsing....
# 3453 번째 페이지 parsing....
# 3454 번째 페이지 parsing....
# 3455 번째 페이지 parsing....
# 3456 번째 페이지 parsing....
# 3457 번째 페이지 parsing....
# 3458 번째 페이지 parsing....
# 3459 번째 페이지 parsing....
# 3460 번째 페이지 parsing....
# 3461 번째 페이지 parsing....
# 3462 번째 페이지 parsing....
# 3463 번째 페이지 parsing....
# 3464 번째 페이지 parsing....
# 3465 번째 페이지 parsing....
# 3466 번째 페이지 parsing....
# 3467 번째 페이지 parsing....
# 3468 번째 페이지 parsing....
# 3469 번째 페이지 parsing....
# 3470 번째 페이지 parsing....
# 3471 번째 페이지 parsing....
# 3472 번째 페이지 parsing....
# 3473 번째 페이지 parsing....
# 3474 번째 페이지 parsing....
# 3475 번째 페이지 parsing....
# 3476 번째 페이지 parsing....
# 3477 번째 페이지 parsing....
# 3478 번째 페이지 parsing....
# 3479 번째 페이지 parsing....
# 3480 번째 페이지 parsing....
# 3481 번째 페이지 parsing....
# 3482 번째 페이지 parsing....
# 3483 번째 페이지 parsing....
# 3484 번째 페이지 parsing....
# 3485 번째 페이지 parsing....
# 3486 번째 페이지 parsing....
# 3487 번째 페이지 parsing....
# 3488 번째 페이지 parsing....
# 3489 번째 페이지 parsing....
# 3490 번째 페이지 parsing....
# 3491 번째 페이지 parsing....
# 3492 번째 페이지 parsing....
# 3493 번째 페이지 parsing....
# 3494 번째 페이지 parsing....
# 3495 번째 페이지 parsing....
# 3496 번째 페이지 parsing....
# 3497 번째 페이지 parsing....
# 3498 번째 페이지 parsing....
# 3499 번째 페이지 parsing....
# 3500 번째 페이지 parsing....
# 3501 번째 페이지 parsing....
# 3502 번째 페이지 parsing....
# 3503 번째 페이지 parsing....
# 3504 번째 페이지 parsing....
# 3505 번째 페이지 parsing....
# 3506 번째 페이지 parsing....
# 3507 번째 페이지 parsing....
# 3508 번째 페이지 parsing....
# 3509 번째 페이지 parsing....
# 3510 번째 페이지 parsing....
# 3511 번째 페이지 parsing....
# 3512 번째 페이지 parsing....
# 3513 번째 페이지 parsing....
# 3514 번째 페이지 parsing....
# 3515 번째 페이지 parsing....
# 3516 번째 페이지 parsing....
# 3517 번째 페이지 parsing....
# 3518 번째 페이지 parsing....
# 3519 번째 페이지 parsing....
# 3520 번째 페이지 parsing....
# 3521 번째 페이지 parsing....
# 3522 번째 페이지 parsing....
# 3523 번째 페이지 parsing....
# 3524 번째 페이지 parsing....
# 3525 번째 페이지 parsing....
# 3526 번째 페이지 parsing....
# 3527 번째 페이지 parsing....
# 3528 번째 페이지 parsing....
# 3529 번째 페이지 parsing....
# 3530 번째 페이지 parsing....
# 3531 번째 페이지 parsing....
# 3532 번째 페이지 parsing....
# 3533 번째 페이지 parsing....
# 3534 번째 페이지 parsing....
# 3535 번째 페이지 parsing....
# 3536 번째 페이지 parsing....
# 3537 번째 페이지 parsing....
# 3538 번째 페이지 parsing....
# 3539 번째 페이지 parsing....
# 3540 번째 페이지 parsing....
# 3541 번째 페이지 parsing....
# 3542 번째 페이지 parsing....
# 3543 번째 페이지 parsing....
# 3544 번째 페이지 parsing....
# 3545 번째 페이지 parsing....
# 3546 번째 페이지 parsing....
# 3547 번째 페이지 parsing....
# 3548 번째 페이지 parsing....
# 3549 번째 페이지 parsing....
# 3550 번째 페이지 parsing....
# 3551 번째 페이지 parsing....
# 3552 번째 페이지 parsing....
# 3553 번째 페이지 parsing....
# 3554 번째 페이지 parsing....
# 3555 번째 페이지 parsing....
# 3556 번째 페이지 parsing....
# 3557 번째 페이지 parsing....
# 3558 번째 페이지 parsing....
# 3559 번째 페이지 parsing....
# 3560 번째 페이지 parsing....
# 3561 번째 페이지 parsing....
# 3562 번째 페이지 parsing....
# 3563 번째 페이지 parsing....
# 3564 번째 페이지 parsing....
# 3565 번째 페이지 parsing....
# 3566 번째 페이지 parsing....
# 3567 번째 페이지 parsing....
# 3568 번째 페이지 parsing....
# 3569 번째 페이지 parsing....
# 3570 번째 페이지 parsing....
# 3571 번째 페이지 parsing....
# 3572 번째 페이지 parsing....
# 3573 번째 페이지 parsing....
# 3574 번째 페이지 parsing....
# 3575 번째 페이지 parsing....
# 3576 번째 페이지 parsing....
# 3577 번째 페이지 parsing....
# 3578 번째 페이지 parsing....
# 3579 번째 페이지 parsing....
# 3580 번째 페이지 parsing....
# 3581 번째 페이지 parsing....
# 3582 번째 페이지 parsing....
# 3583 번째 페이지 parsing....
# 3584 번째 페이지 parsing....
# 3585 번째 페이지 parsing....
# 3586 번째 페이지 parsing....
# 3587 번째 페이지 parsing....
# 3588 번째 페이지 parsing....
# 3589 번째 페이지 parsing....
# 3590 번째 페이지 parsing....
# 3591 번째 페이지 parsing....
# 3592 번째 페이지 parsing....
# 3593 번째 페이지 parsing....
# 3594 번째 페이지 parsing....
# 3595 번째 페이지 parsing....
# 3596 번째 페이지 parsing....
# 3597 번째 페이지 parsing....
# 3598 번째 페이지 parsing....
# 3599 번째 페이지 parsing....
# 3600 번째 페이지 parsing....
# 3601 번째 페이지 parsing....
# 3602 번째 페이지 parsing....
# 3603 번째 페이지 parsing....
# 3604 번째 페이지 parsing....
# 3605 번째 페이지 parsing....
# 3606 번째 페이지 parsing....
# 3607 번째 페이지 parsing....
# 3608 번째 페이지 parsing....
# 3609 번째 페이지 parsing....
# 3610 번째 페이지 parsing....
# 3611 번째 페이지 parsing....
# 3612 번째 페이지 parsing....
# 3613 번째 페이지 parsing....
# 3614 번째 페이지 parsing....
# 3615 번째 페이지 parsing....
# 3616 번째 페이지 parsing....
# 3617 번째 페이지 parsing....
# 3618 번째 페이지 parsing....
# 3619 번째 페이지 parsing....
# 3620 번째 페이지 parsing....
# 3621 번째 페이지 parsing....
# 3622 번째 페이지 parsing....
# 3623 번째 페이지 parsing....
# 3624 번째 페이지 parsing....
# 3625 번째 페이지 parsing....
# 3626 번째 페이지 parsing....
# 3627 번째 페이지 parsing....
# 3628 번째 페이지 parsing....
# 3629 번째 페이지 parsing....
# 3630 번째 페이지 parsing....
# 3631 번째 페이지 parsing....
# 3632 번째 페이지 parsing....
# 3633 번째 페이지 parsing....
# 3634 번째 페이지 parsing....
# 3635 번째 페이지 parsing....
# 3636 번째 페이지 parsing....
# 3637 번째 페이지 parsing....
# 3638 번째 페이지 parsing....
# 3639 번째 페이지 parsing....
# 3640 번째 페이지 parsing....
# 3641 번째 페이지 parsing....
# 3642 번째 페이지 parsing....
# 3643 번째 페이지 parsing....
# 3644 번째 페이지 parsing....
# 3645 번째 페이지 parsing....
# 3646 번째 페이지 parsing....
# 3647 번째 페이지 parsing....
# 3648 번째 페이지 parsing....
# 3649 번째 페이지 parsing....
# 3650 번째 페이지 parsing....
# 3651 번째 페이지 parsing....
# 3652 번째 페이지 parsing....
# 3653 번째 페이지 parsing....
# 3654 번째 페이지 parsing....
# 3655 번째 페이지 parsing....
# 3656 번째 페이지 parsing....
# 3657 번째 페이지 parsing....
# 3658 번째 페이지 parsing....
# 3659 번째 페이지 parsing....
# 3660 번째 페이지 parsing....
# 3661 번째 페이지 parsing....
# 3662 번째 페이지 parsing....
# 3663 번째 페이지 parsing....
# 3664 번째 페이지 parsing....
# 3665 번째 페이지 parsing....
# 3666 번째 페이지 parsing....
# 3667 번째 페이지 parsing....
# 3668 번째 페이지 parsing....
# 3669 번째 페이지 parsing....
# 3670 번째 페이지 parsing....
# 3671 번째 페이지 parsing....
# 3672 번째 페이지 parsing....
# 3673 번째 페이지 parsing....
# 3674 번째 페이지 parsing....
# 3675 번째 페이지 parsing....
# 3676 번째 페이지 parsing....
# 3677 번째 페이지 parsing....
# 3678 번째 페이지 parsing....
# 3679 번째 페이지 parsing....
# 3680 번째 페이지 parsing....
# 3681 번째 페이지 parsing....
# 3682 번째 페이지 parsing....
# 3683 번째 페이지 parsing....
# 3684 번째 페이지 parsing....
# 3685 번째 페이지 parsing....
# 3686 번째 페이지 parsing....
# 3687 번째 페이지 parsing....
# 3688 번째 페이지 parsing....
# 3689 번째 페이지 parsing....
# 3690 번째 페이지 parsing....
# 3691 번째 페이지 parsing....
# 3692 번째 페이지 parsing....
# 3693 번째 페이지 parsing....
# 3694 번째 페이지 parsing....
# 3695 번째 페이지 parsing....
# 3696 번째 페이지 parsing....
# 3697 번째 페이지 parsing....
# 3698 번째 페이지 parsing....
# 3699 번째 페이지 parsing....
# 3700 번째 페이지 parsing....
# 3701 번째 페이지 parsing....
# 3702 번째 페이지 parsing....
# 3703 번째 페이지 parsing....
# 3704 번째 페이지 parsing....
# 3705 번째 페이지 parsing....
# 3706 번째 페이지 parsing....
# 3707 번째 페이지 parsing....
# 3708 번째 페이지 parsing....
# 3709 번째 페이지 parsing....
# 3710 번째 페이지 parsing....
# 3711 번째 페이지 parsing....
# 3712 번째 페이지 parsing....
# 3713 번째 페이지 parsing....
# 3714 번째 페이지 parsing....
# 3715 번째 페이지 parsing....
# 3716 번째 페이지 parsing....
# 3717 번째 페이지 parsing....
# 3718 번째 페이지 parsing....
# 3719 번째 페이지 parsing....
# 3720 번째 페이지 parsing....
# 3721 번째 페이지 parsing....
# 3722 번째 페이지 parsing....
# 3723 번째 페이지 parsing....
# 3724 번째 페이지 parsing....
# 3725 번째 페이지 parsing....
# 3726 번째 페이지 parsing....
# 3727 번째 페이지 parsing....
# 3728 번째 페이지 parsing....
# 3729 번째 페이지 parsing....
# 3730 번째 페이지 parsing....
# 3731 번째 페이지 parsing....
# 3732 번째 페이지 parsing....
# 3733 번째 페이지 parsing....
# 3734 번째 페이지 parsing....
# 3735 번째 페이지 parsing....
# 3736 번째 페이지 parsing....
# 3737 번째 페이지 parsing....
# 3738 번째 페이지 parsing....
# 3739 번째 페이지 parsing....
# 3740 번째 페이지 parsing....
# 3741 번째 페이지 parsing....
# 3742 번째 페이지 parsing....
# 3743 번째 페이지 parsing....
# 3744 번째 페이지 parsing....
# 3745 번째 페이지 parsing....
# 3746 번째 페이지 parsing....
# 3747 번째 페이지 parsing....
# 3748 번째 페이지 parsing....
# 3749 번째 페이지 parsing....
# 3750 번째 페이지 parsing....
# 3751 번째 페이지 parsing....
# 3752 번째 페이지 parsing....
# 3753 번째 페이지 parsing....
# 3754 번째 페이지 parsing....
# 3755 번째 페이지 parsing....
# 3756 번째 페이지 parsing....
# 3757 번째 페이지 parsing....
# 3758 번째 페이지 parsing....
# 3759 번째 페이지 parsing....
# 3760 번째 페이지 parsing....
# 3761 번째 페이지 parsing....
# 3762 번째 페이지 parsing....
# 3763 번째 페이지 parsing....
# 3764 번째 페이지 parsing....
# 3765 번째 페이지 parsing....
# 3766 번째 페이지 parsing....
# 3767 번째 페이지 parsing....
# 3768 번째 페이지 parsing....
# 3769 번째 페이지 parsing....
# 3770 번째 페이지 parsing....
# 3771 번째 페이지 parsing....
# 3772 번째 페이지 parsing....
# 3773 번째 페이지 parsing....
# 3774 번째 페이지 parsing....
# 3775 번째 페이지 parsing....
# 3776 번째 페이지 parsing....
# 3777 번째 페이지 parsing....
# 3778 번째 페이지 parsing....
# 3779 번째 페이지 parsing....
# 3780 번째 페이지 parsing....
# 3781 번째 페이지 parsing....
# 3782 번째 페이지 parsing....
# 3783 번째 페이지 parsing....
# 3784 번째 페이지 parsing....
# 3785 번째 페이지 parsing....
# 3786 번째 페이지 parsing....
# 3787 번째 페이지 parsing....
# 3788 번째 페이지 parsing....
# 3789 번째 페이지 parsing....
# 3790 번째 페이지 parsing....
# 3791 번째 페이지 parsing....
# 3792 번째 페이지 parsing....
# 3793 번째 페이지 parsing....
# 3794 번째 페이지 parsing....
# 3795 번째 페이지 parsing....
# 3796 번째 페이지 parsing....
# 3797 번째 페이지 parsing....
# 3798 번째 페이지 parsing....
# 3799 번째 페이지 parsing....
# 3800 번째 페이지 parsing....
# 3801 번째 페이지 parsing....
# 3802 번째 페이지 parsing....
# 3803 번째 페이지 parsing....
# 3804 번째 페이지 parsing....
# 3805 번째 페이지 parsing....
# 3806 번째 페이지 parsing....
# 3807 번째 페이지 parsing....
# 3808 번째 페이지 parsing....
# 3809 번째 페이지 parsing....
# 3810 번째 페이지 parsing....
# 3811 번째 페이지 parsing....
# 3812 번째 페이지 parsing....
# 3813 번째 페이지 parsing....
# 3814 번째 페이지 parsing....
# 3815 번째 페이지 parsing....
# 3816 번째 페이지 parsing....
# 3817 번째 페이지 parsing....
# 3818 번째 페이지 parsing....
# 3819 번째 페이지 parsing....
# 3820 번째 페이지 parsing....
# 3821 번째 페이지 parsing....
# 3822 번째 페이지 parsing....
# 3823 번째 페이지 parsing....
# 3824 번째 페이지 parsing....
# 3825 번째 페이지 parsing....
# 3826 번째 페이지 parsing....
# 3827 번째 페이지 parsing....
# 3828 번째 페이지 parsing....
# 3829 번째 페이지 parsing....
# 3830 번째 페이지 parsing....
# 3831 번째 페이지 parsing....
# 3832 번째 페이지 parsing....
# 3833 번째 페이지 parsing....
# 3834 번째 페이지 parsing....
# 3835 번째 페이지 parsing....
# 3836 번째 페이지 parsing....
# 3837 번째 페이지 parsing....
# 3838 번째 페이지 parsing....
# 3839 번째 페이지 parsing....
# 3840 번째 페이지 parsing....
# 3841 번째 페이지 parsing....
# 3842 번째 페이지 parsing....
# 3843 번째 페이지 parsing....
# 3844 번째 페이지 parsing....
# 3845 번째 페이지 parsing....
# 3846 번째 페이지 parsing....
# 3847 번째 페이지 parsing....
# 3848 번째 페이지 parsing....
# 3849 번째 페이지 parsing....
# 3850 번째 페이지 parsing....
# 3851 번째 페이지 parsing....
# 3852 번째 페이지 parsing....
# 3853 번째 페이지 parsing....
# 3854 번째 페이지 parsing....
# 3855 번째 페이지 parsing....
# 3856 번째 페이지 parsing....
# 3857 번째 페이지 parsing....
# 3858 번째 페이지 parsing....
# 3859 번째 페이지 parsing....
# 3860 번째 페이지 parsing....
# 3861 번째 페이지 parsing....
# 3862 번째 페이지 parsing....
# 3863 번째 페이지 parsing....
# 3864 번째 페이지 parsing....
# 3865 번째 페이지 parsing....
# 3866 번째 페이지 parsing....
# 3867 번째 페이지 parsing....
# 3868 번째 페이지 parsing....
# 3869 번째 페이지 parsing....
# 3870 번째 페이지 parsing....
# 3871 번째 페이지 parsing....
# 3872 번째 페이지 parsing....
# 3873 번째 페이지 parsing....
# 3874 번째 페이지 parsing....
# 3875 번째 페이지 parsing....
# 3876 번째 페이지 parsing....
# 3877 번째 페이지 parsing....
# 3878 번째 페이지 parsing....

# %%
## 수집 데이터 확인
segment
# Out:
# [['림키(kkl1****)',
#   '살아생전 못가본 퀸 콘서트에 갔다왔습니다.',
#   '10',
#   '13154',
#   '418',
#   datetime.datetime(2018, 10, 31, 11, 35),
#   0],
#  ['조용일(whdy****)',
#   '브라이언메이 싱크로율 말이되냐',
#   '10',
#   '8805',
#   '319',
#   datetime.datetime(2018, 10, 31, 11, 29),
#   0],
#  ['Bang JongHo(shom****)',
#   '슬픈장면은 없는데 눈물 나는 영화 ㅠㅜ',
#   '10',
#   '7568',
#   '231',
#   datetime.datetime(2018, 10, 31, 13, 39),
#   0],
#  ['최와와(choi****)',
#   '그 시절 영국에는 두명의 여왕이 있었다',
#   '9',
#   '7131',
#   '351',
#   datetime.datetime(2018, 10, 31, 9, 7),
#   0],
#  ['김석환(kims****)',
#   '브라이언 메이는 본인을 데려오신건가요?',
#   '10',
#   '5832',
#   '174',
#   datetime.datetime(2018, 10, 31, 13, 37),
#   0],
#  ['김민준(over****)',
#   '오프닝 20세기폭스 나올때 기타변주부터 소름돋은 사람 공감 ㄱ',
#   '10',
#   '5065',
#   '162',
#   datetime.datetime(2018, 11, 1, 21, 42),
#   0],
#  ['Rapmonster(weng****)',
#   '마이클잭슨도 영화화되었으면...',
#   '9',
#   '5192',
#   '342',
#   datetime.datetime(2018, 10, 31, 10, 24),
#   0],
#  ['rfc1****',
#   '나는 스타가 되지 않겠다, 전설이 될 것이다. - 프레디 머큐리',
#   '10',
#   '4949',
#   '159',
#   datetime.datetime(2018, 10, 31, 9, 8),
#   0],
#  ['pusi****',
#   '폭스 로고송 부터 귀를 뗄수없는...',
#   '10',
#   '4594',
#   '153',
#   datetime.datetime(2018, 10, 31, 11, 40),
#   0],
#  ['UNKNOWN(jinh****)',
#   '다들 영화보고 돌아가는 길에 퀸 노래를 틀었겠지..',
#   '10',
#   '4089',
#   '92',
#   datetime.datetime(2018, 11, 1, 12, 44),
#   0],
#  ['고구마라떼(part****)',
#   '15억명을 홀린사람을 안쓰럽게 생각하게 될 줄은 몰랐다.',
#   '10',
#   '3921',
#   '104',
#   datetime.datetime(2018, 10, 31, 13, 58),
#   0],
#  ['안녕(kooo****)',
#   '공연 장면은 감동 그자체...꼭 보세요',
#   '10',
#   '3874',
#   '115',
#   datetime.datetime(2018, 10, 31, 11, 30),
#   '관람객'],
#  ['rlqo****',
#   '2시간 안에 그 긴 기간을 담긴 힘들었게지만  퀸 팬 입장에서 정말 재밌고 감동적이었네요... 시사회 갔다가 또 봅니다...',
#   '10',
#   '2682',
#   '98',
#   datetime.datetime(2018, 10, 31, 9, 41),
#   0],
#  ['syk7****',
#   '퀸 좋아하시는분들은 그냥 음악자체가  압도적인 영화 입니다 너무 좋네요  그런데 영화에서 정작 제목인 노래는 맛베기만 ㅋㅋㅋ',
#   '10',
#   '2505',
#   '128',
#   datetime.datetime(2018, 10, 31, 11, 19),
#   0],
#  ['KG90(koko****)',
#   '미쳤다~올해본 영화중 최고다',
#   '10',
#   '2351',
#   '103',
#   datetime.datetime(2018, 10, 31, 11, 9),
#   0],
#  ['jou(acap****)',
#   '퀸에 대해 잘 몰랐는데도 너무 감동적이었다! 특히 마지막 장면은ㅠㅠ 귀르가즘 폭발!!',
#   '10',
#   '2266',
#   '84',
#   datetime.datetime(2018, 10, 31, 11, 7),
#   '관람객'],
#  ['마도워스(skw6****)',
#   '에이 머큐리랑 싱크 별로 안비슷 하네.. 했다가 마지막 공연때 진짜 머큐리 강림한줄암 크',
#   '10',
#   '2252',
#   '80',
#   datetime.datetime(2018, 10, 31, 14, 3),
#   0],
#  ['이우석(wkle****)',
#   '모드리치랑 푸욜이 이렇게 음악 잘하는지 몰랐네요',
#   '10',
#   '2154',
#   '89',
#   datetime.datetime(2018, 10, 31, 23, 28),
#   0],
#  ['디플컨트(u35s****)',
#   '배우들 싱크로율 진짜 대박이었어요!! 퀸의 노래가 어떻게 탄생했는지 알 수 있었던 소중한 시간이었습니다.',
#   '10',
#   '2152',
#   '88',
#   datetime.datetime(2018, 10, 31, 11, 27),
#   0],
#  ['이수빈(rfv0****)',
#   '이걸 보려고 지금까지 살아왔나 봅니다',
#   '10',
#   '2070',
#   '153',
#   datetime.datetime(2018, 10, 31, 12, 33),
#   0],
#  ['얀웬리(grac****)',
#   '이건 뭐~ 퀸의 광팬이라 몇달전부터 기다리다 개봉일 첫회에 와서 봤는데.. 기대보다 훨씬 엄청나다. 퀸의 팬이든 아니든, 퀸을 알든 모르든~ 마지막 20여분은 눈물을 참다참다 도저히 더는 참을 수 없게 만드는 영화....',
#   '10',
#   '1711',
#   '68',
#   datetime.datetime(2018, 10, 31, 12, 48),
#   0],
#  ['hye(adg4****)',
#   'we are the champion 눈물 줄줄ㅠㅠㅠ',
#   '10',
#   '1444',
#   '48',
#   datetime.datetime(2018, 10, 31, 19, 6),
#   0],
#  ['성공 유전자(kimc****)',
#   '2시간 내내 소름의 연속이였습니다 ㄷㄷ특히 마지막 클라이막스 라이브 에이드 공연은 와...',
#   '10',
#   '1436',
#   '55',
#   datetime.datetime(2018, 10, 31, 12, 32),
#   0],
#  ['위은교(dnld****)',
#   '전세계 19억명이 시청한 그들의 공연을 스크린에서 다시 볼수있단것만으로도 압도적으로감사!',
#   '10',
#   '1306',
#   '65',
#   datetime.datetime(2018, 10, 31, 10, 21),
#   0],
#  ['갱지니(hide****)',
#   '퀸의 팬이라면 꼭 보세요~마지막 20분은  프레드 머큐리가날위해서 노래합니다ㅜㅜ',
#   '10',
#   '1219',
#   '58',
#   datetime.datetime(2018, 10, 31, 13, 23),
#   '관람객'],
#  ['겁쟁이아(sun0****)',
#   '마지막씬, 나는 스크린이 아닌 퀸을보며 헐떡이고 눈물을흘리며 몸을떨었다.',
#   '10',
#   '1286',
#   '207',
#   datetime.datetime(2018, 10, 31, 11, 31),
#   0],
#  ['아아악(yunj****)',
#   '스토리의 개연성은 다소 아쉽지만 퀸의 콘서트에 온 것 같은 기분이 들었음 퀸의 팬이라면 추천',
#   '9',
#   '1145',
#   '152',
#   datetime.datetime(2018, 10, 31, 14, 3),
#   '관람객'],
#  ['자이젠(icem****)',
#   '퀸은 무조건 10점이지',
#   '10',
#   '1022',
#   '68',
#   datetime.datetime(2018, 10, 31, 9, 57),
#   0],
#  ['YNWA 96 Liverpool(nice****)',
#   'Too Much Love Will Kill You  너무많은 사랑은 당신을 죽일거에요.. 파바로티가 사랑한 퀸',
#   '10',
#   '937',
#   '60',
#   datetime.datetime(2018, 10, 31, 10, 41),
#   0],
#  ['표코몽(oyc5****)',
#   '오늘 볼거지만 먼저 10점 준다',
#   '10',
#   '1021',
#   '162',
#   datetime.datetime(2018, 10, 31, 11, 9),
#   0],
#  ['MacGyVer(jeep****)',
#   'love of my life가 TV에서 흘러나오면서 메리에게 자신의 성정체성에 대해서 고백할때부터 울컥했고 눈물이 났다.마지막 LIVE AID 공연장면은 정말 스크린에서만 느낄 수가 있는 멋진 장면이였다.자신의 예언...',
#   '10',
#   '840',
#   '43',
#   datetime.datetime(2018, 10, 31, 13, 13),
#   0],
#  ['California(andy****)',
#   '11점을 주지못해 10점을 줍니다.',
#   '10',
#   '826',
#   '37',
#   datetime.datetime(2018, 10, 31, 20, 45),
#   0],
#  ['자유기사(gund****)',
#   "올해 최고의 외화. 마지막 라이브에이드 공연에서의 '보헤미안 랩소디'의 가사는 마치 자신의 인생을 이야기 하는것 같아 눈물이 났다. 그리고 브라이언 메이 캐스팅은 누가 했는지 싱크로율이 ㄷㄷㄷ",
#   '9',
#   '770',
#   '32',
#   datetime.datetime(2018, 11, 1, 13, 48),
#   0],
#  ['다찌마와리(wuth****)',
#   '네 올해 남우주연상 후보 연기 잘 봤어요',
#   '10',
#   '729',
#   '28',
#   datetime.datetime(2018, 10, 31, 18, 43),
#   0],
#  ['koya(tjgy****)',
#   '기다린만큼 너무 벅차고 재미있었음 ㅠㅠ 아는 노래 나올 때마다 소름돋고 ㅜㅜㅜ 마지막 공연씬은 ㄹㅇ 레전드',
#   '10',
#   '725',
#   '51',
#   datetime.datetime(2018, 10, 31, 11, 25),
#   '관람객'],
#  ['judith(rlaw****)',
#   '따라 부를까봐.. 기립박수 쳐댈까봐.. 대성통곡 할까봐.. 보는 내내 미치는 줄 알았다. 여운마저 내겐, 너무 벅찬 하루다.',
#   '10',
#   '681',
#   '42',
#   datetime.datetime(2018, 11, 1, 17, 45),
#   0],
#  ['in(sadi****)',
#   "'좋은 말, 좋은 생각, 좋은 행동' 을 말하고 아버지와 포옹하는 장면과 마지막 콘서트 장면은 정말 아직도 머리속에서 떠나지 않는다. 그의 성 정체성과 불안한 인간적인 면은 이해할 수 없지만 가족과 사...",
#   '10',
#   '672',
#   '55',
#   datetime.datetime(2018, 10, 31, 23, 53),
#   0],
#  ['seyu****',
#   '일부러 사운드 특화관에서 봤다.. 올해 가장 잘한 선택이었음',
#   '10',
#   '629',
#   '34',
#   datetime.datetime(2018, 10, 31, 15, 28),
#   '관람객'],
#  ['Neo Khan(veri****)',
#   '마지막 웸블리 공연 보다가 더이상 위대한 보컬리스트를 볼수 없다는 사실에 나도 모르게 눈물이 흐르더라',
#   '10',
#   '610',
#   '34',
#   datetime.datetime(2018, 10, 31, 13, 23),
#   '관람객'],
#  ['히로냥(hiro****)',
#   '늦게태어나서 처음으로 아쉬움. 그 라이브를 못본게.',
#   '10',
#   '592',
#   '27',
#   datetime.datetime(2018, 10, 31, 22, 37),
#   0],
#  ['tlsg****',
#   '예술이 할 일을 했다. 고맙습니다.',
#   '10',
#   '584',
#   '25',
#   datetime.datetime(2018, 10, 31, 20, 50),
#   0],
#  ['suna****',
#   '용산 아이맥스 7시 20분 끝나고 다 박수치더라. 나가지도 않음',
#   '10',
#   '585',
#   '45',
#   datetime.datetime(2018, 10, 31, 23, 35),
#   0],
#  ['kdy1****',
#   '옆자리에 50정도 되보이시는 부부가 앉으셨는데 마지막 공연씬에서 펑펑 우시더라구요..저도 같이 울었습니다..',
#   '10',
#   '560',
#   '30',
#   datetime.datetime(2018, 10, 31, 23, 14),
#   0],
#  ['우주심 연우(dhsd****)',
#   '배우들 싱크로 쩔고요. 브라이언 메이는 그냥 도플갱어 수준임 ㅎㅎ 퀀의 음악을 그리고 가장 위대한 웸블리 공연을 완벽히 재현한걸 스크린서 감상할 수 있었다는것에 무한감격. 올해가 가기전에 꼭 봐야 할 영화',
#   '10',
#   '510',
#   '28',
#   datetime.datetime(2018, 10, 31, 21, 4),
#   '관람객'],
#  ['안뇽(jenv****)',
#   '시작하고. 프레디의 뒷모습. 썸바디투럽 울려퍼질때.감격스러워서 눈물이났다.',
#   '10',
#   '490',
#   '25',
#   datetime.datetime(2018, 10, 31, 12, 56),
#   0],
#  ['resi****',
#   '이상하게 입은 미소를 눈에는 눈물이',
#   '9',
#   '474',
#   '27',
#   datetime.datetime(2018, 10, 31, 22, 27),
#   '관람객'],
#  ['Dizzy(rlac****)',
#   '팬이 아닌사람도 재밋게 볼수 있을까에 대한 완벽한 대답',
#   '10',
#   '446',
#   '26',
#   datetime.datetime(2018, 10, 31, 14, 54),
#   0],
#  ['국가의탄생(awas****)',
#   '마지막 공연장면에서 왜 눈물이 나냐...',
#   '9',
#   '443',
#   '28',
#   datetime.datetime(2018, 10, 31, 15, 34),
#   0],
#  ['jungjaewon(wony****)',
#   '방금 보고 왔는데 또 보고 싶음. 라미 말렉 연기 잘했다.',
#   '10',
#   '434',
#   '26',
#   datetime.datetime(2018, 10, 31, 15, 42),
#   0],
#  ['이재만(mn99****)',
#   '2-3번 봐도 좋은영화초반에 스토리 개연성이 떨어진다고 해야하나약간 뚝뚝 끊기는 느낌이 잇는데진짜 클라이막스가 뭔지 보여주는 영화마지막을 위한 영화라고 해야하나여운 굳...마지막 한마디 폴 OOO...',
#   '10',
#   '428',
#   '38',
#   datetime.datetime(2018, 10, 31, 11, 25),
#   0],
#  ['태바(3076****)',
#   '20세기폭스 브금으로 브라이언메이의 기타톤이 흘러나올때부터 울컥했었고 라이브에이드때는 질질 짰다. 정말 감동적이고 잘만든 영화지만 아쉬웠던건 프레디의 다정함과 인간적인 면이아닌 너무 방탕했던 삶을 중점으로 둔게 아닌...',
#   '10',
#   '412',
#   '34',
#   datetime.datetime(2018, 11, 1, 15, 22),
#   0],
#  ['sand****',
#   '우리나라 영화계의  가장 큰 적폐는 국내 평론가들의 얕은 감성 이다.  아쉽다 . 이영화를 보고 저런 평론을 ... ㅋㅋㅋ',
#   '10',
#   '412',
#   '34',
#   datetime.datetime(2018, 11, 1, 2, 41),
#   0],
#  ['솔(pimc****)',
#   '동성애 장면(남자끼리 키스)에서 나가는 인간 한명 있던데.... 나갈려면 조용히 나가던가. 왜 문을 쾅! 닿구 나가냐? 니가 그 극장 전세 냈냐? 왜 화풀이를 관객한테 하는건데? 1일날 롯데시네마 장안점에서 조조로 ...',
#   '10',
#   '412',
#   '51',
#   datetime.datetime(2018, 11, 5, 9, 22),
#   0],
#  ['나니아(katz****)',
#   '왜 우는지 모르고 우는 영화',
#   '10',
#   '370',
#   '19',
#   datetime.datetime(2018, 11, 8, 22, 53),
#   0],
#  ['다솔(hada****)',
#   '라이브에이드 공연은 나까지 웸블리에 있는듯한 착각을 들게했다. 퀸의 공연이 끝나자 왠지모를 눈물이 흘렀다. 그 누구도 아닌 퀸이기 때문에 꼭 봐야하는 영화.',
#   '10',
#   '369',
#   '19',
#   datetime.datetime(2018, 10, 31, 11, 21),
#   0],
#  ['금재이(lapk****)',
#   '가만히 앉아서 봐야하는게 너무 고통스러웠습니다최고의 영화!',
#   '10',
#   '353',
#   '25',
#   datetime.datetime(2018, 11, 1, 0, 17),
#   0],
#  ['SY(lseo****)',
#   '극장에서 봐야하지만 극장이라 꼼작하고 봐야해서 너무 아쉬웠어요~ 최곱니다!! 최고의전율 또보고 싶네요',
#   '10',
#   '328',
#   '23',
#   datetime.datetime(2018, 10, 31, 10, 52),
#   0],
#  ['아씨오(jinn****)',
#   '이래서 극장에 가는 거죠 ㅠㅠ 내용도 흠잡을 데 없이 재밌고, 퀸 멤버들 특성을 잘 살린 배우들의 연기도 정말 좋았습니다. 특히 메리와의 러브 스토리가 정말 좋았어요. 음악도 좋지만 스토리도 정말 감동적이었습니다',
#   '10',
#   '331',
#   '32',
#   datetime.datetime(2018, 10, 31, 13, 23),
#   '관람객'],
#  ['vennylggo(shal****)',
#   '이건 뭐...감동의 전율 그 자체 입니다 !!!마지막 라이브장면 관중 떼창은 눈물 나올 정도로 대박입니다~~!!',
#   '10',
#   '324',
#   '31',
#   datetime.datetime(2018, 10, 31, 15, 47),
#   0],
#  ['임혜영(lgod****)',
#   '그가얼마나 외로웠을까? 마지막까지 자막이 올라가도 그 누구도 자리에서일어나지못했어요..끝까지 남고남는 감동그자체입니다..45세 전설이되어버린 프레디머큐리를 기억하며..',
#   '10',
#   '308',
#   '21',
#   datetime.datetime(2018, 10, 31, 23, 5),
#   '관람객'],
#  ['정시왕(sms9****)',
#   "잘나신 평론가님들은 프레디 살아생전 퀸에게도 평가가 박하더니 영화 역시도 마찬가지다.하지만 팝과 스타는 대중들의 것, 곧 대중들이 평가하는 것이다. 영화에서 '퀸'이 우리에게 선사해주는 원초적 즐거움과...",
#   '10',
#   '302',
#   '20',
#   datetime.datetime(2018, 11, 9, 5, 16),
#   '관람객'],
#  ['kyk(zi3j****)',
#   '와 머큐리를 이렇게 똑같이 데려다 놓다니 ㅋㅋ',
#   '10',
#   '298',
#   '31',
#   datetime.datetime(2018, 10, 31, 12, 43),
#   0],
#  ['흑싹(ssak****)',
#   '콘서트 보는줄알았어요',
#   '9',
#   '266',
#   '25',
#   datetime.datetime(2018, 10, 31, 12, 41),
#   '관람객'],
#  ['스케치(ke_i****)',
#   '볼까 말까를 고민하는게 아니라... 몇 번을 볼지를 고민하게 만드는 영화',
#   '10',
#   '255',
#   '17',
#   datetime.datetime(2018, 11, 6, 21, 58),
#   0],
#  ['bsy8****',
#   '당시에 라이브 에이드 현장에 있던 영국애들이 진심 부럽다.',
#   '10',
#   '245',
#   '11',
#   datetime.datetime(2018, 11, 2, 1, 55),
#   0],
#  ['춤추는마우스(poli****)',
#   '오늘부터 콧수염 기르고 레깅스 사입기로 했습니다',
#   '10',
#   '262',
#   '31',
#   datetime.datetime(2018, 11, 2, 21, 37),
#   0],
#  ['박영은(inm_****)',
#   '퀸을 모르다 입덕하고 나온 영화',
#   '10',
#   '241',
#   '13',
#   datetime.datetime(2018, 11, 4, 1, 28),
#   0],
#  ['어차피 제대(alde****)',
#   '싱크로율이 진짜 미쳤다 ...프레디 머큐리 특유의 팍팍 꺾으면서 하는 돌발적인 움직임이 너무 비슷했다...퀸 팬들이라면 무조건 봐야 할 정도 . 2시간 안에 꾹꾹 눌러담았지만 퀸 이라는 밴드가 무엇인지 보여줌',
#   '9',
#   '242',
#   '21',
#   datetime.datetime(2018, 10, 31, 15, 30),
#   0],
#  ['없음(jyk9****)',
#   '진심 마지막씬이 압권---이것때문이라도 한번  더 봐야겠음. 혈액순환 안좋은신 분 추천. 노래부를때 다리부터 온몸으로 전율이 올라옴.',
#   '9',
#   '225',
#   '16',
#   datetime.datetime(2018, 11, 1, 0, 11),
#   0],
#  ['혁수(chlg****)',
#   '프레디 머큐리에 대해서 몰랏으나. 영화 감상 후 폭풍검색 및 퀸 노래 무한 반복중.. 진짜 대단한 아티스트다..',
#   '10',
#   '203',
#   '16',
#   datetime.datetime(2018, 11, 1, 8, 31),
#   0],
#  ['xoxo코부(kovu****)',
#   '소름 소름 소름 눈물 흘리면서 봤습니다. 프레디가 많이 외로웠을것같아요. 올해 가장 기억에 남는 영화입니다ㅠ ㅠ!',
#   '10',
#   '198',
#   '15',
#   datetime.datetime(2018, 11, 1, 20, 36),
#   '관람객'],
#  ['NOEL(haye****)',
#   '박수치면서 라디오가가 떼창하고싶은거 참으라 죽는줄알았음. 영화보면서 이렇게 고문받기는 처음',
#   '10',
#   '201',
#   '18',
#   datetime.datetime(2018, 11, 1, 4, 32),
#   '관람객'],
#  ['미키아르(1126****)',
#   '앞부분에서 절제하다가 뒤에서 터뜨리는 영화. 밴드 배우 캐스팅 오짐. 마지막 콘서트는 분명 연기일텐데 왜이리 멋있는지',
#   '10',
#   '197',
#   '17',
#   datetime.datetime(2018, 10, 31, 21, 39),
#   '관람객'],
#  ['ㅎㅎㅎㅎ(swh2****)',
#   '모든 댓글에 일정하게 비공이 박히고 별점 테러하는게 눈에 보이네 영화사에서 일하는 쓰레기들아 작품성으로 승부해라 쓸데없는 짓 하지말고',
#   '10',
#   '215',
#   '35',
#   datetime.datetime(2018, 10, 31, 10, 9),
#   0],
#  ['tjda****',
#   '음악영화 좋아해서 조조로 봣는데,.. 마지막 공연장면은 정말 보는내내 소름소름소름.. ㅜ 진짜 대박이었다!!!',
#   '10',
#   '198',
#   '23',
#   datetime.datetime(2018, 10, 31, 11, 1),
#   '관람객'],
#  ['캘리베드(hjm7****)',
#   '20세기 폭스사에서 퀸을 대신해 개최한 21세기 최고의 팬서비스',
#   '10',
#   '183',
#   '18',
#   datetime.datetime(2018, 10, 31, 23, 27),
#   '관람객'],
#  ['리처드핀(idma****)',
#   '와아.. 5천원 아니라 5만원 내고 봤어도 안아까울 음악&전기 영화다ㄷㄷㄷ 간만에 영화보다 심장어택당함. 사람들 끝나고도 안나감.',
#   '10',
#   '181',
#   '20',
#   datetime.datetime(2018, 10, 31, 22, 56),
#   0],
#  ['sjw3****',
#   '영화보고 유튭으로 콘서트 영상 다시 본 사람 손!',
#   '9',
#   '173',
#   '13',
#   datetime.datetime(2018, 11, 12, 10, 48),
#   0],
#  ['서기(moch****)',
#   '영화를 보는건지 라이브 실황을 보는건지 모를 전율의 싱크로....',
#   '10',
#   '178',
#   '21',
#   datetime.datetime(2018, 10, 31, 12, 28),
#   '관람객'],
#  ['feel****',
#   '경고합니다  이 영화를 보시면 며칠동안 퀸 음악이 머리를 떠나지 않아 일상생활에 지장이 올것이고 틈만 나면 인터넷으로 퀸 덕질하는 자신의 모습을 볼 수 있을겁니다',
#   '10',
#   '163',
#   '11',
#   datetime.datetime(2018, 11, 19, 20, 0),
#   0],
#  ['주부청춘(sorr****)',
#   '에이드콘서트때 영화관안에서 위아더챔피언 떼창나왔다..그리고 싱크로율이 대박이다',
#   '10',
#   '166',
#   '17',
#   datetime.datetime(2018, 10, 31, 14, 48),
#   0],
#  ['h3mi****',
#   'Bohemian Rhapsody 엄마 죽기 싫어요 때 울컥, Radio GaGa 레디오 나올때 눈물, Hammer To Fall 나올때  환호, We Are The Champions 끝나고 엄마에게 손 키스때 눈물!...',
#   '10',
#   '157',
#   '14',
#   datetime.datetime(2018, 11, 2, 0, 53),
#   0],
#  ['눈의 꽃(kkk8****)',
#   '스타 이즈 본을 이은 최고의 음악영화.. 이런 영화는 영화관에서 봐야 합니다',
#   '10',
#   '170',
#   '28',
#   datetime.datetime(2018, 10, 31, 10, 6),
#   0],
#  ['OMG(mjkk****)',
#   'Queen Forever',
#   '10',
#   '156',
#   '15',
#   datetime.datetime(2018, 10, 31, 9, 49),
#   0],
#  ['soohyun(lind****)',
#   '영화보고 여기 글 남기긴 처음.',
#   '10',
#   '154',
#   '16',
#   datetime.datetime(2018, 11, 1, 8, 29),
#   0],
#  ['자룡아빠(gjan****)',
#   '이 시대를 살아가면서 퀸 공연을 못봤다면 평생 후회할것이고 이 영화를 못본다면 다시 한번 평생 후회할 것이타10점도 부족하다',
#   '10',
#   '153',
#   '18',
#   datetime.datetime(2018, 11, 1, 13, 42),
#   0],
#  ['아모새(dltj****)',
#   '이 영화를 냅두고 완벽한 타인이 1위를 한다는거 자체가 우리나라가 얼마나 국뽕영화에 찌들어있는지 느끼게 해준다',
#   '10',
#   '186',
#   '53',
#   datetime.datetime(2018, 11, 7, 13, 36),
#   0],
#  ['개군(dksw****)',
#   '꼭 스크린X로 봐야 할 영화 재미와 재치, 스토리 모든것이 완벽했다. 퀸을 모르는 사람들이 봐도 정말 재미있게 볼 수 있게끔 만든영화. 특히 마지막 라이브에이드 공연씬은 단연코 최고였으며, 단 한가지 아쉬운점이 있다...',
#   '10',
#   '147',
#   '15',
#   datetime.datetime(2018, 10, 31, 15, 19),
#   0],
#  ['wile****',
#   '재수시절 아침마다 들었던 I want to break free.. 청년시절 퀸의 음악은 힘들었던 시절 나에게 큰 위안이 되었고 , 이제 초등학교 아이를 둔 40대 가장이 되었다. 많은 이들이 눈물을 흘리는 이유는 과...',
#   '10',
#   '145',
#   '17',
#   datetime.datetime(2018, 11, 1, 15, 8),
#   0],
#  ['siwana(cine****)',
#   '얼마 남지 않은 올해의 최고의 영화였다.. 퀸갓제네럴',
#   '10',
#   '146',
#   '18',
#   datetime.datetime(2018, 10, 31, 15, 23),
#   '관람객'],
#  ['AKASA(toto****)',
#   'IMAX로 뵜는데 진짜  라이브에이드를 간 느낌이었어요. 2시간이라는 짧은 시간이지만 정말 감동적이었고 재밌었어요',
#   '10',
#   '139',
#   '18',
#   datetime.datetime(2018, 10, 31, 11, 10),
#   0],
#  ['띵띵맘(je42****)',
#   '프레디 머큐리 닮은 배역이 너무도연기를 잘 해 좋앗습니다.',
#   '8',
#   '138',
#   '18',
#   datetime.datetime(2018, 10, 31, 23, 39),
#   '관람객'],
#  ['vita****',
#   '영화 내내 퀸 음악이 상영관 꽉 채우는데 진짜 온몸에 전율이.... 말그대로 보는 내내 행복하고 힐링되는 영화였다',
#   '10',
#   '136',
#   '19',
#   datetime.datetime(2018, 10, 31, 11, 36),
#   '관람객'],
#  ['이카(jsyu****)',
#   '영화관에 의자를 다 없에야 합니다.',
#   '10',
#   '129',
#   '13',
#   datetime.datetime(2018, 11, 10, 17, 40),
#   0],
#  ['뽀오(jaju****)',
#   '마지막20분만봐도 아깝지 않음 최고임',
#   '10',
#   '123',
#   '13',
#   datetime.datetime(2018, 10, 31, 14, 14),
#   0],
#  ['이지은(c661****)',
#   '저도 모르게 눈물이 나오더라구요~감동 그자체였어요!',
#   '10',
#   '122',
#   '14',
#   datetime.datetime(2018, 10, 31, 15, 47),
#   0],
#  ['ㄼㅁㄱㅂㄼ(rlag****)',
#   '당신이 프레디 머큐리의 목소리를 알고 한 소절이라도 들어봤다면 영화 시작과 엔딩크레딧 올라가는 순간까지 소름의 연속일거에요.',
#   '10',
#   '127',
#   '19',
#   datetime.datetime(2018, 10, 31, 15, 25),
#   0],
#  ['HelloHowdy(hell****)',
#   '한동안 못빠져나올꺼 같습니다',
#   '10',
#   '118',
#   '11',
#   datetime.datetime(2018, 11, 3, 2, 43),
#   0],
#  ['재패니즈(vu0v****)',
#   '영화 보는 내내 끊임없이 나오는 퀸의 음악들, 이건 인정할 수 밖에 없다',
#   '10',
#   '120',
#   '16',
#   datetime.datetime(2018, 10, 31, 11, 37),
#   0],
#  ['쉐릭(dols****)',
#   '짐 보고나오는 길.. 요즘 수준 낮은 국산영화들이 많은 상영관을 차지하며 좋은 외화들 볼 기회가 없어지는거 같아 안타깝다.',
#   '10',
#   '116',
#   '14',
#   datetime.datetime(2018, 11, 2, 1, 46),
#   0],
#  ['페도라도(dnxk****)',
#   '귀는 즐겁고 눈은 슬프다 ㅜㅜ',
#   '10',
#   '107',
#   '11',
#   datetime.datetime(2018, 11, 3, 11, 47),
#   '관람객'],
#  ['골프의신(asay****)',
#   '프레디형의 인생이 보헤미안 랩소디 였네요. 재미와 감동모두 잡았네요.',
#   '10',
#   '104',
#   '12',
#   datetime.datetime(2018, 10, 31, 13, 16),
#   0],
#  ['tois****',
#   '전설이 만들어지는 과정이 아니라 찬란하게 소멸하는 이야기',
#   '10',
#   '105',
#   '13',
#   datetime.datetime(2018, 11, 2, 22, 35),
#   0],
#  ['점제연(psho****)',
#   '안보고 10점 직접보면 울어버릴것 같다생각만해도 소름돋는다',
#   '10',
#   '104',
#   '15',
#   datetime.datetime(2018, 10, 31, 13, 41),
#   0],
#  ['KEN(7512****)',
#   '평론가, 토마토인가 뭐시긴가는 평점을 왜 그따구로 남긴거지? 안보면 후회합니다. 라이브 에이드를 생전에 다시 한번 즐길 수 있는 기회',
#   '10',
#   '102',
#   '16',
#   datetime.datetime(2018, 10, 31, 21, 49),
#   0],
#  ['에임하이(bara****)',
#   '이제것 영화보면서 다 끝나고도 단 한명도 자리에서 일어나는 사람없는 영화는 처음 봤네...',
#   '10',
#   '95',
#   '11',
#   datetime.datetime(2018, 10, 31, 23, 29),
#   0],
#  ['사슴밤비(heff****)',
#   '전설 그 이상의 단어 없나 ㅠㅠㅠ 전설이랑 표현으로도 부족.. 죽기 전에 이렇게라도 프레디의 공연을 만나는구나..',
#   '10',
#   '93',
#   '11',
#   datetime.datetime(2018, 10, 31, 14, 35),
#   '관람객'],
#  ['레임(qkrw****)',
#   '이 호평들이 댓글 알바가 아니었네',
#   '10',
#   '92',
#   '11',
#   datetime.datetime(2018, 11, 5, 0, 43),
#   0],
#  ['이호진(elti****)',
#   '단 돈9000원으로 퀸 콘서트를 다녀왔다',
#   '10',
#   '92',
#   '12',
#   datetime.datetime(2018, 11, 2, 0, 52),
#   0],
#  ['히죽(lbr3****)',
#   '영화관 사운드가 부족하다고 느낄정도였다...난 어려 머큐리생전의 공연 한편 못봤지만, 이 영화를 알기전부터 퀸은 최고였다. 이영화를 계기로 인생영화가 되었다!!',
#   '10',
#   '93',
#   '13',
#   datetime.datetime(2018, 10, 31, 14, 58),
#   0],
#  ['sain****',
#   '말이 필요 없음....',
#   '10',
#   '93',
#   '13',
#   datetime.datetime(2018, 10, 31, 14, 10),
#   0],
#  ['지누1985(skyh****)',
#   '2018 최고의 영화!! 영화끝나도 아무도 일어나지 않았어요박수가 절로 나옵니다 꼭!! 라이브에이드 영상 한번 보시고 영화보세요디테일 쩝니다~~ㅎ 강추강추',
#   '10',
#   '94',
#   '14',
#   datetime.datetime(2018, 10, 31, 23, 43),
#   '관람객'],
#  ['pm17****',
#   '퀸은 알까.. 동양의 작은 나라, 영어를 1도 못하는 한 인간이 오늘 흘린 눈물을..',
#   '10',
#   '93',
#   '14',
#   datetime.datetime(2018, 11, 12, 21, 59),
#   0],
#  ['아지뱀(yhoc****)',
#   '라이브 에이드 공연을 직접 본 관객들의 눈과 귀를 사고 싶다. 사운드 특화관에서 보면 더 좋다.',
#   '8',
#   '96',
#   '17',
#   datetime.datetime(2018, 10, 31, 13, 18),
#   0],
#  ['SoJuKing(ksj4****)',
#   '각본이 구려도 치트키를 쓰니 당해낼수가없다 ㅠㅠ',
#   '9',
#   '91',
#   '13',
#   datetime.datetime(2018, 11, 3, 16, 21),
#   '관람객'],
#  ['kiki****',
#   '위플래쉬 맘마미아 비긴어게인 라라랜드의 계보를 잇는 음악영화입니다 5점만점에 5점 드립니다',
#   '10',
#   '101',
#   '24',
#   datetime.datetime(2018, 10, 31, 13, 26),
#   '관람객'],
#  ['그린스프링(circ****)',
#   '레전드의 귀환 120분이 12초 같았다',
#   '10',
#   '92',
#   '20',
#   datetime.datetime(2018, 10, 31, 14, 40),
#   0],
#  ['waterdrop(phiw****)',
#   '웸블리 공연 때부터는 눈물을 줄줄 흘렸던 것 같습니다. 영화관에서 상영을 내리기 전에 몇 번 더 감상해야 할 것 같네요. 개봉을 손꼽아 기다렸는데 기대했던 이상으로 감동을 받았습니다.',
#   '10',
#   '82',
#   '12',
#   datetime.datetime(2018, 10, 31, 23, 20),
#   0],
#  ['인피니티(raps****)',
#   '얼마만입니까,,최고입니다//',
#   '10',
#   '81',
#   '12',
#   datetime.datetime(2018, 10, 31, 14, 58),
#   0],
#  ['바람돌이(kwon****)',
#   '왜 눈물이 나는걸까요?',
#   '10',
#   '80',
#   '12',
#   datetime.datetime(2018, 11, 3, 18, 14),
#   0],
#  ['영(seyo****)',
#   '사운드 관으로 한 번, 아이맥스로 한 번 또 보고싶은 올해 최고의 영화ㅠㅠ 영화보고난 뒤로 플레이리스트가 퀸 노래로 꽉꽉 채워짐♥',
#   '10',
#   '83',
#   '19',
#   datetime.datetime(2018, 10, 31, 11, 5),
#   '관람객'],
#  ['숨히얼(tndu****)',
#   '프레디 머큐리 그의 말처럼 지금도 퀸의 쇼는 계속 되고있다.',
#   '10',
#   '73',
#   '10',
#   datetime.datetime(2018, 10, 31, 15, 24),
#   0],
#  ['난닝구요(yasa****)',
#   '남편하고 둘이 펑펑울다왔네요. 왜  눈물짜게하는 장면이 없는데 눈물이 멈춰지질않는걸까요? 남편은 사운드특화영화관에서 한번 더보자고 난리입니다.  정말  너무 일찍 데려가셨어..그는 천재인듯요ㅠㅠ',
#   '10',
#   '75',
#   '13',
#   datetime.datetime(2018, 11, 5, 12, 4),
#   0],
#  ['ㅇㄴㅁㅇ(minf****)',
#   '러닝타임중 20분간의 ‘라이브 에이드’ 재현은 초마다 한번씩 소름돋는 구성. 퀸 자체에 집중하기보다는 프레디에 초점을 공략한건 개인차이겠지만, 역사적 위대함을 증명하기에는 부족했다',
#   '8',
#   '84',
#   '22',
#   datetime.datetime(2018, 10, 31, 22, 57),
#   0],
#  ['백호(gusw****)',
#   '퀸을 2시간안에 담을 수 없다만 퀸의 팬으로써 좋았습니다',
#   '10',
#   '77',
#   '16',
#   datetime.datetime(2018, 10, 31, 11, 16),
#   0],
#  ['elve****',
#   '너무 마음이 아프고 너무 아름답네요.',
#   '10',
#   '69',
#   '10',
#   datetime.datetime(2018, 11, 1, 20, 41),
#   0],
#  ['뿅(mook****)',
#   '전 시사회로 그제 봤으영~제가 워낙 영화를 좋아하는 사람인지라 왠만한 영화는 다보구 있습니다전 지루 하지 않고 잼있게 봤습니다간혹 몸에  전율도 오더라구여~ 이러지도 저러지도 못하는 그맘이안스럽기도ㅡㅠ시간이 된다면 ...',
#   '10',
#   '80',
#   '21',
#   datetime.datetime(2018, 10, 31, 10, 43),
#   0],
#  ['해피바이러스(yj02****)',
#   '복잡한 사생활을 두둔할수는 없지만 왜인지 나는 그가  너무 외로워보였다 마지막 공연장면 내내 감동과 함께 여운이 남았다 한동안 다시 퀸노래 반복예약',
#   '9',
#   '67',
#   '9',
#   datetime.datetime(2018, 11, 11, 1, 36),
#   0],
#  ['xwjg****',
#   '라이브 에이드 공연장면만 봐도 돈 안 아깝다.',
#   '10',
#   '72',
#   '14',
#   datetime.datetime(2018, 10, 31, 21, 40),
#   '관람객'],
#  ['좋은음악(gksr****)',
#   '프레디 머큐리에게 경의를',
#   '10',
#   '68',
#   '11',
#   datetime.datetime(2018, 11, 2, 0, 38),
#   0],
#  ['하이룽(13ou****)',
#   '걍 두말이 필요없음. 개재밌음 무조건 보셈. 진짜 근 10년동안 영화관에서 본 영화중에 탑이었다.',
#   '10',
#   '67',
#   '11',
#   datetime.datetime(2018, 11, 2, 23, 59),
#   0],
#  ['hj(gomo****)',
#   '늘 유튜브로만 보던 퀸을 영화 속 생생한 공연으로 볼수 있게 이 영화를 만들어주신 모든분들께 감사드립니다',
#   '10',
#   '66',
#   '11',
#   datetime.datetime(2018, 11, 2, 2, 12),
#   '관람객'],
#  ['make****',
#   'Love of my life에 서럽게 운건 나뿐?',
#   '10',
#   '66',
#   '12',
#   datetime.datetime(2018, 11, 2, 21, 29),
#   0],
#  ['isnarmire(yoi1****)',
#   '보헤미안 랩소디 가사가 프레디의 인생과 겹쳐보여서 눈물이 났다',
#   '10',
#   '64',
#   '11',
#   datetime.datetime(2018, 11, 10, 2, 12),
#   0],
#  ['roedeer(ucdi****)',
#   '기대 이상으로 재밌게 봤습니다! 콘서트를 다녀온 기분을 들게 만들어 주는 영화인거같아요 퀸 좋아하시는 분들은 실망 안하실거 같아요 단순하게 노래만 생각하고 봤는데 생각보다 중간중간 감동적인 부분들도 많아서 더 재밌게...',
#   '10',
#   '63',
#   '11',
#   datetime.datetime(2018, 10, 31, 14, 6),
#   0],
#  ['사우스포(pana****)',
#   '바로 옆 평론가들 평점 코멘트는 말장난들 개나소나 평론가하는 세상이니.여기 네티즌들 코멘트가 훨 좋고 와닿네.',
#   '10',
#   '62',
#   '11',
#   datetime.datetime(2018, 11, 1, 23, 52),
#   0],
#  ['Stanley(seba****)',
#   '영화 끝나지도 안끝났는데 불좀 키지마. 감동이 싹 사라지자너. - 2018.11.03 16:00 월드타워 관람객.',
#   '7',
#   '73',
#   '22',
#   datetime.datetime(2018, 11, 5, 8, 14),
#   0],
#  ['감귤(kkr7****)',
#   '재밌나요? 재밌으면 공감 재미없으면 비공감 주세요',
#   '10',
#   '73',
#   '22',
#   datetime.datetime(2018, 10, 31, 15, 35),
#   0],
#  ['파도밭(bmbc****)',
#   '눈물만흐른다ㅠㅠ 배우들이 연기를 잘해도 프레디를 기억하는 사람들은 어색하게 느껴 질때가 있는데 퀸의 위대힌 음악이 다 커버해준다. 감독이 찰떡같이 퀸의 정수들만 뽑아놨다.영화 끝까지 보자 제발.프레디가 The sho...',
#   '10',
#   '57',
#   '7',
#   datetime.datetime(2018, 10, 31, 13, 2),
#   0],
#  ['LEEON(zane****)',
#   '며칠 전 스타 이즈 본을 보고 잘 만든 음악영화라고 생각했습니다. 그리고 오늘 이 영화를 봤는데, 이 영화는 그냥 미쳤어요. 일단 보세요.',
#   '10',
#   '60',
#   '10',
#   datetime.datetime(2018, 11, 3, 3, 30),
#   0],
#  ['hwsc****',
#   '위아더챔피언!! 볼 수 없었던 그들의 위대한 공연을 봤다!!!! 내가!!',
#   '10',
#   '61',
#   '11',
#   datetime.datetime(2018, 10, 31, 14, 45),
#   '관람객'],
#  ['sky1****',
#   '영화보고 집에와서 유튜브로 LIve AID 1985 콘서트 실제영상보고 소름 한 번 더...',
#   '10',
#   '56',
#   '7',
#   datetime.datetime(2018, 11, 7, 13, 34),
#   0],
#  ['Junglezone(jung****)',
#   '전율 그자체. 올해 최고의 영화',
#   '10',
#   '58',
#   '9',
#   datetime.datetime(2018, 10, 31, 14, 48),
#   0],
#  ['결심(psj8****)',
#   '혼영하기 정말 좋은 영화',
#   '10',
#   '55',
#   '7',
#   datetime.datetime(2018, 11, 10, 17, 40),
#   0],
#  ['뒤주(gneg****)',
#   'radio gaga 나올때 남정네가 펑펑 울어서 놀라셨을 옆자리 여자분 죄송합니다..',
#   '10',
#   '55',
#   '7',
#   datetime.datetime(2018, 11, 2, 21, 27),
#   0],
#  ['shin****',
#   '메리랑 빗속에서 헤어질때부터 끝날때까지 계속 울었습니다 수십번도 더 본 1985년 공연을 어쩜 그렇게 똑같이 재현했는지..영화 만드신분들 감사합니다ㅠㅠ',
#   '10',
#   '57',
#   '9',
#   datetime.datetime(2018, 11, 2, 2, 28),
#   0],
#  ['조리퐁(kmin****)',
#   '내가 태어난 해에 세상에 나온 보헤미안 랩소디.. 40년이 넘어도 명곡은 변함이 없네요.영화도 너무 좋네요  개봉일 조조로 봤습니다.',
#   '10',
#   '58',
#   '10',
#   datetime.datetime(2018, 10, 31, 13, 37),
#   0],
#  ['컴플라이(lumi****)',
#   '영화보다가 스탠딩 하고싶어진 나!',
#   '10',
#   '60',
#   '12',
#   datetime.datetime(2018, 10, 31, 23, 30),
#   0],
#  ['이지스(lkg5****)',
#   '완벽한 타인도 재미 있다 . 하지만 완벽한 타인때문에 이영화를 놓친다는건 정말 바보 같은 짓이다',
#   '10',
#   '53',
#   '6',
#   datetime.datetime(2018, 11, 13, 22, 27),
#   0],
#  ['전해진(ioli****)',
#   '엔딩크레닛까지 끝난 후 중간에 앉으신 아저씨의 3분간 기립박수.. 처음으로 늦게 태어난 걸 후회해봤음 전설의 가수의 팬으로 이 영화를 접한다면 도대체 어떤 느낌일지',
#   '10',
#   '55',
#   '8',
#   datetime.datetime(2018, 11, 10, 1, 54),
#   0],
#  ['체리맛죠스바(jypa****)',
#   '아주 좋았습니다. 실제 공연장에 와있는 것 같았어요.',
#   '9',
#   '61',
#   '14',
#   datetime.datetime(2018, 10, 31, 11, 6),
#   0],
#  ['catp****',
#   '에이즈 진단 받은 병원에서 앉아있던 환자가 에오할 때 돌아보던 머큐리의 표정이 환자들에게도 기쁨을 줄 수 있어 행복하다는 표정인 것 같았어요',
#   '10',
#   '51',
#   '5',
#   datetime.datetime(2018, 11, 6, 1, 10),
#   0],
#  ['민트(vick****)',
#   '엔딩 크레딧까지 진짜 최고였어요 ^^',
#   '10',
#   '58',
#   '12',
#   datetime.datetime(2018, 10, 31, 15, 16),
#   0],
#  ['brig****',
#   '이미 사라진지 수많은 시간이 흘렀음에도 팬을 만들어내는 퀸의 미친 흡입력',
#   '10',
#   '51',
#   '6',
#   datetime.datetime(2018, 11, 8, 23, 19),
#   0],
#  ['Barbara(mbac****)',
#   'Mama하며 보헤미안랩소디 부르는 앞소절에 왈칵 눈물이 났어요 we are the champion에서도 흘렀구요 저한테 꼭 필요했던 잘 만들어진 영화 입니다 기회가 된다면 다시 꼭 보고싶습니다 ~~',
#   '10',
#   '54',
#   '9',
#   datetime.datetime(2018, 11, 1, 19, 25),
#   '관람객'],
#  ['껴묻거리(whdh****)',
#   '그냥 퀸 노래나 들으러 가자라는 느낌이었는데, 의외로 전개나 연출이 좋아서 큰 감동을 받았네요.',
#   '10',
#   '56',
#   '11',
#   datetime.datetime(2018, 10, 31, 22, 34),
#   0],
#  ['왓썹요(deli****)',
#   '집으로가는길 다들 퀸 음악 들으셨죠?네 맞습니다 감동이네요',
#   '10',
#   '57',
#   '12',
#   datetime.datetime(2018, 11, 10, 2, 7),
#   '관람객'],
#  ['ljb5****',
#   '여러분들 믿고 봐도되겠습니까??? 지금 예매합니다이~!!',
#   '8',
#   '51',
#   '7',
#   datetime.datetime(2018, 11, 8, 22, 36),
#   0],
#  ['gnujnim(gkdl****)',
#   '아무생각없이 남자친구가 예매해서 봤는데 인생영화를 봤습니다.',
#   '10',
#   '51',
#   '7',
#   datetime.datetime(2018, 11, 5, 17, 5),
#   0],
#  ['ooil****',
#   '마지막 콘서트장면 싱크로율 100프로더라구요 ㅋㅋ소름',
#   '10',
#   '52',
#   '8',
#   datetime.datetime(2018, 11, 5, 9, 35),
#   '관람객'],
#  ['제이드홍(hong****)',
#   '마지막 하이라이트 때 옆자리 아줌마 전화 통화했네요. 그장면에서 전화하는것도 신기하고 전 올해들어 가장 빡친순간이었습니다. 영화는 너무 좋았습니다.',
#   '10',
#   '53',
#   '9',
#   datetime.datetime(2018, 11, 7, 22, 50),
#   0],
#  ['yu64****',
#   '과한 치아가 너무거슬렸지만 실제 프레디머큐리는 그정돈아니던데',
#   '10',
#   '54',
#   '10',
#   datetime.datetime(2018, 11, 9, 2, 14),
#   0],
#  ['서랍장남작(rock****)',
#   '기대한만큼 두배로 돌려주는 최고의 영화.',
#   '10',
#   '55',
#   '11',
#   datetime.datetime(2018, 10, 31, 14, 57),
#   0],
#  ['배수인(ddan****)',
#   '솔직히 퀸을 아무리좋아한다해도 약간 걱정반 기대반이였는데 이영화보고 이렇게 울지 몰랐다',
#   '10',
#   '56',
#   '12',
#   datetime.datetime(2018, 10, 31, 21, 44),
#   0],
#  ['ddung(ddun****)',
#   '진짜 두번 아니 세번 네번 볼거에요!!! 마지막 공연만으로도 압도적!!!',
#   '10',
#   '56',
#   '12',
#   datetime.datetime(2018, 10, 31, 16, 3),
#   '관람객'],
#  ['으뜸맘(hjw0****)',
#   '함께 발 구르고 손뼉치며 we will rock you!!!',
#   '10',
#   '59',
#   '15',
#   datetime.datetime(2018, 10, 31, 15, 16),
#   0],
#  ['Heima(cumj****)',
#   '옆에서 팝콘 우적우적 쳐먹는 새 끼들 좀 다 뒤졌으면',
#   '10',
#   '72',
#   '28',
#   datetime.datetime(2018, 11, 1, 18, 10),
#   0],
#  ['renegade12(rene****)',
#   '그냥 도입부에서 흰 나시에 옅은 색의 청바지를 입은 프레디 머큐리의 걸어가는 뒷모습만으로 영화는 끝났다.',
#   '10',
#   '46',
#   '3',
#   datetime.datetime(2018, 11, 13, 18, 52),
#   0],
#  ['elmo****',
#   '라이브에이드 공연장면은 정말최고... 퀸에 대해 전혀 모르고 그냥 가서봤는데 공연장면에서 왜 눈물이나는건지 정말 이유가 궁금함',
#   '10',
#   '48',
#   '5',
#   datetime.datetime(2018, 11, 5, 9, 38),
#   0],
#  ['ANNE(bfw1****)',
#   '세번봤다. 헌데 또 보고싶다. 이거.진짜 중독이다',
#   '10',
#   '49',
#   '6',
#   datetime.datetime(2018, 11, 15, 2, 55),
#   0],
#  ['탐정(j790****)',
#   '극장에서만 두번이상 봐도 될 영화',
#   '10',
#   '49',
#   '6',
#   datetime.datetime(2018, 11, 10, 0, 21),
#   0],
#  ['원더보이(durs****)',
#   '퀸의 히트곡이 이렇게 많을줄 몰랐습니다.',
#   '10',
#   '49',
#   '6',
#   datetime.datetime(2018, 11, 5, 9, 36),
#   0],
#  ['호성잼(a040****)',
#   '프레디 머큐리는 전설이 되길 원했고, 전설이 되었다.',
#   '10',
#   '49',
#   '6',
#   datetime.datetime(2018, 11, 3, 3, 5),
#   0],
#  ['송경수(sks0****)',
#   '이 영화를 본 우리는 챔피언이다',
#   '10',
#   '49',
#   '6',
#   datetime.datetime(2018, 11, 2, 21, 3),
#   0],
#  ['아이러니(rntj****)',
#   '2시간 14분짜리 부적응자를 위한 부적응자들의 콘서트. 반사적으로 박자를 맞추는 당신을 발견할 것이다.',
#   '10',
#   '50',
#   '7',
#   datetime.datetime(2018, 11, 3, 4, 35),
#   0],
#  ['LIGHTYEAR(jbkw****)',
#   '일주일 내내 퀸 노래 밖에 안 듣게되는 마법같은 영화...',
#   '9',
#   '51',
#   '8',
#   datetime.datetime(2018, 11, 14, 16, 31),
#   0],
#  ['jade(cool****)',
#   '손에 땀을 쥐고 벅차오르다가 눈시울도 붉어지는 인간의 위대함을 느끼는 퀸의 음악과 가사는 긍정적인 에너지를 갖고 있어 더욱 감동스럽다. 스토리도 지저분하지 않고 정돈돼 있다. 사람의 외로움에 대해서도 되돌아 보게된다...',
#   '10',
#   '51',
#   '8',
#   datetime.datetime(2018, 11, 2, 4, 26),
#   0],
#  ['안녕(kksm****)',
#   '라디오가가 라디오구구 라디오블라블라',
#   '9',
#   '52',
#   '9',
#   datetime.datetime(2018, 11, 5, 0, 26),
#   0],
#  ['a bittersweet life(jinc****)',
#   '장점이 단점을 다 잡아먹는 영화.어쩔수없이 만점 Queen  forever ㅠ',
#   '10',
#   '52',
#   '9',
#   datetime.datetime(2018, 11, 1, 13, 56),
#   0],
#  ['gracie(jgra****)',
#   '인트로부터 전율이...모든 순간순간들이 좋았습니다프레디 머큐리의 숨결을 다시 느끼는 기분입니다최고예요',
#   '10',
#   '52',
#   '9',
#   datetime.datetime(2018, 10, 31, 12, 54),
#   0],
#  ['3651(kooj****)',
#   '퀸의 노래는 알았으나 퀸에 대해서는 잘 몰랐었는데, 이 영화 덕분에 그들와 그들의 멋진 노래들을 알게 되었네요. 보는 내내 심장이 뛰었고 마지막엔 저절로 눈물이 났습니다. 대학생인 저에게 열정을 선물해 준 인생 영화...',
#   '10',
#   '53',
#   '10',
#   datetime.datetime(2018, 11, 4, 3, 29),
#   0],
#  ['앤(blue****)',
#   '처음 somebody to love 부터 라이브에이드, 엔딩크레딧까지 전율의 연속, 실제 라이브에이드 영상 속 피아노 위에 콜라 까지   똑같이 재연하다니... 브라이언싱어와 라미말렉에게 감사를!',
#   '8',
#   '53',
#   '10',
#   datetime.datetime(2018, 11, 2, 10, 36),
#   0],
#  ['이츠이티(tnrw****)',
#   '영화관에서 떼창하고싶다',
#   '10',
#   '55',
#   '12',
#   datetime.datetime(2018, 11, 3, 2, 48),
#   0],
#  ['voyages(dior****)',
#   '퀸의 완벽한 재림. 프레디와 그의 팬들에게 보내는 감동적인 헌정영화. 다시 못 볼 콘서트를 영화관에서 보고 왔다. 스크린 X로 꼭 보시길!',
#   '10',
#   '55',
#   '12',
#   datetime.datetime(2018, 10, 31, 21, 41),
#   0],
#  ['ahop****',
#   '방금 영화끝나고 나왔는데 이런 영화가 천만관객이 아닌게 신기하네요 지금 한국영화가 영화순위 1위하고있다는게 신기함',
#   '10',
#   '46',
#   '4',
#   datetime.datetime(2018, 11, 10, 15, 33),
#   '관람객'],
#  ['문지섭(moon****)',
#   '라이브로 듣는다면 어떨까? 상상조차 안되네요...',
#   '10',
#   '46',
#   '4',
#   datetime.datetime(2018, 11, 5, 22, 3),
#   0],
#  ['purp****',
#   '전 세계 박스오피스 1위',
#   '10',
#   '47',
#   '5',
#   datetime.datetime(2018, 11, 5, 23, 13),
#   0],
#  ['blue(nymp****)',
#   '불꽃처럼 살다 간 프레디.라이브에이드는 실제 현장에있는듯 끝나고나서도 한참동안 몸이 떨리고 여운이남았다.',
#   '10',
#   '47',
#   '5',
#   datetime.datetime(2018, 11, 5, 17, 16),
#   0],
#  ['불타는핫독(k611****)',
#   '유투브로 다시보니 마지막  프레디의 음색이 힘겨워하는걸  이젠 이해가 되네요영화보고  울고  유투브 보고 다시울고나와같이  울어버린 댓글보고 또 주르륵~',
#   '10',
#   '48',
#   '6',
#   datetime.datetime(2018, 11, 2, 0, 37),
#   0],
#  ['jerr****',
#   '1 프레디 머큐리의 내면 변화를 추적하는 로드 무비같은 영화 2 프레디 중심 서사와 내면 서사의 사건이 쉴틈없이 전개됨 3 영화를 보면서 한 인간으로서 프레디의 고독과 광기를 이해 4 위플래쉬처럼 마지막에 관객도 프...',
#   '9',
#   '48',
#   '6',
#   datetime.datetime(2018, 11, 1, 13, 25),
#   0],
#  ['어디서 좀 놀았니(9444****)',
#   '최고다.콘서트장에 빨려든 느낌.',
#   '10',
#   '48',
#   '6',
#   datetime.datetime(2018, 10, 31, 21, 44),
#   0],
#  ['hych****',
#   '이런 미친 영화를 봤나...방심하고 들어갔다. 울고 나옴',
#   '10',
#   '49',
#   '7',
#   datetime.datetime(2018, 11, 10, 8, 28),
#   0],
#  ['또라이(jsvi****)',
#   '퀸을 몰랐다면 또 퀸이 그리웠다면 또 퀸을 별로라 생각했다면 꼭 보시길!!! 가슴 뛰는 시간 이었다!! 그들을 들을 수 있어서 또 볼 수 있어서!!',
#   '10',
#   '49',
#   '7',
#   datetime.datetime(2018, 10, 31, 11, 46),
#   '관람객'],
#  ['띠로리(chm5****)',
#   '두시간 동안 제대로 귀호강! 공연 장면 진짜 최고 bb',
#   '10',
#   '51',
#   '9',
#   datetime.datetime(2018, 10, 31, 14, 56),
#   '관람객'],
#  ['마니(gmla****)',
#   '인생영화!고독하고.고독하고.또고독하다.',
#   '10',
#   '52',
#   '10',
#   datetime.datetime(2018, 11, 2, 3, 11),
#   0],
#  ['신이치(heij****)',
#   '그동안 몰랐던 천재 뮤지션의 고독과 외로움을 알 수 있어서, 그를 다시 만날 수 있어서 좋았다. 아니 최고였다.',
#   '10',
#   '47',
#   '6',
#   datetime.datetime(2018, 11, 1, 20, 17),
#   0],
#  ['갈비만두(asdg****)',
#   '죽기전에 봐서 다행이다',
#   '10',
#   '48',
#   '7',
#   datetime.datetime(2018, 11, 5, 8, 34),
#   0],
#  ['킴스빈스 커피공장(kims****)',
#   '말해 뭐해.. 브라이언 메이 싱크 100%, 프레디 머큐리 싱크 80% 노래는 립싱크인것 같다..',
#   '10',
#   '53',
#   '12',
#   datetime.datetime(2018, 10, 31, 14, 21),
#   0],
#  ['사오공(9208****)',
#   '요즘 너무 힘들고 외롭고 어디 말할곳은없고영화보다 이게 무슨기분인지.. 울뻔함',
#   '10',
#   '43',
#   '3',
#   datetime.datetime(2018, 11, 4, 23, 55),
#   0],
#  ['애국가(hdhr****)',
#   '리듬타는 다리를 말리느냐 고생했습니다',
#   '10',
#   '45',
#   '5',
#   datetime.datetime(2018, 11, 4, 4, 44),
#   0],
#  ['can3****',
#   '50대 주부입니다개봉 영화는 거의 보는 편입니다만같은 영화를 두번 보고 싶다는 생각은 안 하는데이 번에는 완전?영화 평도 생전 첨 남길 정도로 좋았습니다',
#   '10',
#   '42',
#   '3',
#   datetime.datetime(2018, 11, 8, 20, 1),
#   0],
#  ['노바(scot****)',
#   '그냥 보고 듣고 느껴보길....',
#   '10',
#   '47',
#   '8',
#   datetime.datetime(2018, 11, 1, 22, 54),
#   0],
#  ['행복의경운기(isdn****)',
#   '퀸 팬이라면 무조건 보시길 마지막 공연장면은 압권이다.',
#   '10',
#   '48',
#   '9',
#   datetime.datetime(2018, 10, 31, 23, 27),
#   0],
#  ['ehdw****',
#   '2시간이라는 시간이 전혀 아깝지 않은 그런 영화였고 좋아하는 밴드 퀸의 대해서 잘 나온거 같아 너무 좋았다.배우들도 너무 비슷하여서 영화 몰입감도 좋았고 연기력도 좋았다.',
#   '10',
#   '48',
#   '9',
#   datetime.datetime(2018, 10, 31, 15, 23),
#   0],
#  ['youe****',
#   '자막올라가는동안 사람들 아무도안나가네요. 마블은 한두명은 나가는데',
#   '10',
#   '41',
#   '3',
#   datetime.datetime(2018, 11, 5, 0, 41),
#   '관람객'],
#  ['욥태엽태(rlax****)',
#   '방금 본거까지 해서 5번째 봤습니다. 또 보러 갈 생각입니다. 지난 세월동안 존재해주셔서 감사합니다.',
#   '10',
#   '43',
#   '5',
#   datetime.datetime(2018, 11, 8, 18, 30),
#   0],
#  ['민지님(rlaa****)',
#   '15억명은 공연이 아니라 사건이지..',
#   '10',
#   '43',
#   '5',
#   datetime.datetime(2018, 11, 3, 8, 40),
#   0],
#  ['Zanetti(umty****)',
#   '그냥 보세요 만원이 아깝지 않습니다',
#   '10',
#   '44',
#   '6',
#   datetime.datetime(2018, 11, 5, 9, 29),
#   0],
#  ['Space Bar(kgh7****)',
#   '상영시간늘려서 노래더나왔으면좋겠다!',
#   '10',
#   '45',
#   '7',
#   datetime.datetime(2018, 11, 1, 20, 20),
#   0],
#  ['올라프간달프(ghdg****)',
#   '내가 퀸시대를 못산게 평생한이다.',
#   '10',
#   '43',
#   '6',
#   datetime.datetime(2018, 11, 5, 17, 15),
#   0],
#  ['chle****',
#   '좌빨 개 쓰레기 영화속에서 진주같은 영화다.촤근에 들어서 유일하게. 명작을 만나서 너무 감동적이고.전율이 흘렀다. 다시 한번더 감동을 느끼고 싶다. 여윽시.짱이다!',
#   '10',
#   '47',
#   '10',
#   datetime.datetime(2018, 11, 11, 8, 28),
#   0],
#  ['골디락스(spri****)',
#   '아이맥스로 봤는데 "압도한다" 라는 말은 이 영화 마지막 공연을 두고 하는 말 일듯.',
#   '9',
#   '47',
#   '10',
#   datetime.datetime(2018, 10, 31, 11, 27),
#   0],
#  ['wiz723(jung****)',
#   '주인공 남우주연상 줘야한다!!얼마나 연습했을지 가늠안되는 정말 환상적인 연기..아는 노래 나올때마다 반갑고 떨리는 마음으로 봤다',
#   '10',
#   '38',
#   '2',
#   datetime.datetime(2018, 11, 22, 21, 38),
#   0],
#  ['넷다이버(pata****)',
#   '퀸의 음악만으로도 완벽하다',
#   '10',
#   '39',
#   '3',
#   datetime.datetime(2018, 11, 5, 8, 31),
#   0],
#  ['caco****',
#   '극장에서 안 보면 후회합니다 마직막 공연씬 눈시울이 붉어질 정도로 정말 감동입니다',
#   '10',
#   '40',
#   '4',
#   datetime.datetime(2018, 11, 5, 17, 43),
#   '관람객'],
#  ['JunHee(wnsg****)',
#   '만들어 주신 제작자 여러분 감사합니다',
#   '10',
#   '41',
#   '5',
#   datetime.datetime(2018, 11, 2, 0, 40),
#   0],
#  ['지유개지우님(vivi****)',
#   '돈주고  다시한번 더 보고싶은 영화',
#   '8',
#   '46',
#   '10',
#   datetime.datetime(2018, 11, 6, 1, 57),
#   0],
#  ['장동욱(jdu7****)',
#   '아까보고 왔는데 로튼 토마토는 썩었다',
#   '10',
#   '46',
#   '10',
#   datetime.datetime(2018, 10, 31, 14, 28),
#   0],
#  ['베이비샤크(occb****)',
#   '한 편의 콘서트 같은 영화! 재미 감동 다 있네요! 좋아용!',
#   '10',
#   '51',
#   '15',
#   datetime.datetime(2018, 10, 31, 11, 27),
#   '관람객'],
#  ['llllllIllllll(kyur****)',
#   '하아 마지막 20분공연은 잊을수없을꺼같다. 진짜가슴을 울렸다. 처음으로 귀르가즘 느꼈다 영화관의 웅장한 사운드와 퀸의 노래 한번도 직접본적없는 퀸의 콘서트지만 이영화가 대신 가게해준게같다.',
#   '10',
#   '37',
#   '2',
#   datetime.datetime(2018, 11, 4, 1, 23),
#   0],
#  ['An instigator(quin****)',
#   '스토리는 밋밋하지만, 적절한 음악 배치와 라이브 에이드의 소름 돋을 정도로 똑같은 재현이 이 영화의 가치를 한껏 높여준다. 배우들 싱크로율은 말할 것도 없이 훌륭하다. 퀸의 팬이든, 그렇지 않든 이 영화는 충분히 극...',
#   '8',
#   '40',
#   '5',
#   datetime.datetime(2018, 11, 4, 22, 42),
#   0],
#  ['jjo3****',
#   '보고있는동안 눈물만~~',
#   '10',
#   '42',
#   '7',
#   datetime.datetime(2018, 11, 1, 0, 10),
#   0],
#  ['재로리(ddun****)',
#   '스크라쿼터제는 없어져야 합니다. 국산영화 99%는 쓰레기',
#   '10',
#   '37',
#   '3',
#   datetime.datetime(2018, 11, 16, 14, 19),
#   0],
#  ['Starname(manu****)',
#   '썸바리툴러업~~~~',
#   '10',
#   '40',
#   '6',
#   datetime.datetime(2018, 10, 31, 15, 18),
#   0],
#  ['포포리오(song****)',
#   '최고10101010',
#   '10',
#   '40',
#   '6',
#   datetime.datetime(2018, 10, 31, 14, 9),
#   0],
#  ['진스(deda****)',
#   '보고 다시 확신했다 나도 퀸같은 레전드가 되겠다고',
#   '10',
#   '43',
#   '10',
#   datetime.datetime(2018, 10, 31, 19, 53),
#   '관람객'],
#  ['끼다란애(rhyt****)',
#   '알고봐도 오지고.. 모르고 본 제 와이프는 울었습니다.',
#   '10',
#   '34',
#   '2',
#   datetime.datetime(2018, 11, 2, 4, 21),
#   0],
#  ['홍짬(baik****)',
#   '살아있다면 꼭 한번 콘서트를 보고싶다...',
#   '10',
#   '35',
#   '3',
#   datetime.datetime(2018, 11, 5, 21, 54),
#   0],
#  ['기다리곰(seun****)',
#   '10월31일 롯데시네마 월드타워 슈퍼플렉스G 에서 봤는데, 무대인사 말고 영화관 꽉차는거 처음봤습니다b영화관 사운드로 들으니 최고네요!!',
#   '10',
#   '35',
#   '3',
#   datetime.datetime(2018, 10, 31, 23, 43),
#   0],
#  ['dote upon(dote****)',
#   '아예 가수에 대한 정보도 모르고 갔었는데거의 다 아는 곡이라 놀랐네요',
#   '10',
#   '36',
#   '4',
#   datetime.datetime(2018, 11, 24, 15, 22),
#   '관람객'],
#  ['장한별(star****)',
#   "이 영화는 프레디 머큐리라는 전설적인 인물을 잘 담아내지 못한 것 같습니다...그의 삶과 고통, 그의 고뇌 그것들을 어떻게 극복했는지에 대한 묘사가 턱없이 부족했습니다... 영화적 완성도는 별로였지만 '퀸&#...",
#   '10',
#   '36',
#   '4',
#   datetime.datetime(2018, 11, 3, 23, 42),
#   0],
#  ['명수명수(lumi****)',
#   '그저, 감동꼭 보세요',
#   '10',
#   '36',
#   '4',
#   datetime.datetime(2018, 10, 31, 15, 8),
#   0],
#  ['고나은(bett****)',
#   '이게 왜 완벽한 타인보다 밑에 있는지 이해가 안됨',
#   '10',
#   '40',
#   '8',
#   datetime.datetime(2018, 11, 4, 23, 33),
#   0],
#  ['성유빈(clic****)',
#   '오랜만에 영화다운 영화를 본 것 같은 찐~한 여운이 남네요! 음악영화의 진수를 보여주는... 또 보러 가야겠다는 !',
#   '10',
#   '41',
#   '9',
#   datetime.datetime(2018, 10, 31, 14, 48),
#   '관람객'],
#  ['오잼(timj****)',
#   '역시 영국의 우리하나....',
#   '10',
#   '42',
#   '10',
#   datetime.datetime(2018, 10, 31, 20, 46),
#   0],
#  ['knsg****',
#   '잠이 안 온다. 뭔가로 맞은 듯 한 기분...마지막 장면..시작하자 마자 그냥 눈물이 났다. 그 당시 나는 4살이였다. 너무 어렸다. 몰랐다. 이 어마어마한 사람을....영화를 보고도 말로 표현을 못 하겠는데..참....',
#   '10',
#   '35',
#   '4',
#   datetime.datetime(2018, 11, 10, 2, 45),
#   0],
#  ['h17k****',
#   '집에서 볼 생각하지마요 ㅜㅜ꼭 극장에서 사운드가 정말좋은 극장에서꼭 꼭 보세요',
#   '10',
#   '35',
#   '4',
#   datetime.datetime(2018, 11, 5, 2, 0),
#   0],
#  ['karm****',
#   '퀸을 아는 분들은 추억과 회상을,모르셨던 분들은  새로운 음악의 큰 별을 찾았다는 감동을 느낄수 있을겁니다.',
#   '10',
#   '35',
#   '4',
#   datetime.datetime(2018, 10, 31, 13, 18),
#   0],
#  ['rachel(only****)',
#   '퀸을좋아했었는데  프레디 사적인 생활은 처음 알았네요  라이브에이드 공연장면은 너무 똑같이 재연했네요 영화속  마지막  라이브에이드 장면에서 울컥했어요집에와서 라이브에이드 공연 실화보고 다시한번감동 받았네요',
#   '10',
#   '33',
#   '3',
#   datetime.datetime(2018, 11, 5, 15, 19),
#   0],
#  ['이원재(khan****)',
#   '영화관에서 앵콜 외치고싶었습니다.',
#   '10',
#   '34',
#   '4',
#   datetime.datetime(2018, 11, 2, 4, 24),
#   0],
#  ['버스전문가(yjw0****)',
#   '신파가 아닌데 눈물나는 착한 영화. 이런 영화 처음입니다',
#   '10',
#   '35',
#   '5',
#   datetime.datetime(2018, 11, 8, 23, 39),
#   0],
#  ['이은주(eunj****)',
#   '음악 너무 좋아서 소름돋음 존잼',
#   '9',
#   '35',
#   '5',
#   datetime.datetime(2018, 11, 5, 8, 52),
#   0],
#  ['viol****',
#   '마지막 라이브 공연 장면 감동과 소름..한번 더 보려고 합니다.전설이 너무 일찍 떠난 것이 아깝고 안타까웠습니다ㅡ',
#   '10',
#   '36',
#   '6',
#   datetime.datetime(2018, 11, 2, 0, 33),
#   0],
#  ['비와씨(some****)',
#   '라이브 에드 만으로 표값은 하는 영화',
#   '8',
#   '40',
#   '10',
#   datetime.datetime(2018, 11, 4, 14, 55),
#   0],
#  ['패턴몽상가(good****)',
#   '영화 평론가란..  일반적인 감정 교감을 할 수 없게 되어버린 불쌍한 사람들이구나',
#   '10',
#   '32',
#   '3',
#   datetime.datetime(2018, 11, 20, 12, 42),
#   0],
#  ['민하(a159****)',
#   '원래는 창궐을 볼거였지만 극장을 가던 도중 CGV 앱을 켜서 다른거 볼거있나 찾아보다 평점이 높길래 이걸 보자고 하고 퀸에 대해 아무것도 모르고 줄거리도 모르고 그냥 진짜 아무것도 모르는 상태에서 들어가 영화를 봤는...',
#   '10',
#   '32',
#   '3',
#   datetime.datetime(2018, 11, 5, 3, 22),
#   0],
#  ['nkh9****',
#   '여운이 가시질않네요 또 보고싶습니다',
#   '10',
#   '33',
#   '4',
#   datetime.datetime(2018, 11, 2, 0, 44),
#   0],
#  ['stud****',
#   '마지막 엔딩크레딧 The show must go on 까지 완벽한 선곡이었다',
#   '10',
#   '33',
#   '4',
#   datetime.datetime(2018, 11, 1, 20, 28),
#   0],
#  ['ko(euro****)',
#   '비틀즈나 엘튼존은 너무 말랑말랑하고 메탈리카는 너무 하드하다. 영화를 보고 퀸에 대해서 이제서야 새롭게 알아가고 있다. 아니 흠뻑 빠져 버렸다. 완전히.',
#   '9',
#   '34',
#   '5',
#   datetime.datetime(2018, 11, 14, 19, 16),
#   0],
#  ['오랜벗(rlf2****)',
#   '함께 본 중딩 아들이 엔딩 크레딧이 올라갈 때 자신의 인생(?) 영화라며 감동을 주체하지 못하더군요. 근래 봤던 영화들 중 최고의 감동입니다.',
#   '10',
#   '33',
#   '5',
#   datetime.datetime(2018, 11, 10, 1, 52),
#   0],
#  ['일병라이언(chaj****)',
#   '주변에서 아무도 안본다고해서 태어나서 첨으로 혼자 영화 보고왔습니다. 다음주에 한번 더 볼겁니다 진심 스토리는 모르겠고 영화 자체가 걍 존멋입니다.',
#   '10',
#   '33',
#   '5',
#   datetime.datetime(2018, 11, 2, 0, 50),
#   0],
#  ['Chumini(elwk****)',
#   '장난안치고 처음으로 평점 남깁니다.. 이건 2~3번 봐도 질리지않을듯 퀸노래만 알았지 퀸에 대해 잘 몰랐는데 이양화보고 프레디머큐리라는 전설에게 반했습니다 올해가장 여운이 남는영화.',
#   '10',
#   '30',
#   '3',
#   datetime.datetime(2018, 11, 15, 2, 58),
#   0],
#  ['한제아(slke****)',
#   '보고 나오자 마자 언제 또 보지? 하는 생각이 들었다. 한번만 보기엔 너무 아쉽네.',
#   '10',
#   '30',
#   '3',
#   datetime.datetime(2018, 11, 10, 12, 37),
#   0],
#  ['치코리타(jaeh****)',
#   '음악영화중 단언코 5손가락안에 든다',
#   '10',
#   '30',
#   '3',
#   datetime.datetime(2018, 11, 2, 4, 20),
#   0],
#  ['이주경(jkle****)',
#   '진짜 꼭 보세요 평생 후회 안 합니다. 어제 보자마자 또 보고싶었고 너무 잘 재현한 것 같아요. 꼭 두 번 세 번 열 번 오조오억 번 보세요!!!',
#   '10',
#   '30',
#   '3',
#   datetime.datetime(2018, 11, 2, 0, 37),
#   0],
#  ['붕어한마리(sszs****)',
#   '헤어나올수가없다 요즘 나는 완전히 퀸에 매료되었다',
#   '10',
#   '31',
#   '4',
#   datetime.datetime(2018, 11, 16, 18, 20),
#   0],
#  ['강성범(ksb9****)',
#   '우리나라 음악 영화는 절대로 이 영화를 넘을수 없다.',
#   '10',
#   '31',
#   '4',
#   datetime.datetime(2018, 11, 13, 22, 1),
#   0],
#  ['꽃(dudt****)',
#   '영화가 끝나고 아무도 일어나지 않았다',
#   '10',
#   '31',
#   '4',
#   datetime.datetime(2018, 11, 2, 21, 6),
#   0],
#  ['이하은(haru****)',
#   '꼭 보세요 진짜 정말 인생영화 강추입니다 감동이고 감사하네요',
#   '10',
#   '31',
#   '4',
#   datetime.datetime(2018, 11, 2, 9, 3),
#   0],
#  ['최성균(kjj2****)',
#   '조금만 더 일찍 태어났으면 했어요',
#   '9',
#   '33',
#   '6',
#   datetime.datetime(2018, 11, 2, 8, 34),
#   0],
#  ['푸른서표(book****)',
#   '선 10점박고 후감상한다...  퀸이니까',
#   '10',
#   '37',
#   '10',
#   datetime.datetime(2018, 10, 31, 11, 31),
#   0],
#  ['JEB(pm_0****)',
#   '상영하는 영화 2차도 찍은적 없는 내가 5차를 찍었다..',
#   '10',
#   '28',
#   '2',
#   datetime.datetime(2018, 11, 30, 7, 30),
#   0],
#  ['공주대여자(byr9****)',
#   '그냥 대박이에요 처음 영화리뷰 남겨봐요 아직도 소름돋아서 잠 못자요',
#   '10',
#   '29',
#   '3',
#   datetime.datetime(2018, 11, 2, 23, 56),
#   0],
#  ['조윤서(yyss****)',
#   '와... 인생한번 캐간지나네 진짜. 퀸이고 롹이고 잘 알지도 못했던 1인인데.. 음악으로 영접한기분. 심장터질뻔. 진짜 레전드오브레전드다. 이런감동으로 울어본건 처음',
#   '10',
#   '30',
#   '4',
#   datetime.datetime(2018, 11, 19, 22, 50),
#   '관람객'],
#  ['역정(ilgo****)',
#   '하루에 두 번을 연달아 관람한 영화는 이 영화가 처음이네요. 모든 걸 쏟아붓게 만드는 마법같은 음악, 그리고 인생입니다. 강추, 또 강추입니다.',
#   '10',
#   '30',
#   '4',
#   datetime.datetime(2018, 11, 8, 23, 14),
#   0],
#  ['hehe****',
#   '눈감고 노래만 듣고 와도 본전이상 뽑는데영화까지 재밌어버리니..근 3년간 본 영화중에 다섯손가락 안에 뽑을 수작.',
#   '9',
#   '30',
#   '4',
#   datetime.datetime(2018, 11, 5, 9, 41),
#   0],
#  ['샤방정민(nohj****)',
#   '왜 별을 10개밖에 못주나요 637284개는 주고싶은데...진짜 그냥 보세요 제발 이건 영화관에서 봐야되요 나중에 컴터로 보실생각이면 애초에 보지도마세요ㅠ 저 ㅎ평점 같은거 안남기는데 씁니다 진짜 퀸뽕에 지대로 취했...',
#   '10',
#   '30',
#   '4',
#   datetime.datetime(2018, 11, 2, 23, 25),
#   0],
#  ['깡(ttsn****)',
#   '성인용 기저귀 사가세요. 지립니다.',
#   '10',
#   '32',
#   '6',
#   datetime.datetime(2018, 11, 13, 16, 28),
#   '관람객'],
#  ['대연동푸른(spdl****)',
#   '더 이상 말이 필요가 없다. 퀸을 알면 꼭 봐야하는 영화',
#   '10',
#   '32',
#   '6',
#   datetime.datetime(2018, 10, 31, 13, 24),
#   0],
#  ['Rockish(vudd****)',
#   '퀸을 좋아한다면 꼭 !!!!',
#   '10',
#   '35',
#   '9',
#   datetime.datetime(2018, 10, 31, 15, 54),
#   '관람객'],
#  ['레드마운틴(gene****)',
#   '라이브에이드가 방영한 1985년에 태어났습니다. 그 시절 퀸과 함께 이 세상에서 숨을 쉬고 있었다는 것만으로도 영광입니다.♡ 영화본지가 벌써 3주가 되었는데 아직까지 머릿속에 계속 맴돌아요ㅠ 세얼간이 이후 내 인생영...',
#   '10',
#   '27',
#   '2',
#   datetime.datetime(2018, 11, 24, 7, 21),
#   0],
#  ['rock****',
#   '프레디머큐리 생전에 내한공연하여 잠실주경기장에서 Radio ga ga를 불렀다면 하는 생각이 간절하네..',
#   '10',
#   '27',
#   '2',
#   datetime.datetime(2018, 11, 13, 17, 26),
#   0],
#  ['dkwlrdjqtdma(ebss****)',
#   '완벽한 타인 한번, 보헤미안 랩소디 한번 봤는데 개인적으론 보헤미안 랩소디를 두번 보는 게 더 기분 좋은 시간을 보낼 수 있지 않았을까...',
#   '9',
#   '28',
#   '3',
#   datetime.datetime(2018, 11, 15, 5, 22),
#   0],
#  ['ksd1****',
#   '아니 왜 노래가 다 좋아요???',
#   '10',
#   '29',
#   '4',
#   datetime.datetime(2018, 11, 20, 12, 45),
#   0],
#  ['팻보이(mega****)',
#   '정책선동용   영화나  만드는   사람들은  이런  감동적인  영화   죽었다 깨어나도   못만들듯 ㅋ',
#   '10',
#   '29',
#   '4',
#   datetime.datetime(2018, 11, 4, 3, 27),
#   0],
#  ['사장님(skya****)',
#   '나는 왜 눈물이 멈추지 않는가',
#   '10',
#   '30',
#   '5',
#   datetime.datetime(2018, 11, 5, 0, 11),
#   '관람객'],
#  ['삼시세끼(gzpo****)',
#   '노래만 들어도 눈물이남ㅠㅠ',
#   '10',
#   '30',
#   '5',
#   datetime.datetime(2018, 10, 31, 13, 18),
#   0],
#  ['박용철(dog_****)',
#   '머리는 영화를 못 만들었다고 하는데, 가슴은 아니라고 한다.',
#   '10',
#   '26',
#   '2',
#   datetime.datetime(2018, 11, 19, 23, 50),
#   0],
#  ['RaeRae(audf****)',
#   '뮤직페스티벌 온줄 엄청 감동받고 마지막엔 감동에 벅차 눈물까지나옴',
#   '10',
#   '26',
#   '2',
#   datetime.datetime(2018, 11, 12, 21, 39),
#   0],
#  ['vict****',
#   '영화끝나고 유투브에서 LIVE AID 실제영상 찾아봄',
#   '10',
#   '27',
#   '3',
#   datetime.datetime(2018, 11, 18, 20, 42),
#   0],
#  ['rlaw****',
#   '와 저 여기 평 남기는거 처음인데 영화 미쳤어요..내가 저시대에 저기에서 공연을 못본게 너무 아쉬울뿐....너무 울어서 얼굴 부었습니다 주옥같은 명곡들이랑 프레디의 인생까지 잘 담아낸거 같아요ㅠㅠ전 데이빗보위팬인데 ...',
#   '10',
#   '27',
#   '3',
#   datetime.datetime(2018, 11, 16, 18, 1),
#   0],
#  ['wlgu****',
#   '꼭 꼭 사운드 빵빵한 영화관에서 보세요! 연출 너무 좋았고 고막 힐링 제대로 했습니다. 슬픈 장면없이도 눈물이 나오는 영화는 처음이네요 ㅠㅠ',
#   '10',
#   '27',
#   '3',
#   datetime.datetime(2018, 11, 15, 1, 50),
#   0],
#  ['휘날리며(hans****)',
#   '오늘까지 세번봤다..원래 두번보구  끝내려구  했는데 엠비씨에서 해준 라이브에이드보구 나서 오늘 또봤음,..이영화 두번이상 본사람은 공감 눌러주세요^^',
#   '10',
#   '28',
#   '4',
#   datetime.datetime(2018, 12, 4, 16, 29),
#   0],
#  ['qodp****',
#   '저는 19살이고퀸이 뭘불렀는지 어떤밴든지 모르는상태에서영화를 봤습니다하지만 정말 재밌었고 감동적이고,영화가 끝나고 극장에 불이켜졌을때도계속 앉아있었어요그리고 집에와서도 여운이 가시질않아계속 이노래만들으며 공부하고있습...',
#   '10',
#   '27',
#   '4',
#   datetime.datetime(2018, 11, 13, 18, 40),
#   '관람객'],
#  ['hyun(ratm****)',
#   '막판에 겁나 울었음ㅜㅜ',
#   '10',
#   '27',
#   '4',
#   datetime.datetime(2018, 11, 5, 17, 28),
#   0],
#  ['또뎨디빵(seoy****)',
#   '무조건 스엑! 퀸 노래 들으러 갑니다ㅠㅠㅠ',
#   '10',
#   '27',
#   '4',
#   datetime.datetime(2018, 10, 31, 14, 50),
#   '관람객'],
#  ['engg****',
#   '드디어 영화가 되어서 나왔고 드디어 영화로 완벽하게 재연했다',
#   '10',
#   '28',
#   '5',
#   datetime.datetime(2018, 10, 31, 13, 28),
#   '관람객'],
#  ['혜성처럼(jung****)',
#   '최고~최고~최고~!!!! QUEEN의 음악을 극장의 빠방한 사운드로 즐기다보면 러닝타임이 짧게 느껴질 정도 입니다~!!ㅎㅎㅎㅎ',
#   '10',
#   '31',
#   '8',
#   datetime.datetime(2018, 10, 31, 10, 13),
#   0],
#  ['대마황(lemo****)',
#   '프레디 머큐리의 외로움이 느껴져서 슬펐고 퀸노래는 이렇게 듣기 좋을수가 없다',
#   '10',
#   '25',
#   '3',
#   datetime.datetime(2018, 11, 22, 10, 39),
#   0],
#  ['misty(qkfk****)',
#   '벌써 3번째봤는데 오늘도 뭐에 홀린듯 극장에 다시왔다... 넘 좋다라는 말밖에 할게없다',
#   '10',
#   '25',
#   '3',
#   datetime.datetime(2018, 11, 20, 12, 26),
#   0],
#  ['모스키(mosk****)',
#   '걍 러닝타임 늘려서 노래 풀로 틀어주세요.... 언더 프레셔 풀로 듣고 싶어요...',
#   '10',
#   '25',
#   '3',
#   datetime.datetime(2018, 11, 13, 4, 24),
#   '관람객'],
#  ['나에게 행운이(mrmr****)',
#   '12월 2일날 mbc에서 다큐식으로 따로 방영해준다는데 영화안봐도 될까요? 볼까요 봐라 추천 보지마라 비추 부탁드려요',
#   '10',
#   '28',
#   '6',
#   datetime.datetime(2018, 11, 28, 5, 5),
#   0],
#  ['MrClever(scwp****)',
#   '이 영화를 IPTV나 다운받아서 보는 것만큼 안타까운 일도 없을거라고 생각될 정도로, 반드시 극장의 사운드로 라이브 콘서트의 현장감과 사운드를 만끽하시기를 추천드립니다.',
#   '10',
#   '24',
#   '3',
#   datetime.datetime(2018, 11, 20, 22, 31),
#   '관람객'],
#  ['파파이스(gpai****)',
#   '상영할때 극장서 봐라 아님 평생후회알끼야',
#   '10',
#   '24',
#   '3',
#   datetime.datetime(2018, 11, 18, 18, 32),
#   0],
#  ['장명진(rive****)',
#   '그렇게 슬픈 내용이 아닌데;; 왜 이렇게 눈물이 나는지 모르겠습니다. 바보처럼 펑펑 울다가 왔네요~ 사운드 작업을 누가 했는지 모르겠지만  지금 까지 봤던 영화 중에서 최고의 사운드와 음악이었습니다.!!!아직도 가슴...',
#   '10',
#   '25',
#   '4',
#   datetime.datetime(2018, 11, 14, 15, 46),
#   0],
#  ['김종균(rlaw****)',
#   '마지막 콘서트 장면 너무 멋있었습니다...검색해서 실제 퀸 라이브에이드 공연 영상 찾아봤는데 너무 똑같이 잘 만들어서 소름이... 어제 봤는데 오늘 또 보려고요!',
#   '10',
#   '25',
#   '4',
#   datetime.datetime(2018, 11, 2, 9, 19),
#   0],
#  ['vjvm****',
#   '눈물은 안흘렀는데 어제본영화가 오늘까지 슬픕니다 ...걸작 탄생이네요',
#   '10',
#   '23',
#   '3',
#   datetime.datetime(2018, 11, 19, 7, 23),
#   0],
#  ['gyyd****',
#   '천재 실존인물의 스토리 전개 자체는 흔한듯 했지만 음악 스토리 싱크로율 할것없이 너무나도 완벽한 영화였던것 같습니다. 퀸을 알기엔 조금 뒷세대였지만 전혀 상관없었네요. 오히려 퀸을 잘 알거나 팬인 세대라면 아마도 울...',
#   '10',
#   '23',
#   '3',
#   datetime.datetime(2018, 11, 13, 18, 5),
#   '관람객'],
#  ['스마일걸(prin****)',
#   '역시 음악이 말이필요없이 최고다 굿굿',
#   '10',
#   '24',
#   '4',
#   datetime.datetime(2018, 10, 31, 11, 41),
#   '관람객'],
#  ['효잉크(kimh****)',
#   '영화 배우 연출 모두 흠잡을곳 없이 훌륭했음. 근데 아무리 신나도 극장이고 공공장소 인데 초반부터 박수 치고 노래 크게 따라부르는건 좀 자제했으면.. 공연장이면 당연히 이해하겠는데 보는내내 짜증남',
#   '9',
#   '25',
#   '5',
#   datetime.datetime(2018, 11, 18, 16, 45),
#   0],
#  ['toriya(mool****)',
#   '몇번을 더봐야 이 마음이 채워질지, 영화를 볼수록 프레디가 더 그립다  I still love you',
#   '10',
#   '30',
#   '10',
#   datetime.datetime(2018, 11, 11, 7, 36),
#   0],
#  ['mayo****',
#   '영화 보는 내내 눈물이 났어요음악도 좋고 라미 말렉의 연기에도놀랐습니다. 공연 장면시  손동작하나 하나가 너무 똑 같아서 한번더놀랐습니다 다시 한번 더 봐도 후회없을 듯 해요 ^^',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 22, 11, 25),
#   0],
#  ['제주넘기(jeju****)',
#   '방금보고 왔지만, 다시 또보고픈 영화!',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 8, 22, 11),
#   0],
#  ['오정원(ynsp****)',
#   '지금까지 본 영화중 제일 감동이네 라이브 에이드 다녀왔다',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 4, 2, 56),
#   0],
#  ['줌인(iran****)',
#   '실제 프레디가 환생한 줄...극장은 콘서트장!',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 2, 1, 53),
#   0],
#  ['머지(moya****)',
#   '퀸의 라이브를 간접체험했다. 마지막 씬에서 감동에 벅차서 눈물이 흘렀다. 며칠동안 퀸에 계속 흠뻑 빠져있을 듯...',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 2, 1, 45),
#   0],
#  ['앙마(moon****)',
#   '마지막20분은 정말 최고다~~^^',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 1, 18, 16),
#   0],
#  ['버찌(choc****)',
#   '응원상영 함 해주세요 we will rock you랑 위아더챔피언에서 떼창이랑 발구르기본능 대박이었는데 아무도안해서 뻘쭘 ㅠ',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 1, 14, 34),
#   0],
#  ['jsmo****',
#   '프레디 머큐리~~당신은 전설이며 최고입니다~열정가득한 무대 퍼포먼스  프레디아니면 불가능한 일지요~ 정말 가슴벅찬 라이브를 들으니 찡했고 행곡했어요',
#   '10',
#   '22',
#   '3',
#   datetime.datetime(2018, 11, 1, 0, 15),
#   0],
#  ['가보자가는데까지(jsdr****)',
#   '쿠키영상없는데도 엔딩크레딧 올라가는 중에 아무도 일어나지 않더군요...힐링됩니다...집에 와서 퀸 계속 듣는중~~',
#   '10',
#   '23',
#   '4',
#   datetime.datetime(2018, 11, 1, 20, 0),
#   0],
#  ['Ssssss_(sehy****)',
#   '퀸 노래를 한번이라도 들어봤다면  봐야할 영화쓰',
#   '10',
#   '23',
#   '4',
#   datetime.datetime(2018, 10, 31, 13, 26),
#   '관람객'],
#  ['데스(rnss****)',
#   '무엇보다 퀸의 노래가 매우 좋네요. 프레디의 인생이 짠하고. 프레디 머리 자르기 전 시절을 너무 찐따같이 묘사해놨던데, 실제 그 시절 영상보면 그정돈 아니던데 아쉽네요',
#   '10',
#   '24',
#   '5',
#   datetime.datetime(2018, 11, 4, 1, 36),
#   '관람객'],
#  ['볼볼봉ㄹ볼(c5b8****)',
#   '고3 수능 끝나자마자 보고 3번 더 봤습니다. 특히 마지막 20분은 몇번이고 볼 수 있을듯 개인적으로 저는 스토리도 좋았고 실제 퀸과 닮은 배우들과 프레디 머큐리 연기한 배우가 진짜 소름돋게 연기를 잘했음 고3들 추...',
#   '10',
#   '20',
#   '2',
#   datetime.datetime(2018, 11, 22, 12, 5),
#   0],
#  ['스턴(nss3****)',
#   '명곡의 향연!프레디가 그립다.감동~',
#   '10',
#   '21',
#   '3',
#   datetime.datetime(2018, 11, 24, 10, 18),
#   0],
#  ['hett****',
#   '8년만에 마누라와 같이  가서 본 영화인데 인생작입니다. 마지막 장면은 콘서트 그 느낌입니다.',
#   '10',
#   '21',
#   '3',
#   datetime.datetime(2018, 11, 18, 16, 15),
#   0],
#  ['와이에미(kym8****)',
#   '소름이 몇 번 돋았는지 모르겠음 올해가기전 또 인생영화 하나 건졌네요... 꼭 보세요 두 번 보세요',
#   '10',
#   '21',
#   '3',
#   datetime.datetime(2018, 11, 5, 3, 38),
#   0],
#  ['sosv****',
#   '와후 마지막 을 위해 보는영화',
#   '10',
#   '22',
#   '4',
#   datetime.datetime(2018, 11, 5, 17, 17),
#   0],
#  ['댕댕(wsyj****)',
#   '노래 끝날때마다 박수칠뻔했다...  너무 좋았아!!!',
#   '10',
#   '22',
#   '4',
#   datetime.datetime(2018, 11, 4, 3, 20),
#   0],
#  ['수호천사(ange****)',
#   '같은 실화인데 퍼스트맨이랑은 너무 차이가 나네요!! 마지막 자선 공연에서 피아노 치며 엄마 죽기 싫어요 라는 가사가 나오며 노래부르는데 좀찡해요 영화가 끝나고 영상이 나오면서 엔딩에서 영화관 불이켜지는데 대부분 일어...',
#   '10',
#   '22',
#   '4',
#   datetime.datetime(2018, 10, 31, 21, 43),
#   0],
#  ['쿤엘리아(hb72****)',
#   '오짐대박전율소름응가',
#   '10',
#   '22',
#   '4',
#   datetime.datetime(2018, 10, 31, 13, 17),
#   0],
#  ['songsong(choi****)',
#   '그냥 음악영화인가보다 하고 봤는데 그 이상이었어요 프레디머큐리의 인생을 잠깐 살다 나온 것 같은 기분이 들죠 중반이후부터는 왜인지 눈물이 계속 났어요 뭔가 설명할 수 없는 기분이 들게 만드는 영화에요!',
#   '10',
#   '23',
#   '5',
#   datetime.datetime(2018, 12, 13, 4, 19),
#   0],
#  ['이민형(atom****)',
#   '제 인생에 퀸이 있다는것 자체가 영광입니다',
#   '10',
#   '20',
#   '3',
# ...
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 10, 31),
#   0],
#  ['행복솔솔(ljh8****)',
#   '주연배우의 연기력과 감독의 연출력이 더해진감동의 영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 10, 21),
#   0],
#  ['와구몬친구들(chlw****)',
#   '... 미쳤다 이건 영화라기보단 예술..',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 10, 9),
#   0],
#  ['wnzl****',
#   '진짜 음향좋은곳가서보세요  한동안 음악목록에 퀸노래만있을거에요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 10, 4),
#   '관람객'],
#  ['이드(sinj****)',
#   '말이되나 마지막은 그냥 실사판임',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 10, 3),
#   0],
#  ['이성희(plp1****)',
#   '무한전율입니다 온 몸으로 느끼고 왔습니다',
#   '9',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 9, 55),
#   '관람객'],
#  ['jung5989(exit****)',
#   '현망진창일정도로 푹 빠져 사는 일인',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 9, 47),
#   '관람객'],
#  ['정은(ashl****)',
#   '퀸도 레전드 영화도 레전드',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 9, 31),
#   '관람객'],
#  ['장지헌(jajh****)',
#   '퀸을 몰랐어 영화보고 퀸을 알았어 오마이갓 살면서 본의아니게 들어서 흐느낀 팝송들이 퀸이야 !나온지 50년 이다되가는데 언빌리 버블 당신들 뭐야 ?',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 9, 10),
#   0],
#  ['김태연(calm****)',
#   '우리에게 멋진 곡들을 들려주셔서 감사해요. Queen Forever!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 9, 7),
#   '관람객'],
#  ['왕건(nawa****)',
#   '엿출도 굿연기도 굿다시 봐야 할 영화~~소장해야 할 영화목록에 추가합니다~^^',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 8, 55),
#   '관람객'],
#  ['용두섭이(qkqh****)',
#   '중간에 한번씩 울컥했는데 마지막에 보헤미안햅소디부를때 눈물남..노래듣는데 계속 소름돋을정도 영화가이런데 실제로는 더 멋있었겠지',
#   '9',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 8, 54),
#   0],
#  ['포도당코끼리(sbs0****)',
#   '최고의 영화ㅠㅜㅜ정말 두번봤지만 세번네번보고싶어요ㅜㅜ',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 8, 53),
#   0],
#  ['아다지다아(trse****)',
#   '두번 봣는데 몇번 더 보러 가려구요.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 8, 0),
#   '관람객'],
#  ['테준(ptjm****)',
#   '퀸을 모르는 세대에 태어나 퀸의 광팬으로 만든 영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 5, 17),
#   0],
#  ['74jo****',
#   '일반 상영관이라 박수도 칠수없었다음악에  빠져들고 퀸에 빠져들고..소름과 감동이 주체할수 없을만큼  요동치는 시간이었다..',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 4, 21),
#   '관람객'],
#  ['유형민(hum9****)',
#   '10점만점에 1억점 나 따위가 평가할 수준이 아님..',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 3, 56),
#   0],
#  ['이현주(mini****)',
#   '동시대에 살지 못한것이 너무나 안타깝다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 3, 12),
#   0],
#  ['호러퀸카(whit****)',
#   'pink님 저두요 평생소장각 얼른 vod나왔으면',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 2, 9),
#   0],
#  ['똑시미(dohe****)',
#   '딸이 세번이나 보고 왔네요. 생애 최고의 영화라고.. 시디도 두개 사고.. 덩달아 저도 좋네요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 2, 8),
#   '관람객'],
#  ['소원(pink****)',
#   '말이 필요없음. 3번 봄. 평생소장도 살 예정.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 2, 7),
#   0],
#  ['유윤선(ywns****)',
#   '실제랑 무대 연출과 거의 흡사하네요. 배우섭외부터 연기, 특히 음악이 미쳤습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 2, 4),
#   '관람객'],
#  ['행복밍이(kmkd****)',
#   '세번보고도 더보고싶은...퀸러버가될수있는영화. 당신은전설입니다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 35),
#   0],
#  ['exce****',
#   '유쾌하고 감동적이고 애잔하고 슬프다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 32),
#   0],
#  ['지별(momk****)',
#   '무대의 분위기, 전율에 눈물을 흘린적은 처음이네요.두번 봤습니다. 친구랑 한번, 혼자서 한번. 감정을 억누르고 보는것과 흐르는대로 보는거 색다르고 둘다 좋았습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 29),
#   '관람객'],
#  ['비배쫑(8282****)',
#   '감동 그 자체. 퀸을 몰라도 보자. 그냥 보자. 눙물.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 26),
#   '관람객'],
#  ['00(uj97****)',
#   '3번봤어요ㅠㅠ! 최고!!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 14),
#   0],
#  ['게이머(bong****)',
#   '너무너무 재밌게 봤어요! 라이브 에이드 때는 온 몸에 전율이 ㄷㄷ',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 6),
#   0],
#  ['이상용(yong****)',
#   '컨트롤씨 컨트롤브이 음악시대에좋은 교훈을 주는 아티스트다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 1, 5),
#   0],
#  ['Quik(ysh9****)',
#   '개인적으로 스토리 전개가 다소 빠르다고 생각했었으나 감동과 여운을 많이 남긴 영화였습니다!',
#   '9',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 56),
#   0],
#  ['w932****',
#   '좋네요, 좋아요 생각나네요 자꾸',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 54),
#   '관람객'],
#  ['lhk(lahe****)',
#   '말이필요없음 ....꼭 보세요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 38),
#   0],
#  ['봉어멈(udud****)',
#   '정말 감동적인 영화에요ㅜㅜ',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 35),
#   '관람객'],
#  ['고프(rhgu****)',
#   '퀸은!! 프레디는!! 영원하다!!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 32),
#   0],
#  ['주한혁(hanh****)',
#   '퀸으로 시작해 퀸으로 끝나는 영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 21),
#   0],
#  ['목동싸나이(knjh****)',
#   '배우들의 노력이 결실을 맺은 영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 20),
#   '관람객'],
#  ['예자(wlsd****)',
#   '영화 보고 난 후로 퀸 노래에서 빠져나올 수가 없다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 19),
#   0],
#  ['heek****',
#   'absoultely no doubt!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 15),
#   0],
#  ['해피엄마(youn****)',
#   '감동또감동 나도모르게 흐르는눈물 주체할수없었다눙요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 7),
#   '관람객'],
#  ['방탕이(boo6****)',
#   '한번더 보러갈거임..미쳤다영화..',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 6, 0, 2),
#   0],
#  ['디지털(hate****)',
#   '정말 눈물이 주르륵 감동 그자체입니다 ㅠㅠ 전설이여~',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 52),
#   0],
#  ['불광 코코리따(suk1****)',
#   '기대없이 봤다가 감동하고 나온 영화...그냥 음악만 들어도 감동인 영화...그시대로 가보고 싶어진다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 50),
#   0],
#  ['유다(suns****)',
#   '프레디가 안쓰러워서 눈물이 났다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 49),
#   0],
#  ['거기누구니(hell****)',
#   '두번보세요 세번보세요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 45),
#   0],
#  ['얼음공주(icef****)',
#   '아직도 생생하게 들려옵니다음악을 들으면 영상들이 내 머리속을 지나가요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 41),
#   0],
#  ['이지수(bene****)',
#   '마지막 20분은 음악영화의 전설로 남을 장면',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 14),
#   0],
#  ['ksih****',
#   '죽기전에꼭한번봐야됨',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 14),
#   0],
#  ['시티너(dmsw****)',
#   '신이 그의 노래를 가까이 듣고싶어서 일찍 데려갔나보다.. 보는 내내 전율이 느껴졌다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 23, 5),
#   0],
#  ['슈슈항(youk****)',
#   '전설의 락밴드 퀸과 40년 전 명곡의 비하인드 스토리가 궁금한 사람. 위대한 스타 이면에 가려진 고독과 고뇌를 이해할 수 있는 사람. 감동과 위안을 모두 느끼고 싶은 사람에게 강추! 그리고 마지막 20분은 온 몸에 ...',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 22, 56),
#   0],
#  ['tjzo****',
#   '콘서트장면에서 감동의 눈물이 주르륵',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 22, 38),
#   '관람객'],
#  ['민서김(mins****)',
#   '제 인생 역대최고로 감동 재밌었습니다. 원래 액션 좋아하는데 이 영화 극장가서 두번 봤어요.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 22, 25),
#   0],
#  ['정상에서(onth****)',
#   '아..이건 영화관에서 봐야된다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 22, 16),
#   0],
#  ['GPsanghee(mone****)',
#   '콘서트보는 기분이었습니다볼까말까 고민하시는분들 꼭보세요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 21, 6),
#   '관람객'],
#  ['하양이(khh2****)',
#   '대박 소름돋았다... 또 보러가야지',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 20, 55),
#   0],
#  ['lees****',
#   '대단한 영화입니다. 주인공의 먼기가 돋보이고, 라이브에이드의 공연실황은 압권입니다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 20, 34),
#   '관람객'],
#  ['duddms99(iye9****)',
#   '보는내내 울뻔했습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 20, 22),
#   0],
#  ['로즈로즈(rose****)',
#   '정말 감동적이었습니다~~~',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 20, 15),
#   0],
#  ['코코몽조아(kimd****)',
#   '프레디머큐리가 프레디머큐리햇다;',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 19, 53),
#   0],
#  ['damp****',
#   '최고! 엄지 척 간만에 심장떨림',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 18, 55),
#   0],
#  ['Sunset(love****)',
#   'ㅜㅜ진짜 주변에 보라고 권유할수있는 영화에요..',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 18, 18),
#   0],
#  ['장원익(wel-****)',
#   '최고의 영화 퀸을 다시 알게된 계기',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 18, 17),
#   '관람객'],
#  ['ttutto(bana****)',
#   '극장에서 보길 잘 했습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 18, 17),
#   '관람객'],
#  ['skyp****',
#   '재밌게 잘 봤습니다^^ 추천합니다.',
#   '9',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 18, 16),
#   '관람객'],
#  ['정효빈(cat0****)',
#   '올해본영화중 가장 재밌습니다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 18, 5),
#   0],
#  ['YGHHH(zmgk****)',
#   '솔직히 마지막 신에 너무 많이 투자해서 그전까지난 흐름이 많이 끊기고 재미는 없었어요 그래도 퀸의 주옥같은 노래들, 소름돋는 싱크로율이 단점을 모두 상쇄시키네요 진짜 마지막 공연에 눈물흘렸습니다',
#   '8',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 17, 58),
#   0],
#  ['단단(amer****)',
#   '주인공이 프레디를 안닮았지만 더 프레디같았다 연기에 찬사를 보낸다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 17, 50),
#   0],
#  ['CTID(yena****)',
#   '대박... 4번봤네요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 16, 19),
#   0],
#  ['인간(andh****)',
#   '올해 본 영화중 단연 최고',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 15, 34),
#   0],
#  ['mirei(mire****)',
#   '두번보세요. 세번 봐도 됩니다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 15, 7),
#   0],
#  ['황현주(81hj****)',
#   '프레디의 운명적인 삶이 그를 외로운 길로 안내 해서 슬프고도 음악의 예술적인 면에서는 감동 받았 습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 13, 36),
#   '관람객'],
#  ['곱게자랐어요(zofo****)',
#   '왜 눈물이 난지 모르겠는.. 팝콘 한알 주워먹을 정신도 없는 영화',
#   '9',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 11, 38),
#   0],
#  ['채찍(mega****)',
#   '배우들의 노력이 멋졌던 영화.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 10, 35),
#   '관람객'],
#  ['이오(mj83****)',
#   '아빠가 너무 좋아하셔서 세번째 보내 드렸어요 호',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 9, 45),
#   '관람객'],
#  ['뾰뾰(pink****)',
#   '점수 더 주고 싶은데ㅜㅜ 감동적이엇음♡',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 7, 42),
#   0],
#  ['미공개(ljgl****)',
#   '평범하고 전형적인 스토리라인에 퀸을 끼얹으니 퀸스러운 영화가 되었다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 7, 36),
#   '관람객'],
#  ['저녁노을(pqqv****)',
#   '말이 필요하나요?? 전설을 볼 수 있는데?',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 7, 27),
#   '관람객'],
#  ['김철수(cjft****)',
#   '계속 보고싶다. 또 보러 가야지.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 6, 31),
#   0],
#  ['WASSAP(wass****)',
#   '라이브에이드에서 울리는 보헤미안 랩소디에 난 다 마시고 얼음만 남은 콜라잔을 내 눈물로 채웠다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 0, 21),
#   0],
#  ['0108****',
#   '너무 좋습니다 시간가는줄모름',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 5, 0, 7),
#   '관람객'],
#  ['딸기(jbn1****)',
#   '영화가  끝나고  나오는순간  다시보고싶었습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 22, 48),
#   0],
#  ['밍(miny****)',
#   '진짜 인생 영화... 후유증이 이렇게 남았던 적은 처음인 것 같다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 21, 58),
#   0],
#  ['최지은(jieu****)',
#   '주말에4번째보러갑니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 18, 15),
#   0],
#  ['미나리(dosd****)',
#   '혼이 담기긴 열창과 가사에 감동을 아니할수 없고 울지 아니할수 없었다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 16, 24),
#   0],
#  ['조수현(suhy****)',
#   '정말 영화로 만들어줘서 고맙습니다. 이제야 퀸을 프레디머큐리를 알게되었어요. 평생 잊지못할 영화입니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 16, 15),
#   0],
#  ['THEAMY(thea****)',
#   '엔딩크레딧 다 끝날때까지 불 안켰으면 좋겠어요...',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 16, 6),
#   '관람객'],
#  ['hbs9****',
#   '두번보면 다른장면도 보이고 이해가되서 더 짠하고 감동적인..  팝송노래를 처음으로 좋아하게만들어준 퀸',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 15, 59),
#   0],
#  ['월향(sunf****)',
#   '2번째 봤는데도 또 보러가고 싶어요!!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 14, 50),
#   '관람객'],
#  ['박동진(pdj4****)',
#   '웸블리 스타디움에서 펼쳐지는 퀸의 공연장면이 스크린에서 펼쳐졌을때 내눈을 믿을 수 없었다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 14, 50),
#   0],
#  ['op99****',
#   '이 영화를 보기위해 태어났다는 평과 슬픈장면 없는데 눈물이 난다는 평에 극공감 합니다 혼자봐서 남편에게도 이 행복감을 느끼게해주고 싶어서 내일 같이 한번더 보려구요?행복합니다~^^',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 14, 48),
#   0],
#  ['아라라라라라(govl****)',
#   '퀸을아는시대가 아닌데 노래를 다 알고있더라구요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 14, 41),
#   '관람객'],
#  ['LimPossible(alvi****)',
#   '스타할땐 퀸만 뽑고 롤할때 퀸만 픽한다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 14, 27),
#   0],
#  ['패트릭베이트먼(jyu7****)',
#   '오프닝 부터 울컥해서 마지막에는 펑펑 울었습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 8, 15),
#   0],
#  ['이승연(lsy_****)',
#   '보면서 소름이 몇번 끼쳤는지...',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 8, 12),
#   0],
#  ['윤채영(dksd****)',
#   '말로표현못하는영화계속울었네요ㅠ한번더보러가야겟습니다^^이런영화는무조건극장에서봐야해요최고였습니다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 1, 44),
#   0],
#  ['류시현(rsh5****)',
#   '공연장면들이 가슴뛰게하고 좋네연',
#   '8',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 0, 12),
#   '관람객'],
#  ['yh70****',
#   '브라이언 메이의 매력에 감동과 눈물이 나는 영화~음악이 자꾸 떠오르는 영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 0, 8),
#   '관람객'],
#  ['예원할배(zero****)',
#   '퍙소 퀸을 좋아하긴 했지만다시 한번 진한 감동을 주는영화 였네오',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 4, 0, 5),
#   '관람객'],
#  ['silb****',
#   '감동과 여운이 떠나질 않는 영화 ~~',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 23, 55),
#   0],
#  ['hosa****',
#   '꼭보세요 진짜 보는 내내 소름이 돋네요...',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 23, 48),
#   0],
#  ['MiMy(dalk****)',
#   '진짜 최고, 더 이상 말이 필요없음',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 23, 38),
#   0],
#  ['비범(sj10****)',
#   '절대적 완벽, 그 이상의 것.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 23, 37),
#   0],
#  ['기부(wlsd****)',
#   '스크린x관  죽인다는데없어서ㆍ애트모스인가그기서두번째  다시봣는데 ㆍ사운드 빵빵은 모르겠고ㆍ두번째 더재밌게 봤네요평일밤 인데 만석ㆍ후프레디의 고독으로  눈물이다 나네요세번봐도  좋을듯',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 23, 25),
#   '관람객'],
#  ['조형매(rock****)',
#   '메리의 한마디 한마디에 여자인 내 심장도 쿵쿵 내려앉았다. 안 보려다가 사무실에서 하도 난리길래 이제야 봤는데..안 봤으면 진짜 후회할 뻔.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 23, 8),
#   0],
#  ['hard****',
#   '마지막에 전율이 왔어요...,',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 22, 56),
#   '관람객'],
#  ['tmdrlfjqn(mlnd****)',
#   '프레디 머큐리 보고싶어요',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 22, 54),
#   0],
#  ['공경배(away****)',
#   '한마디로 표현하겠음완벽한영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 22, 50),
#   0],
#  ['onod****',
#   '라이브 에이드 씬의 마마~ 만 듣고도 오열 !!!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 22, 49),
#   0],
#  ['고선옥(nys0****)',
#   '두번 보고 왔습니다...내용이 조금 아쉬는부분은 있으나마지막 공연 장면을 다시 보고 싶어서2번 봤네요 또 보고 싶네요퀸이라는 가수를 몰랐는데 이 유명한 노래들이퀸의 노래라니 너무 놀랐습니다40년이 넘은 노래인데 전설...',
#   '9',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 22, 42),
#   0],
#  ['멋진한이(need****)',
#   '대박 더이상 무슨말이 필요할까',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 22, 21),
#   0],
#  ['옐로우자켓(cool****)',
#   '엔딩 스테이지에서 눈물이 절로 나고 가슴이 터질것 같았다. 두어번 더 볼까 싶다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 21, 58),
#   0],
#  ['kkqoqo(flyh****)',
#   '최고의 영화. 평론가는 뭐하는 ㅅㄲ들이지',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 21, 48),
#   0],
#  ['대박(kong****)',
#   '아무리 재미있어도 영화를 두번이상 보러가는 분들 이해가 안갔는데 딱 이 영화가 그랬다 평점도 높고 관객수도 뒤늦게 오르길레 호기심에 봤는데    전율에 눈물에 미치겠더라 스크린엑스나 싱어롱으로 다시한번 보고싶다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 21, 23),
#   0],
#  ['시현맘(redh****)',
#   '영화를 본 뒤에도 계속 생각나는 영화예요..정말 매력적인 프레디 머큐리예요..프레디를 연기한 라미 멜락의 연기는 정말 프레디 머큐리의 몸 동작과 똑같아요.. 집에와서 유튜브로 퀸 영상보고 더 감동했어요~~',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 21, 7),
#   0],
#  ['진달래엔딩(fl20****)',
#   '퀸이라는 그룹이나 노래에대한 정보가 전혀없이 보러갔는데 아는노래가 나올땐 반갑고 보느내내 제가 그시대에 태어나지 못한게 슬펐어요. 저는 라라랜드식의 영화를 전혀 안좋아하고 라라랜드 같은 영화라고 해서 안보려고 했는데...',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 21, 4),
#   '관람객'],
#  ['gci(zk34****)',
#   '이 영화는 영화가 아니다. 거대한 콘서트이다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 20, 12),
#   0],
#  ['들꽃향기(r383****)',
#   '이 영화를 개봉 마지막 까지 극장에서 못 보게 된다면 영화가 막을 내린 다음날 아침 눈 뜨자마자 영화 못 본 사람들은 후회하게 될것이다.진심 두번 봤는데 감동! 눈물 펑펑 쏟아집니다.~',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 1, 51),
#   0],
#  ['돌란(fist****)',
#   '내일 또 보러간다. 몇 번 더 보러갈지 나도 이제 모르겠다.',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 3, 1, 41),
#   0],
#  ['여명(brig****)',
#   '퀸의 노래를 안들어본사람은 있어도 한번들어본 사람은 없다',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 2, 14, 13),
#   0],
#  ['마이트리(beul****)',
#   '최고 처음으로 혼자가서 두번째다시 본 영화!',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 2, 13, 4),
#   '관람객'],
#  ['마족지팽(sk21****)',
#   '별100개가 안찍혀서 10개줌',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 2, 12, 45),
#   0],
#  ['늘해랑(cjcf****)',
#   '영화보고 와서 퀸 공부중입니다 같은 세대였다면 얼마나 좋았을까요?',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 2, 12, 28),
#   0],
#  ['고기반찬(swam****)',
#   '기대 없이 갔다가 미쳐버린 영화',
#   '10',
#   '13',
#   '2',
#   datetime.datetime(2018, 12, 2, 1, 56),
#   0],
#  ...]

# %%
# 결과를 dataFrame으로 변환
moviere = pd.DataFrame(segment)
moviere
# Out:
#                            0  ...    6
# 0               림키(kkl1****)  ...    0
# 1              조용일(whdy****)  ...    0
# 2      Bang JongHo(shom****)  ...    0
# 3              최와와(choi****)  ...    0
# 4              김석환(kims****)  ...    0
# ...                      ...  ...  ...
# 38775          미쓰백(hhs2****)  ...    0
# 38776         초경합금(toor****)  ...    0
# 38777               ds77****  ...  관람객
# 38778          김정숙(hhwa****)  ...    0
# 38779      only 1d(eune****)  ...    0
#
# [38780 rows x 7 columns]

# %%
## 컬럼 이름 변경
moviere.columns = ["nickname","text","score","like","dislike","time","watch_movie"]
moviere
# Out:
#                     nickname  ... watch_movie
# 0               림키(kkl1****)  ...           0
# 1              조용일(whdy****)  ...           0
# 2      Bang JongHo(shom****)  ...           0
# 3              최와와(choi****)  ...           0
# 4              김석환(kims****)  ...           0
# ...                      ...  ...         ...
# 38775          미쓰백(hhs2****)  ...           0
# 38776         초경합금(toor****)  ...           0
# 38777               ds77****  ...         관람객
# 38778          김정숙(hhwa****)  ...           0
# 38779      only 1d(eune****)  ...           0
#
# [38780 rows x 7 columns]

# %%
## CSV로 저장
moviere.to_csv('moviere.csv', header='true', encoding='utf-8')
